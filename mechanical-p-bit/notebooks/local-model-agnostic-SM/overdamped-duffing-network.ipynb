# %%
import jax
from jax import flatten_util, vmap 
import jax.numpy as jnp
import jax.random as jr
import diffrax
from diffrax import ControlTerm, MultiTerm, ODETerm
import matplotlib.pyplot as plt
from functools import partial
import optax
from helper_fns_general import sample_gaussian_mixture, normalize_samples, CD1_gradient, setup_score_matching_loss, grad_loss
jax.config.update("jax_enable_x64", True)

# %% [markdown]
# ### Generate samples from a Gaussian mixture

# %%
# Set random seed
key = jr.PRNGKey(0)

# Parameters
N = 2  # number of dimensions
N_mixgauss = 3  # number of mixture components
n_samples = 100000

# Define mixture weights (must sum to 1)
weights = jnp.array([0.5, 0.5])

# Define means
means = jnp.array([
    [2.0, 0.0],   # mean of first Gaussian
    [-0.0, -1.0],  # mean of second Gaussian
])

# Define covariance matrices
covs = 100*jnp.array([
    [[1, 0.0],    # covariance of first Gaussian
        [0.0, 1]],
    [[1, -0.0],   # covariance of second Gaussian
        [-0.0, 1]],
])

# Generate samples
samples = sample_gaussian_mixture(key, n_samples, weights, means, covs)
# Normalize samples
# samples = normalize_samples(samples_raw)
# Out:
# CUDA backend failed to initialize: Unable to use CUDA because of the following issues with CUDA components:
# Outdated cuDNN installation found.
# Version JAX was built against: 8907
# Minimum supported: 9100
# Installed version: 8907
# The local installation version must be no lower than 9100..(Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %% [markdown]
# ### Plot samples and marginal distributions

# %%
# Plot samples and marginal distributions
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# First subplot: Scatter plot of samples
ax1.scatter(samples[:, 0], samples[:, 1], alpha=0.5)
ax1.set_title('Samples')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')

# Second subplot: Combined marginal distributions
ax2.hist(samples[:, 0], bins=50, density=True, alpha=0.7, label='X distribution')
ax2.hist(samples[:, 1], bins=50, density=True, alpha=0.7, label='Y distribution')
ax2.set_title('Marginal Distributions')
ax2.set_xlabel('Value')
ax2.set_ylabel('Density')
ax2.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Define energy function of duffing oscillator network

# %%
def energy_self_oscillator(x, k_lin, k_duff):
    return 1 / 2 * k_lin * x**2 + 1 / 4 * k_duff * x**4

def energy_self_network(x, k_lin, k_duff):
    return jnp.sum(vmap(energy_self_oscillator)(x, k_lin, k_duff))


def energy_coupling_pair(x, y, c_lin, c_optomech):
    return c_lin * x * (x - y) + c_lin * y * (y - x) + c_optomech * (x**2) * y

def energy_coupling_network(x, c_lin, c_optomech, connectivity):
    # get contribution to total energy from each pair of oscillators
    
    def _coupling_energy_pair(x, c_lin, c_optomech, pair):
        # get energy of one pair of oscillators
        i, j = pair
        return energy_coupling_pair(x[i], x[j], c_lin, c_optomech)

    # get energy of all pairs of oscillators
    return jnp.sum(
        vmap(_coupling_energy_pair, in_axes=(None, 0, 0, 0))(
            x, c_lin, c_optomech, connectivity
        )
    )

def _energy_duffing_network(x, k_lin, k_duff, c_lin, c_optomech, connectivity, k_b=1.0, T=1.0):
    # returns energy of network of oscillators given input parameters
    return (
        energy_self_network(x, k_lin, k_duff) +
        energy_coupling_network(x, c_lin, c_optomech, connectivity)
    ) / (k_b * T)

# %% [markdown]
# ### Define initial parameters

# %%
N_osc = 2

k_lin_0 = jnp.array([-10., -10.])
k_duff_0 = jnp.array([10., 10.])
c_lin_0 = jnp.array([1.,])
c_optomech_0 = jnp.array([0.,])
connectivity = jnp.array([[0, 1]])

args_initial = (k_lin_0, k_duff_0, c_lin_0, c_optomech_0)

flattened_args_initial, unflatten = flatten_util.ravel_pytree(args_initial)

# %% [markdown]
# ### Bringe energy into correct form

# %%
def energy_duffing_network(x, flattened_args, connectivity):
    k_lin, k_duffing, c_lin, c_optomech = unflatten(flattened_args)
    return _energy_duffing_network(x, k_lin, k_duffing, c_lin, c_optomech, connectivity)
energy_fn = lambda x, flattened_args: energy_duffing_network(x, flattened_args, connectivity)

# %% [markdown]
# ### Plot energy landscape

# %%
# Create a grid of phase values
n_points = 30
x1 = jnp.linspace(-5, 5, n_points)*10
x2 = jnp.linspace(-5, 5, n_points)*10
X1, X2 = jnp.meshgrid(x1, x2)

# Compute energy for each point in the grid
energy = jnp.zeros((n_points, n_points))
for i in range(n_points):
    for j in range(n_points):
        x = jnp.array([X1[i,j], X2[i,j]])
        energy = energy.at[i,j].set(energy_fn(x, flattened_args_initial))

# Create the contour plot
plt.figure(figsize=(10, 8))
plt.contourf(X1, X2, energy, levels=20, cmap='viridis')
plt.colorbar(label='Energy')
# Add scatter plot of samples
plt.scatter(samples[:, 0], samples[:, 1], c='black', s=1, alpha=0.5, label='Samples')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('XY Model Energy Landscape for initial parameters')
plt.legend()
plt.show()

# %% [markdown]
# ### Test minus CD1 gradient vs score matching gradient (eq. 10 in Connections Between Score Matching, Contrastive Divergence, and Pseudolikelihood for Continuous-Valued Variables)

# %%
# Compare gradient differences with score_matching_loss for different dt values
dt_values = jnp.logspace(-18, 1, 30)  # logarithmically spaced dt values
key = jr.PRNGKey(1)

# Get score matching gradient results (only need to compute once)
score_matching_loss = setup_score_matching_loss(energy_fn, samples)
score_matching_grad = grad_loss(score_matching_loss, flattened_args_initial)

# Initialize arrays to store results
n_params = len(flattened_args_initial)
relative_differences = jnp.zeros((len(dt_values), n_params))
total_relative_differences = jnp.zeros(len(dt_values))  # New array for total differences

# Loop over dt values
for i, dt in enumerate(dt_values):
    key, subkey = jr.split(key)
    
    # Get CD1 gradient for this dt
    cd1_grad = -CD1_gradient(energy_fn, samples, flattened_args_initial, 
                            dt=dt, D=1, key=subkey, num_noise_samples=0)
    
    # Calculate relative difference for each parameter
    rel_diff = jnp.abs(cd1_grad - score_matching_grad) / jnp.abs(score_matching_grad)
    relative_differences = relative_differences.at[i].set(rel_diff)
    
    # Calculate total relative difference using L2 norm
    total_rel_diff = jnp.linalg.norm(cd1_grad - score_matching_grad) / jnp.linalg.norm(score_matching_grad)
    total_relative_differences = total_relative_differences.at[i].set(total_rel_diff)

# Create figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 6))

# First subplot: Individual parameter differences
param_names = ['k_lin_1', 'k_lin_2', 'k_duff_1', 'k_duff_2', 'c_lin', 'c_optomech']
for param_idx in range(n_params):
    ax1.loglog(dt_values, relative_differences[:, param_idx], 'o-', 
               label=param_names[param_idx])

ax1.set_xlabel('dt')
ax1.set_ylabel('Relative Difference')
ax1.set_title('Individual Parameter Relative Differences')
ax1.grid(True)
ax1.legend()

# Second subplot: Total gradient difference
ax2.loglog(dt_values, total_relative_differences, 'o-', color='black', label='Total gradient')
ax2.set_xlabel('dt')
ax2.set_ylabel('Total Relative Difference')
ax2.set_title('Total Gradient Relative Difference (L2 norm)')
ax2.grid(True)
ax2.legend()

plt.tight_layout()
plt.show()

# Print the minimum relative differences
print("\nIndividual parameter minimum differences:")
for param_idx in range(n_params):
    min_idx = jnp.argmin(relative_differences[:, param_idx])
    print(f"\n{param_names[param_idx]}:")
    print(f"Minimum relative difference: {relative_differences[min_idx, param_idx]:.2e}")
    print(f"Optimal dt: {dt_values[min_idx]:.2e}")

print("\nTotal gradient minimum difference:")
min_total_idx = jnp.argmin(total_relative_differences)
print(f"Minimum total relative difference: {total_relative_differences[min_total_idx]:.2e}")
print(f"Optimal dt: {dt_values[min_total_idx]:.2e}")
# Out:
# Individual parameter minimum differences:
#
# k_lin_1:
# Minimum relative difference: 1.27e-06
# Optimal dt: 1.49e-09
#
# k_lin_2:
# Minimum relative difference: 1.42e-06
# Optimal dt: 1.49e-09
#
# k_duff_1:
# Minimum relative difference: 7.67e-08
# Optimal dt: 3.29e-10
#
# k_duff_2:
# Minimum relative difference: 2.19e-07
# Optimal dt: 3.29e-10
#
# c_lin:
# Minimum relative difference: 1.35e-06
# Optimal dt: 1.49e-09
#
# c_optomech:
# Minimum relative difference: 3.75e-07
# Optimal dt: 8.53e-15
#
# Total gradient minimum difference:
# Minimum total relative difference: 1.62e-07
# Optimal dt: 3.29e-10

# %%
# Define optimization parameters
learning_rate = 0.01
n_epochs = 20000
batch_size = 128

# Initialize optimizer
optimizer = optax.adam(learning_rate=learning_rate)
opt_state = optimizer.init(flattened_args_initial)

@partial(jax.jit, static_argnums=(3,))
def training_step(params, opt_state, samples, n_samples, key):
    """Single training step using CD-1"""
    # Get gradient of parameters
    key, subkey = jr.split(key)
    dparams_CD1 = -CD1_gradient(energy_fn, samples, params, dt=2.59e-5, D=1, key=subkey, num_noise_samples=0)
    dparams_sm = grad_loss(score_matching_loss, params)
    
    # Compute relative difference between raw gradients
    rel_diff = jnp.linalg.norm(dparams_CD1 - dparams_sm) / jnp.linalg.norm(dparams_sm)
    
    # Compute relative difference between normalized gradients
    norm_dparams = dparams_CD1 / jnp.linalg.norm(dparams_CD1)
    norm_dparams_sm = dparams_sm / jnp.linalg.norm(dparams_sm)
    rel_diff_norm = jnp.linalg.norm(norm_dparams - norm_dparams_sm)
    
    # Compute log likelihood (negative energy)
    loss = score_matching_loss(params)
    
    # Apply updates
    updates, opt_state = optimizer.update(dparams_sm, opt_state)
    params = optax.apply_updates(params, updates)
    
    return params, opt_state, key, loss, rel_diff, rel_diff_norm

# Training loop
key = jr.PRNGKey(0)
params_history = []
loss_history = []
gradient_diff_history = []  # Raw gradient differences
gradient_diff_norm_history = []  # Normalized gradient differences

params = flattened_args_initial

for epoch in range(n_epochs):
    key, subkey = jr.split(key)
    params, opt_state, key, loss, rel_diff, rel_diff_norm = training_step(
        params, opt_state, samples, batch_size, subkey)
    
    # Store parameters, loss, and both gradient differences
    params_history.append(params)
    loss_history.append(loss)
    gradient_diff_history.append(rel_diff)
    gradient_diff_norm_history.append(rel_diff_norm)
    
    if epoch % 10 == 0:
        k_lin, k_duffing, c_lin, c_optomech = unflatten(params)
        print(f"Epoch {epoch}")
        print(f"k_lin:\n{k_lin}")
        print(f"k_duffing:\n{k_duffing}")
        print(f"c_lin:\n{c_lin}")
        print(f"c_optomech:\n{c_optomech}")
        print(f"Loss: {loss:.4f}")
        print(f"Raw gradient relative difference: {rel_diff:.4e}")
        print(f"Normalized gradient relative difference: {rel_diff_norm:.4e}")
        print("---")
# Out:
# Epoch 0
# k_lin:
# [-10.01 -10.01]
# k_duffing:
# [9.99 9.99]
# c_lin:
# [0.99]
# c_optomech:
# [0.01]
# Loss: 1573895892.9389
# Raw gradient relative difference: 1.2927e-01
# Normalized gradient relative difference: 2.5841e-03
# ---
# Epoch 10
# k_lin:
# [-10.10995655 -10.10995661]
# k_duffing:
# [9.89004318 9.89004314]
# c_lin:
# [0.89004403]
# c_optomech:
# [0.10988986]
# Loss: 1542306578.7528
# Raw gradient relative difference: 1.2808e-01
# Normalized gradient relative difference: 2.5601e-03
# ---
# Epoch 20
# k_lin:
# [-10.20972    -10.20972037]
# k_duffing:
# [9.79027829 9.79027802]
# c_lin:
# [0.79028378]
# c_optomech:
# [0.20928628]
# Loss: 1511093282.9621
# Raw gradient relative difference: 1.2688e-01
# Normalized gradient relative difference: 2.5361e-03
# ---
# Epoch 30
# k_lin:
# [-10.30915653 -10.30915764]
# k_duffing:
# [9.6908383  9.69083749]
# c_lin:
# [0.69085492]
# c_optomech:
# [0.30783835]
# Loss: 1480296617.0199
# Raw gradient relative difference: 1.2569e-01
# Normalized gradient relative difference: 2.5121e-03
# ---
# Epoch 40
# k_lin:
# [-10.40817639 -10.40817879]
# k_duffing:
# [9.5918124  9.59181063]
# c_lin:
# [0.59184843]
# c_optomech:
# [0.40530216]
# Loss: 1449942105.5746
# Raw gradient relative difference: 1.2450e-01
# Normalized gradient relative difference: 2.4882e-03
# ---
# Epoch 50
# k_lin:
# [-10.50672751 -10.50673181]
# k_duffing:
# [9.49325229 9.49324913]
# c_lin:
# [0.49331716]
# c_optomech:
# [0.50152754]
# Loss: 1420042442.0662
# Raw gradient relative difference: 1.2332e-01
# Normalized gradient relative difference: 2.4644e-03
# ---
# Epoch 60
# k_lin:
# [-10.60478268 -10.60478954]
# k_duffing:
# [9.39518501 9.39517996]
# c_lin:
# [0.39528873]
# c_optomech:
# [0.5964271]
# Loss: 1390601871.4161
# Raw gradient relative difference: 1.2214e-01
# Normalized gradient relative difference: 2.4407e-03
# ---
# Epoch 70
# k_lin:
# [-10.70232853 -10.7023386 ]
# k_duffing:
# [9.29762379 9.29761639]
# c_lin:
# [0.29777674]
# c_optomech:
# [0.68994886]
# Loss: 1361619950.2794
# Raw gradient relative difference: 1.2096e-01
# Normalized gradient relative difference: 2.4171e-03
# ---
# Epoch 80
# k_lin:
# [-10.79935857 -10.79937252]
# k_duffing:
# [9.20057506 9.20056481]
# c_lin:
# [0.20078782]
# c_optomech:
# [0.78205853]
# Loss: 1333093922.6234
# Raw gradient relative difference: 1.1979e-01
# Normalized gradient relative difference: 2.3935e-03
# ---
# Epoch 90
# k_lin:
# [-10.89586948 -10.89588798]
# k_duffing:
# [9.10404209 9.1040285 ]
# c_lin:
# [0.10432536]
# c_optomech:
# [0.87272996]
# Loss: 1305019983.9141
# Raw gradient relative difference: 1.1862e-01
# Normalized gradient relative difference: 2.3700e-03
# ---
# Epoch 100
# k_lin:
# [-10.99185932 -10.99188303]
# k_duffing:
# [9.00802676 9.00800936]
# c_lin:
# [0.00839139]
# c_optomech:
# [0.96194051]
# Loss: 1277393885.5371
# Raw gradient relative difference: 1.1746e-01
# Normalized gradient relative difference: 2.3467e-03
# ---
# Epoch 110
# k_lin:
# [-11.0873267  -11.08735628]
# k_duffing:
# [8.91253043 8.91250874]
# c_lin:
# [-0.08701267]
# c_optomech:
# [1.04966891]
# Loss: 1250211204.0206
# Raw gradient relative difference: 1.1630e-01
# Normalized gradient relative difference: 2.3234e-03
# ---
# Epoch 120
# k_lin:
# [-11.18227047 -11.18230657]
# k_duffing:
# [8.8175542  8.81752774]
# c_lin:
# [-0.18188559]
# c_optomech:
# [1.13589445]
# Loss: 1223467455.1586
# Raw gradient relative difference: 1.1514e-01
# Normalized gradient relative difference: 2.3002e-03
# ---
# Epoch 130
# k_lin:
# [-11.27668957 -11.27673284]
# k_duffing:
# [8.7230991 8.7230674]
# c_lin:
# [-0.27622626]
# c_optomech:
# [1.22059657]
# Loss: 1197158140.6118
# Raw gradient relative difference: 1.1399e-01
# Normalized gradient relative difference: 2.2772e-03
# ---
# Epoch 140
# k_lin:
# [-11.37058296 -11.37063404]
# k_duffing:
# [8.62916611 8.62912873]
# c_lin:
# [-0.3700336]
# c_optomech:
# [1.30375475]
# Loss: 1171278766.3435
# Raw gradient relative difference: 1.1285e-01
# Normalized gradient relative difference: 2.2542e-03
# ---
# Epoch 150
# k_lin:
# [-11.46394961 -11.46400914]
# k_duffing:
# [8.53575624 8.53571271]
# c_lin:
# [-0.46330652]
# c_optomech:
# [1.38534853]
# Loss: 1145824849.6859
# Raw gradient relative difference: 1.1171e-01
# Normalized gradient relative difference: 2.2313e-03
# ---
# Epoch 160
# k_lin:
# [-11.55678849 -11.55685709]
# k_duffing:
# [8.44287047 8.44282034]
# c_lin:
# [-0.55604395]
# c_optomech:
# [1.46535748]
# Loss: 1120791921.9443
# Raw gradient relative difference: 1.1057e-01
# Normalized gradient relative difference: 2.2086e-03
# ---
# Epoch 170
# k_lin:
# [-11.64909857 -11.64917687]
# k_duffing:
# [8.35050979 8.35045261]
# c_lin:
# [-0.64824481]
# c_optomech:
# [1.54376122]
# Loss: 1096175529.3047
# Raw gradient relative difference: 1.0944e-01
# Normalized gradient relative difference: 2.1859e-03
# ---
# Epoch 180
# k_lin:
# [-11.74087882 -11.74096743]
# k_duffing:
# [8.25867518 8.25861052]
# c_lin:
# [-0.73990802]
# c_optomech:
# [1.62053953]
# Loss: 1071971233.1211
# Raw gradient relative difference: 1.0831e-01
# Normalized gradient relative difference: 2.1633e-03
# ---
# Epoch 190
# k_lin:
# [-11.83212821 -11.83222772]
# k_duffing:
# [8.16736764 8.16729508]
# c_lin:
# [-0.83103249]
# c_optomech:
# [1.69567232]
# Loss: 1048174609.9939
# Raw gradient relative difference: 1.0719e-01
# Normalized gradient relative difference: 2.1409e-03
# ---
# Epoch 200
# k_lin:
# [-11.92284569 -11.9229567 ]
# k_duffing:
# [8.07658817 8.07650728]
# c_lin:
# [-0.92161716]
# c_optomech:
# [1.76913971]
# Loss: 1024781251.7910
# Raw gradient relative difference: 1.0607e-01
# Normalized gradient relative difference: 2.1185e-03
# ---
# Epoch 210
# k_lin:
# [-12.01303023 -12.01315333]
# k_duffing:
# [7.98633775 7.98624813]
# c_lin:
# [-1.01166094]
# c_optomech:
# [1.84092208]
# Loss: 1001786765.6651
# Raw gradient relative difference: 1.0496e-01
# Normalized gradient relative difference: 2.0963e-03
# ---
# Epoch 220
# k_lin:
# [-12.1026808  -12.10281656]
# k_duffing:
# [7.89661739 7.89651863]
# c_lin:
# [-1.10116274]
# c_optomech:
# [1.9110001]
# Loss: 979186774.0822
# Raw gradient relative difference: 1.0385e-01
# Normalized gradient relative difference: 2.0741e-03
# ---
# Epoch 230
# k_lin:
# [-12.19179634 -12.19194534]
# k_duffing:
# [7.80742808 7.80731978]
# c_lin:
# [-1.19012151]
# c_optomech:
# [1.9793548]
# Loss: 956976914.8680
# Raw gradient relative difference: 1.0275e-01
# Normalized gradient relative difference: 2.0521e-03
# ---
# Epoch 240
# k_lin:
# [-12.28037584 -12.28053862]
# k_duffing:
# [7.71877081 7.71865258]
# c_lin:
# [-1.27853615]
# c_optomech:
# [2.04596765]
# Loss: 935152841.2702
# Raw gradient relative difference: 1.0165e-01
# Normalized gradient relative difference: 2.0302e-03
# ---
# Epoch 250
# k_lin:
# [-12.36841825 -12.36859535]
# k_duffing:
# [7.63064656 7.63051804]
# c_lin:
# [-1.36640561]
# c_optomech:
# [2.11082056]
# Loss: 913710222.0354
# Raw gradient relative difference: 1.0056e-01
# Normalized gradient relative difference: 2.0084e-03
# ---
# Epoch 260
# k_lin:
# [-12.45592255 -12.4561145 ]
# k_duffing:
# [7.54305634 7.54291715]
# c_lin:
# [-1.45372881]
# c_optomech:
# [2.17389599]
# Loss: 892644741.5003
# Raw gradient relative difference: 9.9469e-02
# Normalized gradient relative difference: 1.9867e-03
# ---
# Epoch 270
# k_lin:
# [-12.54288769 -12.54309502]
# k_duffing:
# [7.45600112 7.45585092]
# c_lin:
# [-1.5405047]
# c_optomech:
# [2.23517699]
# Loss: 871952099.6946
# Raw gradient relative difference: 9.8386e-02
# Normalized gradient relative difference: 1.9651e-03
# ---
# Epoch 280
# k_lin:
# [-12.62931267 -12.62953587]
# k_duffing:
# [7.36948189 7.36932032]
# c_lin:
# [-1.62673222]
# c_optomech:
# [2.29464725]
# Loss: 851628012.4560
# Raw gradient relative difference: 9.7308e-02
# Normalized gradient relative difference: 1.9437e-03
# ---
# Epoch 290
# k_lin:
# [-12.71519645 -12.71543601]
# k_duffing:
# [7.28349962 7.28332635]
# c_lin:
# [-1.71241031]
# c_optomech:
# [2.35229119]
# Loss: 831668211.5548
# Raw gradient relative difference: 9.6236e-02
# Normalized gradient relative difference: 1.9223e-03
# ---
# Epoch 300
# k_lin:
# [-12.80053801 -12.80079442]
# k_duffing:
# [7.19805529 7.19787   ]
# c_lin:
# [-1.79753794]
# c_optomech:
# [2.40809404]
# Loss: 812068444.8292
# Raw gradient relative difference: 9.5168e-02
# Normalized gradient relative difference: 1.9011e-03
# ---
# Epoch 310
# k_lin:
# [-12.88533635 -12.88561007]
# k_duffing:
# [7.11314986 7.11295224]
# c_lin:
# [-1.88211407]
# c_optomech:
# [2.46204184]
# Loss: 792824476.3292
# Raw gradient relative difference: 9.4106e-02
# Normalized gradient relative difference: 1.8799e-03
# ---
# Epoch 320
# k_lin:
# [-12.96959046 -12.96988193]
# k_duffing:
# [7.02878429 7.02857404]
# c_lin:
# [-1.96613766]
# c_optomech:
# [2.51412159]
# Loss: 773932086.4694
# Raw gradient relative difference: 9.3049e-02
# Normalized gradient relative difference: 1.8589e-03
# ---
# Epoch 330
# k_lin:
# [-13.05329934 -13.05360899]
# k_duffing:
# [6.94495955 6.94473638]
# c_lin:
# [-2.0496077]
# c_optomech:
# [2.56432126]
# Loss: 755387072.1903
# Raw gradient relative difference: 9.1997e-02
# Normalized gradient relative difference: 1.8380e-03
# ---
# Epoch 340
# k_lin:
# [-13.136462   -13.13679025]
# k_duffing:
# [6.86167657 6.86144022]
# c_lin:
# [-2.13252317]
# c_optomech:
# [2.61262989]
# Loss: 737185247.1272
# Raw gradient relative difference: 9.0951e-02
# Normalized gradient relative difference: 1.8173e-03
# ---
# Epoch 350
# k_lin:
# [-13.21907745 -13.21942469]
# k_duffing:
# [6.77893629 6.7786865 ]
# c_lin:
# [-2.21488308]
# c_optomech:
# [2.65903762]
# Loss: 719322441.7867
# Raw gradient relative difference: 8.9910e-02
# Normalized gradient relative difference: 1.7966e-03
# ---
# Epoch 360
# k_lin:
# [-13.30114471 -13.30151133]
# k_duffing:
# [6.69673965 6.69647617]
# c_lin:
# [-2.29668642]
# c_optomech:
# [2.70353581]
# Loss: 701794503.7301
# Raw gradient relative difference: 8.8875e-02
# Normalized gradient relative difference: 1.7761e-03
# ---
# Epoch 370
# k_lin:
# [-13.38266281 -13.38304917]
# k_duffing:
# [6.61508757 6.61481018]
# c_lin:
# [-2.37793222]
# c_optomech:
# [2.74611707]
# Loss: 684597297.7635
# Raw gradient relative difference: 8.7845e-02
# Normalized gradient relative difference: 1.7557e-03
# ---
# Epoch 380
# k_lin:
# [-13.46363081 -13.46403725]
# k_duffing:
# [6.53398096 6.53368943]
# c_lin:
# [-2.45861952]
# c_optomech:
# [2.78677532]
# Loss: 667726706.1343
# Raw gradient relative difference: 8.6820e-02
# Normalized gradient relative difference: 1.7354e-03
# ---
# Epoch 390
# k_lin:
# [-13.54404774 -13.54447459]
# k_duffing:
# [6.45342072 6.45311487]
# c_lin:
# [-2.53874734]
# c_optomech:
# [2.82550589]
# Loss: 651178628.7336
# Raw gradient relative difference: 8.5801e-02
# Normalized gradient relative difference: 1.7152e-03
# ---
# Epoch 400
# k_lin:
# [-13.62391267 -13.62436024]
# k_duffing:
# [6.37340775 6.37308737]
# c_lin:
# [-2.61831475]
# c_optomech:
# [2.86230553]
# Loss: 634948983.3036
# Raw gradient relative difference: 8.4788e-02
# Normalized gradient relative difference: 1.6952e-03
# ---
# Epoch 410
# k_lin:
# [-13.70322468 -13.70369325]
# k_duffing:
# [6.29394292 6.29360786]
# c_lin:
# [-2.69732081]
# c_optomech:
# [2.89717249]
# Loss: 619033705.6507
# Raw gradient relative difference: 8.3780e-02
# Normalized gradient relative difference: 1.6752e-03
# ---
# Epoch 420
# k_lin:
# [-13.78198285 -13.78247269]
# k_duffing:
# [6.21502709 6.21467719]
# c_lin:
# [-2.77576461]
# c_optomech:
# [2.93010658]
# Loss: 603428749.8628
# Raw gradient relative difference: 8.2778e-02
# Normalized gradient relative difference: 1.6554e-03
# ---
# Epoch 430
# k_lin:
# [-13.86018628 -13.86069763]
# k_duffing:
# [6.13666113 6.13629625]
# c_lin:
# [-2.85364524]
# c_optomech:
# [2.96110922]
# Loss: 588130088.5306
# Raw gradient relative difference: 8.1781e-02
# Normalized gradient relative difference: 1.6357e-03
# ---
# Epoch 440
# k_lin:
# [-13.93783409 -13.93836717]
# k_duffing:
# [6.05884587 6.05846589]
# c_lin:
# [-2.93096182]
# c_optomech:
# [2.99018345]
# Loss: 573133712.9734
# Raw gradient relative difference: 8.0791e-02
# Normalized gradient relative difference: 1.6162e-03
# ---
# Epoch 450
# k_lin:
# [-14.01492539 -14.01548042]
# k_duffing:
# [5.98158214 5.98118696]
# c_lin:
# [-3.00771346]
# c_optomech:
# [3.017334]
# Loss: 558435633.4674
# Raw gradient relative difference: 7.9806e-02
# Normalized gradient relative difference: 1.5967e-03
# ---
# Epoch 460
# k_lin:
# [-14.09145934 -14.09203648]
# k_duffing:
# [5.90487074 5.90446027]
# c_lin:
# [-3.08389933]
# c_optomech:
# [3.04256732]
# Loss: 544031879.4774
# Raw gradient relative difference: 7.8827e-02
# Normalized gradient relative difference: 1.5774e-03
# ---
# Epoch 470
# k_lin:
# [-14.16743508 -14.16803451]
# k_duffing:
# [5.82871248 5.82828664]
# c_lin:
# [-3.15951858]
# c_optomech:
# [3.0658916]
# Loss: 529918499.8912
# Raw gradient relative difference: 7.7853e-02
# Normalized gradient relative difference: 1.5582e-03
# ---
# Epoch 480
# k_lin:
# [-14.2428518  -14.24347365]
# k_duffing:
# [5.75310812 5.75266687]
# c_lin:
# [-3.23457038]
# c_optomech:
# [3.08731678]
# Loss: 516091563.2552
# Raw gradient relative difference: 7.6886e-02
# Normalized gradient relative difference: 1.5391e-03
# ---
# Epoch 490
# k_lin:
# [-14.31770869 -14.31835307]
# k_duffing:
# [5.67805843 5.67760173]
# c_lin:
# [-3.30905394]
# c_optomech:
# [3.1068546]
# Loss: 502547158.0126
# Raw gradient relative difference: 7.5924e-02
# Normalized gradient relative difference: 1.5202e-03
# ---
# Epoch 500
# k_lin:
# [-14.39200495 -14.39267196]
# k_duffing:
# [5.60356414 5.60309198]
# c_lin:
# [-3.38296847]
# c_optomech:
# [3.12451857]
# Loss: 489281392.7428
# Raw gradient relative difference: 7.4968e-02
# Normalized gradient relative difference: 1.5014e-03
# ---
# Epoch 510
# k_lin:
# [-14.46573981 -14.46642951]
# k_duffing:
# [5.52962599 5.52913836]
# c_lin:
# [-3.45631322]
# c_optomech:
# [3.14032397]
# Loss: 476290396.4011
# Raw gradient relative difference: 7.4019e-02
# Normalized gradient relative difference: 1.4827e-03
# ---
# Epoch 520
# k_lin:
# [-14.53891253 -14.53962497]
# k_duffing:
# [5.45624468 5.45574159]
# c_lin:
# [-3.52908743]
# c_optomech:
# [3.15428789]
# Loss: 463570318.5599
# Raw gradient relative difference: 7.3075e-02
# Normalized gradient relative difference: 1.4641e-03
# ---
# Epoch 530
# k_lin:
# [-14.61152236 -14.61225756]
# k_duffing:
# [5.38342088 5.38290238]
# c_lin:
# [-3.60129038]
# c_optomech:
# [3.16642915]
# Loss: 451117329.6496
# Raw gradient relative difference: 7.2137e-02
# Normalized gradient relative difference: 1.4457e-03
# ---
# Epoch 540
# k_lin:
# [-14.6835686  -14.68432656]
# k_duffing:
# [5.31115525 5.31062139]
# c_lin:
# [-3.67292139]
# c_optomech:
# [3.17676832]
# Loss: 438927621.2002
# Raw gradient relative difference: 7.1206e-02
# Normalized gradient relative difference: 1.4274e-03
# ---
# Epoch 550
# k_lin:
# [-14.75505055 -14.75583125]
# k_duffing:
# [5.23944845 5.23889929]
# c_lin:
# [-3.74397976]
# c_optomech:
# [3.18532769]
# Loss: 426997406.0821
# Raw gradient relative difference: 7.0280e-02
# Normalized gradient relative difference: 1.4092e-03
# ---
# Epoch 560
# k_lin:
# [-14.82596756 -14.82677094]
# k_duffing:
# [5.16830107 5.16773671]
# c_lin:
# [-3.81446485]
# c_optomech:
# [3.19213122]
# Loss: 415322918.7470
# Raw gradient relative difference: 6.9361e-02
# Normalized gradient relative difference: 1.3911e-03
# ---
# Epoch 570
# k_lin:
# [-14.89631897 -14.89714496]
# k_duffing:
# [5.09771372 5.09713427]
# c_lin:
# [-3.88437602]
# c_optomech:
# [3.19720449]
# Loss: 403900415.4680
# Raw gradient relative difference: 6.8448e-02
# Normalized gradient relative difference: 1.3732e-03
# ---
# Epoch 580
# k_lin:
# [-14.96610416 -14.96695267]
# k_duffing:
# [5.02768696 5.02709254]
# c_lin:
# [-3.95371267]
# c_optomech:
# [3.20057469]
# Loss: 392726174.5797
# Raw gradient relative difference: 6.7541e-02
# Normalized gradient relative difference: 1.3553e-03
# ---
# Epoch 590
# k_lin:
# [-15.03532256 -15.03619346]
# k_duffing:
# [4.95822134 4.95761208]
# c_lin:
# [-4.02247421]
# c_optomech:
# [3.20227051]
# Loss: 381796496.7165
# Raw gradient relative difference: 6.6640e-02
# Normalized gradient relative difference: 1.3377e-03
# ---
# Epoch 600
# k_lin:
# [-15.10397357 -15.10486673]
# k_duffing:
# [4.88931737 4.88869344]
# c_lin:
# [-4.0906601]
# c_optomech:
# [3.20232211]
# Loss: 371107705.0514
# Raw gradient relative difference: 6.5745e-02
# Normalized gradient relative difference: 1.3201e-03
# ---
# Epoch 610
# k_lin:
# [-15.17205667 -15.17297191]
# k_duffing:
# [4.82097553 4.82033712]
# c_lin:
# [-4.1582698]
# c_optomech:
# [3.20076104]
# Loss: 360656145.5324
# Raw gradient relative difference: 6.4857e-02
# Normalized gradient relative difference: 1.3027e-03
# ---
# Epoch 620
# k_lin:
# [-15.23957134 -15.24050847]
# k_duffing:
# [4.75319629 4.75254358]
# c_lin:
# [-4.22530282]
# c_optomech:
# [3.19762017]
# Loss: 350438187.1202
# Raw gradient relative difference: 6.3975e-02
# Normalized gradient relative difference: 1.2854e-03
# ---
# Epoch 630
# k_lin:
# [-15.30651708 -15.3074759 ]
# k_duffing:
# [4.68598009 4.6853133 ]
# c_lin:
# [-4.29175867]
# c_optomech:
# [3.19293364]
# Loss: 340450222.0229
# Raw gradient relative difference: 6.3100e-02
# Normalized gradient relative difference: 1.2682e-03
# ---
# Epoch 640
# k_lin:
# [-15.37289346 -15.37387372]
# k_duffing:
# [4.61932732 4.61864668]
# c_lin:
# [-4.35763692]
# c_optomech:
# [3.18673671]
# Loss: 330688665.9317
# Raw gradient relative difference: 6.2230e-02
# Normalized gradient relative difference: 1.2511e-03
# ---
# Epoch 650
# k_lin:
# [-15.43870003 -15.43970148]
# k_duffing:
# [4.55323836 4.55254411]
# c_lin:
# [-4.42293716]
# c_optomech:
# [3.17906575]
# Loss: 321149958.2549
# Raw gradient relative difference: 6.1368e-02
# Normalized gradient relative difference: 1.2342e-03
# ---
# Epoch 660
# k_lin:
# [-15.5039364  -15.50495876]
# k_duffing:
# [4.48771355 4.48700595]
# c_lin:
# [-4.48765899]
# c_optomech:
# [3.1699581]
# Loss: 311830562.3520
# Raw gradient relative difference: 6.0511e-02
# Normalized gradient relative difference: 1.2174e-03
# ---
# Epoch 670
# k_lin:
# [-15.56860222 -15.56964518]
# k_duffing:
# [4.4227532  4.42203252]
# c_lin:
# [-4.55180206]
# c_optomech:
# [3.15945198]
# Loss: 302726965.7669
# Raw gradient relative difference: 5.9661e-02
# Normalized gradient relative difference: 1.2007e-03
# ---
# Epoch 680
# k_lin:
# [-15.63269714 -15.63376038]
# k_duffing:
# [4.35835757 4.35762412]
# c_lin:
# [-4.61536606]
# c_optomech:
# [3.14758646]
# Loss: 293835680.4614
# Raw gradient relative difference: 5.8818e-02
# Normalized gradient relative difference: 1.1842e-03
# ---
# Epoch 690
# k_lin:
# [-15.69622088 -15.69730404]
# k_duffing:
# [4.29452692 4.29378101]
# c_lin:
# [-4.67835069]
# c_optomech:
# [3.13440128]
# Loss: 285153243.0472
# Raw gradient relative difference: 5.7981e-02
# Normalized gradient relative difference: 1.1678e-03
# ---
# Epoch 700
# k_lin:
# [-15.75917316 -15.76027589]
# k_duffing:
# [4.23126145 4.2305034 ]
# c_lin:
# [-4.7407557]
# c_optomech:
# [3.11993681]
# Loss: 276676215.0194
# Raw gradient relative difference: 5.7151e-02
# Normalized gradient relative difference: 1.1515e-03
# ---
# Epoch 710
# k_lin:
# [-15.82155376 -15.82267566]
# k_duffing:
# [4.16856133 4.16779148]
# c_lin:
# [-4.80258087]
# c_optomech:
# [3.10423394]
# Loss: 268401182.9886
# Raw gradient relative difference: 5.6327e-02
# Normalized gradient relative difference: 1.1354e-03
# ---
# Epoch 720
# k_lin:
# [-15.8833625  -15.88450316]
# k_duffing:
# [4.10642669 4.10564539]
# c_lin:
# [-4.86382601]
# c_optomech:
# [3.087334]
# Loss: 260324758.9142
# Raw gradient relative difference: 5.5509e-02
# Normalized gradient relative difference: 1.1193e-03
# ---
# Epoch 730
# k_lin:
# [-15.9445992 -15.9457582]
# k_duffing:
# [4.04485764 4.04406526]
# c_lin:
# [-4.92449098]
# c_optomech:
# [3.06927864]
# Loss: 252443580.3367
# Raw gradient relative difference: 5.4699e-02
# Normalized gradient relative difference: 1.1034e-03
# ---
# Epoch 740
# k_lin:
# [-16.00526377 -16.00644066]
# k_duffing:
# [3.98385422 3.98305114]
# c_lin:
# [-4.98457566]
# c_optomech:
# [3.05010978]
# Loss: 244754310.6110
# Raw gradient relative difference: 5.3895e-02
# Normalized gradient relative difference: 1.0877e-03
# ---
# Epoch 750
# k_lin:
# [-16.06535612 -16.06655043]
# k_duffing:
# [3.92341646 3.92260308]
# c_lin:
# [-5.04407997]
# c_optomech:
# [3.02986946]
# Loss: 237253639.1401
# Raw gradient relative difference: 5.3097e-02
# Normalized gradient relative difference: 1.0720e-03
# ---
# Epoch 760
# k_lin:
# [-16.12487621 -16.12608746]
# k_duffing:
# [3.86354433 3.86272106]
# c_lin:
# [-5.10300388]
# c_optomech:
# [3.00859983]
# Loss: 229938281.6082
# Raw gradient relative difference: 5.2307e-02
# Normalized gradient relative difference: 1.0565e-03
# ---
# Epoch 770
# k_lin:
# [-16.18382405 -16.18505174]
# k_duffing:
# [3.80423777 3.80340502]
# c_lin:
# [-5.16134739]
# c_optomech:
# [2.98634303]
# Loss: 222804980.2145
# Raw gradient relative difference: 5.1523e-02
# Normalized gradient relative difference: 1.0412e-03
# ---
# Epoch 780
# k_lin:
# [-16.24219969 -16.2434433 ]
# k_duffing:
# [3.74549668 3.74465489]
# c_lin:
# [-5.21911054]
# c_optomech:
# [2.96314107]
# Loss: 215850503.9077
# Raw gradient relative difference: 5.0746e-02
# Normalized gradient relative difference: 1.0259e-03
# ---
# Epoch 790
# k_lin:
# [-16.30000321 -16.3012622 ]
# k_duffing:
# [3.68732091 3.68647052]
# c_lin:
# [-5.27629342]
# c_optomech:
# [2.93903584]
# Loss: 209071648.6201
# Raw gradient relative difference: 4.9975e-02
# Normalized gradient relative difference: 1.0108e-03
# ---
# Epoch 800
# k_lin:
# [-16.35723475 -16.35850856]
# k_duffing:
# [3.62971026 3.62885172]
# c_lin:
# [-5.33289614]
# c_optomech:
# [2.91406896]
# Loss: 202465237.5014
# Raw gradient relative difference: 4.9211e-02
# Normalized gradient relative difference: 9.9580e-04
# ---
# Epoch 810
# k_lin:
# [-16.41389447 -16.41518255]
# k_duffing:
# [3.57266451 3.57179828]
# c_lin:
# [-5.38891889]
# c_optomech:
# [2.88828176]
# Loss: 196028121.1535
# Raw gradient relative difference: 4.8454e-02
# Normalized gradient relative difference: 9.8094e-04
# ---
# Epoch 820
# k_lin:
# [-16.46998261 -16.47128437]
# k_duffing:
# [3.51618335 3.51530992]
# c_lin:
# [-5.44436188]
# c_optomech:
# [2.86171521]
# Loss: 189757177.8642
# Raw gradient relative difference: 4.7704e-02
# Normalized gradient relative difference: 9.6621e-04
# ---
# Epoch 830
# k_lin:
# [-16.52549943 -16.52681427]
# k_duffing:
# [3.46026648 3.45938632]
# c_lin:
# [-5.49922535]
# c_optomech:
# [2.83440981]
# Loss: 183649313.8409
# Raw gradient relative difference: 4.6960e-02
# Normalized gradient relative difference: 9.5161e-04
# ---
# Epoch 840
# k_lin:
# [-16.58044524 -16.58177256]
# k_duffing:
# [3.40491351 3.40402712]
# c_lin:
# [-5.55350961]
# c_optomech:
# [2.8064056]
# Loss: 177701463.4434
# Raw gradient relative difference: 4.6224e-02
# Normalized gradient relative difference: 9.3714e-04
# ---
# Epoch 850
# k_lin:
# [-16.6348204  -16.63615958]
# k_duffing:
# [3.35012402 3.34923189]
# c_lin:
# [-5.60721501]
# c_optomech:
# [2.77774208]
# Loss: 171910589.4166
# Raw gradient relative difference: 4.5494e-02
# Normalized gradient relative difference: 9.2281e-04
# ---
# Epoch 860
# k_lin:
# [-16.68862534 -16.68997573]
# k_duffing:
# [3.29589752 3.29500017]
# c_lin:
# [-5.66034194]
# c_optomech:
# [2.74845815]
# Loss: 166273683.1213
# Raw gradient relative difference: 4.4771e-02
# Normalized gradient relative difference: 9.0860e-04
# ---
# Epoch 870
# k_lin:
# [-16.7418605  -16.74322146]
# k_duffing:
# [3.24223351 3.24133145]
# c_lin:
# [-5.71289086]
# c_optomech:
# [2.7185921]
# Loss: 160787764.7640
# Raw gradient relative difference: 4.4055e-02
# Normalized gradient relative difference: 8.9453e-04
# ---
# Epoch 880
# k_lin:
# [-16.79452641 -16.79589728]
# k_duffing:
# [3.18913141 3.18822515]
# c_lin:
# [-5.76486224]
# c_optomech:
# [2.68818152]
# Loss: 155449883.6252
# Raw gradient relative difference: 4.3346e-02
# Normalized gradient relative difference: 8.8058e-04
# ---
# Epoch 890
# k_lin:
# [-16.84662361 -16.84800373]
# k_duffing:
# [3.13659059 3.13568067]
# c_lin:
# [-5.81625663]
# c_optomech:
# [2.65726332]
# Loss: 150257118.2855
# Raw gradient relative difference: 4.2643e-02
# Normalized gradient relative difference: 8.6677e-04
# ---
# Epoch 900
# k_lin:
# [-16.89815274 -16.89954142]
# k_duffing:
# [3.08461037 3.08369732]
# c_lin:
# [-5.86707463]
# c_optomech:
# [2.62587366]
# Loss: 145206576.8496
# Raw gradient relative difference: 4.1948e-02
# Normalized gradient relative difference: 8.5309e-04
# ---
# Epoch 910
# k_lin:
# [-16.94911445 -16.95051101]
# k_duffing:
# [3.03319002 3.03227438]
# c_lin:
# [-5.91731687]
# c_optomech:
# [2.59404795]
# Loss: 140295397.1672
# Raw gradient relative difference: 4.1259e-02
# Normalized gradient relative difference: 8.3954e-04
# ---
# Epoch 920
# k_lin:
# [-16.99950947 -17.00091321]
# k_duffing:
# [2.98232876 2.98141107]
# c_lin:
# [-5.96698406]
# c_optomech:
# [2.56182078]
# Loss: 135520747.0517
# Raw gradient relative difference: 4.0578e-02
# Normalized gradient relative difference: 8.2612e-04
# ---
# Epoch 930
# k_lin:
# [-17.04933857 -17.05074879]
# k_duffing:
# [2.93202575 2.93110656]
# c_lin:
# [-6.01607694]
# c_optomech:
# [2.52922597]
# Loss: 130879824.4948
# Raw gradient relative difference: 3.9903e-02
# Normalized gradient relative difference: 8.1284e-04
# ---
# Epoch 940
# k_lin:
# [-17.09860258 -17.10001857]
# k_duffing:
# [2.8822801  2.88135996]
# c_lin:
# [-6.06459632]
# c_optomech:
# [2.49629649]
# Loss: 126369857.8774
# Raw gradient relative difference: 3.9235e-02
# Normalized gradient relative difference: 7.9969e-04
# ---
# Epoch 950
# k_lin:
# [-17.14730239 -17.14872344]
# k_duffing:
# [2.83309085 2.83217031]
# c_lin:
# [-6.11254305]
# c_optomech:
# [2.46306447]
# Loss: 121988106.1769
# Raw gradient relative difference: 3.8574e-02
# Normalized gradient relative difference: 7.8666e-04
# ---
# Epoch 960
# k_lin:
# [-17.19543895 -17.19686432]
# k_duffing:
# [2.784457   2.78353662]
# c_lin:
# [-6.15991804]
# c_optomech:
# [2.4295612]
# Loss: 117731859.1687
# Raw gradient relative difference: 3.7920e-02
# Normalized gradient relative difference: 7.7377e-04
# ---
# Epoch 970
# k_lin:
# [-17.24301325 -17.24444222]
# k_duffing:
# [2.73637748 2.73545783]
# c_lin:
# [-6.20672227]
# c_optomech:
# [2.3958171]
# Loss: 113598437.6246
# Raw gradient relative difference: 3.7273e-02
# Normalized gradient relative difference: 7.6102e-04
# ---
# Epoch 980
# k_lin:
# [-17.29002635 -17.29145818]
# k_duffing:
# [2.68885118 2.6879328 ]
# c_lin:
# [-6.25295675]
# c_optomech:
# [2.36186174]
# Loss: 109585193.5037
# Raw gradient relative difference: 3.6633e-02
# Normalized gradient relative difference: 7.4839e-04
# ---
# Epoch 990
# k_lin:
# [-17.33647938 -17.33791333]
# k_duffing:
# [2.64187692 2.64096038]
# c_lin:
# [-6.29862258]
# c_optomech:
# [2.3277238]
# Loss: 105689510.1391
# Raw gradient relative difference: 3.6000e-02
# Normalized gradient relative difference: 7.3590e-04
# ---
# Epoch 1000
# k_lin:
# [-17.3823735  -17.38380883]
# k_duffing:
# [2.59545345 2.5945393 ]
# c_lin:
# [-6.34372089]
# c_optomech:
# [2.2934311]
# Loss: 101908802.4178
# Raw gradient relative difference: 3.5374e-02
# Normalized gradient relative difference: 7.2354e-04
# ---
# Epoch 1010
# k_lin:
# [-17.42770995 -17.42914592]
# k_duffing:
# [2.54957947 2.54866829]
# c_lin:
# [-6.38825287]
# c_optomech:
# [2.25901061]
# Loss: 98240516.9537
# Raw gradient relative difference: 3.4755e-02
# Normalized gradient relative difference: 7.1131e-04
# ---
# Epoch 1020
# k_lin:
# [-17.47249003 -17.47392589]
# k_duffing:
# [2.50425364 2.50334598]
# c_lin:
# [-6.4322198]
# c_optomech:
# [2.22448841]
# Loss: 94682132.2543
# Raw gradient relative difference: 3.4142e-02
# Normalized gradient relative difference: 6.9921e-04
# ---
# Epoch 1030
# k_lin:
# [-17.51671509 -17.51815009]
# k_duffing:
# [2.45947452 2.45857094]
# c_lin:
# [-6.47562298]
# c_optomech:
# [2.18988973]
# Loss: 91231158.8795
# Raw gradient relative difference: 3.3537e-02
# Normalized gradient relative difference: 6.8724e-04
# ---
# Epoch 1040
# k_lin:
# [-17.56038656 -17.56181994]
# k_duffing:
# [2.41524065 2.41434171]
# c_lin:
# [-6.51846379]
# c_optomech:
# [2.15523894]
# Loss: 87885139.5925
# Raw gradient relative difference: 3.2938e-02
# Normalized gradient relative difference: 6.7541e-04
# ---
# Epoch 1050
# k_lin:
# [-17.60350591 -17.60493693]
# k_duffing:
# [2.37155047 2.37065672]
# c_lin:
# [-6.56074367]
# c_optomech:
# [2.12055957]
# Loss: 84641649.5032
# Raw gradient relative difference: 3.2347e-02
# Normalized gradient relative difference: 6.6371e-04
# ---
# Epoch 1060
# k_lin:
# [-17.64607468 -17.64750258]
# k_duffing:
# [2.32840239 2.32751439]
# c_lin:
# [-6.60246413]
# c_optomech:
# [2.08587431]
# Loss: 81498296.2023
# Raw gradient relative difference: 3.1762e-02
# Normalized gradient relative difference: 6.5214e-04
# ---
# Epoch 1070
# k_lin:
# [-17.68809448 -17.68951851]
# k_duffing:
# [2.28579474 2.28491304]
# c_lin:
# [-6.64362673]
# c_optomech:
# [2.05120503]
# Loss: 78452719.8873
# Raw gradient relative difference: 3.1185e-02
# Normalized gradient relative difference: 6.4070e-04
# ---
# Epoch 1080
# k_lin:
# [-17.72956697 -17.73098639]
# k_duffing:
# [2.24372579 2.24285095]
# c_lin:
# [-6.68423308]
# c_optomech:
# [2.01657277]
# Loss: 75502593.4782
# Raw gradient relative difference: 3.0614e-02
# Normalized gradient relative difference: 6.2940e-04
# ---
# Epoch 1090
# k_lin:
# [-17.7704939  -17.77190794]
# k_duffing:
# [2.20219376 2.20132631]
# c_lin:
# [-6.72428489]
# c_optomech:
# [1.98199777]
# Loss: 72645622.7250
# Raw gradient relative difference: 3.0050e-02
# Normalized gradient relative difference: 6.1822e-04
# ---
# Epoch 1100
# k_lin:
# [-17.81087704 -17.81228496]
# k_duffing:
# [2.16119679 2.16033727]
# c_lin:
# [-6.76378388]
# c_optomech:
# [1.94749949]
# Loss: 69879546.3040
# Raw gradient relative difference: 2.9493e-02
# Normalized gradient relative difference: 6.0718e-04
# ---
# Epoch 1110
# k_lin:
# [-17.85071825 -17.85211931]
# k_duffing:
# [2.12073296 2.11988192]
# c_lin:
# [-6.80273189]
# c_optomech:
# [1.9130966]
# Loss: 67202135.9048
# Raw gradient relative difference: 2.8943e-02
# Normalized gradient relative difference: 5.9627e-04
# ---
# Epoch 1120
# k_lin:
# [-17.89001946 -17.89141291]
# k_duffing:
# [2.08080029 2.07995826]
# c_lin:
# [-6.84113078]
# c_optomech:
# [1.87880701]
# Loss: 64611196.3064
# Raw gradient relative difference: 2.8399e-02
# Normalized gradient relative difference: 5.8549e-04
# ---
# Epoch 1130
# k_lin:
# [-17.92878266 -17.93016775]
# k_duffing:
# [2.04139675 2.04056424]
# c_lin:
# [-6.87898249]
# c_optomech:
# [1.84464788]
# Loss: 62104565.4427
# Raw gradient relative difference: 2.7863e-02
# Normalized gradient relative difference: 5.7484e-04
# ---
# Epoch 1140
# k_lin:
# [-17.96700988 -17.96838589]
# k_duffing:
# [2.00252022 2.00169777]
# c_lin:
# [-6.91628904]
# c_optomech:
# [1.81063564]
# Loss: 59680114.4569
# Raw gradient relative difference: 2.7333e-02
# Normalized gradient relative difference: 5.6432e-04
# ---
# Epoch 1150
# k_lin:
# [-18.00470325 -18.00606944]
# k_duffing:
# [1.96416854 1.96335665]
# c_lin:
# [-6.95305248]
# c_optomech:
# [1.776786]
# Loss: 57335747.7443
# Raw gradient relative difference: 2.6811e-02
# Normalized gradient relative difference: 5.5393e-04
# ---
# Epoch 1160
# k_lin:
# [-18.04186495 -18.04322059]
# k_duffing:
# [1.92633947 1.92553866]
# c_lin:
# [-6.98927495]
# c_optomech:
# [1.74311395]
# Loss: 55069402.9845
# Raw gradient relative difference: 2.6295e-02
# Normalized gradient relative difference: 5.4367e-04
# ---
# Epoch 1170
# k_lin:
# [-18.0784972  -18.07984157]
# k_duffing:
# [1.88903071 1.88824148]
# c_lin:
# [-7.02495863]
# c_optomech:
# [1.70963383]
# Loss: 52879051.1609
# Raw gradient relative difference: 2.5785e-02
# Normalized gradient relative difference: 5.3355e-04
# ---
# Epoch 1180
# k_lin:
# [-18.11460232 -18.11593471]
# k_duffing:
# [1.8522399  1.85146275]
# c_lin:
# [-7.06010581]
# c_optomech:
# [1.67635926]
# Loss: 50762696.5689
# Raw gradient relative difference: 2.5283e-02
# Normalized gradient relative difference: 5.2355e-04
# ---
# Epoch 1190
# k_lin:
# [-18.15018269 -18.15150237]
# k_duffing:
# [1.81596463 1.81520003]
# c_lin:
# [-7.09471878]
# c_optomech:
# [1.64330325]
# Loss: 48718376.8116
# Raw gradient relative difference: 2.4787e-02
# Normalized gradient relative difference: 5.1368e-04
# ---
# Epoch 1200
# k_lin:
# [-18.18524072 -18.186547  ]
# k_duffing:
# [1.7802024  1.77945085]
# c_lin:
# [-7.12879995]
# c_optomech:
# [1.61047813]
# Loss: 46744162.7837
# Raw gradient relative difference: 2.4298e-02
# Normalized gradient relative difference: 5.0394e-04
# ---
# Epoch 1210
# k_lin:
# [-18.21977893 -18.2210711 ]
# k_duffing:
# [1.74495066 1.74421262]
# c_lin:
# [-7.16235177]
# c_optomech:
# [1.57789564]
# Loss: 44838158.6431
# Raw gradient relative difference: 2.3816e-02
# Normalized gradient relative difference: 4.9433e-04
# ---
# Epoch 1220
# k_lin:
# [-18.25379986 -18.25507724]
# k_duffing:
# [1.7102068  1.70948274]
# c_lin:
# [-7.19537674]
# c_optomech:
# [1.54556689]
# Loss: 42998501.7689
# Raw gradient relative difference: 2.3340e-02
# Normalized gradient relative difference: 4.8484e-04
# ---
# Epoch 1230
# k_lin:
# [-18.28730615 -18.28856804]
# k_duffing:
# [1.67596814 1.67525852]
# c_lin:
# [-7.22787746]
# c_optomech:
# [1.51350239]
# Loss: 41223362.7087
# Raw gradient relative difference: 2.2872e-02
# Normalized gradient relative difference: 4.7549e-04
# ---
# Epoch 1240
# k_lin:
# [-18.32030048 -18.32154622]
# k_duffing:
# [1.64223195 1.64153722]
# c_lin:
# [-7.25985655]
# c_optomech:
# [1.48171211]
# Loss: 39510945.1116
# Raw gradient relative difference: 2.2409e-02
# Normalized gradient relative difference: 4.6626e-04
# ---
# Epoch 1250
# k_lin:
# [-18.35278561 -18.35401451]
# k_duffing:
# [1.60899543 1.60831602]
# c_lin:
# [-7.29131672]
# c_optomech:
# [1.45020542]
# Loss: 37859485.6492
# Raw gradient relative difference: 2.1953e-02
# Normalized gradient relative difference: 4.5716e-04
# ---
# Epoch 1260
# k_lin:
# [-18.38476434 -18.38597575]
# k_duffing:
# [1.57625572 1.57559206]
# c_lin:
# [-7.32226074]
# c_optomech:
# [1.41899117]
# Loss: 36267253.9238
# Raw gradient relative difference: 2.1504e-02
# Normalized gradient relative difference: 4.4818e-04
# ---
# Epoch 1270
# k_lin:
# [-18.41623954 -18.41743281]
# k_duffing:
# [1.54400989 1.54336241]
# c_lin:
# [-7.35269144]
# c_optomech:
# [1.38807766]
# Loss: 34732552.3639
# Raw gradient relative difference: 2.1062e-02
# Normalized gradient relative difference: 4.3933e-04
# ---
# Epoch 1280
# k_lin:
# [-18.44721415 -18.44838864]
# k_duffing:
# [1.51225497 1.51162407]
# c_lin:
# [-7.38261171]
# c_optomech:
# [1.35747269]
# Loss: 33253716.1068
# Raw gradient relative difference: 2.0626e-02
# Normalized gradient relative difference: 4.3061e-04
# ---
# Epoch 1290
# k_lin:
# [-18.47769117 -18.47884624]
# k_duffing:
# [1.48098792 1.480374  ]
# c_lin:
# [-7.41202449]
# c_optomech:
# [1.32718354]
# Loss: 31829112.8683
# Raw gradient relative difference: 2.0196e-02
# Normalized gradient relative difference: 4.2201e-04
# ---
# Epoch 1300
# k_lin:
# [-18.50767365 -18.50880867]
# k_duffing:
# [1.45020563 1.44960908]
# c_lin:
# [-7.44093281]
# c_optomech:
# [1.29721703]
# Loss: 30457142.8004
# Raw gradient relative difference: 1.9773e-02
# Normalized gradient relative difference: 4.1354e-04
# ---
# Epoch 1310
# k_lin:
# [-18.53716471 -18.53827906]
# k_duffing:
# [1.41990495 1.41932616]
# c_lin:
# [-7.46933972]
# c_optomech:
# [1.26757948]
# Loss: 29136238.3354
# Raw gradient relative difference: 1.9356e-02
# Normalized gradient relative difference: 4.0519e-04
# ---
# Epoch 1320
# k_lin:
# [-18.56616751 -18.5672606 ]
# k_duffing:
# [1.39008265 1.38952199]
# c_lin:
# [-7.49724837]
# c_optomech:
# [1.23827678]
# Loss: 27864864.0183
# Raw gradient relative difference: 1.8946e-02
# Normalized gradient relative difference: 3.9697e-04
# ---
# Epoch 1330
# k_lin:
# [-18.59468529 -18.59575652]
# k_duffing:
# [1.36073548 1.36019329]
# c_lin:
# [-7.52466193]
# c_optomech:
# [1.20931435]
# Loss: 26641516.3262
# Raw gradient relative difference: 1.8542e-02
# Normalized gradient relative difference: 3.8886e-04
# ---
# Epoch 1340
# k_lin:
# [-18.62272134 -18.62377012]
# k_duffing:
# [1.3318601  1.33133674]
# c_lin:
# [-7.55158366]
# c_optomech:
# [1.1806972]
# Loss: 25464723.4758
# Raw gradient relative difference: 1.8144e-02
# Normalized gradient relative difference: 3.8088e-04
# ---
# Epoch 1350
# k_lin:
# [-18.650279   -18.65130476]
# k_duffing:
# [1.30345312 1.30294893]
# c_lin:
# [-7.57801686]
# c_optomech:
# [1.15242991]
# Loss: 24333045.2187
# Raw gradient relative difference: 1.7753e-02
# Normalized gradient relative difference: 3.7302e-04
# ---
# Epoch 1360
# k_lin:
# [-18.67736167 -18.67836385]
# k_duffing:
# [1.2755111  1.27502641]
# c_lin:
# [-7.60396489]
# c_optomech:
# [1.12451666]
# Loss: 23245072.6243
# Raw gradient relative difference: 1.7367e-02
# Normalized gradient relative difference: 3.6528e-04
# ---
# Epoch 1370
# k_lin:
# [-18.7039728  -18.70495085]
# k_duffing:
# [1.24803056 1.24756567]
# c_lin:
# [-7.62943116]
# c_optomech:
# [1.09696124]
# Loss: 22199427.8513
# Raw gradient relative difference: 1.6988e-02
# Normalized gradient relative difference: 3.5767e-04
# ---
# Epoch 1380
# k_lin:
# [-18.73011591 -18.73106928]
# k_duffing:
# [1.22100795 1.22056317]
# c_lin:
# [-7.65441914]
# c_optomech:
# [1.06976706]
# Loss: 21194763.9074
# Raw gradient relative difference: 1.6615e-02
# Normalized gradient relative difference: 3.5017e-04
# ---
# Epoch 1390
# k_lin:
# [-18.75579455 -18.75672272]
# k_duffing:
# [1.19443967 1.1940153 ]
# c_lin:
# [-7.67893235]
# c_optomech:
# [1.04293716]
# Loss: 20229764.3976
# Raw gradient relative difference: 1.6249e-02
# Normalized gradient relative difference: 3.4279e-04
# ---
# Epoch 1400
# k_lin:
# [-18.78101234 -18.78191478]
# k_duffing:
# [1.16832207 1.16791838]
# c_lin:
# [-7.70297438]
# c_optomech:
# [1.01647424]
# Loss: 19303143.2617
# Raw gradient relative difference: 1.5888e-02
# Normalized gradient relative difference: 3.3553e-04
# ---
# Epoch 1410
# k_lin:
# [-18.80577294 -18.80664915]
# k_duffing:
# [1.14265147 1.14226873]
# c_lin:
# [-7.72654883]
# c_optomech:
# [0.99038064]
# Loss: 18413644.5001
# Raw gradient relative difference: 1.5533e-02
# Normalized gradient relative difference: 3.2839e-04
# ---
# Epoch 1420
# k_lin:
# [-18.83008005 -18.83092953]
# k_duffing:
# [1.11742411 1.11706258]
# c_lin:
# [-7.7496594]
# c_optomech:
# [0.96465838]
# Loss: 17560041.8897
# Raw gradient relative difference: 1.5185e-02
# Normalized gradient relative difference: 3.2136e-04
# ---
# Epoch 1430
# k_lin:
# [-18.85393744 -18.85475972]
# k_duffing:
# [1.0926362  1.09229613]
# c_lin:
# [-7.77230979]
# c_optomech:
# [0.93930916]
# Loss: 16741138.6890
# Raw gradient relative difference: 1.4842e-02
# Normalized gradient relative difference: 3.1445e-04
# ---
# Epoch 1440
# k_lin:
# [-18.87734892 -18.87814352]
# k_duffing:
# [1.06828391 1.06796552]
# c_lin:
# [-7.79450379]
# c_optomech:
# [0.91433436]
# Loss: 15955767.3335
# Raw gradient relative difference: 1.4505e-02
# Normalized gradient relative difference: 3.0765e-04
# ---
# Epoch 1450
# k_lin:
# [-18.90031834 -18.9010848 ]
# k_duffing:
# [1.04436335 1.04406687]
# c_lin:
# [-7.81624522]
# c_optomech:
# [0.88973509]
# Loss: 15202789.1210
# Raw gradient relative difference: 1.4174e-02
# Normalized gradient relative difference: 3.0097e-04
# ---
# Epoch 1460
# k_lin:
# [-18.92284959 -18.92358747]
# k_duffing:
# [1.0208706  1.02059624]
# c_lin:
# [-7.83753793]
# c_optomech:
# [0.86551213]
# Loss: 14481093.8876
# Raw gradient relative difference: 1.3849e-02
# Normalized gradient relative difference: 2.9440e-04
# ---
# Epoch 1470
# k_lin:
# [-18.94494662 -18.94565548]
# k_duffing:
# [0.99780168 0.99754964]
# c_lin:
# [-7.85838584]
# c_optomech:
# [0.84166603]
# Loss: 13789599.6748
# Raw gradient relative difference: 1.3529e-02
# Normalized gradient relative difference: 2.8795e-04
# ---
# Epoch 1480
# k_lin:
# [-18.96661341 -18.96729283]
# k_duffing:
# [0.9751526  0.97492306]
# c_lin:
# [-7.87879289]
# c_optomech:
# [0.81819704]
# Loss: 13127252.3872
# Raw gradient relative difference: 1.3216e-02
# Normalized gradient relative difference: 2.8161e-04
# ---
# Epoch 1490
# k_lin:
# [-18.98785398 -18.98850354]
# k_duffing:
# [0.9529193  0.95271243]
# c_lin:
# [-7.89876308]
# c_optomech:
# [0.79510516]
# Loss: 12493025.4429
# Raw gradient relative difference: 1.2908e-02
# Normalized gradient relative difference: 2.7537e-04
# ---
# Epoch 1500
# k_lin:
# [-19.00867239 -19.00929171]
# k_duffing:
# [0.93109769 0.93091367]
# c_lin:
# [-7.91830044]
# c_optomech:
# [0.77239017]
# Loss: 11885919.4151
# Raw gradient relative difference: 1.2605e-02
# Normalized gradient relative difference: 2.6925e-04
# ---
# Epoch 1510
# k_lin:
# [-19.02907274 -19.02966143]
# k_duffing:
# [0.90968366 0.90952262]
# c_lin:
# [-7.93740904]
# c_optomech:
# [0.75005158]
# Loss: 11304961.6660
# Raw gradient relative difference: 1.2308e-02
# Normalized gradient relative difference: 2.6324e-04
# ---
# Epoch 1520
# k_lin:
# [-19.04905917 -19.04961685]
# k_duffing:
# [0.88867304 0.88853513]
# c_lin:
# [-7.95609298]
# c_optomech:
# [0.72808868]
# Loss: 10749205.9742
# Raw gradient relative difference: 1.2017e-02
# Normalized gradient relative difference: 2.5734e-04
# ---
# Epoch 1530
# k_lin:
# [-19.06863585 -19.06916216]
# k_duffing:
# [0.86806164 0.86794699]
# c_lin:
# [-7.97435642]
# c_optomech:
# [0.70650055]
# Loss: 10217732.1542
# Raw gradient relative difference: 1.1731e-02
# Normalized gradient relative difference: 2.5154e-04
# ---
# Epoch 1540
# k_lin:
# [-19.08780697 -19.08830157]
# k_duffing:
# [0.84784525 0.84775396]
# c_lin:
# [-7.99220351]
# c_optomech:
# [0.68528606]
# Loss: 9709645.6709
# Raw gradient relative difference: 1.1450e-02
# Normalized gradient relative difference: 2.4585e-04
# ---
# Epoch 1550
# k_lin:
# [-19.10657678 -19.10703933]
# k_duffing:
# [0.8280196  0.82795178]
# c_lin:
# [-8.00963848]
# c_optomech:
# [0.66444386]
# Loss: 9224077.2463
# Raw gradient relative difference: 1.1175e-02
# Normalized gradient relative difference: 2.4026e-04
# ---
# Epoch 1560
# k_lin:
# [-19.12494954 -19.12537972]
# k_duffing:
# [0.80858041 0.80853615]
# c_lin:
# [-8.02666557]
# c_optomech:
# [0.64397243]
# Loss: 8760182.4625
# Raw gradient relative difference: 1.0905e-02
# Normalized gradient relative difference: 2.3478e-04
# ---
# Epoch 1570
# k_lin:
# [-19.14292955 -19.14332705]
# k_duffing:
# [0.78952337 0.78950276]
# c_lin:
# [-8.04328904]
# c_optomech:
# [0.62387005]
# Loss: 8317141.3577
# Raw gradient relative difference: 1.0640e-02
# Normalized gradient relative difference: 2.2941e-04
# ---
# Epoch 1580
# k_lin:
# [-19.16052112 -19.16088563]
# k_duffing:
# [0.77084414 0.77084724]
# c_lin:
# [-8.05951318]
# c_optomech:
# [0.60413484]
# Loss: 7894158.0189
# Raw gradient relative difference: 1.0381e-02
# Normalized gradient relative difference: 2.2413e-04
# ---
# Epoch 1590
# k_lin:
# [-19.1777286  -19.17805984]
# k_duffing:
# [0.75253836 0.75256523]
# c_lin:
# [-8.07534233]
# c_optomech:
# [0.58476473]
# Loss: 7490460.1694
# Raw gradient relative difference: 1.0126e-02
# Normalized gradient relative difference: 2.1896e-04
# ---
# Epoch 1600
# k_lin:
# [-19.19455636 -19.19485406]
# k_duffing:
# [0.73460165 0.73465233]
# c_lin:
# [-8.09078083]
# c_optomech:
# [0.5657575]
# Loss: 7105298.7529
# Raw gradient relative difference: 9.8771e-03
# Normalized gradient relative difference: 2.1389e-04
# ---
# Epoch 1610
# k_lin:
# [-19.21100879 -19.21127268]
# k_duffing:
# [0.71702959 0.71710412]
# c_lin:
# [-8.10583305]
# c_optomech:
# [0.54711078]
# Loss: 6737947.5133
# Raw gradient relative difference: 9.6327e-03
# Normalized gradient relative difference: 2.0892e-04
# ---
# Epoch 1620
# k_lin:
# [-19.2270903  -19.22732014]
# k_duffing:
# [0.69981778 0.69991618]
# c_lin:
# [-8.12050338]
# c_optomech:
# [0.52882205]
# Loss: 6387702.5729
# Raw gradient relative difference: 9.3934e-03
# Normalized gradient relative difference: 2.0405e-04
# ---
# Epoch 1630
# k_lin:
# [-19.24280532 -19.24300087]
# k_duffing:
# [0.68296175 0.68308404]
# c_lin:
# [-8.13479623]
# c_optomech:
# [0.51088865]
# Loss: 6053882.0062
# Raw gradient relative difference: 9.1589e-03
# Normalized gradient relative difference: 1.9927e-04
# ---
# Epoch 1640
# k_lin:
# [-19.25815831 -19.25831933]
# k_duffing:
# [0.66645706 0.66660323]
# c_lin:
# [-8.14871603]
# c_optomech:
# [0.49330779]
# Loss: 5735825.4133
# Raw gradient relative difference: 8.9293e-03
# Normalized gradient relative difference: 1.9460e-04
# ---
# Epoch 1650
# k_lin:
# [-19.27315371 -19.27328   ]
# k_duffing:
# [0.65029923 0.65046927]
# c_lin:
# [-8.16226723]
# c_optomech:
# [0.47607655]
# Loss: 5432893.4897
# Raw gradient relative difference: 8.7044e-03
# Normalized gradient relative difference: 1.9001e-04
# ---
# Epoch 1660
# k_lin:
# [-19.28779602 -19.28788737]
# k_duffing:
# [0.63448376 0.63467767]
# c_lin:
# [-8.17545427]
# c_optomech:
# [0.4591919]
# Loss: 5144467.5965
# Raw gradient relative difference: 8.4843e-03
# Normalized gradient relative difference: 1.8553e-04
# ---
# Epoch 1670
# k_lin:
# [-19.30208972 -19.30214593]
# k_duffing:
# [0.61900618 0.6192239 ]
# c_lin:
# [-8.18828165]
# c_optomech:
# [0.44265068]
# Loss: 4869949.3283
# Raw gradient relative difference: 8.2688e-03
# Normalized gradient relative difference: 1.8113e-04
# ---
# Epoch 1680
# k_lin:
# [-19.3160393 -19.3160602]
# k_duffing:
# [0.60386195 0.60410347]
# c_lin:
# [-8.20075382]
# c_optomech:
# [0.42644965]
# Loss: 4608760.0814
# Raw gradient relative difference: 8.0579e-03
# Normalized gradient relative difference: 1.7683e-04
# ---
# Epoch 1690
# k_lin:
# [-19.32964928 -19.32963469]
# k_duffing:
# [0.58904658 0.58931184]
# c_lin:
# [-8.2128753]
# c_optomech:
# [0.41058545]
# Loss: 4360340.6213
# Raw gradient relative difference: 7.8516e-03
# Normalized gradient relative difference: 1.7262e-04
# ---
# Epoch 1700
# k_lin:
# [-19.34292416 -19.34287393]
# k_duffing:
# [0.57455554 0.57484447]
# c_lin:
# [-8.22465057]
# c_optomech:
# [0.39505463]
# Loss: 4124150.6509
# Raw gradient relative difference: 7.6498e-03
# Normalized gradient relative difference: 1.6850e-04
# ---
# Epoch 1710
# k_lin:
# [-19.35586848 -19.35578245]
# k_duffing:
# [0.5603843  0.56069684]
# c_lin:
# [-8.23608415]
# c_optomech:
# [0.37985367]
# Loss: 3899668.3793
# Raw gradient relative difference: 7.4524e-03
# Normalized gradient relative difference: 1.6447e-04
# ---
# Epoch 1720
# k_lin:
# [-19.36848675 -19.36836478]
# k_duffing:
# [0.54652834 0.5468644 ]
# c_lin:
# [-8.24718053]
# c_optomech:
# [0.36497894]
# Loss: 3686390.0911
# Raw gradient relative difference: 7.2594e-03
# Normalized gradient relative difference: 1.6053e-04
# ---
# Epoch 1730
# k_lin:
# [-19.38078349 -19.38062546]
# k_duffing:
# [0.53298311 0.53334262]
# c_lin:
# [-8.25794424]
# c_optomech:
# [0.35042675]
# Loss: 3483829.7180
# Raw gradient relative difference: 7.0706e-03
# Normalized gradient relative difference: 1.5668e-04
# ---
# Epoch 1740
# k_lin:
# [-19.39276323 -19.39256902]
# k_duffing:
# [0.51974411 0.52012696]
# c_lin:
# [-8.26837978]
# c_optomech:
# [0.33619333]
# Loss: 3291518.4115
# Raw gradient relative difference: 6.8862e-03
# Normalized gradient relative difference: 1.5291e-04
# ---
# Epoch 1750
# k_lin:
# [-19.4044305 -19.4042   ]
# k_duffing:
# [0.50680678 0.50721287]
# c_lin:
# [-8.27849167]
# c_optomech:
# [0.32227486]
# Loss: 3109004.1177
# Raw gradient relative difference: 6.7059e-03
# Normalized gradient relative difference: 1.4923e-04
# ---
# Epoch 1760
# k_lin:
# [-19.41578981 -19.41552293]
# k_duffing:
# [0.49416662 0.49459584]
# c_lin:
# [-8.28828441]
# c_optomech:
# [0.30866744]
# Loss: 2935851.1552
# Raw gradient relative difference: 6.5297e-03
# Normalized gradient relative difference: 1.4563e-04
# ---
# Epoch 1770
# k_lin:
# [-19.42684568 -19.42654233]
# k_duffing:
# [0.4818191  0.48227132]
# c_lin:
# [-8.2977625]
# c_optomech:
# [0.29536713]
# Loss: 2771639.7952
# Raw gradient relative difference: 6.3576e-03
# Normalized gradient relative difference: 1.4211e-04
# ---
# Epoch 1780
# k_lin:
# [-19.43760263 -19.43726272]
# k_duffing:
# [0.46975971 0.4702348 ]
# c_lin:
# [-8.30693045]
# c_optomech:
# [0.28236993]
# Loss: 2615965.8448
# Raw gradient relative difference: 6.1895e-03
# Normalized gradient relative difference: 1.3868e-04
# ---
# Epoch 1790
# k_lin:
# [-19.44806514 -19.44768861]
# k_duffing:
# [0.45798394 0.45848176]
# c_lin:
# [-8.31579274]
# c_optomech:
# [0.26967178]
# Loss: 2468440.2341
# Raw gradient relative difference: 6.0254e-03
# Normalized gradient relative difference: 1.3533e-04
# ---
# Epoch 1800
# k_lin:
# [-19.45823771 -19.45782449]
# k_duffing:
# [0.44648731 0.44700772]
# c_lin:
# [-8.32435386]
# c_optomech:
# [0.25726861]
# Loss: 2328688.6066
# Raw gradient relative difference: 5.8651e-03
# Normalized gradient relative difference: 1.3205e-04
# ---
# Epoch 1810
# k_lin:
# [-19.46812483 -19.46767487]
# k_duffing:
# [0.43526533 0.43580816]
# c_lin:
# [-8.33261827]
# c_optomech:
# [0.24515629]
# Loss: 2196350.9139
# Raw gradient relative difference: 5.7087e-03
# Normalized gradient relative difference: 1.2886e-04
# ---
# Epoch 1820
# k_lin:
# [-19.47773095 -19.47724421]
# k_duffing:
# [0.42431353 0.42487863]
# c_lin:
# [-8.34059044]
# c_optomech:
# [0.23333066]
# Loss: 2071081.0146
# Raw gradient relative difference: 5.5561e-03
# Normalized gradient relative difference: 1.2575e-04
# ---
# Epoch 1830
# k_lin:
# [-19.48706054 -19.48653698]
# k_duffing:
# [0.41362746 0.41421466]
# c_lin:
# [-8.3482748]
# c_optomech:
# [0.22178754]
# Loss: 1952546.2777
# Raw gradient relative difference: 5.4071e-03
# Normalized gradient relative difference: 1.2271e-04
# ---
# Epoch 1840
# k_lin:
# [-19.49611803 -19.49555762]
# k_duffing:
# [0.40320268 0.4038118 ]
# c_lin:
# [-8.35567579]
# c_optomech:
# [0.2105227]
# Loss: 1840427.1907
# Raw gradient relative difference: 5.2618e-03
# Normalized gradient relative difference: 1.1974e-04
# ---
# Epoch 1850
# k_lin:
# [-19.50490783 -19.50431057]
# k_duffing:
# [0.39303477 0.39366563]
# c_lin:
# [-8.36279781]
# c_optomech:
# [0.19953193]
# Loss: 1734416.9732
# Raw gradient relative difference: 5.1201e-03
# Normalized gradient relative difference: 1.1686e-04
# ---
# Epoch 1860
# k_lin:
# [-19.51343436 -19.51280021]
# k_duffing:
# [0.38311932 0.38377174]
# c_lin:
# [-8.36964526]
# c_optomech:
# [0.18881095]
# Loss: 1634221.1952
# Raw gradient relative difference: 4.9820e-03
# Normalized gradient relative difference: 1.1404e-04
# ---
# Epoch 1870
# k_lin:
# [-19.52170199 -19.52103096]
# k_duffing:
# [0.37345196 0.37412573]
# c_lin:
# [-8.37622251]
# c_optomech:
# [0.17835552]
# Loss: 1539557.4012
# Raw gradient relative difference: 4.8473e-03
# Normalized gradient relative difference: 1.1130e-04
# ---
# Epoch 1880
# k_lin:
# [-19.52971508 -19.52900717]
# k_duffing:
# [0.36402833 0.36472326]
# c_lin:
# [-8.38253392]
# c_optomech:
# [0.16816135]
# Loss: 1450154.7398
# Raw gradient relative difference: 4.7160e-03
# Normalized gradient relative difference: 1.0863e-04
# ---
# Epoch 1890
# k_lin:
# [-19.53747797 -19.53673318]
# k_duffing:
# [0.35484409 0.35555997]
# c_lin:
# [-8.3885838]
# c_optomech:
# [0.15822417]
# Loss: 1365753.5992
# Raw gradient relative difference: 4.5880e-03
# Normalized gradient relative difference: 1.0603e-04
# ---
# Epoch 1900
# k_lin:
# [-19.54499496 -19.54421332]
# k_duffing:
# [0.34589492 0.34663154]
# c_lin:
# [-8.39437647]
# c_optomech:
# [0.14853968]
# Loss: 1286105.2487
# Raw gradient relative difference: 4.4634e-03
# Normalized gradient relative difference: 1.0351e-04
# ---
# Epoch 1910
# k_lin:
# [-19.55227036 -19.55145188]
# k_duffing:
# [0.33717655 0.33793369]
# c_lin:
# [-8.39991619]
# c_optomech:
# [0.13910359]
# Loss: 1210971.4863
# Raw gradient relative difference: 4.3420e-03
# Normalized gradient relative difference: 1.0105e-04
# ---
# Epoch 1920
# k_lin:
# [-19.5593084  -19.55845312]
# k_duffing:
# [0.32868471 0.32946215]
# c_lin:
# [-8.40520724]
# c_optomech:
# [0.12991163]
# Loss: 1140124.2929
# Raw gradient relative difference: 4.2238e-03
# Normalized gradient relative difference: 9.8654e-05
# ---
# Epoch 1930
# k_lin:
# [-19.56611334 -19.56522128]
# k_duffing:
# [0.32041518 0.32121269]
# c_lin:
# [-8.41025381]
# c_optomech:
# [0.12095952]
# Loss: 1073345.4923
# Raw gradient relative difference: 4.1087e-03
# Normalized gradient relative difference: 9.6329e-05
# ---
# ...
# c_lin:
# [9.65354454e-06]
# c_optomech:
# [7.52555136e-06]
# Loss: -0.0099
# Raw gradient relative difference: 1.4950e+12
# Normalized gradient relative difference: 7.4638e-01
# ---
# Epoch 19380
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06042055e-07 -2.20256678e-07]
# c_lin:
# [9.65354452e-06]
# c_optomech:
# [7.52555139e-06]
# Loss: -0.0099
# Raw gradient relative difference: 1.7148e+11
# Normalized gradient relative difference: 7.7185e-01
# ---
# Epoch 19390
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06042056e-07 -2.20256678e-07]
# c_lin:
# [9.6535445e-06]
# c_optomech:
# [7.52555175e-06]
# Loss: -0.0099
# Raw gradient relative difference: 1.3307e+10
# Normalized gradient relative difference: 7.7466e-01
# ---
# Epoch 19400
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06042073e-07 -2.20256686e-07]
# c_lin:
# [9.65354445e-06]
# c_optomech:
# [7.52555844e-06]
# Loss: -0.0099
# Raw gradient relative difference: 7.5008e+08
# Normalized gradient relative difference: 7.7485e-01
# ---
# Epoch 19410
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06042489e-07 -2.20256879e-07]
# c_lin:
# [9.65354336e-06]
# c_optomech:
# [7.52572388e-06]
# Loss: -0.0099
# Raw gradient relative difference: 3.1667e+07
# Normalized gradient relative difference: 7.7485e-01
# ---
# Epoch 19420
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06055842e-07 -2.20263065e-07]
# c_lin:
# [9.65350899e-06]
# c_optomech:
# [7.53103107e-06]
# Loss: -0.0099
# Raw gradient relative difference: 1.0230e+06
# Normalized gradient relative difference: 7.7485e-01
# ---
# Epoch 19430
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06603780e-07 -2.20516924e-07]
# c_lin:
# [9.65209859e-06]
# c_optomech:
# [7.74882091e-06]
# Loss: -0.0099
# Raw gradient relative difference: 2.5724e+04
# Normalized gradient relative difference: 7.7483e-01
# ---
# Epoch 19440
# k_lin:
# [0.00984495 0.0100163 ]
# k_duffing:
# [-2.35000285e-07 -2.33672985e-07]
# c_lin:
# [9.57900608e-06]
# c_optomech:
# [1.90356017e-05]
# Loss: -0.0099
# Raw gradient relative difference: 5.1058e+02
# Normalized gradient relative difference: 7.7357e-01
# ---
# Epoch 19450
# k_lin:
# [0.00984306 0.01001537]
# k_duffing:
# [-2.05909073e-06 -1.07880341e-06]
# c_lin:
# [4.89306496e-06]
# c_optomech:
# [0.00073898]
# Loss: -0.0014
# Raw gradient relative difference: 8.1379e+00
# Normalized gradient relative difference: 6.9928e-01
# ---
# Epoch 19460
# k_lin:
# [0.00985264 0.01002009]
# k_duffing:
# [7.72392618e-06 3.48739182e-06]
# c_lin:
# [2.50733223e-05]
# c_optomech:
# [-0.00161707]
# Loss: 0.1622
# Raw gradient relative difference: 1.3772e+00
# Normalized gradient relative difference: 1.5088e+00
# ---
# Epoch 19470
# k_lin:
# [0.00983817 0.010013  ]
# k_duffing:
# [-7.42511267e-06 -3.59500963e-06]
# c_lin:
# [-2.76612257e-06]
# c_optomech:
# [0.00116133]
# Loss: 0.0196
# Raw gradient relative difference: 3.0650e+00
# Normalized gradient relative difference: 4.4706e-01
# ---
# Epoch 19480
# k_lin:
# [0.00984886 0.01001821]
# k_duffing:
# [3.89492132e-06 1.68532491e-06]
# c_lin:
# [1.68160037e-05]
# c_optomech:
# [-0.00065245]
# Loss: 0.0019
# Raw gradient relative difference: 4.8661e+00
# Normalized gradient relative difference: 1.8674e+00
# ---
# Epoch 19490
# k_lin:
# [0.00984298 0.01001534]
# k_duffing:
# [-2.30931602e-06 -1.20741042e-06]
# c_lin:
# [5.87916858e-06]
# c_optomech:
# [0.00036016]
# Loss: -0.0043
# Raw gradient relative difference: 6.5732e+00
# Normalized gradient relative difference: 4.8621e-01
# ---
# Epoch 19500
# k_lin:
# [0.0098461  0.01001687]
# k_duffing:
# [9.92490230e-07 3.47105281e-07]
# c_lin:
# [1.16518345e-05]
# c_optomech:
# [-0.00017022]
# Loss: -0.0076
# Raw gradient relative difference: 9.8896e+00
# Normalized gradient relative difference: 1.9078e+00
# ---
# Epoch 19510
# k_lin:
# [0.0098444  0.01001604]
# k_duffing:
# [-8.30008682e-07 -5.07902046e-07]
# c_lin:
# [8.62918297e-06]
# c_optomech:
# [9.75098615e-05]
# Loss: -0.0090
# Raw gradient relative difference: 1.7243e+01
# Normalized gradient relative difference: 5.3687e-01
# ---
# Epoch 19520
# k_lin:
# [0.00984525 0.01001645]
# k_duffing:
# [ 8.29979087e-08 -8.62449619e-08]
# c_lin:
# [1.01796283e-05]
# c_optomech:
# [-4.18852055e-05]
# Loss: -0.0096
# Raw gradient relative difference: 2.8876e+01
# Normalized gradient relative difference: 1.9143e+00
# ---
# Epoch 19530
# k_lin:
# [0.00984479 0.01001623]
# k_duffing:
# [-4.04977362e-07 -3.16002021e-07]
# c_lin:
# [9.31318591e-06]
# c_optomech:
# [3.81849266e-05]
# Loss: -0.0098
# Raw gradient relative difference: 4.5910e+01
# Normalized gradient relative difference: 5.3199e-01
# ---
# Epoch 19540
# k_lin:
# [0.00984512 0.01001639]
# k_duffing:
# [-5.77965578e-08 -1.51910108e-07]
# c_lin:
# [9.89485281e-06]
# c_optomech:
# [-1.36360629e-05]
# Loss: -0.0098
# Raw gradient relative difference: 8.1816e+01
# Normalized gradient relative difference: 1.9174e+00
# ---
# Epoch 19550
# k_lin:
# [0.00984489 0.01001628]
# k_duffing:
# [-2.98486002e-07 -2.63035967e-07]
# c_lin:
# [9.48941465e-06]
# c_optomech:
# [2.26936905e-05]
# Loss: -0.0099
# Raw gradient relative difference: 1.4786e+02
# Normalized gradient relative difference: 5.5848e-01
# ---
# Epoch 19560
# k_lin:
# [0.00984504 0.01001635]
# k_duffing:
# [-1.38797948e-07 -1.88029625e-07]
# c_lin:
# [9.76854628e-06]
# c_optomech:
# [-2.81605961e-06]
# Loss: -0.0099
# Raw gradient relative difference: 2.7881e+02
# Normalized gradient relative difference: 1.9253e+00
# ---
# Epoch 19570
# k_lin:
# [0.00984494 0.0100163 ]
# k_duffing:
# [-2.4799322e-07 -2.3949696e-07]
# c_lin:
# [9.58415366e-06]
# c_optomech:
# [1.36839781e-05]
# Loss: -0.0099
# Raw gradient relative difference: 8.8885e+02
# Normalized gradient relative difference: 5.7754e-01
# ---
# Epoch 19580
# k_lin:
# [0.00984499 0.01001633]
# k_duffing:
# [-1.89736515e-07 -2.12610651e-07]
# c_lin:
# [9.68286273e-06]
# c_optomech:
# [4.78748647e-06]
# Loss: -0.0099
# Raw gradient relative difference: 8.2170e+03
# Normalized gradient relative difference: 5.6966e-01
# ---
# Epoch 19590
# k_lin:
# [0.00984497 0.01001632]
# k_duffing:
# [-2.09011249e-07 -2.21782945e-07]
# c_lin:
# [9.64885802e-06]
# c_optomech:
# [7.904385e-06]
# Loss: -0.0099
# Raw gradient relative difference: 1.7609e+03
# Normalized gradient relative difference: 1.9170e+00
# ---
# Epoch 19600
# k_lin:
# [0.00984497 0.01001632]
# k_duffing:
# [-2.10717427e-07 -2.22575741e-07]
# c_lin:
# [9.6453993e-06]
# c_optomech:
# [8.2544945e-06]
# Loss: -0.0099
# Raw gradient relative difference: 1.7679e+03
# Normalized gradient relative difference: 5.4280e-01
# ---
# Epoch 19610
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.00750633e-07 -2.17855240e-07]
# c_lin:
# [9.66231194e-06]
# c_optomech:
# [6.74392285e-06]
# Loss: -0.0099
# Raw gradient relative difference: 4.1997e+03
# Normalized gradient relative difference: 1.9167e+00
# ---
# Epoch 19620
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.07879937e-07 -2.21142672e-07]
# c_lin:
# [9.65020276e-06]
# c_optomech:
# [7.8363254e-06]
# Loss: -0.0099
# Raw gradient relative difference: 4.4519e+04
# Normalized gradient relative difference: 1.9040e+00
# ---
# Epoch 19630
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06582120e-07 -2.20509457e-07]
# c_lin:
# [9.65250266e-06]
# c_optomech:
# [7.62463393e-06]
# Loss: -0.0099
# Raw gradient relative difference: 9.4512e+03
# Normalized gradient relative difference: 5.5517e-01
# ---
# Epoch 19640
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.04919072e-07 -2.19722276e-07]
# c_lin:
# [9.65540593e-06]
# c_optomech:
# [7.35961056e-06]
# Loss: -0.0099
# Raw gradient relative difference: 2.0139e+04
# Normalized gradient relative difference: 1.9232e+00
# ---
# Epoch 19650
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06196249e-07 -2.20319293e-07]
# c_lin:
# [9.65326246e-06]
# c_optomech:
# [7.55149712e-06]
# Loss: -0.0099
# Raw gradient relative difference: 4.4368e+04
# Normalized gradient relative difference: 1.9257e+00
# ---
# Epoch 19660
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06392478e-07 -2.20413300e-07]
# c_lin:
# [9.65294262e-06]
# c_optomech:
# [7.57969092e-06]
# Loss: -0.0099
# Raw gradient relative difference: 4.5903e+04
# Normalized gradient relative difference: 5.6775e-01
# ---
# Epoch 19670
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.05951714e-07 -2.20209458e-07]
# c_lin:
# [9.65369869e-06]
# c_optomech:
# [7.51119269e-06]
# Loss: -0.0099
# Raw gradient relative difference: 2.1400e+05
# Normalized gradient relative difference: 5.9289e-01
# ---
# Epoch 19680
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.05916519e-07 -2.20194813e-07]
# c_lin:
# [9.65375887e-06]
# c_optomech:
# [7.50572202e-06]
# Loss: -0.0099
# Raw gradient relative difference: 1.2413e+05
# Normalized gradient relative difference: 1.9251e+00
# ---
# Epoch 19690
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06051945e-07 -2.20259383e-07]
# c_lin:
# [9.65352743e-06]
# c_optomech:
# [7.52669526e-06]
# Loss: -0.0099
# Raw gradient relative difference: 3.0119e+05
# Normalized gradient relative difference: 1.9267e+00
# ---
# Epoch 19700
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06090173e-07 -2.20278014e-07]
# c_lin:
# [9.6534619e-06]
# c_optomech:
# [7.53271372e-06]
# Loss: -0.0099
# Raw gradient relative difference: 6.3283e+05
# Normalized gradient relative difference: 5.7873e-01
# ---
# Epoch 19710
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06062379e-07 -2.20265460e-07]
# c_lin:
# [9.65350902e-06]
# c_optomech:
# [7.528535e-06]
# Loss: -0.0099
# Raw gradient relative difference: 5.6021e+05
# Normalized gradient relative difference: 5.6761e-01
# ---
# Epoch 19720
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06038859e-07 -2.20254733e-07]
# c_lin:
# [9.65354896e-06]
# c_optomech:
# [7.52498153e-06]
# Loss: -0.0099
# Raw gradient relative difference: 2.0044e+06
# Normalized gradient relative difference: 5.8109e-01
# ---
# Epoch 19730
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06033454e-07 -2.20252383e-07]
# c_lin:
# [9.65355817e-06]
# c_optomech:
# [7.52419218e-06]
# Loss: -0.0099
# Raw gradient relative difference: 4.2608e+06
# Normalized gradient relative difference: 1.9300e+00
# ---
# Epoch 19740
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06036102e-07 -2.20253738e-07]
# c_lin:
# [9.65355374e-06]
# c_optomech:
# [7.52462465e-06]
# Loss: -0.0099
# Raw gradient relative difference: 2.8720e+06
# Normalized gradient relative difference: 1.9245e+00
# ---
# Epoch 19750
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06039279e-07 -2.20255302e-07]
# c_lin:
# [9.65354842e-06]
# c_optomech:
# [7.5251267e-06]
# Loss: -0.0099
# Raw gradient relative difference: 4.1668e+06
# Normalized gradient relative difference: 1.9234e+00
# ---
# Epoch 19760
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06041055e-07 -2.20256183e-07]
# c_lin:
# [9.6535455e-06]
# c_optomech:
# [7.52540513e-06]
# Loss: -0.0099
# Raw gradient relative difference: 7.7525e+06
# Normalized gradient relative difference: 1.9223e+00
# ---
# Epoch 19770
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06041757e-07 -2.20256540e-07]
# c_lin:
# [9.65354442e-06]
# c_optomech:
# [7.52551355e-06]
# Loss: -0.0099
# Raw gradient relative difference: 1.5695e+07
# Normalized gradient relative difference: 1.9206e+00
# ---
# Epoch 19780
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06041956e-07 -2.20256645e-07]
# c_lin:
# [9.65354419e-06]
# c_optomech:
# [7.52554208e-06]
# Loss: -0.0099
# Raw gradient relative difference: 3.0345e+07
# Normalized gradient relative difference: 1.9181e+00
# ---
# Epoch 19790
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06041980e-07 -2.20256657e-07]
# c_lin:
# [9.65354425e-06]
# c_optomech:
# [7.52554289e-06]
# Loss: -0.0099
# Raw gradient relative difference: 5.0538e+07
# Normalized gradient relative difference: 1.9167e+00
# ---
# Epoch 19800
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06041964e-07 -2.20256645e-07]
# c_lin:
# [9.65354436e-06]
# c_optomech:
# [7.52553799e-06]
# Loss: -0.0099
# Raw gradient relative difference: 7.2641e+07
# Normalized gradient relative difference: 1.9176e+00
# ---
# Epoch 19810
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06041954e-07 -2.20256635e-07]
# c_lin:
# [9.65354444e-06]
# c_optomech:
# [7.52553525e-06]
# Loss: -0.0099
# Raw gradient relative difference: 1.0132e+08
# Normalized gradient relative difference: 1.9200e+00
# ---
# Epoch 19820
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06041968e-07 -2.20256637e-07]
# c_lin:
# [9.65354446e-06]
# c_optomech:
# [7.52553696e-06]
# Loss: -0.0099
# Raw gradient relative difference: 1.6253e+08
# Normalized gradient relative difference: 1.9226e+00
# ---
# Epoch 19830
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06042003e-07 -2.20256652e-07]
# c_lin:
# [9.65354443e-06]
# c_optomech:
# [7.5255426e-06]
# Loss: -0.0099
# Raw gradient relative difference: 4.0708e+08
# Normalized gradient relative difference: 1.9257e+00
# ---
# Epoch 19840
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06042044e-07 -2.20256672e-07]
# c_lin:
# [9.65354438e-06]
# c_optomech:
# [7.52554938e-06]
# Loss: -0.0099
# Raw gradient relative difference: 2.9942e+09
# Normalized gradient relative difference: 6.0757e-01
# ---
# Epoch 19850
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06042069e-07 -2.20256685e-07]
# c_lin:
# [9.65354435e-06]
# c_optomech:
# [7.5255535e-06]
# Loss: -0.0099
# Raw gradient relative difference: 7.8883e+08
# Normalized gradient relative difference: 5.5295e-01
# ---
# Epoch 19860
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06042068e-07 -2.20256685e-07]
# c_lin:
# [9.65354437e-06]
# c_optomech:
# [7.52555324e-06]
# Loss: -0.0099
# Raw gradient relative difference: 1.8491e+09
# Normalized gradient relative difference: 5.4085e-01
# ---
# Epoch 19870
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06042054e-07 -2.20256678e-07]
# c_lin:
# [9.6535444e-06]
# c_optomech:
# [7.52555105e-06]
# Loss: -0.0099
# Raw gradient relative difference: 3.0843e+09
# Normalized gradient relative difference: 1.9192e+00
# ---
# Epoch 19880
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06042052e-07 -2.20256677e-07]
# c_lin:
# [9.65354442e-06]
# c_optomech:
# [7.52555066e-06]
# Loss: -0.0099
# Raw gradient relative difference: 4.7659e+09
# Normalized gradient relative difference: 1.9239e+00
# ---
# Epoch 19890
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06042058e-07 -2.20256679e-07]
# c_lin:
# [9.65354441e-06]
# c_optomech:
# [7.52555163e-06]
# Loss: -0.0099
# Raw gradient relative difference: 6.2473e+09
# Normalized gradient relative difference: 5.6404e-01
# ---
# Epoch 19900
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06042056e-07 -2.20256679e-07]
# c_lin:
# [9.65354442e-06]
# c_optomech:
# [7.52555146e-06]
# Loss: -0.0099
# Raw gradient relative difference: 2.3064e+11
# Normalized gradient relative difference: 1.8265e+00
# ---
# Epoch 19910
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06042055e-07 -2.20256678e-07]
# c_lin:
# [9.65354443e-06]
# c_optomech:
# [7.52555121e-06]
# Loss: -0.0099
# Raw gradient relative difference: 2.0459e+10
# Normalized gradient relative difference: 1.9182e+00
# ---
# Epoch 19920
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06042056e-07 -2.20256679e-07]
# c_lin:
# [9.65354443e-06]
# c_optomech:
# [7.52555146e-06]
# Loss: -0.0099
# Raw gradient relative difference: 2.3849e+10
# Normalized gradient relative difference: 5.5967e-01
# ---
# Epoch 19930
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06042055e-07 -2.20256678e-07]
# c_lin:
# [9.65354443e-06]
# c_optomech:
# [7.5255513e-06]
# Loss: -0.0099
# Raw gradient relative difference: 3.8382e+10
# Normalized gradient relative difference: 1.9231e+00
# ---
# Epoch 19940
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06042056e-07 -2.20256679e-07]
# c_lin:
# [9.65354443e-06]
# c_optomech:
# [7.5255514e-06]
# Loss: -0.0099
# Raw gradient relative difference: 6.3126e+10
# Normalized gradient relative difference: 5.4993e-01
# ---
# Epoch 19950
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06042055e-07 -2.20256678e-07]
# c_lin:
# [9.65354443e-06]
# c_optomech:
# [7.52555133e-06]
# Loss: -0.0099
# Raw gradient relative difference: 1.0448e+11
# Normalized gradient relative difference: 1.9205e+00
# ---
# Epoch 19960
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06042056e-07 -2.20256679e-07]
# c_lin:
# [9.65354443e-06]
# c_optomech:
# [7.52555137e-06]
# Loss: -0.0099
# Raw gradient relative difference: 2.9540e+11
# Normalized gradient relative difference: 5.6814e-01
# ---
# Epoch 19970
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06042056e-07 -2.20256679e-07]
# c_lin:
# [9.65354443e-06]
# c_optomech:
# [7.52555136e-06]
# Loss: -0.0099
# Raw gradient relative difference: 3.8675e+11
# Normalized gradient relative difference: 5.5151e-01
# ---
# Epoch 19980
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06042056e-07 -2.20256678e-07]
# c_lin:
# [9.65354443e-06]
# c_optomech:
# [7.52555135e-06]
# Loss: -0.0099
# Raw gradient relative difference: 4.5239e+11
# Normalized gradient relative difference: 1.9205e+00
# ---
# Epoch 19990
# k_lin:
# [0.00984498 0.01001632]
# k_duffing:
# [-2.06042056e-07 -2.20256678e-07]
# c_lin:
# [9.65354443e-06]
# c_optomech:
# [7.52555135e-06]
# Loss: -0.0099
# Raw gradient relative difference: 3.0750e+11
# Normalized gradient relative difference: 1.9221e+00
# ---

# %%
# Convert histories to arrays for plotting
slicing = 1
params_history = jnp.array(params_history[::slicing])
k_lin_history = jnp.zeros((len(params_history), N_osc))
k_duff_history = jnp.zeros((len(params_history), N_osc))
c_lin_history = jnp.zeros((len(params_history), 1))
c_optomech_history = jnp.zeros((len(params_history), 1))

for i in range(len(params_history)):
    k_lin, k_duff, c_lin, c_optomech = unflatten(params_history[i])
    k_lin_history = k_lin_history.at[i].set(k_lin)
    k_duff_history = k_duff_history.at[i].set(k_duff)
    c_lin_history = c_lin_history.at[i].set(c_lin)
    c_optomech_history = c_optomech_history.at[i].set(c_optomech)

loss_history = jnp.array(loss_history[::slicing])
gradient_diff_history = jnp.array(gradient_diff_history[::slicing])
gradient_diff_norm_history = jnp.array(gradient_diff_norm_history[::slicing])

# Create figure with 3 rows and 2 columns
fig, axes = plt.subplots(3, 2, figsize=(20, 24))

# Plot k_lin evolution
for i in range(N_osc):
    axes[0, 0].plot(k_lin_history[:, i], label=f'k_lin[{i}]')
axes[0, 0].set_title(f'Evolution of k_lin\nFinal values:\n' + 
                     '\n'.join([f'k_lin[{i}] = {k_lin_history[-1,i]:.3f}' 
                               for i in range(N_osc)]))
axes[0, 0].set_xlabel('Epoch')
axes[0, 0].set_ylabel('Linear Strength')
axes[0, 0].legend()
axes[0, 0].grid(True)

# Plot k_duff evolution
for i in range(N_osc):
    axes[0, 1].plot(k_duff_history[:, i], label=f'k_duff[{i}]')
axes[0, 1].set_title(f'Evolution of k_duff\nFinal values:\n' + 
                     '\n'.join([f'k_duff[{i}] = {k_duff_history[-1,i]:.3f}' 
                               for i in range(N_osc)]))
axes[0, 1].set_xlabel('Epoch')
axes[0, 1].set_ylabel('Duffing Strength')
axes[0, 1].legend()
axes[0, 1].grid(True)

# Plot c_lin and c_optomech evolution
axes[1, 0].plot(c_lin_history, label='c_lin')
axes[1, 0].plot(c_optomech_history, label='c_optomech')
axes[1, 0].set_title(f'Evolution of Coupling Parameters\nFinal values:\n' +
                     f'c_lin = {c_lin_history[-1,0]:.3f}\n' +
                     f'c_optomech = {c_optomech_history[-1,0]:.3f}')
axes[1, 0].set_xlabel('Epoch')
axes[1, 0].set_ylabel('Coupling Strength')
axes[1, 0].legend()
axes[1, 0].grid(True)

# Plot loss evolution
axes[1, 1].semilogy(loss_history, label='Loss')  # Changed plot to semilogy
axes[1, 1].set_title(f'Evolution of Loss\nFinal value: {loss_history[-1]:.3e}')  # Changed to scientific notation
axes[1, 1].set_xlabel('Epoch')
axes[1, 1].set_ylabel('Loss')
axes[1, 1].legend()
axes[1, 1].grid(True)

# Plot raw gradient difference evolution
axes[2, 0].semilogy(gradient_diff_history, label='Raw Gradient Difference')
axes[2, 0].set_title('Evolution of Raw Gradient Difference\n' +
                     f'Final value: {gradient_diff_history[-1]:.2e}')
axes[2, 0].set_xlabel('Epoch')
axes[2, 0].set_ylabel('Relative Difference')
axes[2, 0].legend()
axes[2, 0].grid(True)

# Plot normalized gradient difference evolution
axes[2, 1].semilogy(gradient_diff_norm_history, label='Normalized Gradient Difference')
axes[2, 1].set_title('Evolution of Normalized Gradient Difference\n' +
                     f'Final value: {gradient_diff_norm_history[-1]:.2e}')
axes[2, 1].set_xlabel('Epoch')
axes[2, 1].set_ylabel('Relative Difference')
axes[2, 1].legend()
axes[2, 1].grid(True)

plt.tight_layout()
plt.show()

# %%
# Create figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# Plot initial energy landscape
energy_initial = jnp.zeros((n_points, n_points))
energy_final = jnp.zeros((n_points, n_points))
for i in range(n_points):
    for j in range(n_points):
        x = jnp.array([X1[i,j], X2[i,j]])
        energy_initial = energy_initial.at[i,j].set(energy_fn(x, flattened_args_initial))
        energy_final = energy_final.at[i,j].set(energy_fn(x, params))

contour1 = ax1.contourf(X1, X2, energy_initial, levels=20, cmap='viridis', alpha=0.7)
plt.colorbar(contour1, ax=ax1, label='Energy')
ax1.scatter(samples[:, 0], samples[:, 1], c='black', s=1, alpha=0.9, label='Training Samples')
ax1.set_xlabel('x₁')
ax1.set_ylabel('x₂')
ax1.set_title('Initial Energy Landscape')
ax1.legend()


contour2 = ax2.contourf(X1, X2, energy_final, levels=20, cmap='viridis', alpha=0.7)
plt.colorbar(contour2, ax=ax2, label='Energy')
ax2.scatter(samples[:, 0], samples[:, 1], c='black', s=1, alpha=0.9, label='Training Samples')
ax2.set_xlabel('x₁')
ax2.set_ylabel('x₂')
ax2.set_title('Final Energy Landscape')
ax2.legend()

plt.tight_layout()
plt.show()

# %%
# Get final values from histories
k_lin_final = k_lin_history[-1]
k_duff_final = k_duff_history[-1]
c_lin_final = c_lin_history[-1]
c_optomech_final = c_optomech_history[-1]

# Create tuple of final args in same structure as initial args
args_final = (k_lin_final, k_duff_final, c_lin_final, c_optomech_final)

# Flatten using the same unflatten function from earlier
flattened_args_final, _ = flatten_util.ravel_pytree(args_final)

# %%
# Compare gradient differences with score_matching_loss for different dt values
dt_values = jnp.logspace(-18, 1, 30)  # logarithmically spaced dt values
key = jr.PRNGKey(1)

# Get score matching gradient results (only need to compute once)
score_matching_loss = setup_score_matching_loss(energy_fn, samples)
score_matching_grad = grad_loss(score_matching_loss, flattened_args_final)

# Initialize arrays to store results
n_params = len(flattened_args_final)
relative_differences = jnp.zeros((len(dt_values), n_params))
total_relative_differences = jnp.zeros(len(dt_values))  # New array for total differences

# Loop over dt values
for i, dt in enumerate(dt_values):
    key, subkey = jr.split(key)
    
    # Get CD1 gradient for this dt
    cd1_grad = -CD1_gradient(energy_fn, samples, flattened_args_final, 
                            dt=dt, D=1, key=subkey, num_noise_samples=0)
    
    # Calculate relative difference for each parameter
    rel_diff = jnp.abs(cd1_grad - score_matching_grad) / jnp.abs(score_matching_grad)
    relative_differences = relative_differences.at[i].set(rel_diff)
    
    # Calculate total relative difference using L2 norm
    total_rel_diff = jnp.linalg.norm(cd1_grad - score_matching_grad) / jnp.linalg.norm(score_matching_grad)
    total_relative_differences = total_relative_differences.at[i].set(total_rel_diff)

# Create figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 6))

# First subplot: Individual parameter differences
param_names = ['k_lin_1', 'k_lin_2', 'k_duff_1', 'k_duff_2', 'c_lin', 'c_optomech']
for param_idx in range(n_params):
    ax1.loglog(dt_values, relative_differences[:, param_idx], 'o-', 
               label=param_names[param_idx])

ax1.set_xlabel('dt')
ax1.set_ylabel('Relative Difference')
ax1.set_title('Individual Parameter Relative Differences')
ax1.grid(True)
ax1.legend()

# Second subplot: Total gradient difference
ax2.loglog(dt_values, total_relative_differences, 'o-', color='black', label='Total gradient')
ax2.set_xlabel('dt')
ax2.set_ylabel('Total Relative Difference')
ax2.set_title('Total Gradient Relative Difference (L2 norm)')
ax2.grid(True)
ax2.legend()

plt.tight_layout()
plt.show()

# Print the minimum relative differences
print("\nIndividual parameter minimum differences:")
for param_idx in range(n_params):
    min_idx = jnp.argmin(relative_differences[:, param_idx])
    print(f"\n{param_names[param_idx]}:")
    print(f"Minimum relative difference: {relative_differences[min_idx, param_idx]:.2e}")
    print(f"Optimal dt: {dt_values[min_idx]:.2e}")

print("\nTotal gradient minimum difference:")
min_total_idx = jnp.argmin(total_relative_differences)
print(f"Minimum total relative difference: {total_relative_differences[min_total_idx]:.2e}")
print(f"Optimal dt: {dt_values[min_total_idx]:.2e}")
# Out:
# Individual parameter minimum differences:
#
# k_lin_1:
# Minimum relative difference: 1.00e+00
# Optimal dt: 1.00e-18
#
# k_lin_2:
# Minimum relative difference: 1.00e+00
# Optimal dt: 1.00e-18
#
# k_duff_1:
# Minimum relative difference: 1.00e+00
# Optimal dt: 1.00e-18
#
# k_duff_2:
# Minimum relative difference: 1.00e+00
# Optimal dt: 1.00e-18
#
# c_lin:
# Minimum relative difference: 1.00e+00
# Optimal dt: 1.00e-18
#
# c_optomech:
# Minimum relative difference: 1.00e+00
# Optimal dt: 1.00e-18
#
# Total gradient minimum difference:
# Minimum total relative difference: 1.00e+00
# Optimal dt: 1.00e-18

# %%
# def drift_x_fn(t, state, args):
#     """
#     Drift function for the XY model with effective temperature
#     Args:
#         t: time
#         state: array of phases (shape: N_osc)
#         args: tuple containing (W, h)
#     Returns:
#         Array of phase velocities
#     """
#     W, h = args
#     # Compute force from energy gradient
#     dE_dtheta = jax.grad(XY_energy, argnums=0)(state, W, h)
    
#     # Damping term
#     gamma = 1.0  # Damping coefficient, adjust as needed
    
#     dtheta_dt = -gamma * dE_dtheta
    
#     return dtheta_dt

# def diffusion_x_fn(t, state, args):
#     """
#     Diffusion function for the XY model with effective temperature
#     Args:
#         t: time
#         state: array of phases (shape: N_osc)
#         args: additional arguments
#     Returns:
#         Noise matrix (shape: N_osc x 1)
#     """
#     T_eff = 1.0  # Effective temperature, adjust as needed
#     gamma = 1.0  # Same damping coefficient as in drift
    
#     noise_strength = jnp.sqrt(2 * gamma * T_eff)
#     noise_matrix = jnp.eye(N_osc)
#     return noise_strength * noise_matrix

# %%
# # Calculate characteristic time scales
# gamma = 1.0
# T_eff = 1.0
# J = jnp.max(jnp.abs(W))  # Coupling strength

# tau_relax = 1/gamma
# tau_diffusion = gamma/(2*T_eff)

# print(f"Relaxation time scale: {tau_relax:.2f}")
# print(f"Diffusion time scale: {tau_diffusion:.2f}")

# # Set simulation time accordingly
# t0 = 0.0
# t1 = 100 * max(tau_relax, tau_diffusion)  # Simulate for 10x the longest time scale
# dt0 = min(tau_relax, tau_diffusion) / 10  # Initial time step should be smaller than fastest time scale

# print(f"\nSuggested simulation parameters:")
# print(f"Total time: {t1:.2f}")
# print(f"Initial dt: {dt0:.2f}")

# ts = jnp.linspace(t0, t1, 10000)
# dt = ts[1] - ts[0]

# y0_x = jnp.array([jnp.pi,jnp.pi])

# %%
# # Update shape to match number of oscillators
# w_shape = (N_osc,)  # state is just phases for each oscillator
# brownian_motion = diffrax.VirtualBrownianTree(
#     t0, t1, 1.e-11, w_shape, jr.PRNGKey(0), diffrax.SpaceTimeLevyArea
# )
# terms_x = MultiTerm(ODETerm(drift_x_fn), ControlTerm(diffusion_x_fn, brownian_motion))
# saveat = diffrax.SaveAt(ts=ts)


# # sample 1000 points
# solution_x = diffrax.diffeqsolve(
#     terms_x,
#     solver=diffrax.SRA1(),
#     t0=t0,
#     t1=t1,
#     dt0=dt0,
#     y0=y0_x,
#     args=(),
#     saveat=saveat,
#     progress_meter=diffrax.TqdmProgressMeter(),
#     max_steps=1000000000,
#     stepsize_controller=diffrax.PIDController(rtol=1e-3, atol=1e-6),  # Enable adaptive stepping
# )
# sde_samples_x = solution_x.ys

# %%
# # Calculate number of timesteps corresponding to one relaxation time
# relax_steps = int(1/(gamma * dt))

# # Thin the samples by taking every relax_steps point
# sde_samples_x = solution_x.ys[::relax_steps]
# ts = ts[::relax_steps]

# %%
# # Create figure with a grid of subplots
# fig = plt.figure(figsize=(16, 12))
# gs = plt.GridSpec(2, 2, height_ratios=[2, 1])

# # Top left: Phase trajectories
# ax1 = fig.add_subplot(gs[0, 0])
# # Mod 2π for time trajectories
# ax1.plot(ts, jnp.mod(sde_samples_x[:, 0], 2*jnp.pi), label='θ₁(t)')
# ax1.plot(ts, jnp.mod(sde_samples_x[:, 1], 2*jnp.pi), label='θ₂(t)')
# ax1.set_xlabel('Time')
# ax1.set_ylabel('Phase (rad)')
# ax1.set_title('SDE Simulation: Phase vs Time')
# ax1.grid(True)
# ax1.legend()

# # Top right: Phase space with Energy contour
# ax2 = fig.add_subplot(gs[0, 1])
# contour = ax2.contourf(X1, X2, energy, levels=20, cmap='RdYlBu')
# plt.colorbar(contour, ax=ax2, label='Energy')

# # Mod 2π for phase space trajectory
# wrapped_x = jnp.mod(sde_samples_x, 2*jnp.pi)
# ax2.scatter(wrapped_x[:, 0], wrapped_x[:, 1], c='g', s=1, alpha=0.9999, label='Trajectory')
# ax2.plot(wrapped_x[0, 0], wrapped_x[0, 1], 'go', label='Start', markersize=10)


# ax2.set_xlabel('θ₁')
# ax2.set_ylabel('θ₂')
# ax2.set_title('Phase Space (Torus)')
# ax2.legend()

# # Bottom left: θ₁ histogram (mod 2π)
# ax3 = fig.add_subplot(gs[1, 0])
# ax3.hist(wrapped_x[:, 0], bins=50, density=True, alpha=0.7, label='θ₁ distribution')
# ax3.set_xlabel('θ₁')
# ax3.set_ylabel('Probability Density')
# ax3.grid(True)
# ax3.legend()

# # Bottom right: θ₂ histogram (mod 2π)
# ax4 = fig.add_subplot(gs[1, 1])
# ax4.hist(wrapped_x[:, 1], bins=50, density=True, alpha=0.7, label='θ₂ distribution')
# ax4.set_xlabel('θ₂')
# ax4.set_ylabel('Probability Density')
# ax4.grid(True)
# ax4.legend()

# plt.tight_layout()
# # Add title with parameters
# title = f'T_eff={T_eff}, γ={gamma}'
# plt.suptitle(title, y=1.02)

# plt.show()
