# %%
import jax
from jax import flatten_util, vmap 
import jax.numpy as jnp
import jax.random as jr
import diffrax
from diffrax import ControlTerm, MultiTerm, ODETerm
import matplotlib.pyplot as plt
from functools import partial
import optax
from helper_fns_general import sample_gaussian_mixture, normalize_samples, CD1_gradient, setup_score_matching_loss, grad_loss
jax.config.update("jax_enable_x64", True)

# %% [markdown]
# ### Generate samples from a Gaussian mixture

# %%
# Set random seed
key = jr.PRNGKey(0)

# Parameters
N = 2  # number of dimensions
N_mixgauss = 3  # number of mixture components
n_samples = 10000

# Define mixture weights (must sum to 1)
weights = jnp.array([1., 0.])

# Define means
means = jnp.array([
    [0.0, 0.0],   # mean of first Gaussian
    [-0.0, 0.0],  # mean of second Gaussian
])

# Define covariance matrices
covs = jnp.array([
    [[1, 0.0],    # covariance of first Gaussian
        [0.0, 1]],
    [[1, -0.0],   # covariance of second Gaussian
        [-0.0, 1]],
])

# Generate samples
samples = sample_gaussian_mixture(key, n_samples, weights, means, covs)
# Normalize samples
# samples = normalize_samples(samples_raw)
# Out:
# CUDA backend failed to initialize: Unable to use CUDA because of the following issues with CUDA components:
# Outdated cuDNN installation found.
# Version JAX was built against: 8907
# Minimum supported: 9100
# Installed version: 8907
# The local installation version must be no lower than 9100..(Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %% [markdown]
# ### Plot samples and marginal distributions

# %%
# Plot samples and marginal distributions
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# First subplot: Scatter plot of samples
ax1.scatter(samples[:, 0], samples[:, 1], alpha=0.5)
ax1.set_title('Samples')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')

# Second subplot: Combined marginal distributions
ax2.hist(samples[:, 0], bins=50, density=True, alpha=0.7, label='X distribution')
ax2.hist(samples[:, 1], bins=50, density=True, alpha=0.7, label='Y distribution')
ax2.set_title('Marginal Distributions')
ax2.set_xlabel('Value')
ax2.set_ylabel('Density')
ax2.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Define energy function of duffing oscillator network

# %%
def energy_self_oscillator(x, k_lin, k_duff):
    return 1 / 2 * k_lin * x**2 + 1 / 4 * k_duff * x**4

def energy_self_network(x, k_lin, k_duff):
    return jnp.sum(vmap(energy_self_oscillator)(x, k_lin, k_duff))


def energy_coupling_pair(x, y, c_lin, c_optomech):
    return c_lin * x * (x - y) + c_lin * y * (y - x) + c_optomech * (x**2) * y

def energy_coupling_network(x, c_lin, c_optomech, connectivity):
    # get contribution to total energy from each pair of oscillators
    
    def _coupling_energy_pair(x, c_lin, c_optomech, pair):
        # get energy of one pair of oscillators
        i, j = pair
        return energy_coupling_pair(x[i], x[j], c_lin, c_optomech)

    # get energy of all pairs of oscillators
    return jnp.sum(
        vmap(_coupling_energy_pair, in_axes=(None, 0, 0, 0))(
            x, c_lin, c_optomech, connectivity
        )
    )

k_b = 1.0
T = .1
def _energy_duffing_network(x, k_lin, k_duff, c_lin, c_optomech, connectivity, k_b=k_b, T=T):
    # returns energy of network of oscillators given input parameters
    return (
        energy_self_network(x, k_lin, k_duff) +
        energy_coupling_network(x, c_lin, c_optomech, connectivity)
    ) / (k_b * T)

# %% [markdown]
# ### Define initial parameters

# %%
N_osc = 2

k_lin_0 = jnp.array([1., 1.])
k_duff_0 = jnp.array([0., 0.])
c_lin_0 = jnp.array([0.,])
c_optomech_0 = jnp.array([0.,])
connectivity = jnp.array([[0, 1]])



args_initial = (k_lin_0, k_duff_0, c_lin_0, c_optomech_0)

flattened_args_initial, unflatten = flatten_util.ravel_pytree(args_initial)

# %% [markdown]
# ### Bringe energy into correct form

# %%
def energy_duffing_network(x, flattened_args, connectivity):
    k_lin, k_duffing, c_lin, c_optomech = unflatten(flattened_args)
    return _energy_duffing_network(x, k_lin, k_duffing, c_lin, c_optomech, connectivity)
energy_fn = lambda x, flattened_args: energy_duffing_network(x, flattened_args, connectivity)

# %% [markdown]
# ### Plot energy landscape

# %%
# Create a grid of phase values
n_points = 30
x1 = jnp.linspace(-5, 5, n_points)
x2 = jnp.linspace(-5, 5, n_points)
X1, X2 = jnp.meshgrid(x1, x2)

# Compute energy for each point in the grid
energy = jnp.zeros((n_points, n_points))
for i in range(n_points):
    for j in range(n_points):
        x = jnp.array([X1[i,j], X2[i,j]])
        energy = energy.at[i,j].set(energy_fn(x, flattened_args_initial))

# Compute probability distribution
prob = jnp.exp(-energy)
# Normalize probability (integrate to 1)
prob = prob / (jnp.sum(prob) * (x1[1]-x1[0]) * (x2[1]-x2[0]))

# Create figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# Plot energy landscape
contour1 = ax1.contourf(X1, X2, energy, levels=20, cmap='viridis')
plt.colorbar(contour1, ax=ax1, label='Energy')
ax1.scatter(samples[:, 0], samples[:, 1], c='red', s=1, alpha=0.5, label='Samples')
ax1.set_xlabel('x1')
ax1.set_ylabel('x2')
ax1.set_title('Energy Landscape')
ax1.legend()

# Plot probability distribution
contour2 = ax2.contourf(X1, X2, prob, levels=20, cmap='viridis')
plt.colorbar(contour2, ax=ax2, label='Probability Density')
ax2.scatter(samples[:, 0], samples[:, 1], c='red', s=1, alpha=0.5, label='Samples')
ax2.set_xlabel('x1')
ax2.set_ylabel('x2')
ax2.set_title('Probability Distribution')
ax2.legend()

plt.tight_layout()
plt.show()

# Print some statistics
print(f"Total probability (should be ≈ 1): {jnp.sum(prob) * (x1[1]-x1[0]) * (x2[1]-x2[0]):.6f}")
print(f"Maximum probability density: {jnp.max(prob):.6f}")
print(f"Minimum probability density: {jnp.min(prob):.6f}")
# Out:
# Total probability (should be ≈ 1): 1.000000
# Maximum probability density: 1.182278
# Minimum probability density: 0.000000

# %% [markdown]
# ### Test minus CD1 gradient vs score matching gradient (eq. 10 in Connections Between Score Matching, Contrastive Divergence, and Pseudolikelihood for Continuous-Valued Variables)

# %%
# Compare gradient differences with score_matching_loss for different dt values
dt_values = jnp.logspace(-18, 1, 30)  # logarithmically spaced dt values
key = jr.PRNGKey(1)

# Get score matching gradient results (only need to compute once)
score_matching_loss = setup_score_matching_loss(energy_fn, samples)
score_matching_grad = grad_loss(score_matching_loss, flattened_args_initial)
score_matching_grad_norm = score_matching_grad / jnp.linalg.norm(score_matching_grad)

# Initialize arrays to store results
n_params = len(flattened_args_initial)
relative_differences = jnp.zeros((len(dt_values), n_params))
total_relative_differences = jnp.zeros(len(dt_values))
normalized_differences = jnp.zeros(len(dt_values))  # New array for normalized differences

# Loop over dt values
for i, dt in enumerate(dt_values):
    key, subkey = jr.split(key)
    
    # Get CD1 gradient for this dt
    cd1_grad = -CD1_gradient(energy_fn, samples, flattened_args_initial, 
                            dt=dt, D=k_b*T, key=subkey, num_noise_samples=1000)
    
    # Calculate relative difference for each parameter
    rel_diff = jnp.abs(cd1_grad - score_matching_grad) / jnp.abs(score_matching_grad)
    relative_differences = relative_differences.at[i].set(rel_diff)
    
    # Calculate total relative difference using L2 norm
    total_rel_diff = jnp.linalg.norm(cd1_grad - score_matching_grad) / jnp.linalg.norm(score_matching_grad)
    total_relative_differences = total_relative_differences.at[i].set(total_rel_diff)
    
    # Calculate normalized gradient difference
    cd1_grad_norm = cd1_grad / jnp.linalg.norm(cd1_grad)
    norm_diff = jnp.linalg.norm(cd1_grad_norm - score_matching_grad_norm)
    normalized_differences = normalized_differences.at[i].set(norm_diff)

# Create figure with three subplots
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(24, 6))

# First subplot: Individual parameter differences
param_names = ['k_lin_1', 'k_lin_2', 'k_duff_1', 'k_duff_2', 'c_lin', 'c_optomech']
for param_idx in range(n_params):
    ax1.loglog(dt_values, relative_differences[:, param_idx], 'o-', 
               label=param_names[param_idx])

ax1.set_xlabel('dt')
ax1.set_ylabel('Relative Difference')
ax1.set_title('Individual Parameter Relative Differences')
ax1.grid(True)
ax1.legend()

# Second subplot: Total gradient difference
ax2.loglog(dt_values, total_relative_differences, 'o-', color='black', label='Total gradient')
ax2.set_xlabel('dt')
ax2.set_ylabel('Total Relative Difference')
ax2.set_title('Total Gradient Relative Difference (L2 norm)')
ax2.grid(True)
ax2.legend()

# Third subplot: Normalized gradient difference
ax3.loglog(dt_values, normalized_differences, 'o-', color='red', label='Normalized gradient')
ax3.set_xlabel('dt')
ax3.set_ylabel('L2 Distance')
ax3.set_title('Normalized Gradient Difference')
ax3.grid(True)
ax3.legend()

plt.tight_layout()
plt.show()

# Print the minimum relative differences
print("\nIndividual parameter minimum differences:")
for param_idx in range(n_params):
    min_idx = jnp.argmin(relative_differences[:, param_idx])
    print(f"\n{param_names[param_idx]}:")
    print(f"Minimum relative difference: {relative_differences[min_idx, param_idx]:.2e}")
    print(f"Optimal dt: {dt_values[min_idx]:.2e}")

print("\nTotal gradient minimum difference:")
min_total_idx = jnp.argmin(total_relative_differences)
print(f"Minimum total relative difference: {total_relative_differences[min_total_idx]:.2e}")
print(f"Optimal dt: {dt_values[min_total_idx]:.2e}")

print("\nNormalized gradient minimum difference:")
min_norm_idx = jnp.argmin(normalized_differences)
print(f"Minimum normalized difference: {normalized_differences[min_norm_idx]:.2e}")
print(f"Optimal dt: {dt_values[min_norm_idx]:.2e}")
# Out:
# Individual parameter minimum differences:
#
# k_lin_1:
# Minimum relative difference: 1.19e-02
# Optimal dt: 1.37e-07
#
# k_lin_2:
# Minimum relative difference: 4.73e-03
# Optimal dt: 6.72e-09
#
# k_duff_1:
# Minimum relative difference: 5.98e-02
# Optimal dt: 5.30e-03
#
# k_duff_2:
# Minimum relative difference: 5.70e-02
# Optimal dt: 5.30e-03
#
# c_lin:
# Minimum relative difference: 3.55e-02
# Optimal dt: 2.40e-02
#
# c_optomech:
# Minimum relative difference: 1.30e-02
# Optimal dt: 1.17e-03
#
# Total gradient minimum difference:
# Minimum total relative difference: 6.21e-02
# Optimal dt: 2.40e-02
#
# Normalized gradient minimum difference:
# Minimum normalized difference: 1.79e-03
# Optimal dt: 5.74e-05

# %%
# Define optimization parameters
learning_rate = 0.01
n_epochs = 20000
batch_size = 128

# Initialize optimizer
optimizer = optax.adam(learning_rate=learning_rate)
opt_state = optimizer.init(flattened_args_initial)


@partial(jax.jit, static_argnums=(3,))
def training_step(params, opt_state, samples, n_samples, key):
    """Single training step using CD-1"""
    # Get gradient of parameters
    key, subkey = jr.split(key)
    dparams_CD1 = -CD1_gradient(energy_fn, samples, params, dt=2.59e-9, D=1, key=subkey, num_noise_samples=0)
    dparams_sm = grad_loss(score_matching_loss, params)
    
    # Compute relative difference between raw gradients
    rel_diff = jnp.linalg.norm(dparams_CD1 - dparams_sm) / jnp.linalg.norm(dparams_sm)
    
    # Compute relative difference between normalized gradients
    norm_dparams = dparams_CD1 / jnp.linalg.norm(dparams_CD1)
    norm_dparams_sm = dparams_sm / jnp.linalg.norm(dparams_sm)
    rel_diff_norm = jnp.linalg.norm(norm_dparams - norm_dparams_sm)
    
    # Store norms of both gradients
    sm_grad_norm = jnp.linalg.norm(dparams_sm)
    cd1_grad_norm = jnp.linalg.norm(dparams_CD1)
    
    # Compute log likelihood (negative energy)
    loss = score_matching_loss(params)
    
    # Apply updates
    updates, opt_state = optimizer.update(dparams_sm, opt_state)
    params = optax.apply_updates(params, updates)
    
    return params, opt_state, key, loss, rel_diff, rel_diff_norm, sm_grad_norm, cd1_grad_norm

# Training loop
key = jr.PRNGKey(0)
params_history = []
loss_history = []
gradient_diff_history = []  # Raw gradient differences
gradient_diff_norm_history = []  # Normalized gradient differences
sm_grad_norm_history = []  # Score matching gradient norm history
cd1_grad_norm_history = []  # CD1 gradient norm history

params = flattened_args_initial

for epoch in range(n_epochs):
    key, subkey = jr.split(key)
    params, opt_state, key, loss, rel_diff, rel_diff_norm, sm_grad_norm, cd1_grad_norm = training_step(
        params, opt_state, samples, batch_size, subkey)
    
    # Store parameters, loss, and gradient information
    params_history.append(params)
    loss_history.append(loss)
    gradient_diff_history.append(rel_diff)
    gradient_diff_norm_history.append(rel_diff_norm)
    sm_grad_norm_history.append(sm_grad_norm)
    cd1_grad_norm_history.append(cd1_grad_norm)
    
    if epoch % 10 == 0:
        k_lin, k_duffing, c_lin, c_optomech = unflatten(params)
        print(f"Epoch {epoch}")
        print(f"k_lin:\n{k_lin}")
        print(f"k_duffing:\n{k_duffing}")
        print(f"c_lin:\n{c_lin}")
        print(f"c_optomech:\n{c_optomech}")
        print(f"Loss: {loss:.4f}")
        print(f"Raw gradient relative difference: {rel_diff:.4e}")
        print(f"Normalized gradient relative difference: {rel_diff_norm:.4e}")
        print(f"Score matching gradient norm: {sm_grad_norm:.4e}")
        print(f"CD1 gradient norm: {cd1_grad_norm:.4e}")
        print("---")
# Out:
# Epoch 0
# k_lin:
# [-10.01 -10.01]
# k_duffing:
# [9.99 9.99]
# c_lin:
# [0.99]
# c_optomech:
# [-0.01]
# Loss: 1686738626.6501
# Raw gradient relative difference: 1.2223e-05
# Normalized gradient relative difference: 1.9912e-06
# Score matching gradient norm: 2.4056e+08
# CD1 gradient norm: 2.4056e+08
# ---
# Epoch 10
# k_lin:
# [-10.10995661 -10.10995667]
# k_duffing:
# [9.89004318 9.89004317]
# c_lin:
# [0.89004335]
# c_optomech:
# [-0.10990518]
# Loss: 1652877591.3535
# Raw gradient relative difference: 1.2065e-05
# Normalized gradient relative difference: 1.9747e-06
# Score matching gradient norm: 2.3814e+08
# CD1 gradient norm: 2.3813e+08
# ---
# Epoch 20
# k_lin:
# [-10.20972039 -10.20972078]
# k_duffing:
# [9.79027825 9.79027818]
# c_lin:
# [0.79027937]
# c_optomech:
# [-0.20938629]
# Loss: 1619419580.0708
# Raw gradient relative difference: 1.1907e-05
# Normalized gradient relative difference: 1.9584e-06
# Score matching gradient norm: 2.3571e+08
# CD1 gradient norm: 2.3571e+08
# ---
# Epoch 30
# k_lin:
# [-10.30915768 -10.30915886]
# k_duffing:
# [9.69083821 9.69083798]
# c_lin:
# [0.69084159]
# c_optomech:
# [-0.30814343]
# Loss: 1586408123.3494
# Raw gradient relative difference: 1.1749e-05
# Normalized gradient relative difference: 1.9421e-06
# Score matching gradient norm: 2.3330e+08
# CD1 gradient norm: 2.3330e+08
# ---
# Epoch 40
# k_lin:
# [-10.40817888 -10.40818145]
# k_duffing:
# [9.5918122 9.5918117]
# c_lin:
# [0.59181955]
# c_optomech:
# [-0.40596969]
# Loss: 1553870582.8897
# Raw gradient relative difference: 1.1592e-05
# Normalized gradient relative difference: 1.9259e-06
# Score matching gradient norm: 2.3089e+08
# CD1 gradient norm: 2.3089e+08
# ---
# Epoch 50
# k_lin:
# [-10.50673199 -10.5067366 ]
# k_duffing:
# [9.49325194 9.49325105]
# c_lin:
# [0.49326522]
# c_optomech:
# [-0.5027391]
# Loss: 1521820568.6491
# Raw gradient relative difference: 1.1434e-05
# Normalized gradient relative difference: 1.9099e-06
# Score matching gradient norm: 2.2850e+08
# CD1 gradient norm: 2.2850e+08
# ---
# Epoch 60
# k_lin:
# [-10.60478982 -10.60479719]
# k_duffing:
# [9.39518446 9.39518302]
# c_lin:
# [0.39520578]
# c_optomech:
# [-0.5983797]
# Loss: 1490262635.8827
# Raw gradient relative difference: 1.1278e-05
# Normalized gradient relative difference: 1.8939e-06
# Score matching gradient norm: 2.2612e+08
# CD1 gradient norm: 2.2611e+08
# ---
# Epoch 70
# k_lin:
# [-10.70233902 -10.70234989]
# k_duffing:
# [9.29762301 9.29762088]
# c_lin:
# [0.2976546]
# c_optomech:
# [-0.6928499]
# Loss: 1459196315.1981
# Raw gradient relative difference: 1.1121e-05
# Normalized gradient relative difference: 1.8781e-06
# Score matching gradient norm: 2.2375e+08
# CD1 gradient norm: 2.2375e+08
# ---
# Epoch 80
# k_lin:
# [-10.79937311 -10.79938822]
# k_duffing:
# [9.20057402 9.20057103]
# c_lin:
# [0.20061816]
# c_optomech:
# [-0.78612326]
# Loss: 1428618658.6141
# Raw gradient relative difference: 1.0965e-05
# Normalized gradient relative difference: 1.8624e-06
# Score matching gradient norm: 2.2139e+08
# CD1 gradient norm: 2.2139e+08
# ---
# Epoch 90
# k_lin:
# [-10.89588877 -10.89590888]
# k_duffing:
# [9.10404075 9.10403673]
# c_lin:
# [0.10409982]
# c_optomech:
# [-0.87818025]
# Loss: 1398525594.4794
# Raw gradient relative difference: 1.0810e-05
# Normalized gradient relative difference: 1.8469e-06
# Score matching gradient norm: 2.1905e+08
# CD1 gradient norm: 2.1904e+08
# ---
# Epoch 100
# k_lin:
# [-10.99188406 -10.99190991]
# k_duffing:
# [9.00802512 9.00801991]
# c_lin:
# [0.00810156]
# c_optomech:
# [-0.96900433]
# Loss: 1368912575.2755
# Raw gradient relative difference: 1.0655e-05
# Normalized gradient relative difference: 1.8314e-06
# Score matching gradient norm: 2.1671e+08
# CD1 gradient norm: 2.1671e+08
# ---
# Epoch 110
# k_lin:
# [-11.08735758 -11.08738995]
# k_duffing:
# [8.91252847 8.91252188]
# c_lin:
# [-0.08737523]
# c_optomech:
# [-1.05858011]
# Loss: 1339774866.1615
# Raw gradient relative difference: 1.0500e-05
# Normalized gradient relative difference: 1.8162e-06
# Score matching gradient norm: 2.1439e+08
# CD1 gradient norm: 2.1439e+08
# ---
# Epoch 120
# k_lin:
# [-11.18230819 -11.18234785]
# k_duffing:
# [8.81755193 8.81754377]
# c_lin:
# [-0.18232935]
# c_optomech:
# [-1.14689264]
# Loss: 1311107667.2847
# Raw gradient relative difference: 1.0346e-05
# Normalized gradient relative difference: 1.8010e-06
# Score matching gradient norm: 2.1209e+08
# CD1 gradient norm: 2.1209e+08
# ---
# Epoch 130
# k_lin:
# [-11.27673481 -11.27678253]
# k_duffing:
# [8.72309652 8.7230866 ]
# c_lin:
# [-0.2767597]
# c_optomech:
# [-1.23392703]
# Loss: 1282906163.7196
# Raw gradient relative difference: 1.0192e-05
# Normalized gradient relative difference: 1.7859e-06
# Score matching gradient norm: 2.0979e+08
# CD1 gradient norm: 2.0979e+08
# ---
# Epoch 140
# k_lin:
# [-11.3706364  -11.37069295]
# k_duffing:
# [8.62916325 8.62915137]
# c_lin:
# [-0.37066521]
# c_optomech:
# [-1.31966839]
# Loss: 1255165545.2194
# Raw gradient relative difference: 1.0038e-05
# Normalized gradient relative difference: 1.7710e-06
# Score matching gradient norm: 2.0751e+08
# CD1 gradient norm: 2.0751e+08
# ---
# Epoch 150
# k_lin:
# [-11.46401193 -11.4640781 ]
# k_duffing:
# [8.53575312 8.53573907]
# c_lin:
# [-0.4640448]
# c_optomech:
# [-1.40410179]
# Loss: 1227881013.7791
# Raw gradient relative difference: 9.8852e-06
# Normalized gradient relative difference: 1.7563e-06
# Score matching gradient norm: 2.0524e+08
# CD1 gradient norm: 2.0524e+08
# ---
# Epoch 160
# k_lin:
# [-11.55686036 -11.55693693]
# k_duffing:
# [8.44286712 8.44285069]
# c_lin:
# [-0.55689741]
# c_optomech:
# [-1.48721222]
# Loss: 1201047786.4157
# Raw gradient relative difference: 9.7324e-06
# Normalized gradient relative difference: 1.7416e-06
# Score matching gradient norm: 2.0299e+08
# CD1 gradient norm: 2.0299e+08
# ---
# Epoch 170
# k_lin:
# [-11.64918065 -11.64926841]
# k_duffing:
# [8.35050626 8.35048722]
# c_lin:
# [-0.64922196]
# c_optomech:
# [-1.56898465]
# Loss: 1174661096.1285
# Raw gradient relative difference: 9.5801e-06
# Normalized gradient relative difference: 1.7271e-06
# Score matching gradient norm: 2.0075e+08
# CD1 gradient norm: 2.0074e+08
# ---
# Epoch 180
# k_lin:
# [-11.74097178 -11.74107152]
# k_duffing:
# [8.25867153 8.25864965]
# c_lin:
# [-0.74101737]
# c_optomech:
# [-1.64940401]
# Loss: 1148716192.1931
# Raw gradient relative difference: 9.4281e-06
# Normalized gradient relative difference: 1.7128e-06
# Score matching gradient norm: 1.9851e+08
# CD1 gradient norm: 1.9851e+08
# ---
# Epoch 190
# k_lin:
# [-11.83223268 -11.83234519]
# k_duffing:
# [8.16736394 8.16733899]
# c_lin:
# [-0.83228256]
# c_optomech:
# [-1.72845523]
# Loss: 1123208340.2304
# Raw gradient relative difference: 9.2765e-06
# Normalized gradient relative difference: 1.6985e-06
# Score matching gradient norm: 1.9630e+08
# CD1 gradient norm: 1.9630e+08
# ---
# Epoch 200
# k_lin:
# [-11.92296233 -11.92308841]
# k_duffing:
# [8.0765845  8.07655622]
# c_lin:
# [-0.92301645]
# c_optomech:
# [-1.80612325]
# Loss: 1098132822.2136
# Raw gradient relative difference: 9.1253e-06
# Normalized gradient relative difference: 1.6845e-06
# Score matching gradient norm: 1.9409e+08
# CD1 gradient norm: 1.9409e+08
# ---
# Epoch 210
# k_lin:
# [-12.01315967 -12.01330012]
# k_duffing:
# [7.9863342  7.98630235]
# c_lin:
# [-1.01321793]
# c_optomech:
# [-1.88239303]
# Loss: 1073484936.4685
# Raw gradient relative difference: 8.9744e-06
# Normalized gradient relative difference: 1.6705e-06
# Score matching gradient norm: 1.9190e+08
# CD1 gradient norm: 1.9190e+08
# ---
# Epoch 220
# k_lin:
# [-12.10282365 -12.10297927]
# k_duffing:
# [7.89661407 7.89657837]
# c_lin:
# [-1.10288592]
# c_optomech:
# [-1.9572496]
# Loss: 1049259997.6865
# Raw gradient relative difference: 8.8239e-06
# Normalized gradient relative difference: 1.6567e-06
# Score matching gradient norm: 1.8972e+08
# CD1 gradient norm: 1.8972e+08
# ---
# Epoch 230
# k_lin:
# [-12.19195324 -12.19212483]
# k_duffing:
# [7.80742509 7.80738528]
# c_lin:
# [-1.19201933]
# c_optomech:
# [-2.03067807]
# Loss: 1025453336.9543
# Raw gradient relative difference: 8.6737e-06
# Normalized gradient relative difference: 1.6431e-06
# Score matching gradient norm: 1.8756e+08
# CD1 gradient norm: 1.8755e+08
# ---
# Epoch 240
# k_lin:
# [-12.28054739 -12.28073575]
# k_duffing:
# [7.71876829 7.71872408]
# c_lin:
# [-1.28061706]
# c_optomech:
# [-2.10266364]
# Loss: 1002060301.7995
# Raw gradient relative difference: 8.5239e-06
# Normalized gradient relative difference: 1.6295e-06
# Score matching gradient norm: 1.8540e+08
# CD1 gradient norm: 1.8540e+08
# ---
# Epoch 250
# k_lin:
# [-12.36860504 -12.36881098]
# k_duffing:
# [7.63064465 7.63059575]
# c_lin:
# [-1.368678]
# c_optomech:
# [-2.17319166]
# Loss: 979076256.2524
# Raw gradient relative difference: 8.3744e-06
# Normalized gradient relative difference: 1.6162e-06
# Score matching gradient norm: 1.8326e+08
# CD1 gradient norm: 1.8326e+08
# ---
# Epoch 260
# k_lin:
# [-12.45612516 -12.45634949]
# k_duffing:
# [7.54305519 7.5430013 ]
# c_lin:
# [-1.45620107]
# c_optomech:
# [-2.24224763]
# Loss: 956496580.9198
# Raw gradient relative difference: 8.2252e-06
# Normalized gradient relative difference: 1.6029e-06
# Score matching gradient norm: 1.8114e+08
# CD1 gradient norm: 1.8114e+08
# ---
# Epoch 270
# k_lin:
# [-12.54310671 -12.54335024]
# k_duffing:
# [7.4560009  7.45594171]
# c_lin:
# [-1.54318516]
# c_optomech:
# [-2.30981722]
# Loss: 934316673.0726
# Raw gradient relative difference: 8.0763e-06
# Normalized gradient relative difference: 1.5899e-06
# Score matching gradient norm: 1.7902e+08
# CD1 gradient norm: 1.7902e+08
# ---
# Epoch 280
# k_lin:
# [-12.62954865 -12.62981218]
# k_duffing:
# [7.36948278 7.36941797]
# c_lin:
# [-1.62962918]
# c_optomech:
# [-2.37588635]
# Loss: 912531946.7438
# Raw gradient relative difference: 7.9278e-06
# Normalized gradient relative difference: 1.5769e-06
# Score matching gradient norm: 1.7692e+08
# CD1 gradient norm: 1.7692e+08
# ---
# Epoch 290
# k_lin:
# [-12.71544995 -12.71573429]
# k_duffing:
# [7.28350181 7.28343106]
# c_lin:
# [-1.71553204]
# c_optomech:
# [-2.44044115]
# Loss: 891137832.8374
# Raw gradient relative difference: 7.7796e-06
# Normalized gradient relative difference: 1.5641e-06
# Score matching gradient norm: 1.7483e+08
# CD1 gradient norm: 1.7483e+08
# ---
# Epoch 300
# k_lin:
# [-12.80080957 -12.80111553]
# k_duffing:
# [7.198059   7.19798195]
# c_lin:
# [-1.80089263]
# c_optomech:
# [-2.50346805]
# Loss: 870129779.2470
# Raw gradient relative difference: 7.6317e-06
# Normalized gradient relative difference: 1.5515e-06
# Score matching gradient norm: 1.7276e+08
# CD1 gradient norm: 1.7276e+08
# ---
# Epoch 310
# k_lin:
# [-12.88562649 -12.88595487]
# k_duffing:
# [7.11315531 7.11307162]
# c_lin:
# [-1.88570988]
# c_optomech:
# [-2.5649538]
# Loss: 849503250.9839
# Raw gradient relative difference: 7.4840e-06
# Normalized gradient relative difference: 1.5390e-06
# Score matching gradient norm: 1.7070e+08
# CD1 gradient norm: 1.7070e+08
# ---
# Epoch 320
# k_lin:
# [-12.96989969 -12.9702513 ]
# k_duffing:
# [7.02879172 7.02870103]
# c_lin:
# [-1.96998269]
# c_optomech:
# [-2.62488548]
# Loss: 829253730.3145
# Raw gradient relative difference: 7.3367e-06
# Normalized gradient relative difference: 1.5267e-06
# Score matching gradient norm: 1.6865e+08
# CD1 gradient norm: 1.6865e+08
# ---
# Epoch 330
# k_lin:
# [-13.05362816 -13.05400381]
# k_duffing:
# [6.94496921 6.94487114]
# c_lin:
# [-2.05370997]
# c_optomech:
# [-2.68325055]
# Loss: 809376716.9057
# Raw gradient relative difference: 7.1896e-06
# Normalized gradient relative difference: 1.5146e-06
# Score matching gradient norm: 1.6661e+08
# CD1 gradient norm: 1.6661e+08
# ---
# Epoch 340
# k_lin:
# [-13.13681089 -13.13721137]
# k_duffing:
# [6.86168874 6.86158291]
# c_lin:
# [-2.13689065]
# c_optomech:
# [-2.74003691]
# Loss: 789867727.9795
# Raw gradient relative difference: 7.0429e-06
# Normalized gradient relative difference: 1.5026e-06
# Score matching gradient norm: 1.6459e+08
# CD1 gradient norm: 1.6459e+08
# ---
# Epoch 350
# k_lin:
# [-13.21944687 -13.21987299]
# k_duffing:
# [6.77895126 6.77883727]
# c_lin:
# [-2.21952366]
# c_optomech:
# [-2.79523289]
# Loss: 770722298.4750
# Raw gradient relative difference: 6.8963e-06
# Normalized gradient relative difference: 1.4907e-06
# Score matching gradient norm: 1.6258e+08
# CD1 gradient norm: 1.6258e+08
# ---
# Epoch 360
# k_lin:
# [-13.30153512 -13.30198768]
# k_duffing:
# [6.69675773 6.69663517]
# c_lin:
# [-2.30160792]
# c_optomech:
# [-2.84882732]
# Loss: 751935981.2195
# Raw gradient relative difference: 6.7501e-06
# Normalized gradient relative difference: 1.4790e-06
# Score matching gradient norm: 1.6059e+08
# CD1 gradient norm: 1.6059e+08
# ---
# Epoch 370
# k_lin:
# [-13.38307465 -13.38355444]
# k_duffing:
# [6.61510907 6.61497753]
# c_lin:
# [-2.38314236]
# c_optomech:
# [-2.90080958]
# Loss: 733504347.1056
# Raw gradient relative difference: 6.6041e-06
# Normalized gradient relative difference: 1.4675e-06
# Score matching gradient norm: 1.5861e+08
# CD1 gradient norm: 1.5860e+08
# ---
# Epoch 380
# k_lin:
# [-13.46406449 -13.4645723 ]
# k_duffing:
# [6.53400622 6.53386526]
# c_lin:
# [-2.46412594]
# c_optomech:
# [-2.95116959]
# Loss: 715422985.2781
# Raw gradient relative difference: 6.4583e-06
# Normalized gradient relative difference: 1.4561e-06
# Score matching gradient norm: 1.5664e+08
# CD1 gradient norm: 1.5664e+08
# ---
# Epoch 390
# k_lin:
# [-13.54450367 -13.54504029]
# k_duffing:
# [6.4534501  6.45329928]
# c_lin:
# [-2.5445576]
# c_optomech:
# [-2.99989791]
# Loss: 697687503.3261
# Raw gradient relative difference: 6.3128e-06
# Normalized gradient relative difference: 1.4449e-06
# Score matching gradient norm: 1.5468e+08
# CD1 gradient norm: 1.5468e+08
# ---
# Epoch 400
# k_lin:
# [-13.62439124 -13.62495745]
# k_duffing:
# [6.37344161 6.37328047]
# c_lin:
# [-2.62443631]
# c_optomech:
# [-3.04698572]
# Loss: 680293527.4839
# Raw gradient relative difference: 6.1675e-06
# Normalized gradient relative difference: 1.4339e-06
# Score matching gradient norm: 1.5274e+08
# CD1 gradient norm: 1.5274e+08
# ---
# Epoch 410
# k_lin:
# [-13.70372626 -13.70432283]
# k_duffing:
# [6.29398165 6.29380973]
# c_lin:
# [-2.70376102]
# c_optomech:
# [-3.09242492]
# Loss: 663236702.8381
# Raw gradient relative difference: 6.0225e-06
# Normalized gradient relative difference: 1.4230e-06
# Score matching gradient norm: 1.5081e+08
# CD1 gradient norm: 1.5081e+08
# ---
# Epoch 420
# k_lin:
# [-13.78250779 -13.7831355 ]
# k_duffing:
# [6.21507111 6.21488792]
# c_lin:
# [-2.78253072]
# c_optomech:
# [-3.13620812]
# Loss: 646512693.5417
# Raw gradient relative difference: 5.8777e-06
# Normalized gradient relative difference: 1.4124e-06
# Score matching gradient norm: 1.4889e+08
# CD1 gradient norm: 1.4889e+08
# ---
# Epoch 430
# k_lin:
# [-13.86073491 -13.86139453]
# k_duffing:
# [6.13671085 6.1365159 ]
# c_lin:
# [-2.86074438]
# c_optomech:
# [-3.1783287]
# Loss: 630117183.0349
# Raw gradient relative difference: 5.7331e-06
# Normalized gradient relative difference: 1.4018e-06
# Score matching gradient norm: 1.4699e+08
# CD1 gradient norm: 1.4699e+08
# ---
# Epoch 440
# k_lin:
# [-13.93840673 -13.93909901]
# k_duffing:
# [6.05890174 6.05869451]
# c_lin:
# [-2.93840102]
# c_optomech:
# [-3.21878085]
# Loss: 614045874.2720
# Raw gradient relative difference: 5.5887e-06
# Normalized gradient relative difference: 1.3915e-06
# Score matching gradient norm: 1.4510e+08
# CD1 gradient norm: 1.4510e+08
# ---
# Epoch 450
# k_lin:
# [-14.01552234 -14.01624804]
# k_duffing:
# [5.98164461 5.98142459]
# c_lin:
# [-3.01549964]
# c_optomech:
# [-3.25755962]
# Loss: 598294489.9546
# Raw gradient relative difference: 5.4446e-06
# Normalized gradient relative difference: 1.3813e-06
# Score matching gradient norm: 1.4323e+08
# CD1 gradient norm: 1.4323e+08
# ---
# Epoch 460
# k_lin:
# [-14.09208088 -14.09284075]
# k_duffing:
# [5.9049403  5.90470695]
# c_lin:
# [-3.09203926]
# c_optomech:
# [-3.29466092]
# Loss: 582858772.7706
# Raw gradient relative difference: 5.3006e-06
# Normalized gradient relative difference: 1.3714e-06
# Score matching gradient norm: 1.4137e+08
# CD1 gradient norm: 1.4136e+08
# ---
# Epoch 470
# k_lin:
# [-14.16808148 -14.16887625]
# k_duffing:
# [5.82878961 5.82854238]
# c_lin:
# [-3.16801891]
# c_optomech:
# [-3.3300816]
# Loss: 567734485.6392
# Raw gradient relative difference: 5.1569e-06
# Normalized gradient relative difference: 1.3615e-06
# Score matching gradient norm: 1.3952e+08
# CD1 gradient norm: 1.3952e+08
# ---
# Epoch 480
# k_lin:
# [-14.24352331 -14.24435371]
# k_duffing:
# [5.75319333 5.75293167]
# c_lin:
# [-3.24343765]
# c_optomech:
# [-3.36381946]
# Loss: 552917411.9607
# Raw gradient relative difference: 5.0133e-06
# Normalized gradient relative difference: 1.3519e-06
# Score matching gradient norm: 1.3768e+08
# CD1 gradient norm: 1.3768e+08
# ---
# Epoch 490
# k_lin:
# [-14.31840552 -14.31927228]
# k_duffing:
# [5.67815226 5.67787558]
# c_lin:
# [-3.31829454]
# c_optomech:
# [-3.39587328]
# Loss: 538403355.8717
# Raw gradient relative difference: 4.8700e-06
# Normalized gradient relative difference: 1.3425e-06
# Score matching gradient norm: 1.3586e+08
# CD1 gradient norm: 1.3586e+08
# ---
# Epoch 500
# k_lin:
# [-14.39272732 -14.39363114]
# k_duffing:
# [5.60366714 5.60337485]
# c_lin:
# [-3.39258865]
# c_optomech:
# [-3.42624287]
# Loss: 524188142.5051
# Raw gradient relative difference: 4.7269e-06
# Normalized gradient relative difference: 1.3332e-06
# Score matching gradient norm: 1.3405e+08
# CD1 gradient norm: 1.3405e+08
# ---
# Epoch 510
# k_lin:
# [-14.46648792 -14.4674295 ]
# k_duffing:
# [5.52973871 5.52943022]
# c_lin:
# [-3.46631908]
# c_optomech:
# [-3.45492911]
# Loss: 510267618.2547
# Raw gradient relative difference: 4.5840e-06
# Normalized gradient relative difference: 1.3242e-06
# Score matching gradient norm: 1.3226e+08
# CD1 gradient norm: 1.3226e+08
# ---
# Epoch 520
# k_lin:
# [-14.53968655 -14.54066658]
# k_duffing:
# [5.45636769 5.45604238]
# c_lin:
# [-3.53948495]
# c_optomech:
# [-3.48193392]
# Loss: 496637651.0436
# Raw gradient relative difference: 4.4414e-06
# Normalized gradient relative difference: 1.3153e-06
# Score matching gradient norm: 1.3048e+08
# CD1 gradient norm: 1.3048e+08
# ---
# Epoch 530
# k_lin:
# [-14.61232245 -14.61334161]
# k_duffing:
# [5.38355479 5.38321202]
# c_lin:
# [-3.61208539]
# c_optomech:
# [-3.50726036]
# Loss: 483294130.5970
# Raw gradient relative difference: 4.2990e-06
# Normalized gradient relative difference: 1.3066e-06
# Score matching gradient norm: 1.2871e+08
# CD1 gradient norm: 1.2871e+08
# ---
# Epoch 540
# k_lin:
# [-14.68439489 -14.68545385]
# k_duffing:
# [5.31130068 5.31093981]
# c_lin:
# [-3.68411954]
# c_optomech:
# [-3.53091261]
# Loss: 470232968.7185
# Raw gradient relative difference: 4.1568e-06
# Normalized gradient relative difference: 1.2981e-06
# Score matching gradient norm: 1.2696e+08
# CD1 gradient norm: 1.2696e+08
# ---
# Epoch 550
# k_lin:
# [-14.75590318 -14.7570026 ]
# k_duffing:
# [5.23960602 5.23922638]
# c_lin:
# [-3.75558657]
# c_optomech:
# [-3.55289599]
# Loss: 457450099.5690
# Raw gradient relative difference: 4.0149e-06
# Normalized gradient relative difference: 1.2899e-06
# Score matching gradient norm: 1.2522e+08
# CD1 gradient norm: 1.2522e+08
# ---
# Epoch 560
# k_lin:
# [-14.82684663 -14.82798714]
# k_duffing:
# [5.16847143 5.16807235]
# c_lin:
# [-3.82648568]
# c_optomech:
# [-3.57321699]
# Loss: 444941479.9497
# Raw gradient relative difference: 3.8733e-06
# Normalized gradient relative difference: 1.2818e-06
# Score matching gradient norm: 1.2349e+08
# CD1 gradient norm: 1.2349e+08
# ---
# Epoch 570
# k_lin:
# [-14.89722458 -14.89840681]
# k_duffing:
# [5.09789752 5.09747832]
# c_lin:
# [-3.89681608]
# c_optomech:
# [-3.59188328]
# Loss: 432703089.5867
# Raw gradient relative difference: 3.7321e-06
# Normalized gradient relative difference: 1.2739e-06
# Score matching gradient norm: 1.2178e+08
# CD1 gradient norm: 1.2178e+08
# ---
# Epoch 580
# k_lin:
# [-14.9670364  -14.96826095]
# k_duffing:
# [5.02788488 5.02744485]
# c_lin:
# [-3.96657699]
# c_optomech:
# [-3.60890374]
# Loss: 420730931.4180
# Raw gradient relative difference: 3.5912e-06
# Normalized gradient relative difference: 1.2662e-06
# Score matching gradient norm: 1.2008e+08
# CD1 gradient norm: 1.2008e+08
# ---
# Epoch 590
# k_lin:
# [-15.03628147 -15.03754896]
# k_duffing:
# [4.95843407 4.95797249]
# c_lin:
# [-4.03576768]
# c_optomech:
# [-3.62428841]
# Loss: 409021031.8835
# Raw gradient relative difference: 3.4507e-06
# Normalized gradient relative difference: 1.2588e-06
# Score matching gradient norm: 1.1839e+08
# CD1 gradient norm: 1.1839e+08
# ---
# Epoch 600
# k_lin:
# [-15.10495922 -15.10627022]
# k_duffing:
# [4.8895456  4.88906175]
# c_lin:
# [-4.10438744]
# c_optomech:
# [-3.63804856]
# Loss: 397569441.2150
# Raw gradient relative difference: 3.3107e-06
# Normalized gradient relative difference: 1.2515e-06
# Score matching gradient norm: 1.1672e+08
# CD1 gradient norm: 1.1672e+08
# ---
# Epoch 610
# k_lin:
# [-15.17306908 -15.17442416]
# k_duffing:
# [4.82122    4.82071313]
# c_lin:
# [-4.17243555]
# c_optomech:
# [-3.65019667]
# Loss: 386372233.7289
# Raw gradient relative difference: 3.1713e-06
# Normalized gradient relative difference: 1.2445e-06
# Score matching gradient norm: 1.1506e+08
# CD1 gradient norm: 1.1506e+08
# ---
# Epoch 620
# k_lin:
# [-15.24061054 -15.24201025]
# k_duffing:
# [4.75345772 4.75292707]
# c_lin:
# [-4.23991137]
# c_optomech:
# [-3.66074639]
# Loss: 375425508.1195
# Raw gradient relative difference: 3.0324e-06
# Normalized gradient relative difference: 1.2377e-06
# Score matching gradient norm: 1.1342e+08
# CD1 gradient norm: 1.1342e+08
# ---
# Epoch 630
# k_lin:
# [-15.30758309 -15.30902797]
# k_duffing:
# [4.68625922 4.68570402]
# c_lin:
# [-4.30681425]
# c_optomech:
# [-3.66971258]
# Loss: 364725387.7524
# Raw gradient relative difference: 2.8944e-06
# Normalized gradient relative difference: 1.2311e-06
# Score matching gradient norm: 1.1179e+08
# CD1 gradient norm: 1.1179e+08
# ---
# Epoch 640
# k_lin:
# [-15.37398626 -15.37547682]
# k_duffing:
# [4.6196249  4.61904437]
# c_lin:
# [-4.37314358]
# c_optomech:
# [-3.67711128]
# Loss: 354268020.9595
# Raw gradient relative difference: 2.7573e-06
# Normalized gradient relative difference: 1.2247e-06
# Score matching gradient norm: 1.1017e+08
# CD1 gradient norm: 1.1017e+08
# ---
# Epoch 650
# k_lin:
# [-15.43981963 -15.44135637]
# k_duffing:
# [4.55355516 4.5529485 ]
# c_lin:
# [-4.43889877]
# c_optomech:
# [-3.6829597]
# Loss: 344049581.3336
# Raw gradient relative difference: 2.6213e-06
# Normalized gradient relative difference: 1.2186e-06
# Score matching gradient norm: 1.0857e+08
# CD1 gradient norm: 1.0857e+08
# ---
# Epoch 660
# k_lin:
# [-15.50508277 -15.50666617]
# k_duffing:
# [4.48805034 4.48741674]
# c_lin:
# [-4.50407928]
# c_optomech:
# [-3.68727618]
# Loss: 334066268.0223
# Raw gradient relative difference: 2.4865e-06
# Normalized gradient relative difference: 1.2126e-06
# Score matching gradient norm: 1.0698e+08
# CD1 gradient norm: 1.0698e+08
# ---
# Epoch 670
# k_lin:
# [-15.56977533 -15.57140585]
# k_duffing:
# [4.42311077 4.4224494 ]
# c_lin:
# [-4.56868459]
# c_optomech:
# [-3.6900802]
# Loss: 324314306.0227
# Raw gradient relative difference: 2.3534e-06
# Normalized gradient relative difference: 1.2070e-06
# Score matching gradient norm: 1.0541e+08
# CD1 gradient norm: 1.0540e+08
# ---
# Epoch 680
# k_lin:
# [-15.63389696 -15.63557503]
# k_duffing:
# [4.35873672 4.35804674]
# c_lin:
# [-4.6327142]
# c_optomech:
# [-3.69139234]
# Loss: 314789946.4747
# Raw gradient relative difference: 2.2222e-06
# Normalized gradient relative difference: 1.2015e-06
# Score matching gradient norm: 1.0384e+08
# CD1 gradient norm: 1.0384e+08
# ---
# Epoch 690
# k_lin:
# [-15.69744736 -15.69917341]
# k_duffing:
# [4.29492845 4.29420902]
# c_lin:
# [-4.69616766]
# c_optomech:
# [-3.69123423]
# Loss: 305489466.9539
# Raw gradient relative difference: 2.0934e-06
# Normalized gradient relative difference: 1.1963e-06
# Score matching gradient norm: 1.0230e+08
# CD1 gradient norm: 1.0230e+08
# ---
# Epoch 700
# k_lin:
# [-15.76042626 -15.76220068]
# k_duffing:
# [4.23168616 4.23093642]
# c_lin:
# [-4.75904455]
# c_optomech:
# [-3.68962857]
# Loss: 296409171.7630
# Raw gradient relative difference: 1.9676e-06
# Normalized gradient relative difference: 1.1914e-06
# Score matching gradient norm: 1.0076e+08
# CD1 gradient norm: 1.0076e+08
# ---
# Epoch 710
# k_lin:
# [-15.82283343 -15.82465659]
# k_duffing:
# [4.16901005 4.16822912]
# c_lin:
# [-4.82134448]
# c_optomech:
# [-3.68659903]
# Loss: 287545392.2228
# Raw gradient relative difference: 1.8454e-06
# Normalized gradient relative difference: 1.1867e-06
# Score matching gradient norm: 9.9241e+07
# CD1 gradient norm: 9.9241e+07
# ---
# Epoch 720
# k_lin:
# [-15.88466866 -15.88654092]
# k_duffing:
# [4.10690024 4.10608724]
# c_lin:
# [-4.88306711]
# c_optomech:
# [-3.68217026]
# Loss: 278894486.9604
# Raw gradient relative difference: 1.7278e-06
# Normalized gradient relative difference: 1.1822e-06
# Score matching gradient norm: 9.7734e+07
# CD1 gradient norm: 9.7734e+07
# ---
# Epoch 730
# k_lin:
# [-15.94593181 -15.9478535 ]
# k_duffing:
# [4.04535685 4.04451088]
# c_lin:
# [-4.94421212]
# c_optomech:
# [-3.67636783]
# Loss: 270452842.1975
# Raw gradient relative difference: 1.6159e-06
# Normalized gradient relative difference: 1.1780e-06
# Score matching gradient norm: 9.6241e+07
# CD1 gradient norm: 9.6241e+07
# ---
# Epoch 740
# k_lin:
# [-16.00662276 -16.00859419]
# k_duffing:
# [3.98437992 3.98350009]
# c_lin:
# [-5.00477923]
# c_optomech:
# [-3.66921816]
# Loss: 262216872.0353
# Raw gradient relative difference: 1.5111e-06
# Normalized gradient relative difference: 1.1740e-06
# Score matching gradient norm: 9.4762e+07
# CD1 gradient norm: 9.4762e+07
# ---
# Epoch 750
# k_lin:
# [-16.06674143 -16.06876287]
# k_duffing:
# [3.92396949 3.92305487]
# c_lin:
# [-5.06476822]
# c_optomech:
# [-3.66074854]
# Loss: 254183018.7385
# Raw gradient relative difference: 1.4154e-06
# Normalized gradient relative difference: 1.1703e-06
# Score matching gradient norm: 9.3297e+07
# CD1 gradient norm: 9.3297e+07
# ---
# Epoch 760
# k_lin:
# [-16.12628777 -16.12835949]
# k_duffing:
# [3.86412554 3.86317521]
# c_lin:
# [-5.12417888]
# c_optomech:
# [-3.65098702]
# Loss: 246347753.0168
# Raw gradient relative difference: 1.3308e-06
# Normalized gradient relative difference: 1.1669e-06
# Score matching gradient norm: 9.1845e+07
# CD1 gradient norm: 9.1845e+07
# ---
# Epoch 770
# k_lin:
# [-16.18526181 -16.18738403]
# k_duffing:
# [3.804848   3.80386102]
# c_lin:
# [-5.18301106]
# c_optomech:
# [-3.63996237]
# Loss: 238707574.3038
# Raw gradient relative difference: 1.2600e-06
# Normalized gradient relative difference: 1.1638e-06
# Score matching gradient norm: 9.0407e+07
# CD1 gradient norm: 9.0407e+07
# ---
# Epoch 780
# k_lin:
# [-16.24366357 -16.24583652]
# k_duffing:
# [3.74613678 3.74511221]
# c_lin:
# [-5.24126465]
# c_optomech:
# [-3.62770407]
# Loss: 231259011.0345
# Raw gradient relative difference: 1.2056e-06
# Normalized gradient relative difference: 1.1609e-06
# Score matching gradient norm: 8.8983e+07
# CD1 gradient norm: 8.8983e+07
# ---
# Epoch 790
# k_lin:
# [-16.30149316 -16.30371701]
# k_duffing:
# [3.68799172 3.6869286 ]
# c_lin:
# [-5.29893958]
# c_optomech:
# [-3.61424218]
# Loss: 223998620.9189
# Raw gradient relative difference: 1.1702e-06
# Normalized gradient relative difference: 1.1583e-06
# Score matching gradient norm: 8.7573e+07
# CD1 gradient norm: 8.7573e+07
# ---
# Epoch 800
# k_lin:
# [-16.35875072 -16.36102562]
# k_duffing:
# [3.63041263 3.62931001]
# c_lin:
# [-5.35603583]
# c_optomech:
# [-3.59960738]
# Loss: 216922991.2137
# Raw gradient relative difference: 1.1560e-06
# Normalized gradient relative difference: 1.1560e-06
# Score matching gradient norm: 8.6176e+07
# CD1 gradient norm: 8.6176e+07
# ---
# Epoch 810
# k_lin:
# [-16.41543641 -16.41776249]
# k_duffing:
# [3.57339927 3.57225619]
# c_lin:
# [-5.41255342]
# c_optomech:
# [-3.58383083]
# Loss: 210028738.9912
# Raw gradient relative difference: 1.1643e-06
# Normalized gradient relative difference: 1.1540e-06
# Score matching gradient norm: 8.4794e+07
# CD1 gradient norm: 8.4794e+07
# ---
# Epoch 820
# k_lin:
# [-16.47155048 -16.47392784]
# k_duffing:
# [3.51695137 3.51576684]
# c_lin:
# [-5.46849241]
# c_optomech:
# [-3.56694417]
# Loss: 203312511.4048
# Raw gradient relative difference: 1.1949e-06
# Normalized gradient relative difference: 1.1523e-06
# Score matching gradient norm: 8.3425e+07
# CD1 gradient norm: 8.3425e+07
# ---
# Epoch 830
# k_lin:
# [-16.52709319 -16.5295219 ]
# k_duffing:
# [3.46106859 3.45984164]
# c_lin:
# [-5.52385293]
# c_optomech:
# [-3.54897943]
# Loss: 196770985.9514
# Raw gradient relative difference: 1.2466e-06
# Normalized gradient relative difference: 1.1509e-06
# Score matching gradient norm: 8.2069e+07
# CD1 gradient norm: 8.2069e+07
# ---
# Epoch 840
# k_lin:
# [-16.58206486 -16.58454497]
# k_duffing:
# [3.40575054 3.40448019]
# c_lin:
# [-5.57863512]
# c_optomech:
# [-3.52996901]
# Loss: 190400870.7306
# Raw gradient relative difference: 1.3175e-06
# Normalized gradient relative difference: 1.1498e-06
# Score matching gradient norm: 8.0728e+07
# CD1 gradient norm: 8.0728e+07
# ---
# Epoch 850
# k_lin:
# [-16.63646588 -16.6389974 ]
# k_duffing:
# [3.35099681 3.34968206]
# c_lin:
# [-5.6328392]
# c_optomech:
# [-3.50994559]
# Loss: 184198904.7005
# Raw gradient relative difference: 1.4050e-06
# Normalized gradient relative difference: 1.1490e-06
# Score matching gradient norm: 7.9400e+07
# CD1 gradient norm: 7.9400e+07
# ---
# Epoch 860
# k_lin:
# [-16.69029666 -16.69287958]
# k_duffing:
# [3.29680692 3.29544677]
# c_lin:
# [-5.68646544]
# c_optomech:
# [-3.48894208]
# Loss: 178161857.9294
# Raw gradient relative difference: 1.5067e-06
# Normalized gradient relative difference: 1.1485e-06
# Score matching gradient norm: 7.8086e+07
# CD1 gradient norm: 7.8086e+07
# ---
# Epoch 870
# k_lin:
# [-16.74355767 -16.74619194]
# k_duffing:
# [3.24318033 3.24177378]
# c_lin:
# [-5.73951415]
# c_optomech:
# [-3.4669916]
# Loss: 172286531.8443
# Raw gradient relative difference: 1.6204e-06
# Normalized gradient relative difference: 1.1484e-06
# Score matching gradient norm: 7.6785e+07
# CD1 gradient norm: 7.6785e+07
# ---
# Epoch 880
# k_lin:
# [-16.79624944 -16.79893498]
# k_duffing:
# [3.19011646 3.18866252]
# c_lin:
# [-5.79198569]
# c_optomech:
# [-3.44412739]
# Loss: 166569759.4749
# Raw gradient relative difference: 1.7441e-06
# Normalized gradient relative difference: 1.1486e-06
# Score matching gradient norm: 7.5498e+07
# CD1 gradient norm: 7.5498e+07
# ---
# Epoch 890
# k_lin:
# [-16.84837254 -16.85110925]
# k_duffing:
# [3.13761469 3.13611235]
# c_lin:
# [-5.84388047]
# c_optomech:
# [-3.42038277]
# Loss: 161008405.6931
# Raw gradient relative difference: 1.8764e-06
# Normalized gradient relative difference: 1.1491e-06
# Score matching gradient norm: 7.4225e+07
# CD1 gradient norm: 7.4225e+07
# ---
# Epoch 900
# k_lin:
# [-16.8999276  -16.90271534]
# k_duffing:
# [3.08567433 3.08412259]
# c_lin:
# [-5.89519897]
# c_optomech:
# [-3.39579109]
# Loss: 155599367.4492
# Raw gradient relative difference: 2.0159e-06
# Normalized gradient relative difference: 1.1499e-06
# Score matching gradient norm: 7.2965e+07
# CD1 gradient norm: 7.2965e+07
# ---
# Epoch 910
# k_lin:
# [-16.95091531 -16.9537539 ]
# k_duffing:
# [3.03429464 3.03269248]
# c_lin:
# [-5.94594171]
# c_optomech:
# [-3.3703857]
# Loss: 150339574.0019
# Raw gradient relative difference: 2.1618e-06
# Normalized gradient relative difference: 1.1512e-06
# Score matching gradient norm: 7.1719e+07
# CD1 gradient norm: 7.1720e+07
# ---
# Epoch 920
# k_lin:
# [-17.00133639 -17.00422564]
# k_duffing:
# [2.98347483 2.98182125]
# c_lin:
# [-5.99610927]
# c_optomech:
# [-3.34419987]
# Loss: 145225987.1447
# Raw gradient relative difference: 2.3131e-06
# Normalized gradient relative difference: 1.1527e-06
# Score matching gradient norm: 7.0487e+07
# CD1 gradient norm: 7.0487e+07
# ---
# Epoch 930
# k_lin:
# [-17.05119165 -17.05413132]
# k_duffing:
# [2.93321405 2.93150803]
# c_lin:
# [-6.04570228]
# c_optomech:
# [-3.31726675]
# Loss: 140255601.4262
# Raw gradient relative difference: 2.4694e-06
# Normalized gradient relative difference: 1.1546e-06
# Score matching gradient norm: 6.9268e+07
# CD1 gradient norm: 6.9268e+07
# ---
# Epoch 940
# k_lin:
# [-17.10048193 -17.10347176]
# k_duffing:
# [2.88351139 2.88175194]
# c_lin:
# [-6.09472145]
# c_optomech:
# [-3.28961936]
# Loss: 135425444.3658
# Raw gradient relative difference: 2.6302e-06
# Normalized gradient relative difference: 1.1570e-06
# Score matching gradient norm: 6.8063e+07
# CD1 gradient norm: 6.8063e+07
# ---
# Epoch 950
# k_lin:
# [-17.14920813 -17.15224781]
# k_duffing:
# [2.83436589 2.832552  ]
# c_lin:
# [-6.14316751]
# c_optomech:
# [-3.26129051]
# Loss: 130732576.6630
# Raw gradient relative difference: 2.7950e-06
# Normalized gradient relative difference: 1.1596e-06
# Score matching gradient norm: 6.6871e+07
# CD1 gradient norm: 6.6871e+07
# ---
# Epoch 960
# k_lin:
# [-17.19737123 -17.20046042]
# k_duffing:
# [2.78577655 2.78390721]
# c_lin:
# [-6.19104128]
# c_optomech:
# [-3.23231279]
# Loss: 126174092.4014
# Raw gradient relative difference: 2.9638e-06
# Normalized gradient relative difference: 1.1627e-06
# Score matching gradient norm: 6.5693e+07
# CD1 gradient norm: 6.5693e+07
# ---
# Epoch 970
# k_lin:
# [-17.24497223 -17.24811057]
# k_duffing:
# [2.73774227 2.73581648]
# c_lin:
# [-6.23834363]
# c_optomech:
# [-3.20271851]
# Loss: 121747119.2460
# Raw gradient relative difference: 3.1362e-06
# Normalized gradient relative difference: 1.1662e-06
# Score matching gradient norm: 6.4528e+07
# CD1 gradient norm: 6.4528e+07
# ---
# Epoch 980
# k_lin:
# [-17.29201221 -17.29519931]
# k_duffing:
# [2.69026193 2.6882787 ]
# c_lin:
# [-6.28507548]
# c_optomech:
# [-3.17253967]
# Loss: 117448818.6340
# Raw gradient relative difference: 3.3122e-06
# Normalized gradient relative difference: 1.1700e-06
# Score matching gradient norm: 6.3377e+07
# CD1 gradient norm: 6.3377e+07
# ---
# Epoch 990
# k_lin:
# [-17.33849232 -17.34172773]
# k_duffing:
# [2.64333434 2.64129268]
# c_lin:
# [-6.33123781]
# c_optomech:
# [-3.14180793]
# Loss: 113276385.9595
# Raw gradient relative difference: 3.4915e-06
# Normalized gradient relative difference: 1.1743e-06
# Score matching gradient norm: 6.2239e+07
# CD1 gradient norm: 6.2239e+07
# ---
# Epoch 1000
# k_lin:
# [-17.38441375 -17.38769699]
# k_duffing:
# [2.59695824 2.59485716]
# c_lin:
# [-6.37683168]
# c_optomech:
# [-3.1105546]
# Loss: 109227050.7499
# Raw gradient relative difference: 3.6742e-06
# Normalized gradient relative difference: 1.1790e-06
# Score matching gradient norm: 6.1114e+07
# CD1 gradient norm: 6.1115e+07
# ---
# Epoch 1010
# k_lin:
# [-17.42977777 -17.43310833]
# k_duffing:
# [2.55113232 2.54897084]
# c_lin:
# [-6.4218582]
# c_optomech:
# [-3.07881058]
# Loss: 105298076.8359
# Raw gradient relative difference: 3.8603e-06
# Normalized gradient relative difference: 1.1841e-06
# Score matching gradient norm: 6.0003e+07
# CD1 gradient norm: 6.0003e+07
# ---
# Epoch 1020
# k_lin:
# [-17.47458568 -17.47796302]
# k_duffing:
# [2.50585522 2.50363235]
# c_lin:
# [-6.46631854]
# c_optomech:
# [-3.04660632]
# Loss: 101486762.5133
# Raw gradient relative difference: 4.0496e-06
# Normalized gradient relative difference: 1.1897e-06
# Score matching gradient norm: 5.8905e+07
# CD1 gradient norm: 5.8906e+07
# ---
# Epoch 1030
# k_lin:
# [-17.51883886 -17.52226241]
# k_duffing:
# [2.46112548 2.45884028]
# c_lin:
# [-6.51021393]
# c_optomech:
# [-3.01397186]
# Loss: 97790440.6967
# Raw gradient relative difference: 4.2422e-06
# Normalized gradient relative difference: 1.1957e-06
# Score matching gradient norm: 5.7821e+07
# CD1 gradient norm: 5.7821e+07
# ---
# Epoch 1040
# k_lin:
# [-17.56253877 -17.56600791]
# k_duffing:
# [2.41694163 2.41459312]
# c_lin:
# [-6.55354567]
# c_optomech:
# [-2.98093675]
# Loss: 94206479.0650
# Raw gradient relative difference: 4.4382e-06
# Normalized gradient relative difference: 1.2022e-06
# Score matching gradient norm: 5.6749e+07
# CD1 gradient norm: 5.6750e+07
# ---
# Epoch 1050
# k_lin:
# [-17.6056869  -17.60920097]
# k_duffing:
# [2.37330209 2.37088934]
# c_lin:
# [-6.59631513]
# c_optomech:
# [-2.94753005]
# Loss: 90732280.1980
# Raw gradient relative difference: 4.6376e-06
# Normalized gradient relative difference: 1.2091e-06
# Score matching gradient norm: 5.5691e+07
# CD1 gradient norm: 5.5691e+07
# ---
# Epoch 1060
# k_lin:
# [-17.64828482 -17.65184313]
# k_duffing:
# [2.33020527 2.32772732]
# c_lin:
# [-6.63852373]
# c_optomech:
# [-2.9137803]
# Loss: 87365281.7043
# Raw gradient relative difference: 4.8404e-06
# Normalized gradient relative difference: 1.2165e-06
# Score matching gradient norm: 5.4646e+07
# CD1 gradient norm: 5.4646e+07
# ---
# Epoch 1070
# k_lin:
# [-17.69033417 -17.69393599]
# k_duffing:
# [2.28764946 2.28510539]
# c_lin:
# [-6.68017295]
# c_optomech:
# [-2.87971553]
# Loss: 84102956.3395
# Raw gradient relative difference: 5.0467e-06
# Normalized gradient relative difference: 1.2245e-06
# Score matching gradient norm: 5.3614e+07
# CD1 gradient norm: 5.3614e+07
# ---
# Epoch 1080
# k_lin:
# [-17.73183662 -17.73548119]
# k_duffing:
# [2.24563293 2.24302182]
# c_lin:
# [-6.72126436]
# c_optomech:
# [-2.84536321]
# Loss: 80942812.1154
# Raw gradient relative difference: 5.2566e-06
# Normalized gradient relative difference: 1.2329e-06
# Score matching gradient norm: 5.2595e+07
# CD1 gradient norm: 5.2596e+07
# ---
# Epoch 1090
# k_lin:
# [-17.77279394 -17.77648045]
# k_duffing:
# [2.20415388 2.20147482]
# c_lin:
# [-6.76179958]
# c_optomech:
# [-2.81075028]
# Loss: 77882392.3982
# Raw gradient relative difference: 5.4701e-06
# Normalized gradient relative difference: 1.2419e-06
# Score matching gradient norm: 5.1590e+07
# CD1 gradient norm: 5.1590e+07
# ---
# Epoch 1100
# k_lin:
# [-17.81320795 -17.81693557]
# k_duffing:
# [2.16321042 2.16046252]
# c_lin:
# [-6.80178029]
# c_optomech:
# [-2.77590309]
# Loss: 74919275.9974
# Raw gradient relative difference: 5.6873e-06
# Normalized gradient relative difference: 1.2514e-06
# Score matching gradient norm: 5.0597e+07
# CD1 gradient norm: 5.0597e+07
# ---
# Epoch 1110
# k_lin:
# [-17.85308053 -17.85684837]
# k_duffing:
# [2.12280063 2.119983  ]
# c_lin:
# [-6.84120824]
# c_optomech:
# [-2.74084743]
# Loss: 72051077.2442
# Raw gradient relative difference: 5.9085e-06
# Normalized gradient relative difference: 1.2614e-06
# Score matching gradient norm: 4.9617e+07
# CD1 gradient norm: 4.9617e+07
# ---
# Epoch 1120
# k_lin:
# [-17.89241363 -17.89622078]
# k_duffing:
# [2.08292251 2.08003429]
# c_lin:
# [-6.88008525]
# c_optomech:
# [-2.7056085]
# Loss: 69275446.0581
# Raw gradient relative difference: 6.1336e-06
# Normalized gradient relative difference: 1.2719e-06
# Score matching gradient norm: 4.8650e+07
# CD1 gradient norm: 4.8650e+07
# ---
# Epoch 1130
# k_lin:
# [-17.93120926 -17.93505477]
# k_duffing:
# [2.043574   2.04061433]
# c_lin:
# [-6.91841321]
# c_optomech:
# [-2.67021091]
# Loss: 66590068.0039
# Raw gradient relative difference: 6.3628e-06
# Normalized gradient relative difference: 1.2831e-06
# Score matching gradient norm: 4.7696e+07
# CD1 gradient norm: 4.7696e+07
# ---
# Epoch 1140
# k_lin:
# [-17.9694695  -17.97335236]
# k_duffing:
# [2.00475296 2.00172101]
# c_lin:
# [-6.95619406]
# c_optomech:
# [-2.63467867]
# Loss: 63992664.3358
# Raw gradient relative difference: 6.5961e-06
# Normalized gradient relative difference: 1.2949e-06
# Score matching gradient norm: 4.6754e+07
# CD1 gradient norm: 4.6755e+07
# ---
# Epoch 1150
# k_lin:
# [-18.00719649 -18.01111568]
# k_duffing:
# [1.96645722 1.96335216]
# c_lin:
# [-6.99342982]
# c_optomech:
# [-2.59903521]
# Loss: 61480992.0314
# Raw gradient relative difference: 6.8339e-06
# Normalized gradient relative difference: 1.3072e-06
# Score matching gradient norm: 4.5826e+07
# CD1 gradient norm: 4.5826e+07
# ---
# Epoch 1160
# k_lin:
# [-18.04439243 -18.04834688]
# k_duffing:
# [1.92868453 1.92550555]
# c_lin:
# [-7.03012257]
# c_optomech:
# [-2.56330333]
# Loss: 59052843.8127
# Raw gradient relative difference: 7.0762e-06
# Normalized gradient relative difference: 1.3202e-06
# Score matching gradient norm: 4.4910e+07
# CD1 gradient norm: 4.4910e+07
# ---
# Epoch 1170
# k_lin:
# [-18.0810596  -18.08504819]
# k_duffing:
# [1.89143255 1.88817887]
# c_lin:
# [-7.06627447]
# c_optomech:
# [-2.52750526]
# Loss: 56706048.1561
# Raw gradient relative difference: 7.3231e-06
# Normalized gradient relative difference: 1.3338e-06
# Score matching gradient norm: 4.4006e+07
# CD1 gradient norm: 4.4007e+07
# ---
# Epoch 1180
# k_lin:
# [-18.11720032 -18.12122191]
# k_duffing:
# [1.85469892 1.85136976]
# c_lin:
# [-7.10188773]
# c_optomech:
# [-2.49166259]
# Loss: 54438469.2893
# Raw gradient relative difference: 7.5748e-06
# Normalized gradient relative difference: 1.3480e-06
# Score matching gradient norm: 4.3116e+07
# CD1 gradient norm: 4.3116e+07
# ---
# Epoch 1190
# k_lin:
# [-18.152817  -18.1568704]
# k_duffing:
# [1.81848119 1.8150758 ]
# c_lin:
# [-7.13696463]
# c_optomech:
# [-2.45579633]
# Loss: 52248007.1765
# Raw gradient relative difference: 7.8315e-06
# Normalized gradient relative difference: 1.3629e-06
# Score matching gradient norm: 4.2237e+07
# CD1 gradient norm: 4.2238e+07
# ---
# Epoch 1200
# k_lin:
# [-18.1879121  -18.19199607]
# k_duffing:
# [1.78277685 1.77929449]
# c_lin:
# [-7.17150752]
# c_optomech:
# [-2.41992689]
# Loss: 50132597.4904
# Raw gradient relative difference: 8.0933e-06
# Normalized gradient relative difference: 1.3785e-06
# Score matching gradient norm: 4.1371e+07
# CD1 gradient norm: 4.1372e+07
# ---
# Epoch 1210
# k_lin:
# [-18.22248815 -18.22660143]
# k_duffing:
# [1.74758333 1.7440233 ]
# c_lin:
# [-7.20551881]
# c_optomech:
# [-2.38407405]
# Loss: 48090211.5723
# Raw gradient relative difference: 8.3604e-06
# Normalized gradient relative difference: 1.3948e-06
# Score matching gradient norm: 4.0518e+07
# CD1 gradient norm: 4.0518e+07
# ---
# Epoch 1220
# k_lin:
# [-18.25654772 -18.26068901]
# k_duffing:
# [1.71289801 1.70925959]
# c_lin:
# [-7.23900098]
# c_optomech:
# [-2.34825703]
# Loss: 46118856.3784
# Raw gradient relative difference: 8.6330e-06
# Normalized gradient relative difference: 1.4119e-06
# Score matching gradient norm: 3.9677e+07
# CD1 gradient norm: 3.9677e+07
# ---
# Epoch 1230
# k_lin:
# [-18.29009349 -18.29426143]
# k_duffing:
# [1.67871818 1.67500071]
# c_lin:
# [-7.27195659]
# c_optomech:
# [-2.31249444]
# Loss: 44216574.4142
# Raw gradient relative difference: 8.9114e-06
# Normalized gradient relative difference: 1.4297e-06
# Score matching gradient norm: 3.8848e+07
# CD1 gradient norm: 3.8848e+07
# ---
# Epoch 1240
# k_lin:
# [-18.32312816 -18.32732137]
# k_duffing:
# [1.64504108 1.64124391]
# c_lin:
# [-7.30438823]
# c_optomech:
# [-2.27680428]
# Loss: 42381443.6546
# Raw gradient relative difference: 9.1955e-06
# Normalized gradient relative difference: 1.4482e-06
# Score matching gradient norm: 3.8031e+07
# CD1 gradient norm: 3.8031e+07
# ---
# Epoch 1250
# k_lin:
# [-18.3556545  -18.35987157]
# k_duffing:
# [1.61186391 1.60798639]
# c_lin:
# [-7.33629858]
# c_optomech:
# [-2.24120401]
# Loss: 40611577.4524
# Raw gradient relative difference: 9.4859e-06
# Normalized gradient relative difference: 1.4675e-06
# Score matching gradient norm: 3.7226e+07
# CD1 gradient norm: 3.7227e+07
# ---
# Epoch 1260
# k_lin:
# [-18.38767537 -18.39191482]
# k_duffing:
# [1.57918377 1.5752253 ]
# c_lin:
# [-7.36769039]
# c_optomech:
# [-2.20571046]
# Loss: 38905124.4322
# Raw gradient relative difference: 9.7826e-06
# Normalized gradient relative difference: 1.4877e-06
# Score matching gradient norm: 3.6434e+07
# CD1 gradient norm: 3.6434e+07
# ---
# Epoch 1270
# k_lin:
# [-18.41919366 -18.42345399]
# k_duffing:
# [1.54699772 1.54295771]
# c_lin:
# [-7.39856645]
# c_optomech:
# [-2.17033993]
# Loss: 37260268.3721
# Raw gradient relative difference: 1.0086e-05
# Normalized gradient relative difference: 1.5087e-06
# Score matching gradient norm: 3.5653e+07
# CD1 gradient norm: 3.5654e+07
# ---
# Epoch 1280
# k_lin:
# [-18.45021233 -18.45449201]
# k_duffing:
# [1.51530277 1.51118065]
# c_lin:
# [-7.42892964]
# c_optomech:
# [-2.13510812]
# Loss: 35675228.0716
# Raw gradient relative difference: 1.0396e-05
# Normalized gradient relative difference: 1.5305e-06
# Score matching gradient norm: 3.4884e+07
# CD1 gradient norm: 3.4885e+07
# ---
# Epoch 1290
# k_lin:
# [-18.48073442 -18.48503186]
# k_duffing:
# [1.48409585 1.47989108]
# c_lin:
# [-7.45878287]
# c_optomech:
# [-2.10003019]
# Loss: 34148257.2068
# Raw gradient relative difference: 1.0713e-05
# Normalized gradient relative difference: 1.5533e-06
# Score matching gradient norm: 3.4127e+07
# CD1 gradient norm: 3.4128e+07
# ---
# Epoch 1300
# k_lin:
# [-18.51076299 -18.51507657]
# k_duffing:
# [1.45337384 1.44908591]
# c_lin:
# [-7.48812916]
# c_optomech:
# [-2.06512072]
# Loss: 32677644.1722
# Raw gradient relative difference: 1.1037e-05
# Normalized gradient relative difference: 1.5769e-06
# Score matching gradient norm: 3.3382e+07
# CD1 gradient norm: 3.3383e+07
# ---
# Epoch 1310
# k_lin:
# [-18.5403012  -18.54462927]
# k_duffing:
# [1.42313357 1.41876197]
# c_lin:
# [-7.51697154]
# c_optomech:
# [-2.03039378]
# Loss: 31261711.9091
# Raw gradient relative difference: 1.1369e-05
# Normalized gradient relative difference: 1.6015e-06
# Score matching gradient norm: 3.2649e+07
# CD1 gradient norm: 3.2649e+07
# ---
# Epoch 1320
# k_lin:
# [-18.56935225 -18.5736931 ]
# k_duffing:
# [1.39337179 1.38891606]
# c_lin:
# [-7.54531313]
# c_optomech:
# [-1.99586287]
# Loss: 29898817.7218
# Raw gradient relative difference: 1.1709e-05
# Normalized gradient relative difference: 1.6271e-06
# Score matching gradient norm: 3.1927e+07
# CD1 gradient norm: 3.1927e+07
# ---
# Epoch 1330
# k_lin:
# [-18.59791939 -18.60227129]
# k_duffing:
# [1.36408522 1.35954491]
# c_lin:
# [-7.57315711]
# c_optomech:
# [-1.96154097]
# Loss: 28587353.0798
# Raw gradient relative difference: 1.2057e-05
# Normalized gradient relative difference: 1.6536e-06
# Score matching gradient norm: 3.1217e+07
# CD1 gradient norm: 3.1217e+07
# ---
# Epoch 1340
# k_lin:
# [-18.62600594 -18.63036712]
# k_duffing:
# [1.33527049 1.33064519]
# c_lin:
# [-7.60050671]
# c_optomech:
# [-1.92744052]
# Loss: 27325743.4083
# Raw gradient relative difference: 1.2414e-05
# Normalized gradient relative difference: 1.6813e-06
# Score matching gradient norm: 3.0518e+07
# CD1 gradient norm: 3.0518e+07
# ---
# Epoch 1350
# k_lin:
# [-18.65361527 -18.65798392]
# k_duffing:
# [1.30692422 1.30221353]
# c_lin:
# [-7.62736523]
# c_optomech:
# [-1.89357348]
# Loss: 26112447.8652
# Raw gradient relative difference: 1.2779e-05
# Normalized gradient relative difference: 1.7099e-06
# Score matching gradient norm: 2.9830e+07
# CD1 gradient norm: 2.9830e+07
# ---
# Epoch 1360
# k_lin:
# [-18.68075081 -18.68512508]
# k_duffing:
# [1.27904294 1.27424648]
# c_lin:
# [-7.65373601]
# c_optomech:
# [-1.85995126]
# Loss: 24945959.1060
# Raw gradient relative difference: 1.3153e-05
# Normalized gradient relative difference: 1.7398e-06
# Score matching gradient norm: 2.9154e+07
# CD1 gradient norm: 2.9154e+07
# ---
# Epoch 1370
# k_lin:
# [-18.70741603 -18.71179404]
# k_duffing:
# [1.25162314 1.24674058]
# c_lin:
# [-7.67962245]
# c_optomech:
# [-1.82658479]
# Loss: 23824803.0361
# Raw gradient relative difference: 1.3537e-05
# Normalized gradient relative difference: 1.7706e-06
# Score matching gradient norm: 2.8488e+07
# CD1 gradient norm: 2.8489e+07
# ---
# Epoch 1380
# k_lin:
# [-18.73361448 -18.7379943 ]
# k_duffing:
# [1.22466125 1.21969226]
# c_lin:
# [-7.70502803]
# c_optomech:
# [-1.79348451]
# Loss: 22747538.5515
# Raw gradient relative difference: 1.3930e-05
# Normalized gradient relative difference: 1.8027e-06
# Score matching gradient norm: 2.7834e+07
# CD1 gradient norm: 2.7835e+07
# ---
# Epoch 1390
# k_lin:
# [-18.75934975 -18.76372942]
# k_duffing:
# [1.19815366 1.19309796]
# c_lin:
# [-7.72995627]
# c_optomech:
# [-1.76066038]
# Loss: 21712757.2669
# Raw gradient relative difference: 1.4334e-05
# Normalized gradient relative difference: 1.8359e-06
# Score matching gradient norm: 2.7191e+07
# CD1 gradient norm: 2.7192e+07
# ---
# Epoch 1400
# k_lin:
# [-18.78462546 -18.78900298]
# k_duffing:
# [1.1720967  1.16695402]
# c_lin:
# [-7.75441072]
# c_optomech:
# [-1.72812187]
# Loss: 20719083.2325
# Raw gradient relative difference: 1.4748e-05
# Normalized gradient relative difference: 1.8704e-06
# Score matching gradient norm: 2.6559e+07
# CD1 gradient norm: 2.6559e+07
# ---
# Epoch 1410
# k_lin:
# [-18.8094453  -18.81381865]
# k_duffing:
# [1.14648665 1.14125676]
# c_lin:
# [-7.77839502]
# c_optomech:
# [-1.695878]
# Loss: 19765172.6394
# Raw gradient relative difference: 1.5173e-05
# Normalized gradient relative difference: 1.9062e-06
# Score matching gradient norm: 2.5938e+07
# CD1 gradient norm: 2.5938e+07
# ---
# Epoch 1420
# k_lin:
# [-18.83381303 -18.83818013]
# k_duffing:
# [1.12131975 1.11600244]
# c_lin:
# [-7.80191284]
# c_optomech:
# [-1.66393731]
# Loss: 18849713.5140
# Raw gradient relative difference: 1.5610e-05
# Normalized gradient relative difference: 1.9433e-06
# Score matching gradient norm: 2.5327e+07
# CD1 gradient norm: 2.5327e+07
# ---
# Epoch 1430
# k_lin:
# [-18.85773241 -18.86209116]
# k_duffing:
# [1.0965922  1.09118728]
# c_lin:
# [-7.8249679]
# c_optomech:
# [-1.63230792]
# Loss: 17971425.4010
# Raw gradient relative difference: 1.6058e-05
# Normalized gradient relative difference: 1.9819e-06
# Score matching gradient norm: 2.4727e+07
# CD1 gradient norm: 2.4727e+07
# ---
# Epoch 1440
# k_lin:
# [-18.88120728 -18.88555555]
# k_duffing:
# [1.07230012 1.06680745]
# c_lin:
# [-7.84756398]
# c_optomech:
# [-1.6009975]
# Loss: 17129059.0361
# Raw gradient relative difference: 1.6518e-05
# Normalized gradient relative difference: 2.0218e-06
# Score matching gradient norm: 2.4138e+07
# CD1 gradient norm: 2.4138e+07
# ---
# Epoch 1450
# k_lin:
# [-18.90424151 -18.90857712]
# k_duffing:
# [1.04843964 1.04285907]
# c_lin:
# [-7.86970491]
# c_optomech:
# [-1.57001326]
# Loss: 16321396.0092
# Raw gradient relative difference: 1.6991e-05
# Normalized gradient relative difference: 2.0632e-06
# Score matching gradient norm: 2.3559e+07
# CD1 gradient norm: 2.3559e+07
# ---
# Epoch 1460
# k_lin:
# [-18.92683904 -18.93115978]
# k_duffing:
# [1.02500678 1.01933823]
# c_lin:
# [-7.89139455]
# c_optomech:
# [-1.53936203]
# Loss: 15547248.4162
# Raw gradient relative difference: 1.7478e-05
# Normalized gradient relative difference: 2.1061e-06
# Score matching gradient norm: 2.2990e+07
# CD1 gradient norm: 2.2990e+07
# ---
# Epoch 1470
# k_lin:
# [-18.94900382 -18.95330746]
# k_duffing:
# [1.00199759 0.99624097]
# c_lin:
# [-7.91263682]
# c_optomech:
# [-1.5090502]
# Loss: 14805458.5029
# Raw gradient relative difference: 1.7977e-05
# Normalized gradient relative difference: 2.1505e-06
# Score matching gradient norm: 2.2432e+07
# CD1 gradient norm: 2.2432e+07
# ---
# Epoch 1480
# k_lin:
# [-18.97073985 -18.97502411]
# k_duffing:
# [0.97940802 0.97356329]
# c_lin:
# [-7.93343567]
# c_optomech:
# [-1.47908376]
# Loss: 14094898.2984
# Raw gradient relative difference: 1.8491e-05
# Normalized gradient relative difference: 2.1966e-06
# Score matching gradient norm: 2.1884e+07
# CD1 gradient norm: 2.1884e+07
# ---
# Epoch 1490
# k_lin:
# [-18.99205119 -18.99631376]
# k_duffing:
# [0.957234   0.95130115]
# c_lin:
# [-7.9537951]
# c_optomech:
# [-1.44946829]
# Loss: 13414469.2404
# Raw gradient relative difference: 1.9020e-05
# Normalized gradient relative difference: 2.2443e-06
# Score matching gradient norm: 2.1345e+07
# CD1 gradient norm: 2.1346e+07
# ---
# Epoch 1500
# k_lin:
# [-19.01294191 -19.01718046]
# k_duffing:
# ...
# Score matching gradient norm: 1.7263e-01
# CD1 gradient norm: 4.3297e+02
# ---
# Epoch 19510
# k_lin:
# [0.01102637 0.01050173]
# k_duffing:
# [-2.04668303e-06 -1.40731102e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.11878351e-05]
# Loss: -0.0099
# Raw gradient relative difference: 2.9442e+03
# Normalized gradient relative difference: 1.9373e+00
# Score matching gradient norm: 1.4701e-01
# CD1 gradient norm: 4.3269e+02
# ---
# Epoch 19520
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05521138e-06 -1.42245886e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.35134357e-05]
# Loss: -0.0099
# Raw gradient relative difference: 4.2733e+03
# Normalized gradient relative difference: 4.9633e-01
# Score matching gradient norm: 1.0128e-01
# CD1 gradient norm: 4.3291e+02
# ---
# Epoch 19530
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.04992700e-06 -1.41290822e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.21358605e-05]
# Loss: -0.0099
# Raw gradient relative difference: 8.9845e+03
# Normalized gradient relative difference: 1.9287e+00
# Score matching gradient norm: 4.8174e-02
# CD1 gradient norm: 4.3278e+02
# ---
# Epoch 19540
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05286165e-06 -1.41838723e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.29370703e-05]
# Loss: -0.0099
# Raw gradient relative difference: 2.3161e+04
# Normalized gradient relative difference: 4.9982e-01
# Score matching gradient norm: 1.8687e-02
# CD1 gradient norm: 4.3284e+02
# ---
# Epoch 19550
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05125372e-06 -1.41552571e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.24961648e-05]
# Loss: -0.0099
# Raw gradient relative difference: 1.2389e+05
# Normalized gradient relative difference: 1.9467e+00
# Score matching gradient norm: 3.4935e-03
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19560
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05206311e-06 -1.41698033e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.27062786e-05]
# Loss: -0.0099
# Raw gradient relative difference: 5.8794e+04
# Normalized gradient relative difference: 1.9423e+00
# Score matching gradient norm: 7.3616e-03
# CD1 gradient norm: 4.3281e+02
# ---
# Epoch 19570
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.0518227e-06 -1.4165135e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26392371e-05]
# Loss: -0.0099
# Raw gradient relative difference: 4.4293e+04
# Normalized gradient relative difference: 5.1503e-01
# Score matching gradient norm: 9.7716e-03
# CD1 gradient norm: 4.3283e+02
# ---
# Epoch 19580
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05177996e-06 -1.41642073e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26285208e-05]
# Loss: -0.0099
# Raw gradient relative difference: 5.7155e+04
# Normalized gradient relative difference: 1.9340e+00
# Score matching gradient norm: 7.5727e-03
# CD1 gradient norm: 4.3281e+02
# ---
# Epoch 19590
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05191905e-06 -1.41667237e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26672239e-05]
# Loss: -0.0099
# Raw gradient relative difference: 9.8243e+04
# Normalized gradient relative difference: 4.9878e-01
# Score matching gradient norm: 4.4056e-03
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19600
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05179183e-06 -1.41644540e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26337082e-05]
# Loss: -0.0099
# Raw gradient relative difference: 5.0408e+05
# Normalized gradient relative difference: 1.9263e+00
# Score matching gradient norm: 8.5863e-04
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19610
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05184515e-06 -1.41654610e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26483021e-05]
# Loss: -0.0099
# Raw gradient relative difference: 4.5040e+05
# Normalized gradient relative difference: 1.9312e+00
# Score matching gradient norm: 9.6096e-04
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19620
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05184962e-06 -1.41655625e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26495088e-05]
# Loss: -0.0099
# Raw gradient relative difference: 4.4408e+05
# Normalized gradient relative difference: 5.0450e-01
# Score matching gradient norm: 9.7464e-04
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19630
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05182748e-06 -1.41651667e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26434899e-05]
# Loss: -0.0099
# Raw gradient relative difference: 1.6168e+06
# Normalized gradient relative difference: 1.9352e+00
# Score matching gradient norm: 2.6770e-04
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19640
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183772e-06 -1.41653530e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26462029e-05]
# Loss: -0.0099
# Raw gradient relative difference: 1.6126e+06
# Normalized gradient relative difference: 1.9363e+00
# Score matching gradient norm: 2.6839e-04
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19650
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05184148e-06 -1.41654196e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26471917e-05]
# Loss: -0.0099
# Raw gradient relative difference: 2.5148e+06
# Normalized gradient relative difference: 5.1580e-01
# Score matching gradient norm: 1.7211e-04
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19660
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183717e-06 -1.41653398e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26460255e-05]
# Loss: -0.0099
# Raw gradient relative difference: 7.3230e+06
# Normalized gradient relative difference: 5.2449e-01
# Score matching gradient norm: 5.9104e-05
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19670
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183652e-06 -1.41653272e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.2645854e-05]
# Loss: -0.0099
# Raw gradient relative difference: 6.6378e+06
# Normalized gradient relative difference: 1.9371e+00
# Score matching gradient norm: 6.5205e-05
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19680
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183787e-06 -1.41653514e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26462238e-05]
# Loss: -0.0099
# Raw gradient relative difference: 1.6088e+07
# Normalized gradient relative difference: 1.9381e+00
# Score matching gradient norm: 2.6903e-05
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19690
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183824e-06 -1.41653579e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26463267e-05]
# Loss: -0.0099
# Raw gradient relative difference: 2.6239e+07
# Normalized gradient relative difference: 5.2095e-01
# Score matching gradient norm: 1.6495e-05
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19700
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183790e-06 -1.41653519e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26462427e-05]
# Loss: -0.0099
# Raw gradient relative difference: 2.7565e+07
# Normalized gradient relative difference: 5.1554e-01
# Score matching gradient norm: 1.5702e-05
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19710
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183766e-06 -1.41653475e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26461812e-05]
# Loss: -0.0099
# Raw gradient relative difference: 1.5878e+08
# Normalized gradient relative difference: 5.3824e-01
# Score matching gradient norm: 2.7260e-06
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19720
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183762e-06 -1.41653470e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26461747e-05]
# Loss: -0.0099
# Raw gradient relative difference: 1.3097e+08
# Normalized gradient relative difference: 1.9380e+00
# Score matching gradient norm: 3.3047e-06
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19730
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183766e-06 -1.41653477e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26461874e-05]
# Loss: -0.0099
# Raw gradient relative difference: 1.3135e+08
# Normalized gradient relative difference: 1.9366e+00
# Score matching gradient norm: 3.2952e-06
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19740
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183769e-06 -1.41653484e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26461975e-05]
# Loss: -0.0099
# Raw gradient relative difference: 2.4695e+08
# Normalized gradient relative difference: 1.9366e+00
# Score matching gradient norm: 1.7526e-06
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19750
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183770e-06 -1.41653486e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26462017e-05]
# Loss: -0.0099
# Raw gradient relative difference: 6.7005e+08
# Normalized gradient relative difference: 1.9371e+00
# Score matching gradient norm: 6.4595e-07
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19760
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183770e-06 -1.41653486e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26462026e-05]
# Loss: -0.0099
# Raw gradient relative difference: 2.8116e+09
# Normalized gradient relative difference: 1.9376e+00
# Score matching gradient norm: 1.5394e-07
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19770
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183769e-06 -1.41653486e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26462023e-05]
# Loss: -0.0099
# Raw gradient relative difference: 6.1110e+10
# Normalized gradient relative difference: 1.7922e+00
# Score matching gradient norm: 7.0827e-09
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19780
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183768e-06 -1.41653485e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26462019e-05]
# Loss: -0.0099
# Raw gradient relative difference: 3.5755e+10
# Normalized gradient relative difference: 5.6893e-01
# Score matching gradient norm: 1.2105e-08
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19790
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183768e-06 -1.41653485e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26462015e-05]
# Loss: -0.0099
# Raw gradient relative difference: 4.9706e+10
# Normalized gradient relative difference: 1.8618e+00
# Score matching gradient norm: 8.7076e-09
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19800
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183768e-06 -1.41653484e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26462012e-05]
# Loss: -0.0099
# Raw gradient relative difference: 1.6062e+10
# Normalized gradient relative difference: 1.9288e+00
# Score matching gradient norm: 2.6946e-08
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19810
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183767e-06 -1.41653484e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26462011e-05]
# Loss: -0.0099
# Raw gradient relative difference: 1.2238e+10
# Normalized gradient relative difference: 1.9342e+00
# Score matching gradient norm: 3.5368e-08
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19820
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183767e-06 -1.41653484e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.2646201e-05]
# Loss: -0.0099
# Raw gradient relative difference: 1.3866e+10
# Normalized gradient relative difference: 1.9360e+00
# Score matching gradient norm: 3.1215e-08
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19830
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183767e-06 -1.41653484e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.2646201e-05]
# Loss: -0.0099
# Raw gradient relative difference: 2.4826e+10
# Normalized gradient relative difference: 1.9370e+00
# Score matching gradient norm: 1.7434e-08
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19840
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183767e-06 -1.41653484e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.2646201e-05]
# Loss: -0.0099
# Raw gradient relative difference: 2.1592e+11
# Normalized gradient relative difference: 1.9417e+00
# Score matching gradient norm: 2.0045e-09
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19850
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183767e-06 -1.41653484e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26462011e-05]
# Loss: -0.0099
# Raw gradient relative difference: 7.5306e+10
# Normalized gradient relative difference: 5.0742e-01
# Score matching gradient norm: 5.7475e-09
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19860
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183767e-06 -1.41653484e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26462011e-05]
# Loss: -0.0099
# Raw gradient relative difference: 1.3311e+11
# Normalized gradient relative difference: 5.0445e-01
# Score matching gradient norm: 3.2517e-09
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19870
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183767e-06 -1.41653484e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26462011e-05]
# Loss: -0.0099
# Raw gradient relative difference: 2.7033e+11
# Normalized gradient relative difference: 1.9358e+00
# Score matching gradient norm: 1.6011e-09
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19880
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183767e-06 -1.41653484e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26462011e-05]
# Loss: -0.0099
# Raw gradient relative difference: 3.8432e+11
# Normalized gradient relative difference: 1.9387e+00
# Score matching gradient norm: 1.1262e-09
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19890
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183767e-06 -1.41653484e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26462011e-05]
# Loss: -0.0099
# Raw gradient relative difference: 4.8295e+11
# Normalized gradient relative difference: 5.2159e-01
# Score matching gradient norm: 8.9621e-10
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19900
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183767e-06 -1.41653484e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26462011e-05]
# Loss: -0.0099
# Raw gradient relative difference: 3.4710e+12
# Normalized gradient relative difference: 1.9367e+00
# Score matching gradient norm: 1.2470e-10
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19910
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183767e-06 -1.41653484e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26462011e-05]
# Loss: -0.0099
# Raw gradient relative difference: 2.2472e+12
# Normalized gradient relative difference: 1.9387e+00
# Score matching gradient norm: 1.9261e-10
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19920
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183767e-06 -1.41653484e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26462011e-05]
# Loss: -0.0099
# Raw gradient relative difference: 2.4898e+12
# Normalized gradient relative difference: 5.4121e-01
# Score matching gradient norm: 1.7384e-10
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19930
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183767e-06 -1.41653484e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26462011e-05]
# Loss: -0.0099
# Raw gradient relative difference: 3.4887e+12
# Normalized gradient relative difference: 1.9404e+00
# Score matching gradient norm: 1.2406e-10
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19940
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183767e-06 -1.41653484e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26462011e-05]
# Loss: -0.0099
# Raw gradient relative difference: 6.4347e+12
# Normalized gradient relative difference: 5.5237e-01
# Score matching gradient norm: 6.7264e-11
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19950
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183767e-06 -1.41653484e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26462011e-05]
# Loss: -0.0099
# Raw gradient relative difference: 1.5846e+13
# Normalized gradient relative difference: 1.9383e+00
# Score matching gradient norm: 2.7314e-11
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19960
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183767e-06 -1.41653484e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26462011e-05]
# Loss: -0.0099
# Raw gradient relative difference: 2.3682e+13
# Normalized gradient relative difference: 1.9407e+00
# Score matching gradient norm: 1.8277e-11
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19970
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183767e-06 -1.41653484e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26462011e-05]
# Loss: -0.0099
# Raw gradient relative difference: 2.0139e+13
# Normalized gradient relative difference: 5.8897e-01
# Score matching gradient norm: 2.1491e-11
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19980
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183767e-06 -1.41653484e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26462011e-05]
# Loss: -0.0099
# Raw gradient relative difference: 3.2255e+13
# Normalized gradient relative difference: 6.2735e-01
# Score matching gradient norm: 1.3419e-11
# CD1 gradient norm: 4.3282e+02
# ---
# Epoch 19990
# k_lin:
# [0.01102637 0.01050172]
# k_duffing:
# [-2.05183767e-06 -1.41653484e-06]
# c_lin:
# [-0.00019284]
# c_optomech:
# [-2.26462011e-05]
# Loss: -0.0099
# Raw gradient relative difference: 5.4744e+13
# Normalized gradient relative difference: 6.7201e-01
# Score matching gradient norm: 7.9062e-12
# CD1 gradient norm: 4.3282e+02
# ---

# %%
# Convert histories to arrays for plotting
slicing = 1
params_history = jnp.array(params_history[::slicing])
k_lin_history = jnp.zeros((len(params_history), N_osc))
k_duff_history = jnp.zeros((len(params_history), N_osc))
c_lin_history = jnp.zeros((len(params_history), 1))
c_optomech_history = jnp.zeros((len(params_history), 1))

for i in range(len(params_history)):
    k_lin, k_duff, c_lin, c_optomech = unflatten(params_history[i])
    k_lin_history = k_lin_history.at[i].set(k_lin)
    k_duff_history = k_duff_history.at[i].set(k_duff)
    c_lin_history = c_lin_history.at[i].set(c_lin)
    c_optomech_history = c_optomech_history.at[i].set(c_optomech)

loss_history = jnp.array(loss_history[::slicing])
gradient_diff_history = jnp.array(gradient_diff_history[::slicing])
gradient_diff_norm_history = jnp.array(gradient_diff_norm_history[::slicing])
sm_grad_norm_history = jnp.array(sm_grad_norm_history[::slicing])
cd1_grad_norm_history = jnp.array(cd1_grad_norm_history[::slicing])

# Create figure with 4 rows and 2 columns
fig, axes = plt.subplots(4, 2, figsize=(20, 32))

# Plot k_lin evolution
for i in range(N_osc):
    axes[0, 0].plot(k_lin_history[:, i], label=f'k_lin[{i}]')
axes[0, 0].set_title(f'Evolution of k_lin\nFinal values:\n' + 
                     '\n'.join([f'k_lin[{i}] = {k_lin_history[-1,i]:.3f}' 
                               for i in range(N_osc)]))
axes[0, 0].set_xlabel('Epoch')
axes[0, 0].set_ylabel('Linear Strength')
axes[0, 0].legend()
axes[0, 0].grid(True)

# Plot k_duff evolution
for i in range(N_osc):
    axes[0, 1].plot(k_duff_history[:, i], label=f'k_duff[{i}]')
axes[0, 1].set_title(f'Evolution of k_duff\nFinal values:\n' + 
                     '\n'.join([f'k_duff[{i}] = {k_duff_history[-1,i]:.3f}' 
                               for i in range(N_osc)]))
axes[0, 1].set_xlabel('Epoch')
axes[0, 1].set_ylabel('Duffing Strength')
axes[0, 1].legend()
axes[0, 1].grid(True)

# Plot c_lin and c_optomech evolution
axes[1, 0].plot(c_lin_history, label='c_lin')
axes[1, 0].plot(c_optomech_history, label='c_optomech')
axes[1, 0].set_title(f'Evolution of Coupling Parameters\nFinal values:\n' +
                     f'c_lin = {c_lin_history[-1,0]:.3f}\n' +
                     f'c_optomech = {c_optomech_history[-1,0]:.3f}')
axes[1, 0].set_xlabel('Epoch')
axes[1, 0].set_ylabel('Coupling Strength')
axes[1, 0].legend()
axes[1, 0].grid(True)

# Plot loss evolution
axes[1, 1].semilogy(loss_history, label='Loss')
axes[1, 1].set_title(f'Evolution of Loss\nFinal value: {loss_history[-1]:.3e}')
axes[1, 1].set_xlabel('Epoch')
axes[1, 1].set_ylabel('Loss')
axes[1, 1].legend()
axes[1, 1].grid(True)

# Plot raw gradient difference evolution
axes[2, 0].semilogy(gradient_diff_history, label='Raw Gradient Difference')
axes[2, 0].set_title('Evolution of Raw Gradient Difference\n' +
                     f'Final value: {gradient_diff_history[-1]:.2e}')
axes[2, 0].set_xlabel('Epoch')
axes[2, 0].set_ylabel('Relative Difference')
axes[2, 0].legend()
axes[2, 0].grid(True)

# Plot normalized gradient difference evolution
axes[2, 1].semilogy(gradient_diff_norm_history, label='Normalized Gradient Difference')
axes[2, 1].set_title('Evolution of Normalized Gradient Difference\n' +
                     f'Final value: {gradient_diff_norm_history[-1]:.2e}')
axes[2, 1].set_xlabel('Epoch')
axes[2, 1].set_ylabel('Relative Difference')
axes[2, 1].legend()
axes[2, 1].grid(True)

# Plot gradient norms evolution
axes[3, 0].semilogy(sm_grad_norm_history, label='Score Matching Gradient Norm')
axes[3, 0].semilogy(cd1_grad_norm_history, label='CD1 Gradient Norm')
axes[3, 0].set_title('Evolution of Gradient Norms\n' +
                     f'Final SM value: {sm_grad_norm_history[-1]:.2e}\n' +
                     f'Final CD1 value: {cd1_grad_norm_history[-1]:.2e}')
axes[3, 0].set_xlabel('Epoch')
axes[3, 0].set_ylabel('Gradient Norm')
axes[3, 0].legend()
axes[3, 0].grid(True)

# Hide the empty subplot
axes[3, 1].set_visible(False)

plt.tight_layout()
plt.show()

# %%
# Create figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# Plot initial energy landscape
energy_initial = jnp.zeros((n_points, n_points))
energy_final = jnp.zeros((n_points, n_points))
for i in range(n_points):
    for j in range(n_points):
        x = jnp.array([X1[i,j], X2[i,j]])
        energy_initial = energy_initial.at[i,j].set(energy_fn(x, flattened_args_initial))
        energy_final = energy_final.at[i,j].set(energy_fn(x, params))

contour1 = ax1.contourf(X1, X2, energy_initial, levels=20, cmap='viridis', alpha=0.7)
plt.colorbar(contour1, ax=ax1, label='Energy')
ax1.scatter(samples[:, 0], samples[:, 1], c='black', s=1, alpha=0.9, label='Training Samples')
ax1.set_xlabel('x₁')
ax1.set_ylabel('x₂')
ax1.set_title('Initial Energy Landscape')
ax1.legend()


contour2 = ax2.contourf(X1, X2, energy_final, levels=20, cmap='viridis', alpha=0.7)
plt.colorbar(contour2, ax=ax2, label='Energy')
ax2.scatter(samples[:, 0], samples[:, 1], c='black', s=1, alpha=0.9, label='Training Samples')
ax2.set_xlabel('x₁')
ax2.set_ylabel('x₂')
ax2.set_title('Final Energy Landscape')
ax2.legend()

plt.tight_layout()
plt.show()

# %%
# Get final values from histories
k_lin_final = k_lin_history[-1]
k_duff_final = k_duff_history[-1]
c_lin_final = c_lin_history[-1]
c_optomech_final = c_optomech_history[-1]

# Create tuple of final args in same structure as initial args
args_final = (k_lin_final, k_duff_final, c_lin_final, c_optomech_final)

# Flatten using the same unflatten function from earlier
flattened_args_final, _ = flatten_util.ravel_pytree(args_final)

# %%
# Compare gradient differences with score_matching_loss for different dt values
dt_values = jnp.logspace(-18, 1, 30)  # logarithmically spaced dt values
key = jr.PRNGKey(1)

# Get score matching gradient results (only need to compute once)
score_matching_loss = setup_score_matching_loss(energy_fn, samples)
score_matching_grad = grad_loss(score_matching_loss, flattened_args_final)

# Initialize arrays to store results
n_params = len(flattened_args_final)
relative_differences = jnp.zeros((len(dt_values), n_params))
total_relative_differences = jnp.zeros(len(dt_values))  # New array for total differences

# Loop over dt values
for i, dt in enumerate(dt_values):
    key, subkey = jr.split(key)
    
    # Get CD1 gradient for this dt
    cd1_grad = -CD1_gradient(energy_fn, samples, flattened_args_final, 
                            dt=dt, D=1, key=subkey, num_noise_samples=0)
    
    # Calculate relative difference for each parameter
    rel_diff = jnp.abs(cd1_grad - score_matching_grad) / jnp.abs(score_matching_grad)
    relative_differences = relative_differences.at[i].set(rel_diff)
    
    # Calculate total relative difference using L2 norm
    total_rel_diff = jnp.linalg.norm(cd1_grad - score_matching_grad) / jnp.linalg.norm(score_matching_grad)
    total_relative_differences = total_relative_differences.at[i].set(total_rel_diff)

# Create figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 6))

# First subplot: Individual parameter differences
param_names = ['k_lin_1', 'k_lin_2', 'k_duff_1', 'k_duff_2', 'c_lin', 'c_optomech']
for param_idx in range(n_params):
    ax1.loglog(dt_values, relative_differences[:, param_idx], 'o-', 
               label=param_names[param_idx])

ax1.set_xlabel('dt')
ax1.set_ylabel('Relative Difference')
ax1.set_title('Individual Parameter Relative Differences')
ax1.grid(True)
ax1.legend()

# Second subplot: Total gradient difference
ax2.loglog(dt_values, total_relative_differences, 'o-', color='black', label='Total gradient')
ax2.set_xlabel('dt')
ax2.set_ylabel('Total Relative Difference')
ax2.set_title('Total Gradient Relative Difference (L2 norm)')
ax2.grid(True)
ax2.legend()

plt.tight_layout()
plt.show()

# Print the minimum relative differences
print("\nIndividual parameter minimum differences:")
for param_idx in range(n_params):
    min_idx = jnp.argmin(relative_differences[:, param_idx])
    print(f"\n{param_names[param_idx]}:")
    print(f"Minimum relative difference: {relative_differences[min_idx, param_idx]:.2e}")
    print(f"Optimal dt: {dt_values[min_idx]:.2e}")

print("\nTotal gradient minimum difference:")
min_total_idx = jnp.argmin(total_relative_differences)
print(f"Minimum total relative difference: {total_relative_differences[min_total_idx]:.2e}")
print(f"Optimal dt: {dt_values[min_total_idx]:.2e}")
# Out:
# Individual parameter minimum differences:
#
# k_lin_1:
# Minimum relative difference: 1.00e+00
# Optimal dt: 1.00e-18
#
# k_lin_2:
# Minimum relative difference: 1.00e+00
# Optimal dt: 1.00e-18
#
# k_duff_1:
# Minimum relative difference: 1.00e+00
# Optimal dt: 1.00e-18
#
# k_duff_2:
# Minimum relative difference: 1.00e+00
# Optimal dt: 1.00e-18
#
# c_lin:
# Minimum relative difference: 1.00e+00
# Optimal dt: 1.00e-18
#
# c_optomech:
# Minimum relative difference: 1.00e+00
# Optimal dt: 1.00e-18
#
# Total gradient minimum difference:
# Minimum total relative difference: 1.00e+00
# Optimal dt: 1.00e-18

# %%
# def drift_x_fn(t, state, args):
#     """
#     Drift function for the XY model with effective temperature
#     Args:
#         t: time
#         state: array of phases (shape: N_osc)
#         args: tuple containing (W, h)
#     Returns:
#         Array of phase velocities
#     """
#     W, h = args
#     # Compute force from energy gradient
#     dE_dtheta = jax.grad(XY_energy, argnums=0)(state, W, h)
    
#     # Damping term
#     gamma = 1.0  # Damping coefficient, adjust as needed
    
#     dtheta_dt = -gamma * dE_dtheta
    
#     return dtheta_dt

# def diffusion_x_fn(t, state, args):
#     """
#     Diffusion function for the XY model with effective temperature
#     Args:
#         t: time
#         state: array of phases (shape: N_osc)
#         args: additional arguments
#     Returns:
#         Noise matrix (shape: N_osc x 1)
#     """
#     T_eff = 1.0  # Effective temperature, adjust as needed
#     gamma = 1.0  # Same damping coefficient as in drift
    
#     noise_strength = jnp.sqrt(2 * gamma * T_eff)
#     noise_matrix = jnp.eye(N_osc)
#     return noise_strength * noise_matrix

# %%
# # Calculate characteristic time scales
# gamma = 1.0
# T_eff = 1.0
# J = jnp.max(jnp.abs(W))  # Coupling strength

# tau_relax = 1/gamma
# tau_diffusion = gamma/(2*T_eff)

# print(f"Relaxation time scale: {tau_relax:.2f}")
# print(f"Diffusion time scale: {tau_diffusion:.2f}")

# # Set simulation time accordingly
# t0 = 0.0
# t1 = 100 * max(tau_relax, tau_diffusion)  # Simulate for 10x the longest time scale
# dt0 = min(tau_relax, tau_diffusion) / 10  # Initial time step should be smaller than fastest time scale

# print(f"\nSuggested simulation parameters:")
# print(f"Total time: {t1:.2f}")
# print(f"Initial dt: {dt0:.2f}")

# ts = jnp.linspace(t0, t1, 10000)
# dt = ts[1] - ts[0]

# y0_x = jnp.array([jnp.pi,jnp.pi])

# %%
# # Update shape to match number of oscillators
# w_shape = (N_osc,)  # state is just phases for each oscillator
# brownian_motion = diffrax.VirtualBrownianTree(
#     t0, t1, 1.e-11, w_shape, jr.PRNGKey(0), diffrax.SpaceTimeLevyArea
# )
# terms_x = MultiTerm(ODETerm(drift_x_fn), ControlTerm(diffusion_x_fn, brownian_motion))
# saveat = diffrax.SaveAt(ts=ts)


# # sample 1000 points
# solution_x = diffrax.diffeqsolve(
#     terms_x,
#     solver=diffrax.SRA1(),
#     t0=t0,
#     t1=t1,
#     dt0=dt0,
#     y0=y0_x,
#     args=(),
#     saveat=saveat,
#     progress_meter=diffrax.TqdmProgressMeter(),
#     max_steps=1000000000,
#     stepsize_controller=diffrax.PIDController(rtol=1e-3, atol=1e-6),  # Enable adaptive stepping
# )
# sde_samples_x = solution_x.ys

# %%
# # Calculate number of timesteps corresponding to one relaxation time
# relax_steps = int(1/(gamma * dt))

# # Thin the samples by taking every relax_steps point
# sde_samples_x = solution_x.ys[::relax_steps]
# ts = ts[::relax_steps]

# %%
# # Create figure with a grid of subplots
# fig = plt.figure(figsize=(16, 12))
# gs = plt.GridSpec(2, 2, height_ratios=[2, 1])

# # Top left: Phase trajectories
# ax1 = fig.add_subplot(gs[0, 0])
# # Mod 2π for time trajectories
# ax1.plot(ts, jnp.mod(sde_samples_x[:, 0], 2*jnp.pi), label='θ₁(t)')
# ax1.plot(ts, jnp.mod(sde_samples_x[:, 1], 2*jnp.pi), label='θ₂(t)')
# ax1.set_xlabel('Time')
# ax1.set_ylabel('Phase (rad)')
# ax1.set_title('SDE Simulation: Phase vs Time')
# ax1.grid(True)
# ax1.legend()

# # Top right: Phase space with Energy contour
# ax2 = fig.add_subplot(gs[0, 1])
# contour = ax2.contourf(X1, X2, energy, levels=20, cmap='RdYlBu')
# plt.colorbar(contour, ax=ax2, label='Energy')

# # Mod 2π for phase space trajectory
# wrapped_x = jnp.mod(sde_samples_x, 2*jnp.pi)
# ax2.scatter(wrapped_x[:, 0], wrapped_x[:, 1], c='g', s=1, alpha=0.9999, label='Trajectory')
# ax2.plot(wrapped_x[0, 0], wrapped_x[0, 1], 'go', label='Start', markersize=10)


# ax2.set_xlabel('θ₁')
# ax2.set_ylabel('θ₂')
# ax2.set_title('Phase Space (Torus)')
# ax2.legend()

# # Bottom left: θ₁ histogram (mod 2π)
# ax3 = fig.add_subplot(gs[1, 0])
# ax3.hist(wrapped_x[:, 0], bins=50, density=True, alpha=0.7, label='θ₁ distribution')
# ax3.set_xlabel('θ₁')
# ax3.set_ylabel('Probability Density')
# ax3.grid(True)
# ax3.legend()

# # Bottom right: θ₂ histogram (mod 2π)
# ax4 = fig.add_subplot(gs[1, 1])
# ax4.hist(wrapped_x[:, 1], bins=50, density=True, alpha=0.7, label='θ₂ distribution')
# ax4.set_xlabel('θ₂')
# ax4.set_ylabel('Probability Density')
# ax4.grid(True)
# ax4.legend()

# plt.tight_layout()
# # Add title with parameters
# title = f'T_eff={T_eff}, γ={gamma}'
# plt.suptitle(title, y=1.02)

# plt.show()
