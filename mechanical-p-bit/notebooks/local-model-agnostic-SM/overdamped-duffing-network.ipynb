# %%
import jax
from jax import flatten_util 
import jax.numpy as jnp
import jax.random as jr
import diffrax
from diffrax import ControlTerm, MultiTerm, ODETerm
import matplotlib.pyplot as plt
from functools import partial
import optax
from helper_fns_general import sample_gaussian_mixture, CD1_gradient
jax.config.update("jax_enable_x64", True)

# %%
def normalize_samples(samples):
    """
    Normalize samples to have mean 0 and variance 1 along each dimension.
    
    Args:
        samples: Array of shape (n_samples, n_dimensions)
    
    Returns:
        Normalized samples with same shape as input
    """
    # Calculate mean and std along each dimension
    mean = jnp.mean(samples, axis=0)
    std = jnp.std(samples, axis=0)
    
    # Normalize
    normalized_samples = (samples - mean) / std
    
    return normalized_samples

# Apply normalization to samples

# %%
# Example usage

# Set random seed
key = jr.PRNGKey(0)

# Parameters
N = 2  # number of dimensions
N_mixgauss = 3  # number of mixture components
n_samples = 1000

# Define mixture weights (must sum to 1)
weights = jnp.array([0.5, 0.5])

# Define means
means = jnp.array([
    [1.5, 0.0],   # mean of first Gaussian
    [-0.0, 0.0],  # mean of second Gaussian
])

# Define covariance matrices
covs = jnp.array([
    [[.01, 0.0],    # covariance of first Gaussian
        [0.0, .01]],
    [[.01, -0.0],   # covariance of second Gaussian
        [-0.0, .01]],
])

# Generate samples
samples_raw = sample_gaussian_mixture(key, n_samples, weights, means, covs)
samples = normalize_samples(samples_raw)

# %%
# Plot samples and marginal distributions
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# First subplot: Scatter plot of samples
ax1.scatter(samples[:, 0], samples[:, 1], alpha=0.5)
ax1.set_title('Samples')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')

# Second subplot: Combined marginal distributions
ax2.hist(samples[:, 0], bins=50, density=True, alpha=0.7, label='X distribution')
ax2.hist(samples[:, 1], bins=50, density=True, alpha=0.7, label='Y distribution')
ax2.set_title('Marginal Distributions')
ax2.set_xlabel('Value')
ax2.set_ylabel('Density')
ax2.legend()

plt.tight_layout()
plt.show()

# %%
N_osc = 2
# Set symmetric coupling
K_lin = jnp.zeros((N_osc, N_osc))
K_lin = K_lin.at[0,1].set(-.1)
K_lin = K_lin.at[1,0].set(1.)  # Make it symmetric
K_lin = K_lin.at[0,0].set(1.)
K_lin = K_lin.at[1,1].set(-1.)
# Duffing stiffnesses
k_duffing = jnp.zeros(N_osc)
k_duffing = k_duffing.at[0].set(10.)

# Biases
external_force = jnp.zeros(N_osc)
external_force = external_force.at[0].set(-0)


args_initial = (K_lin, k_duffing, external_force)

flattened_args_initial, unflatten = flatten_util.ravel_pytree(args_initial)

# %%
def overdamped_duffing_energy(x, flattened_args):
    K_lin, k_duffing, external_force = unflatten(flattened_args)
    # Compute linear energy
    linear_energy = 1/2*jnp.dot(x, K_lin @ x)
    # Compute Duffing energy
    duffing_energy = 1/4*jnp.sum(k_duffing * x**4) 
    # Compute bias energy
    bias_energy = jnp.sum(external_force * x)
    return linear_energy + duffing_energy + bias_energy

energy_fn = overdamped_duffing_energy

# %%
# Create a grid of phase values
n_points = 30
x1 = jnp.linspace(-3, 3, n_points)
x2 = jnp.linspace(-3, 3, n_points)*20
X1, X2 = jnp.meshgrid(x1, x2)

# Compute energy for each point in the grid
energy = jnp.zeros((n_points, n_points))
for i in range(n_points):
    for j in range(n_points):
        x = jnp.array([X1[i,j], X2[i,j]])
        energy = energy.at[i,j].set(energy_fn(x, flattened_args_initial))

# Create the contour plot
plt.figure(figsize=(10, 8))
plt.contourf(X1, X2, energy, levels=20, cmap='viridis')
plt.colorbar(label='Energy')
# Add scatter plot of samples
plt.scatter(samples[:, 0], samples[:, 1], c='black', s=1, alpha=0.5, label='Samples')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('XY Model Energy Landscape for initial parameters')
plt.legend()
plt.show()

# %%
# Define optimization parameters
learning_rate = 0.001
n_epochs = 200000
batch_size = 128

# Initialize optimizer
optimizer = optax.adam(learning_rate=learning_rate)
opt_state = optimizer.init(flattened_args_initial)

# Training loop
@partial(jax.jit, static_argnums=(3,))
def training_step(params, opt_state, samples, n_samples, key):
    """Single training step using CD-1"""
    # Get gradient of parameters
    dparams = -CD1_gradient(energy_fn, samples, params, dt=0.001, D=1, key=14, num_noise_samples=0)
    
    # Compute log likelihood (negative energy)
    loss = -jnp.mean(jax.vmap(lambda x: energy_fn(x, params))(samples))
    
    # Apply updates
    updates, opt_state = optimizer.update(dparams, opt_state)
    params = optax.apply_updates(params, updates)
    
    return params, opt_state, key, loss

# Training loop
key = jr.PRNGKey(0)
params_history = []
loss_history = []

params = flattened_args_initial  # Use the flattened initial parameters

for epoch in range(n_epochs):
    key, subkey = jr.split(key)
    params, opt_state, key, loss = training_step(params, opt_state, samples, batch_size, subkey)
    
    # Store parameters and loss
    params_history.append(params)
    loss_history.append(loss)
    
    if epoch % 10 == 0:
        # Unflatten only for printing
        K_lin, k_duffing, external_force = unflatten(params)
        print(f"Epoch {epoch}")
        print(f"K_lin:\n{K_lin}")
        print(f"k_duffing:\n{k_duffing}")
        print(f"external_force:\n{external_force}")
        print(f"Loss: {loss:.4f}")
        print("---")
# Out:
# (1000, 8)
# Epoch 0
# K_lin:
# [[ 0.99900001 -0.09900015]
#  [-0.09900015 -0.99900002]]
# k_duffing:
# [0.99900001 0.00099999]
# external_force:
# [-9.99612621e-04 -1.77635684e-13]
# Loss: -0.2724
# ---
# Epoch 10
# K_lin:
# [[ 0.98900447 -0.0890369 ]
#  [-0.0890369  -0.98901818]]
# k_duffing:
# [0.98900456 0.01097135]
# external_force:
# [-0.01089244 -0.00106787]
# Loss: -0.2770
# ---
# Epoch 20
# K_lin:
# [[ 0.97902832 -0.07923547]
#  [-0.07923547 -0.97911723]]
# k_duffing:
# [0.97902895 0.02081216]
# external_force:
# [-0.02027554 -0.00246707]
# Loss: -0.2815
# ---
# Epoch 30
# K_lin:
# [[ 0.96908498 -0.06971985]
#  [-0.06971985 -0.96935528]]
# k_duffing:
# [0.96908687 0.0304243 ]
# external_force:
# [-0.02868194 -0.00367576]
# Loss: -0.2858
# ---
# Epoch 40
# K_lin:
# [[ 0.95918343 -0.06058338]
#  [-0.06058338 -0.95977235]]
# k_duffing:
# [0.95918743 0.03973529]
# external_force:
# [-0.03571551 -0.00467765]
# Loss: -0.2899
# ---
# Epoch 50
# K_lin:
# [[ 0.94932886 -0.05188876]
#  [-0.05188876 -0.95039191]]
# k_duffing:
# [0.94933576 0.04869711]
# external_force:
# [-0.0411329  -0.00578703]
# Loss: -0.2936
# ---
# Epoch 60
# K_lin:
# [[ 0.93952395 -0.04367559]
#  [-0.04367559 -0.94122577]]
# k_duffing:
# [0.93953439 0.05727945]
# external_force:
# [-0.04489071 -0.00680256]
# Loss: -0.2970
# ---
# Epoch 70
# K_lin:
# [[ 0.92976996 -0.0359682 ]
#  [-0.0359682  -0.93227862]]
# k_duffing:
# [0.92978437 0.06546287]
# external_force:
# [-0.04714255 -0.00777846]
# Loss: -0.3000
# ---
# Epoch 80
# K_lin:
# [[ 0.92006747 -0.02878112]
#  [-0.02878112 -0.92355112]]
# k_duffing:
# [0.92008606 0.07323431]
# external_force:
# [-0.04818399 -0.00869981]
# Loss: -0.3027
# ---
# Epoch 90
# K_lin:
# [[ 0.91041675 -0.02212195]
#  [-0.02212195 -0.91504154]]
# k_duffing:
# [0.91043953 0.08058456]
# external_force:
# [-0.04836893 -0.00958166]
# Loss: -0.3050
# ---
# Epoch 100
# K_lin:
# [[ 0.9008179  -0.01599274]
#  [-0.01599274 -0.90674662]]
# k_duffing:
# [0.90084474 0.0875071 ]
# external_force:
# [-0.04803124 -0.0104008 ]
# Loss: -0.3069
# ---
# Epoch 110
# K_lin:
# [[ 0.89127098 -0.01039053]
#  [-0.01039053 -0.89866194]]
# k_duffing:
# [0.89130168 0.09399769]
# external_force:
# [-0.04743455 -0.01117512]
# Loss: -0.3085
# ---
# Epoch 120
# K_lin:
# [[ 0.88177603 -0.00530753]
#  [-0.00530753 -0.89078211]]
# k_duffing:
# [0.88181034 0.10005425]
# external_force:
# [-0.04675485 -0.01189745]
# Loss: -0.3097
# ---
# Epoch 130
# K_lin:
# [[ 8.72333079e-01 -7.31327986e-04]
#  [-7.31327986e-04 -8.83100825e-01]]
# k_duffing:
# [0.87237074 0.1056769 ]
# external_force:
# [-0.04608807 -0.0125663 ]
# Loss: -0.3104
# ---
# Epoch 140
# K_lin:
# [[ 0.86294214  0.00335492]
#  [ 0.00335492 -0.87561098]]
# k_duffing:
# [0.86298292 0.110868  ]
# external_force:
# [-0.04547108 -0.01318409]
# Loss: -0.3109
# ---
# Epoch 150
# K_lin:
# [[ 0.85360325  0.00697209]
#  [ 0.00697209 -0.86830469]]
# k_duffing:
# [0.85364693 0.11563222]
# external_force:
# [-0.0449055  -0.01375152]
# Loss: -0.3109
# ---
# Epoch 160
# K_lin:
# [[ 0.84431644  0.01014461]
#  [ 0.01014461 -0.86117342]]
# k_duffing:
# [0.84436283 0.11997656]
# external_force:
# [-0.04437767 -0.01426898]
# Loss: -0.3106
# ---
# Epoch 170
# K_lin:
# [[ 0.83508173  0.01289982]
#  [ 0.01289982 -0.854208  ]]
# k_duffing:
# [0.83513067 0.12391027]
# external_force:
# [-0.0438717  -0.01473745]
# Loss: -0.3100
# ---
# Epoch 180
# K_lin:
# [[ 0.82589916  0.01526726]
#  [ 0.01526726 -0.8473988 ]]
# k_duffing:
# [0.8259505  0.12744476]
# external_force:
# [-0.04337578 -0.01515835]
# Loss: -0.3090
# ---
# Epoch 190
# K_lin:
# [[ 0.81676878  0.01727798]
#  [ 0.01727798 -0.84073576]]
# k_duffing:
# [0.81682237 0.13059347]
# external_force:
# [-0.04288357 -0.01553331]
# Loss: -0.3077
# ---
# Epoch 200
# K_lin:
# [[ 0.80769063  0.01896373]
#  [ 0.01896373 -0.83420858]]
# k_duffing:
# [0.80774634 0.13337166]
# external_force:
# [-0.04239305 -0.01586417]
# Loss: -0.3062
# ---
# Epoch 210
# K_lin:
# [[ 0.79866477  0.02035631]
#  [ 0.02035631 -0.82780681]]
# k_duffing:
# [0.79872245 0.13579615]
# external_force:
# [-0.04190453 -0.01615292]
# Loss: -0.3043
# ---
# Epoch 220
# K_lin:
# [[ 0.78969125  0.02148692]
#  [ 0.02148692 -0.82151992]]
# k_duffing:
# [0.78975078 0.13788507]
# external_force:
# [-0.041419   -0.01640172]
# Loss: -0.3021
# ---
# Epoch 230
# K_lin:
# [[ 0.78077013  0.02238562]
#  [ 0.02238562 -0.81533752]]
# k_duffing:
# [0.78083139 0.13965756]
# external_force:
# [-0.0409373  -0.01661285]
# Loss: -0.2997
# ---
# Epoch 240
# K_lin:
# [[ 0.7719015   0.0230809 ]
#  [ 0.0230809  -0.80924937]]
# k_duffing:
# [0.77196436 0.1411335 ]
# external_force:
# [-0.04045979 -0.01678868]
# Loss: -0.2971
# ---
# Epoch 250
# K_lin:
# [[ 0.76308541  0.02359935]
#  [ 0.02359935 -0.80324554]]
# k_duffing:
# [0.76314976 0.14233315]
# external_force:
# [-0.03998643 -0.01693161]
# Loss: -0.2943
# ---
# Epoch 260
# K_lin:
# [[ 0.75432196  0.02396545]
#  [ 0.02396545 -0.79731647]]
# k_duffing:
# [0.75438767 0.14327692]
# external_force:
# [-0.03951703 -0.01704408]
# Loss: -0.2913
# ---
# Epoch 270
# K_lin:
# [[ 0.74561122  0.02420143]
#  [ 0.02420143 -0.79145306]]
# k_duffing:
# [0.74567818 0.1439851 ]
# external_force:
# [-0.03905135 -0.0171285 ]
# Loss: -0.2881
# ---
# Epoch 280
# K_lin:
# [[ 0.73695328  0.02432726]
#  [ 0.02432726 -0.78564674]]
# k_duffing:
# [0.73702139 0.14447758]
# external_force:
# [-0.03858923 -0.01718725]
# Loss: -0.2847
# ---
# Epoch 290
# K_lin:
# [[ 0.72834823  0.02436064]
#  [ 0.02436064 -0.77988949]]
# k_duffing:
# [0.72841737 0.14477368]
# external_force:
# [-0.03813057 -0.01722261]
# Loss: -0.2812
# ---
# Epoch 300
# K_lin:
# [[ 0.71979617  0.02431712]
#  [ 0.02431712 -0.77417391]]
# k_duffing:
# [0.71986624 0.14489198]
# external_force:
# [-0.03767531 -0.0172368 ]
# Loss: -0.2776
# ---
# Epoch 310
# K_lin:
# [[ 0.71129718  0.0242102 ]
#  [ 0.0242102  -0.76849322]]
# k_duffing:
# [0.71136809 0.14485014]
# external_force:
# [-0.03722342 -0.01723193]
# Loss: -0.2739
# ---
# Epoch 320
# K_lin:
# [[ 0.70285138  0.02405152]
#  [ 0.02405152 -0.76284126]]
# k_duffing:
# [0.70292301 0.14466483]
# external_force:
# [-0.03677485 -0.01720997]
# Loss: -0.2701
# ---
# Epoch 330
# K_lin:
# [[ 0.69445885  0.02385099]
#  [ 0.02385099 -0.75721253]]
# k_duffing:
# [0.69453112 0.14435163]
# external_force:
# [-0.03632958 -0.01717279]
# Loss: -0.2663
# ---
# Epoch 340
# K_lin:
# [[ 0.6861197   0.023617  ]
#  [ 0.023617   -0.75160212]]
# k_duffing:
# [0.68619251 0.14392502]
# external_force:
# [-0.03588757 -0.0171221 ]
# Loss: -0.2624
# ---
# Epoch 350
# K_lin:
# [[ 0.67783403  0.02335657]
#  [ 0.02335657 -0.74600575]]
# k_duffing:
# [0.67790729 0.14339831]
# external_force:
# [-0.03544878 -0.0170595 ]
# Loss: -0.2584
# ---
# Epoch 360
# K_lin:
# [[ 0.66960193  0.02307556]
#  [ 0.02307556 -0.74041967]]
# k_duffing:
# [0.66967556 0.1427837 ]
# external_force:
# [-0.03501318 -0.01698643]
# Loss: -0.2544
# ---
# Epoch 370
# K_lin:
# [[ 0.66142351  0.0227788 ]
#  [ 0.0227788  -0.73484072]]
# k_duffing:
# [0.66149743 0.14209225]
# external_force:
# [-0.03458076 -0.01690421]
# Loss: -0.2504
# ---
# Epoch 380
# K_lin:
# [[ 0.65329887  0.02247023]
#  [ 0.02247023 -0.72926622]]
# k_duffing:
# [0.65337298 0.14133398]
# external_force:
# [-0.03415148 -0.01681404]
# Loss: -0.2464
# ---
# Epoch 390
# K_lin:
# [[ 0.6452281   0.02215309]
#  [ 0.02215309 -0.72369396]]
# k_duffing:
# [0.64530234 0.14051786]
# external_force:
# [-0.03372534 -0.01671698]
# Loss: -0.2423
# ---
# Epoch 400
# K_lin:
# [[ 0.6372113   0.02182997]
#  [ 0.02182997 -0.71812216]]
# k_duffing:
# [0.6372856  0.13965189]
# external_force:
# [-0.03330231 -0.01661398]
# Loss: -0.2383
# ---
# Epoch 410
# K_lin:
# [[ 0.62924858  0.02150297]
#  [ 0.02150297 -0.71254942]]
# k_duffing:
# [0.62932285 0.13874319]
# external_force:
# [-0.03288237 -0.0165059 ]
# Loss: -0.2343
# ---
# Epoch 420
# K_lin:
# [[ 0.62134003  0.02117375]
#  [ 0.02117375 -0.70697471]]
# k_duffing:
# [0.6214142  0.13779802]
# external_force:
# [-0.03246553 -0.01639347]
# Loss: -0.2303
# ---
# Epoch 430
# K_lin:
# [[ 0.61348574  0.02084363]
#  [ 0.02084363 -0.70139728]]
# k_duffing:
# [0.61355975 0.13682192]
# external_force:
# [-0.03205175 -0.01627736]
# Loss: -0.2263
# ---
# Epoch 440
# K_lin:
# [[ 0.60568581  0.02051365]
#  [ 0.02051365 -0.69581669]]
# k_duffing:
# [0.60575959 0.13581969]
# external_force:
# [-0.03164104 -0.01615814]
# Loss: -0.2223
# ---
# Epoch 450
# K_lin:
# [[ 0.59794032  0.02018463]
#  [ 0.02018463 -0.69023271]]
# k_duffing:
# [0.59801381 0.13479555]
# external_force:
# [-0.03123338 -0.01603631]
# Loss: -0.2184
# ---
# Epoch 460
# K_lin:
# [[ 0.59024938  0.0198572 ]
#  [ 0.0198572  -0.68464532]]
# k_duffing:
# [0.59032252 0.13375314]
# external_force:
# [-0.03082877 -0.01591231]
# Loss: -0.2145
# ---
# Epoch 470
# K_lin:
# [[ 0.58261306  0.01953185]
#  [ 0.01953185 -0.6790547 ]]
# k_duffing:
# [0.58268579 0.13269559]
# external_force:
# [-0.0304272 -0.0157865]
# Loss: -0.2106
# ---
# Epoch 480
# K_lin:
# [[ 0.57503146  0.01920895]
#  [ 0.01920895 -0.67346116]]
# k_duffing:
# [0.57510372 0.13162563]
# external_force:
# [-0.03002866 -0.01565922]
# Loss: -0.2068
# ---
# Epoch 490
# K_lin:
# [[ 0.56750465  0.01888878]
#  [ 0.01888878 -0.66786513]]
# k_duffing:
# [0.56757639 0.13054558]
# external_force:
# [-0.02963315 -0.01553073]
# Loss: -0.2030
# ---
# Epoch 500
# K_lin:
# [[ 0.56003273  0.01857156]
#  [ 0.01857156 -0.66226717]]
# k_duffing:
# [0.56010389 0.12945742]
# external_force:
# [-0.02924065 -0.01540128]
# Loss: -0.1992
# ---
# Epoch 510
# K_lin:
# [[ 0.55261578  0.01825744]
#  [ 0.01825744 -0.6566679 ]]
# k_duffing:
# [0.55268631 0.12836285]
# external_force:
# [-0.02885117 -0.01527106]
# Loss: -0.1954
# ---
# Epoch 520
# K_lin:
# [[ 0.54525386  0.01794653]
#  [ 0.01794653 -0.65106802]]
# k_duffing:
# [0.54532372 0.12726332]
# external_force:
# [-0.02846471 -0.01514025]
# Loss: -0.1917
# ---
# Epoch 530
# K_lin:
# [[ 0.53794707  0.01763891]
#  [ 0.01763891 -0.64546828]]
# k_duffing:
# [0.5380162  0.12616006]
# external_force:
# [-0.02808125 -0.015009  ]
# Loss: -0.1881
# ---
# Epoch 540
# K_lin:
# [[ 0.53069547  0.01733462]
#  [ 0.01733462 -0.63986947]]
# k_duffing:
# [0.53076383 0.12505411]
# external_force:
# [-0.0277008  -0.01487743]
# Loss: -0.1845
# ---
# Epoch 550
# K_lin:
# [[ 0.52349913  0.01703372]
#  [ 0.01703372 -0.63427241]]
# k_duffing:
# [0.52356667 0.12394637]
# external_force:
# [-0.02732335 -0.01474565]
# Loss: -0.1809
# ---
# Epoch 560
# K_lin:
# [[ 0.51635814  0.0167362 ]
#  [ 0.0167362  -0.62867793]]
# k_duffing:
# [0.51642482 0.12283759]
# external_force:
# [-0.02694889 -0.01461374]
# Loss: -0.1773
# ---
# Epoch 570
# K_lin:
# [[ 0.50927254  0.01644207]
#  [ 0.01644207 -0.62308689]]
# k_duffing:
# [0.50933832 0.12172842]
# external_force:
# [-0.02657744 -0.01448179]
# Loss: -0.1738
# ---
# Epoch 580
# K_lin:
# [[ 0.50224242  0.01615133]
#  [ 0.01615133 -0.61750014]]
# k_duffing:
# [0.50230725 0.1206194 ]
# external_force:
# [-0.02620898 -0.01434985]
# Loss: -0.1704
# ---
# Epoch 590
# K_lin:
# [[ 0.49526782  0.01586396]
#  [ 0.01586396 -0.61191854]]
# k_duffing:
# [0.49533168 0.11951102]
# external_force:
# [-0.02584351 -0.01421799]
# Loss: -0.1670
# ---
# Epoch 600
# K_lin:
# [[ 0.48834882  0.01557996]
#  [ 0.01557996 -0.60634293]]
# k_duffing:
# [0.48841165 0.11840368]
# external_force:
# [-0.02548103 -0.01408625]
# Loss: -0.1636
# ---
# Epoch 610
# K_lin:
# [[ 0.48148546  0.01529929]
#  [ 0.01529929 -0.60077415]]
# k_duffing:
# [0.48154724 0.11729773]
# external_force:
# [-0.02512154 -0.01395468]
# Loss: -0.1603
# ---
# Epoch 620
# K_lin:
# [[ 0.4746778   0.01502194]
#  [ 0.01502194 -0.59521303]]
# k_duffing:
# [0.47473849 0.11619348]
# external_force:
# [-0.02476504 -0.01382331]
# Loss: -0.1570
# ---
# Epoch 630
# K_lin:
# [[ 0.4679259   0.01474788]
#  [ 0.01474788 -0.5896604 ]]
# k_duffing:
# [0.46798547 0.1150912 ]
# external_force:
# [-0.02441153 -0.01369217]
# Loss: -0.1537
# ---
# Epoch 640
# K_lin:
# [[ 0.46122979  0.01447709]
#  [ 0.01447709 -0.58411705]]
# k_duffing:
# [0.46128821 0.11399113]
# external_force:
# [-0.024061  -0.0135613]
# Loss: -0.1505
# ---
# Epoch 650
# K_lin:
# [[ 0.45458953  0.01420953]
#  [ 0.01420953 -0.57858376]]
# k_duffing:
# [0.45464676 0.11289349]
# external_force:
# [-0.02371345 -0.01343072]
# Loss: -0.1473
# ---
# Epoch 660
# K_lin:
# [[ 0.44800516  0.01394519]
#  [ 0.01394519 -0.5730613 ]]
# k_duffing:
# [0.44806117 0.11179847]
# external_force:
# [-0.02336889 -0.01330045]
# Loss: -0.1442
# ---
# Epoch 670
# K_lin:
# [[ 0.44147671  0.01368404]
#  [ 0.01368404 -0.56755042]]
# k_duffing:
# [0.44153148 0.11070624]
# external_force:
# [-0.0230273  -0.01317051]
# Loss: -0.1411
# ---
# Epoch 680
# K_lin:
# [[ 0.43500423  0.01342604]
#  [ 0.01342604 -0.56205186]]
# k_duffing:
# [0.43505772 0.10961697]
# external_force:
# [-0.0226887  -0.01304092]
# Loss: -0.1380
# ---
# Epoch 690
# K_lin:
# [[ 0.42858774  0.01317118]
#  [ 0.01317118 -0.55656632]]
# k_duffing:
# [0.42863993 0.10853082]
# external_force:
# [-0.02235308 -0.0129117 ]
# Loss: -0.1350
# ---
# Epoch 700
# K_lin:
# [[ 0.42222727  0.01291942]
#  [ 0.01291942 -0.5510945 ]]
# k_duffing:
# [0.42227813 0.10744791]
# external_force:
# [-0.02202043 -0.01278287]
# Loss: -0.1320
# ---
# Epoch 710
# K_lin:
# [[ 0.41592284  0.01267075]
#  [ 0.01267075 -0.54563707]]
# k_duffing:
# [0.41597235 0.10636838]
# external_force:
# [-0.02169076 -0.01265444]
# Loss: -0.1291
# ---
# Epoch 720
# K_lin:
# [[ 0.40967448  0.01242514]
#  [ 0.01242514 -0.5401947 ]]
# k_duffing:
# [0.40972262 0.10529235]
# external_force:
# [-0.02136406 -0.01252643]
# Loss: -0.1262
# ---
# Epoch 730
# K_lin:
# [[ 0.40348221  0.01218256]
#  [ 0.01218256 -0.53476802]]
# k_duffing:
# [0.40352895 0.10421995]
# external_force:
# [-0.02104033 -0.01239885]
# Loss: -0.1233
# ---
# Epoch 740
# K_lin:
# [[ 0.39734604  0.011943  ]
#  [ 0.011943   -0.52935765]]
# k_duffing:
# [0.39739136 0.10315128]
# external_force:
# [-0.02071958 -0.01227171]
# Loss: -0.1205
# ---
# Epoch 750
# K_lin:
# [[ 0.39126597  0.01170642]
#  [ 0.01170642 -0.52396421]]
# k_duffing:
# [0.39130985 0.10208645]
# external_force:
# [-0.02040179 -0.01214503]
# Loss: -0.1177
# ---
# Epoch 760
# K_lin:
# [[ 0.38524202  0.01147281]
#  [ 0.01147281 -0.51858829]]
# k_duffing:
# [0.38528444 0.10102557]
# external_force:
# [-0.02008698 -0.01201882]
# Loss: -0.1149
# ---
# Epoch 770
# K_lin:
# [[ 0.37927419  0.01124215]
#  [ 0.01124215 -0.51323044]]
# k_duffing:
# [0.37931513 0.09996874]
# external_force:
# [-0.01977513 -0.01189309]
# Loss: -0.1122
# ---
# Epoch 780
# K_lin:
# [[ 0.37336246  0.01101442]
#  [ 0.01101442 -0.50789124]]
# k_duffing:
# [0.37340191 0.09891605]
# external_force:
# [-0.01946624 -0.01176786]
# Loss: -0.1095
# ---
# Epoch 790
# K_lin:
# [[ 0.36750685  0.01078959]
#  [ 0.01078959 -0.50257123]]
# k_duffing:
# [0.36754478 0.09786759]
# external_force:
# [-0.01916031 -0.01164313]
# Loss: -0.1069
# ---
# Epoch 800
# K_lin:
# [[ 0.36170733  0.01056765]
#  [ 0.01056765 -0.49727092]]
# k_duffing:
# [0.36174373 0.09682346]
# external_force:
# [-0.01885735 -0.01151891]
# Loss: -0.1042
# ---
# Epoch 810
# K_lin:
# [[ 0.35596389  0.01034857]
#  [ 0.01034857 -0.49199084]]
# k_duffing:
# [0.35599874 0.09578374]
# external_force:
# [-0.01855734 -0.01139522]
# Loss: -0.1017
# ---
# Epoch 820
# K_lin:
# [[ 0.3502765   0.01013235]
#  [ 0.01013235 -0.48673149]]
# k_duffing:
# [0.3503098  0.09474852]
# external_force:
# [-0.01826029 -0.01127206]
# Loss: -0.0991
# ---
# Epoch 830
# K_lin:
# [[ 0.34464516  0.00991895]
#  [ 0.00991895 -0.48149334]]
# k_duffing:
# [0.34467688 0.09371788]
# external_force:
# [-0.01796618 -0.01114945]
# Loss: -0.0966
# ---
# Epoch 840
# K_lin:
# [[ 0.33906982  0.00970837]
#  [ 0.00970837 -0.47627687]]
# k_duffing:
# [0.33909996 0.0926919 ]
# external_force:
# [-0.01767503 -0.01102739]
# Loss: -0.0942
# ---
# Epoch 850
# K_lin:
# [[ 0.33355045  0.00950058]
#  [ 0.00950058 -0.47108254]]
# k_duffing:
# [0.33357899 0.09167065]
# external_force:
# [-0.01738682 -0.01090589]
# Loss: -0.0917
# ---
# Epoch 860
# K_lin:
# [[ 0.32808701  0.00929557]
#  [ 0.00929557 -0.46591079]]
# k_duffing:
# [0.32811394 0.09065421]
# external_force:
# [-0.01710156 -0.01078497]
# Loss: -0.0893
# ---
# Epoch 870
# K_lin:
# [[ 0.32267946  0.00909332]
#  [ 0.00909332 -0.46076205]]
# k_duffing:
# [0.32270478 0.08964266]
# external_force:
# [-0.01681923 -0.01066463]
# Loss: -0.0870
# ---
# Epoch 880
# K_lin:
# [[ 0.31732775  0.00889382]
#  [ 0.00889382 -0.45563676]]
# k_duffing:
# [0.31735144 0.08863607]
# external_force:
# [-0.01653984 -0.01054488]
# Loss: -0.0847
# ---
# Epoch 890
# K_lin:
# [[ 0.31203183  0.00869704]
#  [ 0.00869704 -0.4505353 ]]
# k_duffing:
# [0.31205388 0.0876345 ]
# external_force:
# [-0.01626338 -0.01042572]
# Loss: -0.0824
# ---
# Epoch 900
# K_lin:
# [[ 0.30679163  0.00850297]
#  [ 0.00850297 -0.4454581 ]]
# k_duffing:
# [0.30681204 0.08663802]
# external_force:
# [-0.01598984 -0.01030717]
# Loss: -0.0801
# ---
# Epoch 910
# K_lin:
# [[ 0.3016071   0.0083116 ]
#  [ 0.0083116  -0.44040552]]
# k_duffing:
# [0.30162585 0.08564669]
# external_force:
# [-0.01571923 -0.01018924]
# Loss: -0.0779
# ---
# Epoch 920
# K_lin:
# [[ 0.29647815  0.00812291]
#  [ 0.00812291 -0.43537796]]
# k_duffing:
# [0.29649525 0.08466059]
# external_force:
# [-0.01545154 -0.01007192]
# Loss: -0.0757
# ---
# Epoch 930
# K_lin:
# [[ 0.29140473  0.00793688]
#  [ 0.00793688 -0.43037576]]
# k_duffing:
# [0.29142015 0.08367976]
# external_force:
# [-0.01518676 -0.00995524]
# Loss: -0.0736
# ---
# Epoch 940
# K_lin:
# [[ 0.28638674  0.00775349]
#  [ 0.00775349 -0.4253993 ]]
# k_duffing:
# [0.28640049 0.08270428]
# external_force:
# [-0.01492489 -0.00983919]
# Loss: -0.0714
# ---
# Epoch 950
# K_lin:
# [[ 0.2814241   0.00757274]
#  [ 0.00757274 -0.42044891]]
# k_duffing:
# [0.28143618 0.08173419]
# external_force:
# [-0.01466592 -0.00972378]
# Loss: -0.0694
# ---
# Epoch 960
# K_lin:
# [[ 0.27651672  0.00739461]
#  [ 0.00739461 -0.41552493]]
# k_duffing:
# [0.27652712 0.08076956]
# external_force:
# [-0.01440985 -0.00960902]
# Loss: -0.0673
# ---
# Epoch 970
# K_lin:
# [[ 0.2716645   0.00721908]
#  [ 0.00721908 -0.41062768]]
# k_duffing:
# [0.27167322 0.07981044]
# external_force:
# [-0.01415667 -0.00949491]
# Loss: -0.0653
# ---
# Epoch 980
# K_lin:
# [[ 0.26686735  0.00704613]
#  [ 0.00704613 -0.40575748]]
# k_duffing:
# [0.26687438 0.07885687]
# external_force:
# [-0.01390637 -0.00938147]
# Loss: -0.0633
# ---
# Epoch 990
# K_lin:
# [[ 0.26212514  0.00687576]
#  [ 0.00687576 -0.40091464]]
# k_duffing:
# [0.26213049 0.07790892]
# external_force:
# [-0.01365895 -0.0092687 ]
# Loss: -0.0613
# ---
# Epoch 1000
# K_lin:
# [[ 0.25743777  0.00670794]
#  [ 0.00670794 -0.39609945]]
# k_duffing:
# [0.25744143 0.07696663]
# external_force:
# [-0.01341441 -0.00915659]
# Loss: -0.0594
# ---
# Epoch 1010
# K_lin:
# [[ 0.25280511  0.00654265]
#  [ 0.00654265 -0.39131221]]
# k_duffing:
# [0.25280708 0.07603005]
# external_force:
# [-0.01317273 -0.00904517]
# Loss: -0.0575
# ---
# Epoch 1020
# K_lin:
# [[ 0.24822704  0.0063799 ]
#  [ 0.0063799  -0.38655319]]
# k_duffing:
# [0.24822732 0.07509922]
# external_force:
# [-0.01293391 -0.00893443]
# Loss: -0.0557
# ---
# Epoch 1030
# K_lin:
# [[ 0.24370343  0.00621965]
#  [ 0.00621965 -0.38182267]]
# k_duffing:
# [0.24370202 0.0741742 ]
# external_force:
# [-0.01269794 -0.00882439]
# Loss: -0.0539
# ---
# Epoch 1040
# K_lin:
# [[ 0.23923413  0.00606189]
#  [ 0.00606189 -0.3771209 ]]
# k_duffing:
# [0.23923104 0.07325502]
# external_force:
# [-0.01246481 -0.00871503]
# Loss: -0.0521
# ---
# Epoch 1050
# K_lin:
# [[ 0.23481901  0.00590662]
#  [ 0.00590662 -0.37244815]]
# k_duffing:
# [0.23481423 0.07234173]
# external_force:
# [-0.01223451 -0.00860638]
# Loss: -0.0503
# ---
# Epoch 1060
# K_lin:
# [[ 0.23045792  0.0057538 ]
#  [ 0.0057538  -0.36780466]]
# k_duffing:
# [0.23045145 0.07143436]
# external_force:
# [-0.01200705 -0.00849844]
# Loss: -0.0486
# ---
# Epoch 1070
# K_lin:
# [[ 0.22615068  0.00560344]
#  [ 0.00560344 -0.36319067]]
# k_duffing:
# [0.22614254 0.07053297]
# external_force:
# [-0.0117824 -0.0083912]
# Loss: -0.0469
# ---
# Epoch 1080
# K_lin:
# [[ 0.22189716  0.0054555 ]
#  [ 0.0054555  -0.35860642]]
# k_duffing:
# [0.22188734 0.06963758]
# external_force:
# [-0.01156055 -0.00828468]
# Loss: -0.0452
# ---
# Epoch 1090
# K_lin:
# [[ 0.21769716  0.00530998]
#  [ 0.00530998 -0.35405211]]
# k_duffing:
# [0.21768567 0.06874823]
# external_force:
# [-0.01134151 -0.00817887]
# Loss: -0.0436
# ---
# Epoch 1100
# K_lin:
# [[ 0.21355053  0.00516685]
#  [ 0.00516685 -0.34952798]]
# k_duffing:
# [0.21353737 0.06786495]
# external_force:
# [-0.01112526 -0.00807379]
# Loss: -0.0420
# ---
# Epoch 1110
# K_lin:
# [[ 0.20945707  0.00502612]
#  [ 0.00502612 -0.34503423]]
# k_duffing:
# [0.20944225 0.06698779]
# external_force:
# [-0.01091178 -0.00796944]
# Loss: -0.0404
# ---
# Epoch 1120
# K_lin:
# [[ 0.20541661  0.00488775]
#  [ 0.00488775 -0.34057106]]
# k_duffing:
# [0.20540012 0.06611678]
# external_force:
# [-0.01070108 -0.00786582]
# Loss: -0.0388
# ---
# Epoch 1130
# K_lin:
# [[ 0.20142894  0.00475173]
#  [ 0.00475173 -0.33613866]]
# k_duffing:
# [0.2014108  0.06525194]
# external_force:
# [-0.01049313 -0.00776293]
# Loss: -0.0373
# ---
# Epoch 1140
# K_lin:
# [[ 0.19749386  0.00461804]
#  [ 0.00461804 -0.33173723]]
# k_duffing:
# [0.19747408 0.06439331]
# external_force:
# [-0.01028794 -0.00766078]
# Loss: -0.0358
# ---
# Epoch 1150
# K_lin:
# [[ 0.19361118  0.00448667]
#  [ 0.00448667 -0.32736693]]
# k_duffing:
# [0.19358975 0.06354091]
# external_force:
# [-0.01008548 -0.00755937]
# Loss: -0.0344
# ---
# Epoch 1160
# K_lin:
# [[ 0.18978067  0.00435761]
#  [ 0.00435761 -0.32302796]]
# k_duffing:
# [0.18975761 0.06269477]
# external_force:
# [-0.00988574 -0.00745871]
# Loss: -0.0330
# ---
# Epoch 1170
# K_lin:
# [[ 0.18600211  0.00423083]
#  [ 0.00423083 -0.31872046]]
# k_duffing:
# [0.18597743 0.06185493]
# external_force:
# [-0.00968872 -0.00735879]
# Loss: -0.0316
# ---
# Epoch 1180
# K_lin:
# [[ 0.18227529  0.00410631]
#  [ 0.00410631 -0.31444461]]
# k_duffing:
# [0.18224899 0.0610214 ]
# external_force:
# [-0.0094944  -0.00725963]
# Loss: -0.0302
# ---
# Epoch 1190
# K_lin:
# [[ 0.17859996  0.00398405]
#  [ 0.00398405 -0.31020056]]
# k_duffing:
# [0.17857206 0.06019422]
# external_force:
# [-0.00930277 -0.00716122]
# Loss: -0.0288
# ---
# Epoch 1200
# K_lin:
# [[ 0.1749759   0.00386403]
#  [ 0.00386403 -0.30598844]]
# k_duffing:
# [0.17494639 0.05937339]
# external_force:
# [-0.00911382 -0.00706357]
# Loss: -0.0275
# ---
# Epoch 1210
# K_lin:
# [[ 0.17140285  0.00374622]
#  [ 0.00374622 -0.30180841]]
# k_duffing:
# [0.17137176 0.05855895]
# external_force:
# [-0.00892753 -0.00696668]
# Loss: -0.0262
# ---
# Epoch 1220
# K_lin:
# [[ 0.16788057  0.0036306 ]
#  [ 0.0036306  -0.29766059]]
# k_duffing:
# [0.16784789 0.05775092]
# external_force:
# [-0.0087439  -0.00687055]
# Loss: -0.0250
# ---
# Epoch 1230
# K_lin:
# [[ 0.1644088   0.00351717]
#  [ 0.00351717 -0.29354511]]
# k_duffing:
# [0.16437455 0.05694932]
# external_force:
# [-0.00856289 -0.00677519]
# Loss: -0.0238
# ---
# Epoch 1240
# K_lin:
# [[ 0.16098727  0.0034059 ]
#  [ 0.0034059  -0.2894621 ]]
# k_duffing:
# [0.16095146 0.05615416]
# external_force:
# [-0.00838451 -0.00668059]
# Loss: -0.0226
# ---
# Epoch 1250
# K_lin:
# [[ 0.15761572  0.00329678]
#  [ 0.00329678 -0.28541166]]
# k_duffing:
# [0.15757836 0.05536547]
# external_force:
# [-0.00820874 -0.00658676]
# Loss: -0.0214
# ---
# Epoch 1260
# K_lin:
# [[ 0.15429386  0.00318979]
#  [ 0.00318979 -0.28139392]]
# k_duffing:
# [0.15425497 0.05458325]
# external_force:
# [-0.00803557 -0.0064937 ]
# Loss: -0.0202
# ---
# Epoch 1270
# K_lin:
# [[ 0.15102143  0.0030849 ]
#  [ 0.0030849  -0.27740896]]
# k_duffing:
# [0.15098101 0.05380753]
# external_force:
# [-0.00786497 -0.00640142]
# Loss: -0.0191
# ---
# Epoch 1280
# K_lin:
# [[ 0.14779813  0.00298211]
#  [ 0.00298211 -0.27345689]]
# k_duffing:
# [0.1477562  0.05303832]
# external_force:
# [-0.00769694 -0.0063099 ]
# Loss: -0.0180
# ---
# Epoch 1290
# K_lin:
# [[ 0.14462367  0.00288138]
#  [ 0.00288138 -0.2695378 ]]
# k_duffing:
# [0.14458023 0.05227564]
# external_force:
# [-0.00753145 -0.00621917]
# Loss: -0.0169
# ---
# Epoch 1300
# K_lin:
# [[ 0.14149775  0.00278271]
#  [ 0.00278271 -0.26565177]]
# k_duffing:
# [0.14145282 0.05151949]
# external_force:
# [-0.0073685  -0.00612921]
# Loss: -0.0159
# ---
# Epoch 1310
# K_lin:
# [[ 0.13842006  0.00268607]
#  [ 0.00268607 -0.26179888]]
# k_duffing:
# [0.13837365 0.05076989]
# external_force:
# [-0.00720806 -0.00604003]
# Loss: -0.0149
# ---
# Epoch 1320
# K_lin:
# [[ 0.13539029  0.00259145]
#  [ 0.00259145 -0.25797921]]
# k_duffing:
# [0.13534242 0.05002684]
# external_force:
# [-0.00705012 -0.00595164]
# Loss: -0.0139
# ---
# Epoch 1330
# K_lin:
# [[ 0.13240813  0.00249882]
#  [ 0.00249882 -0.25419282]]
# k_duffing:
# [0.13235881 0.04929037]
# external_force:
# [-0.00689467 -0.00586402]
# Loss: -0.0129
# ---
# Epoch 1340
# K_lin:
# [[ 0.12947325  0.00240817]
#  [ 0.00240817 -0.25043978]]
# k_duffing:
# [0.12942249 0.04856047]
# external_force:
# [-0.00674169 -0.00577718]
# Loss: -0.0120
# ---
# Epoch 1350
# K_lin:
# [[ 0.12658533  0.00231947]
#  [ 0.00231947 -0.24672013]]
# k_duffing:
# [0.12653314 0.04783715]
# external_force:
# [-0.00659115 -0.00569113]
# Loss: -0.0111
# ---
# Epoch 1360
# K_lin:
# [[ 0.12374403  0.00223271]
#  [ 0.00223271 -0.24303394]]
# k_duffing:
# [0.12369043 0.04712042]
# external_force:
# [-0.00644304 -0.00560587]
# Loss: -0.0102
# ---
# Epoch 1370
# K_lin:
# [[ 0.12094901  0.00214787]
#  [ 0.00214787 -0.23938125]]
# k_duffing:
# [0.12089402 0.04641029]
# external_force:
# [-0.00629735 -0.00552138]
# Loss: -0.0093
# ---
# Epoch 1380
# K_lin:
# [[ 0.11819993  0.00206492]
#  [ 0.00206492 -0.23576209]]
# k_duffing:
# [0.11814356 0.04570675]
# external_force:
# [-0.00615406 -0.00543768]
# Loss: -0.0084
# ---
# Epoch 1390
# K_lin:
# [[ 0.11549644  0.00198385]
#  [ 0.00198385 -0.2321765 ]]
# k_duffing:
# [0.11543871 0.04500982]
# external_force:
# [-0.00601314 -0.00535477]
# Loss: -0.0076
# ---
# Epoch 1400
# K_lin:
# [[ 0.11283819  0.00190463]
#  [ 0.00190463 -0.22862451]]
# k_duffing:
# [0.1127791  0.04431949]
# external_force:
# [-0.00587458 -0.00527265]
# Loss: -0.0068
# ---
# Epoch 1410
# K_lin:
# [[ 0.11022481  0.00182725]
#  [ 0.00182725 -0.22510615]]
# k_duffing:
# [0.11016438 0.04363577]
# external_force:
# [-0.00573836 -0.0051913 ]
# Loss: -0.0060
# ---
# Epoch 1420
# K_lin:
# [[ 0.10765594  0.00175168]
#  [ 0.00175168 -0.22162143]]
# k_duffing:
# [0.10759419 0.04295866]
# external_force:
# [-0.00560447 -0.00511075]
# Loss: -0.0053
# ---
# Epoch 1430
# K_lin:
# [[ 0.10513122  0.0016779 ]
#  [ 0.0016779  -0.21817036]]
# k_duffing:
# [0.10506816 0.04228815]
# external_force:
# [-0.00547287 -0.00503098]
# Loss: -0.0045
# ---
# Epoch 1440
# K_lin:
# [[ 0.10265026  0.0016059 ]
#  [ 0.0016059  -0.21475295]]
# k_duffing:
# [0.10258591 0.04162425]
# external_force:
# [-0.00534356 -0.004952  ]
# Loss: -0.0038
# ---
# Epoch 1450
# K_lin:
# [[ 0.10021269  0.00153564]
#  [ 0.00153564 -0.21136921]]
# k_duffing:
# [0.10014706 0.04096695]
# external_force:
# [-0.00521651 -0.0048738 ]
# Loss: -0.0031
# ---
# Epoch 1460
# K_lin:
# [[ 0.09781812  0.00146712]
#  [ 0.00146712 -0.20801913]]
# k_duffing:
# [0.09775124 0.04031625]
# external_force:
# [-0.0050917  -0.00479639]
# Loss: -0.0025
# ---
# Epoch 1470
# K_lin:
# [[ 0.09546618  0.0014003 ]
#  [ 0.0014003  -0.2047027 ]]
# k_duffing:
# [0.09539805 0.03967215]
# external_force:
# [-0.00496911 -0.00471976]
# Loss: -0.0018
# ---
# Epoch 1480
# K_lin:
# [[ 0.09315646  0.00133517]
#  [ 0.00133517 -0.20141991]]
# k_duffing:
# [0.0930871  0.03903464]
# external_force:
# [-0.00484873 -0.00464392]
# Loss: -0.0012
# ---
# Epoch 1490
# K_lin:
# [[ 0.09088857  0.00127171]
#  [ 0.00127171 -0.19817074]]
# k_duffing:
# [0.09081801 0.03840371]
# external_force:
# [-0.00473052 -0.00456886]
# Loss: -0.0006
# ---
# Epoch 1500
# K_lin:
# [[ 0.08866212  0.00120988]
#  [ 0.00120988 -0.19495518]]
# k_duffing:
# [0.08859036 0.03777936]
# external_force:
# [-0.00461448 -0.00449458]
# Loss: -0.0000
# ---
# Epoch 1510
# K_lin:
# [[ 0.08647669  0.00114968]
#  [ 0.00114968 -0.19177318]]
# k_duffing:
# [0.08640375 0.03716157]
# external_force:
# [-0.00450057 -0.00442108]
# Loss: 0.0006
# ---
# Epoch 1520
# K_lin:
# [[ 0.08433188  0.00109108]
#  [ 0.00109108 -0.18862473]]
# k_duffing:
# [0.08425778 0.03655035]
# external_force:
# [-0.00438879 -0.00434837]
# Loss: 0.0011
# ---
# Epoch 1530
# K_lin:
# [[ 0.08222729  0.00103405]
#  [ 0.00103405 -0.18550977]]
# k_duffing:
# [0.08215204 0.03594569]
# external_force:
# [-0.0042791  -0.00427643]
# Loss: 0.0016
# ---
# Epoch 1540
# K_lin:
# [[ 0.08016249  0.00097859]
#  [ 0.00097859 -0.18242827]]
# k_duffing:
# [0.08008611 0.03534756]
# external_force:
# [-0.00417148 -0.00420527]
# Loss: 0.0022
# ---
# Epoch 1550
# K_lin:
# [[ 0.07813708  0.00092465]
#  [ 0.00092465 -0.17938018]]
# k_duffing:
# [0.07805958 0.03475596]
# external_force:
# [-0.00406592 -0.00413489]
# Loss: 0.0026
# ---
# Epoch 1560
# K_lin:
# [[ 0.07615062  0.00087222]
#  [ 0.00087222 -0.17636545]]
# k_duffing:
# [0.07607203 0.03417088]
# external_force:
# [-0.00396238 -0.00406529]
# Loss: 0.0031
# ---
# Epoch 1570
# K_lin:
# [[ 0.0742027   0.00082129]
#  [ 0.00082129 -0.17338402]]
# k_duffing:
# [0.07412302 0.03359231]
# external_force:
# [-0.00386086 -0.00399645]
# Loss: 0.0036
# ---
# Epoch 1580
# K_lin:
# [[ 0.07229289  0.00077181]
#  [ 0.00077181 -0.17043583]]
# k_duffing:
# [0.07221215 0.03302022]
# external_force:
# [-0.00376132 -0.00392839]
# Loss: 0.0040
# ---
# Epoch 1590
# K_lin:
# [[ 0.07042076  0.00072379]
#  [ 0.00072379 -0.1675208 ]]
# k_duffing:
# [0.07033897 0.03245461]
# external_force:
# [-0.00366375 -0.0038611 ]
# Loss: 0.0044
# ---
# Epoch 1600
# K_lin:
# [[ 0.06858588  0.00067718]
#  [ 0.00067718 -0.16463888]]
# k_duffing:
# [0.06850307 0.03189547]
# external_force:
# [-0.00356812 -0.00379458]
# Loss: 0.0048
# ---
# Epoch 1610
# K_lin:
# [[ 0.06678782  0.00063197]
#  [ 0.00063197 -0.16178999]]
# k_duffing:
# [0.06670399 0.03134276]
# external_force:
# [-0.00347441 -0.00372883]
# Loss: 0.0052
# ---
# Epoch 1620
# K_lin:
# [[ 0.06502614  0.00058814]
#  [ 0.00058814 -0.15897403]]
# k_duffing:
# [0.06494132 0.03079648]
# external_force:
# [-0.00338259 -0.00366384]
# Loss: 0.0056
# ---
# Epoch 1630
# K_lin:
# [[ 0.06330041  0.00054567]
#  [ 0.00054567 -0.15619094]]
# k_duffing:
# [0.0632146  0.03025661]
# external_force:
# [-0.00329265 -0.00359961]
# Loss: 0.0059
# ---
# Epoch 1640
# K_lin:
# [[ 0.06161018  0.00050452]
#  [ 0.00050452 -0.15344061]]
# k_duffing:
# [0.06152341 0.02972313]
# external_force:
# [-0.00320456 -0.00353615]
# Loss: 0.0063
# ---
# Epoch 1650
# K_lin:
# [[ 0.05995502  0.00046469]
#  [ 0.00046469 -0.15072297]]
# k_duffing:
# [0.0598673  0.02919602]
# external_force:
# [-0.00311829 -0.00347344]
# Loss: 0.0066
# ---
# Epoch 1660
# K_lin:
# [[ 0.05833448  0.00042614]
#  [ 0.00042614 -0.1480379 ]]
# k_duffing:
# [0.05824582 0.02867526]
# external_force:
# [-0.00303383 -0.00341148]
# Loss: 0.0069
# ---
# Epoch 1670
# K_lin:
# [[ 0.05674812  0.00038885]
#  [ 0.00038885 -0.1453853 ]]
# k_duffing:
# [0.05665855 0.02816082]
# external_force:
# [-0.00295116 -0.00335028]
# Loss: 0.0072
# ---
# Epoch 1680
# K_lin:
# [[ 0.05519549  0.00035281]
#  [ 0.00035281 -0.14276507]]
# k_duffing:
# [0.05510502 0.02765269]
# external_force:
# [-0.00287024 -0.00328983]
# Loss: 0.0075
# ---
# Epoch 1690
# K_lin:
# [[ 0.05367615  0.00031799]
#  [ 0.00031799 -0.1401771 ]]
# k_duffing:
# [0.05358479 0.02715085]
# external_force:
# [-0.00279105 -0.00323013]
# Loss: 0.0077
# ---
# Epoch 1700
# K_lin:
# [[ 0.05218964  0.00028436]
#  [ 0.00028436 -0.13762127]]
# k_duffing:
# [0.05209742 0.02665526]
# external_force:
# [-0.00271358 -0.00317117]
# Loss: 0.0080
# ---
# Epoch 1710
# K_lin:
# [[ 0.05073554  0.00025191]
#  [ 0.00025191 -0.13509747]]
# k_duffing:
# [0.05064246 0.02616591]
# external_force:
# [-0.00263779 -0.00311295]
# Loss: 0.0082
# ---
# Epoch 1720
# K_lin:
# [[ 0.04931337  0.00022061]
#  [ 0.00022061 -0.13260556]]
# k_duffing:
# [0.04921947 0.02568276]
# external_force:
# [-0.00256367 -0.00305547]
# Loss: 0.0085
# ---
# Epoch 1730
# K_lin:
# [[ 0.04792271  0.00019044]
#  [ 0.00019044 -0.13014542]]
# k_duffing:
# [0.04782798 0.0252058 ]
# external_force:
# [-0.0024912  -0.00299873]
# Loss: 0.0087
# ---
# Epoch 1740
# K_lin:
# [[ 0.04656309  0.00016138]
#  [ 0.00016138 -0.12771692]]
# k_duffing:
# [0.04646756 0.024735  ]
# external_force:
# [-0.00242034 -0.00294272]
# Loss: 0.0089
# ---
# Epoch 1750
# K_lin:
# [[ 0.04523407  0.0001334 ]
#  [ 0.0001334  -0.12531992]]
# k_duffing:
# [0.04513775 0.02427032]
# external_force:
# [-0.00235107 -0.00288743]
# Loss: 0.0090
# ---
# Epoch 1760
# K_lin:
# [[ 4.39352009e-02  1.06487442e-04]
#  [ 1.06487442e-04 -1.22954290e-01]]
# k_duffing:
# [0.04383811 0.02381175]
# external_force:
# [-0.00228338 -0.00283288]
# Loss: 0.0092
# ---
# Epoch 1770
# K_lin:
# [[ 4.26660365e-02  8.06177911e-05]
#  [ 8.06177911e-05 -1.20619877e-01]]
# k_duffing:
# [0.04256819 0.02335925]
# external_force:
# [-0.00221723 -0.00277904]
# Loss: 0.0094
# ---
# Epoch 1780
# K_lin:
# [[ 4.14261276e-02  5.57685207e-05]
#  [ 5.57685207e-05 -1.18316536e-01]]
# k_duffing:
# [0.04132755 0.02291279]
# external_force:
# [-0.00215261 -0.00272593]
# Loss: 0.0095
# ---
# Epoch 1790
# K_lin:
# [[ 4.02150270e-02  3.19179676e-05]
#  [ 3.19179676e-05 -1.16044116e-01]]
# k_duffing:
# [0.04011572 0.02247234]
# external_force:
# [-0.00208949 -0.00267353]
# Loss: 0.0097
# ---
# Epoch 1800
# K_lin:
# [[ 3.90322885e-02  9.04458359e-06]
#  [ 9.04458359e-06 -1.13802462e-01]]
# k_duffing:
# [0.03893227 0.02203787]
# external_force:
# [-0.00202785 -0.00262184]
# Loss: 0.0098
# ---
# Epoch 1810
# K_lin:
# [[ 3.78774668e-02 -1.28730574e-05]
#  [-1.28730574e-05 -1.11591417e-01]]
# k_duffing:
# [0.03777675 0.02160935]
# external_force:
# [-0.00196766 -0.00257086]
# Loss: 0.0099
# ---
# Epoch 1820
# K_lin:
# [[ 3.67501176e-02 -3.38562521e-05]
#  [-3.38562521e-05 -1.09410816e-01]]
# k_duffing:
# [0.03664873 0.02118675]
# external_force:
# [-0.00190891 -0.00252059]
# Loss: 0.0100
# ---
# Epoch 1830
# K_lin:
# [[ 3.56497978e-02 -5.39261607e-05]
#  [-5.39261607e-05 -1.07260496e-01]]
# k_duffing:
# [0.03554774 0.02077004]
# external_force:
# [-0.00185156 -0.00247101]
# Loss: 0.0101
# ---
# Epoch 1840
# K_lin:
# [[ 3.45760658e-02 -7.31038005e-05]
#  [-7.31038005e-05 -1.05140287e-01]]
# k_duffing:
# [0.03447336 0.02035917]
# external_force:
# [-0.0017956  -0.00242213]
# Loss: 0.0102
# ---
# Epoch 1850
# K_lin:
# [[ 3.35284813e-02 -9.14100386e-05]
#  [-9.14100386e-05 -1.03050016e-01]]
# k_duffing:
# [0.03342514 0.01995412]
# external_force:
# [-0.001741   -0.00237394]
# Loss: 0.0103
# ---
# Epoch 1860
# K_lin:
# [[ 0.03250661 -0.00010887]
#  [-0.00010887 -0.10098951]]
# k_duffing:
# [0.03240264 0.01955485]
# external_force:
# [-0.00168775 -0.00232644]
# Loss: 0.0103
# ---
# Epoch 1870
# K_lin:
# [[ 0.03151    -0.00012549]
#  [-0.00012549 -0.09895858]]
# k_duffing:
# [0.03140543 0.01916133]
# external_force:
# [-0.00163581 -0.00227962]
# Loss: 0.0104
# ---
# Epoch 1880
# K_lin:
# [[ 0.03053824 -0.00014131]
#  [-0.00014131 -0.09695705]]
# k_duffing:
# [0.03043307 0.01877352]
# external_force:
# [-0.00158516 -0.00223349]
# Loss: 0.0104
# ---
# Epoch 1890
# K_lin:
# [[ 0.02959088 -0.00015633]
#  [-0.00015633 -0.09498474]]
# k_duffing:
# [0.02948513 0.01839138]
# external_force:
# [-0.00153579 -0.00218802]
# Loss: 0.0105
# ---
# Epoch 1900
# K_lin:
# [[ 0.02866749 -0.00017059]
#  [-0.00017059 -0.09304146]]
# k_duffing:
# [0.02856118 0.01801487]
# external_force:
# [-0.00148766 -0.00214323]
# Loss: 0.0105
# ---
# Epoch 1910
# K_lin:
# [[ 0.02776765 -0.0001841 ]
#  [-0.0001841  -0.09112701]]
# k_duffing:
# [0.02766079 0.01764397]
# external_force:
# [-0.00144076 -0.00209911]
# Loss: 0.0105
# ---
# Epoch 1920
# K_lin:
# [[ 0.02689094 -0.00019687]
#  [-0.00019687 -0.0892412 ]]
# k_duffing:
# [0.02678354 0.01727862]
# external_force:
# [-0.00139507 -0.00205564]
# Loss: 0.0105
# ---
# Epoch 1930
# K_lin:
# [[ 0.02603692 -0.00020894]
#  [-0.00020894 -0.08738383]]
# k_duffing:
# [0.02592899 0.0169188 ]
# external_force:
# [-0.00135056 -0.00201283]
# Loss: 0.0105
# ---
# Epoch 1940
# K_lin:
# [[ 0.02520518 -0.00022031]
#  [-0.00022031 -0.0855547 ]]
# k_duffing:
# [0.02509674 0.01656445]
# external_force:
# [-0.00130721 -0.00197068]
# Loss: 0.0105
# ---
# Epoch 1950
# K_lin:
# [[ 0.0243953  -0.00023102]
#  [-0.00023102 -0.0837536 ]]
# k_duffing:
# [0.02428636 0.01621555]
# external_force:
# [-0.00126501 -0.00192917]
# Loss: 0.0105
# ---
# Epoch 1960
# K_lin:
# [[ 0.02360686 -0.00024106]
#  [-0.00024106 -0.08198034]]
# k_duffing:
# [0.02349744 0.01587205]
# external_force:
# [-0.00122391 -0.0018883 ]
# Loss: 0.0105
# ---
# Epoch 1970
# K_lin:
# [[ 0.02283946 -0.00025048]
#  [-0.00025048 -0.0802347 ]]
# k_duffing:
# [0.02272957 0.0155339 ]
# external_force:
# [-0.00118392 -0.00184807]
# Loss: 0.0105
# ---
# Epoch 1980
# K_lin:
# [[ 0.02209269 -0.00025928]
#  [-0.00025928 -0.07851648]]
# k_duffing:
# [0.02198234 0.01520108]
# external_force:
# [-0.001145   -0.00180848]
# Loss: 0.0105
# ---
# Epoch 1990
# K_lin:
# [[ 0.02136614 -0.00026747]
#  [-0.00026747 -0.07682545]]
# k_duffing:
# [0.02125534 0.01487353]
# external_force:
# [-0.00110713 -0.00176951]
# Loss: 0.0104
# ---
# Epoch 2000
# K_lin:
# [[ 0.02065941 -0.00027509]
#  [-0.00027509 -0.0751614 ]]
# k_duffing:
# [0.02054817 0.01455122]
# external_force:
# [-0.0010703  -0.00173116]
# Loss: 0.0104
# ---
# Epoch 2010
# K_lin:
# [[ 0.01997211 -0.00028215]
#  [-0.00028215 -0.07352411]]
# k_duffing:
# [0.01986044 0.01423409]
# external_force:
# [-0.00103448 -0.00169344]
# Loss: 0.0104
# ---
# Epoch 2020
# K_lin:
# [[ 0.01930383 -0.00028866]
#  [-0.00028866 -0.07191336]]
# k_duffing:
# [0.01919175 0.01392212]
# external_force:
# [-0.00099965 -0.00165632]
# Loss: 0.0103
# ---
# Epoch 2030
# K_lin:
# [[ 0.01865419 -0.00029464]
#  [-0.00029464 -0.07032894]]
# k_duffing:
# [0.01854171 0.01361525]
# external_force:
# [-0.00096579 -0.00161981]
# Loss: 0.0103
# ---
# Epoch 2040
# K_lin:
# [[ 0.0180228  -0.00030011]
#  [-0.00030011 -0.0687706 ]]
# k_duffing:
# [0.01790993 0.01331343]
# external_force:
# [-0.00093289 -0.00158391]
# Loss: 0.0102
# ---
# Epoch 2050
# K_lin:
# [[ 0.01740928 -0.00030509]
#  [-0.00030509 -0.06723813]]
# k_duffing:
# [0.01729603 0.01301664]
# external_force:
# [-0.00090091 -0.0015486 ]
# Loss: 0.0101
# ---
# Epoch 2060
# K_lin:
# [[ 0.01681325 -0.00030959]
#  [-0.00030959 -0.0657313 ]]
# k_duffing:
# [0.01669964 0.01272482]
# external_force:
# [-0.00086985 -0.00151388]
# Loss: 0.0101
# ---
# Epoch 2070
# K_lin:
# [[ 0.01623434 -0.00031362]
#  [-0.00031362 -0.06424987]]
# k_duffing:
# [0.01612036 0.01243792]
# external_force:
# [-0.00083968 -0.00147975]
# Loss: 0.0100
# ---
# Epoch 2080
# K_lin:
# [[ 0.01567216 -0.00031721]
#  [-0.00031721 -0.06279361]]
# k_duffing:
# [0.01555785 0.0121559 ]
# external_force:
# [-0.00081038 -0.0014462 ]
# Loss: 0.0099
# ---
# Epoch 2090
# K_lin:
# [[ 0.01512637 -0.00032037]
#  [-0.00032037 -0.06136229]]
# k_duffing:
# [0.01501171 0.01187872]
# external_force:
# [-0.00078193 -0.00141322]
# Loss: 0.0098
# ---
# Epoch 2100
# K_lin:
# [[ 0.01459659 -0.00032311]
#  [-0.00032311 -0.05995567]]
# k_duffing:
# [0.01448161 0.01160632]
# external_force:
# [-0.00075432 -0.00138081]
# Loss: 0.0098
# ---
# Epoch 2110
# K_lin:
# [[ 0.01408246 -0.00032546]
#  [-0.00032546 -0.05857351]]
# k_duffing:
# [0.01396717 0.01133867]
# external_force:
# [-0.00072753 -0.00134897]
# Loss: 0.0097
# ---
# Epoch 2120
# K_lin:
# [[ 0.01358364 -0.00032742]
#  [-0.00032742 -0.05721557]]
# k_duffing:
# [0.01346804 0.01107571]
# external_force:
# [-0.00070153 -0.00131769]
# Loss: 0.0096
# ---
# Epoch 2130
# K_lin:
# [[ 0.01309977 -0.00032901]
#  [-0.00032901 -0.05588161]]
# k_duffing:
# [0.01298388 0.0108174 ]
# external_force:
# [-0.00067631 -0.00128695]
# Loss: 0.0095
# ---
# Epoch 2140
# K_lin:
# [[ 0.01263051 -0.00033024]
#  [-0.00033024 -0.05457139]]
# k_duffing:
# [0.01251433 0.01056369]
# external_force:
# [-0.00065185 -0.00125677]
# Loss: 0.0094
# ---
# Epoch 2150
# K_lin:
# [[ 0.01217552 -0.00033113]
#  [-0.00033113 -0.05328467]]
# k_duffing:
# [0.01205907 0.01031454]
# external_force:
# [-0.00062814 -0.00122713]
# Loss: 0.0093
# ---
# Epoch 2160
# K_lin:
# [[ 0.01173446 -0.00033169]
#  [-0.00033169 -0.0520212 ]]
# k_duffing:
# [0.01161774 0.01006989]
# external_force:
# [-0.00060515 -0.00119802]
# Loss: 0.0092
# ---
# Epoch 2170
# K_lin:
# [[ 0.011307   -0.00033194]
#  [-0.00033194 -0.05078072]]
# k_duffing:
# [0.01119002 0.0098297 ]
# external_force:
# [-0.00058288 -0.00116945]
# Loss: 0.0091
# ---
# Epoch 2180
# K_lin:
# [[ 0.01089282 -0.00033189]
#  [-0.00033189 -0.04956301]]
# k_duffing:
# [0.01077559 0.00959392]
# external_force:
# [-0.00056129 -0.0011414 ]
# Loss: 0.0090
# ---
# Epoch 2190
# K_lin:
# [[ 0.01049159 -0.00033155]
#  [-0.00033155 -0.0483678 ]]
# k_duffing:
# [0.01037412 0.0093625 ]
# external_force:
# [-0.00054038 -0.00111387]
# Loss: 0.0089
# ---
# Epoch 2200
# K_lin:
# [[ 0.010103   -0.00033093]
#  [-0.00033093 -0.04719485]]
# k_duffing:
# [0.0099853  0.00913539]
# external_force:
# [-0.00052013 -0.00108685]
# Loss: 0.0088
# ---
# Epoch 2210
# K_lin:
# [[ 0.00972673 -0.00033005]
#  [-0.00033005 -0.04604391]]
# k_duffing:
# [0.00960881 0.00891255]
# external_force:
# [-0.00050052 -0.00106033]
# Loss: 0.0086
# ---
# Epoch 2220
# K_lin:
# [[ 0.00936247 -0.00032892]
#  [-0.00032892 -0.04491473]]
# k_duffing:
# [0.00924434 0.00869392]
# external_force:
# [-0.00048153 -0.00103432]
# Loss: 0.0085
# ---
# Epoch 2230
# K_lin:
# [[ 0.00900993 -0.00032754]
#  [-0.00032754 -0.04380705]]
# k_duffing:
# [0.00889159 0.00847946]
# external_force:
# [-0.00046316 -0.00100881]
# Loss: 0.0084
# ---
# Epoch 2240
# K_lin:
# [[ 0.00866881 -0.00032594]
#  [-0.00032594 -0.04272063]]
# k_duffing:
# [0.00855027 0.00826912]
# external_force:
# [-0.00044538 -0.00098379]
# Loss: 0.0083
# ---
# Epoch 2250
# K_lin:
# [[ 0.0083388  -0.00032413]
#  [-0.00032413 -0.04165521]]
# k_duffing:
# [0.00822007 0.00806284]
# external_force:
# [-0.00042818 -0.00095925]
# Loss: 0.0082
# ---
# Epoch 2260
# K_lin:
# [[ 0.00801964 -0.00032211]
#  [-0.00032211 -0.04061054]]
# k_duffing:
# [0.00790072 0.00786059]
# external_force:
# [-0.00041155 -0.00093518]
# Loss: 0.0081
# ---
# Epoch 2270
# K_lin:
# [[ 0.00771102 -0.00031989]
#  [-0.00031989 -0.03958636]]
# k_duffing:
# [0.00759193 0.00766231]
# external_force:
# [-0.00039547 -0.00091159]
# Loss: 0.0079
# ---
# Epoch 2280
# K_lin:
# [[ 0.00741267 -0.00031749]
#  [-0.00031749 -0.03858243]]
# k_duffing:
# [0.00729341 0.00746794]
# external_force:
# [-0.00037992 -0.00088847]
# Loss: 0.0078
# ---
# Epoch 2290
# K_lin:
# [[ 0.00712432 -0.00031491]
#  [-0.00031491 -0.03759849]]
# k_duffing:
# [0.0070049  0.00727745]
# external_force:
# [-0.00036489 -0.00086581]
# Loss: 0.0077
# ---
# Epoch 2300
# K_lin:
# [[ 0.0068457  -0.00031218]
#  [-0.00031218 -0.03663427]]
# k_duffing:
# [0.00672613 0.00709078]
# external_force:
# [-0.00035037 -0.0008436 ]
# Loss: 0.0076
# ---
# Epoch 2310
# K_lin:
# [[ 0.00657655 -0.00030928]
#  [-0.00030928 -0.03568954]]
# k_duffing:
# [0.00645683 0.00690789]
# external_force:
# [-0.00033634 -0.00082184]
# Loss: 0.0074
# ---
# Epoch 2320
# K_lin:
# [[ 0.0063166  -0.00030624]
#  [-0.00030624 -0.03476404]]
# k_duffing:
# [0.00619674 0.00672872]
# external_force:
# [-0.0003228  -0.00080053]
# Loss: 0.0073
# ---
# Epoch 2330
# K_lin:
# [[ 0.0060656  -0.00030307]
#  [-0.00030307 -0.03385751]]
# k_duffing:
# [0.0059456  0.00655322]
# external_force:
# [-0.00030972 -0.00077965]
# Loss: 0.0072
# ---
# Epoch 2340
# K_lin:
# [[ 0.0058233  -0.00029977]
#  [-0.00029977 -0.03296969]]
# k_duffing:
# [0.00570318 0.00638135]
# external_force:
# [-0.00029709 -0.0007592 ]
# Loss: 0.0071
# ---
# Epoch 2350
# K_lin:
# [[ 0.00558946 -0.00029635]
#  [-0.00029635 -0.03210034]]
# k_duffing:
# [0.00546922 0.00621306]
# external_force:
# [-0.0002849  -0.00073918]
# Loss: 0.0069
# ---
# Epoch 2360
# K_lin:
# [[ 0.00536383 -0.00029282]
#  [-0.00029282 -0.03124921]]
# k_duffing:
# [0.00524348 0.00604829]
# external_force:
# [-0.00027315 -0.00071957]
# Loss: 0.0068
# ---
# Epoch 2370
# K_lin:
# [[ 0.00514619 -0.00028919]
#  [-0.00028919 -0.03041603]]
# k_duffing:
# [0.00502573 0.005887  ]
# external_force:
# [-0.0002618  -0.00070039]
# Loss: 0.0067
# ---
# Epoch 2380
# K_lin:
# [[ 0.0049363  -0.00028547]
#  [-0.00028547 -0.02960056]]
# k_duffing:
# [0.00481573 0.00572914]
# external_force:
# [-0.00025087 -0.00068161]
# Loss: 0.0066
# ---
# Epoch 2390
# K_lin:
# [[ 0.00473393 -0.00028166]
#  [-0.00028166 -0.02880254]]
# k_duffing:
# [0.00461326 0.00557466]
# external_force:
# [-0.00024032 -0.00066323]
# Loss: 0.0065
# ---
# Epoch 2400
# K_lin:
# [[ 0.00453886 -0.00027777]
#  [-0.00027777 -0.02802173]]
# k_duffing:
# [0.00441811 0.00542352]
# external_force:
# [-0.00023015 -0.00064524]
# Loss: 0.0063
# ---
# Epoch 2410
# K_lin:
# [[ 0.00435089 -0.00027381]
#  [-0.00027381 -0.02725787]]
# k_duffing:
# [0.00423004 0.00527565]
# external_force:
# [-0.00022036 -0.00062765]
# Loss: 0.0062
# ---
# Epoch 2420
# K_lin:
# [[ 0.00416978 -0.00026979]
#  [-0.00026979 -0.02651072]]
# k_duffing:
# [0.00404886 0.00513102]
# external_force:
# [-0.00021092 -0.00061045]
# Loss: 0.0061
# ---
# Epoch 2430
# K_lin:
# [[ 0.00399534 -0.0002657 ]
#  [-0.0002657  -0.02578002]]
# k_duffing:
# [0.00387434 0.00498958]
# external_force:
# [-0.00020183 -0.00059362]
# Loss: 0.0060
# ---
# Epoch 2440
# K_lin:
# [[ 0.00382737 -0.00026157]
#  [-0.00026157 -0.02506552]]
# k_duffing:
# [0.0037063  0.00485127]
# external_force:
# [-0.00019308 -0.00057716]
# Loss: 0.0058
# ---
# Epoch 2450
# K_lin:
# [[ 0.00366566 -0.00025739]
#  [-0.00025739 -0.02436698]]
# k_duffing:
# [0.00354453 0.00471605]
# external_force:
# [-0.00018465 -0.00056108]
# Loss: 0.0057
# ---
# Epoch 2460
# K_lin:
# [[ 0.00351003 -0.00025318]
#  [-0.00025318 -0.02368416]]
# k_duffing:
# [0.00338883 0.00458388]
# external_force:
# [-0.00017654 -0.00054535]
# Loss: 0.0056
# ---
# Epoch 2470
# K_lin:
# [[ 0.00336028 -0.00024892]
#  [-0.00024892 -0.0230168 ]]
# k_duffing:
# [0.00323902 0.0044547 ]
# external_force:
# [-0.00016874 -0.00052998]
# Loss: 0.0055
# ---
# Epoch 2480
# K_lin:
# [[ 0.00321622 -0.00024465]
#  [-0.00024465 -0.02236467]]
# k_duffing:
# [0.00309492 0.00432847]
# external_force:
# [-0.00016123 -0.00051497]
# Loss: 0.0054
# ---
# Epoch 2490
# K_lin:
# [[ 0.00307768 -0.00024034]
#  [-0.00024034 -0.02172752]]
# k_duffing:
# [0.00295633 0.00420514]
# external_force:
# [-0.00015402 -0.00050029]
# Loss: 0.0053
# ---
# Epoch 2500
# K_lin:
# [[ 0.00294448 -0.00023603]
#  [-0.00023603 -0.0211051 ]]
# k_duffing:
# [0.00282309 0.00408466]
# external_force:
# [-0.00014708 -0.00048596]
# Loss: 0.0051
# ---
# Epoch 2510
# K_lin:
# [[ 0.00281645 -0.0002317 ]
#  [-0.0002317  -0.02049718]]
# k_duffing:
# [0.00269502 0.00396699]
# external_force:
# [-0.00014041 -0.00047196]
# Loss: 0.0050
# ---
# Epoch 2520
# K_lin:
# [[ 0.00269342 -0.00022736]
#  [-0.00022736 -0.01990353]]
# k_duffing:
# [0.00257196 0.00385208]
# external_force:
# [-0.000134   -0.00045829]
# Loss: 0.0049
# ---
# Epoch 2530
# K_lin:
# [[ 0.00257522 -0.00022302]
#  [-0.00022302 -0.01932389]]
# k_duffing:
# [0.00245373 0.00373989]
# external_force:
# [-0.00012784 -0.00044494]
# Loss: 0.0048
# ---
# Epoch 2540
# K_lin:
# [[ 0.0024617  -0.00021868]
#  [-0.00021868 -0.01875803]]
# k_duffing:
# [0.00234018 0.00363036]
# external_force:
# [-0.00012192 -0.00043191]
# Loss: 0.0047
# ---
# Epoch 2550
# K_lin:
# [[ 0.0023527  -0.00021434]
#  [-0.00021434 -0.01820573]]
# k_duffing:
# [0.00223116 0.00352346]
# external_force:
# [-0.00011624 -0.00041919]
# Loss: 0.0046
# ---
# Epoch 2560
# K_lin:
# [[ 0.00224807 -0.00021002]
#  [-0.00021002 -0.01766674]]
# k_duffing:
# [0.00212651 0.00341914]
# external_force:
# [-0.00011079 -0.00040678]
# Loss: 0.0045
# ---
# Epoch 2570
# K_lin:
# [[ 0.00214765 -0.0002057 ]
#  [-0.0002057  -0.01714084]]
# k_duffing:
# [0.00202608 0.00331735]
# external_force:
# [-0.00010556 -0.00039467]
# Loss: 0.0044
# ---
# Epoch 2580
# K_lin:
# [[ 0.00205132 -0.00020141]
#  [-0.00020141 -0.0166278 ]]
# k_duffing:
# [0.00192974 0.00321804]
# external_force:
# [-0.00010054 -0.00038286]
# Loss: 0.0043
# ---
# Epoch 2590
# K_lin:
# [[ 0.00195892 -0.00019713]
#  [-0.00019713 -0.01612738]]
# k_duffing:
# [0.00183733 0.00312119]
# external_force:
# [-9.57307734e-05 -3.71334967e-04]
# Loss: 0.0042
# ---
# Epoch 2600
# K_lin:
# [[ 0.00187031 -0.00019288]
#  [-0.00019288 -0.01563936]]
# k_duffing:
# [0.00174872 0.00302673]
# external_force:
# [-9.11155480e-05 -3.60097285e-04]
# Loss: 0.0041
# ---
# Epoch 2610
# K_lin:
# [[ 0.00178538 -0.00018865]
#  [-0.00018865 -0.01516351]]
# k_duffing:
# [0.00166379 0.00293463]
# external_force:
# [-8.66914580e-05 -3.49140019e-04]
# Loss: 0.0040
# ---
# Epoch 2620
# K_lin:
# [[ 0.00170398 -0.00018446]
#  [-0.00018446 -0.01469962]]
# k_duffing:
# [0.00158239 0.00284484]
# external_force:
# [-8.24517692e-05 -3.38458029e-04]
# Loss: 0.0039
# ---
# Epoch 2630
# K_lin:
# [[ 0.00162599 -0.00018029]
#  [-0.00018029 -0.01424746]]
# k_duffing:
# [0.00150441 0.00275733]
# external_force:
# [-7.83899335e-05 -3.28046221e-04]
# Loss: 0.0038
# ---
# Epoch 2640
# K_lin:
# [[ 0.00155129 -0.00017617]
#  [-0.00017617 -0.01380681]]
# k_duffing:
# [0.00142972 0.00267204]
# external_force:
# [-7.44995858e-05 -3.17899545e-04]
# Loss: 0.0037
# ---
# Epoch 2650
# K_lin:
# [[ 0.00147977 -0.00017207]
#  [-0.00017207 -0.01337746]]
# k_duffing:
# [0.0013582  0.00258894]
# external_force:
# [-7.07745411e-05 -3.08012995e-04]
# Loss: 0.0036
# ---
# Epoch 2660
# K_lin:
# [[ 0.00141129 -0.00016802]
#  [-0.00016802 -0.01295918]]
# k_duffing:
# [0.00128975 0.00250799]
# external_force:
# [-6.7208791e-05 -2.9838161e-04]
# Loss: 0.0035
# ---
# Epoch 2670
# K_lin:
# [[ 0.00134576 -0.00016401]
#  [-0.00016401 -0.01255177]]
# k_duffing:
# [0.00122424 0.00242913]
# external_force:
# [-6.37965005e-05 -2.89000479e-04]
# Loss: 0.0034
# ---
# Epoch 2680
# K_lin:
# [[ 0.00128307 -0.00016004]
#  [-0.00016004 -0.01215502]]
# k_duffing:
# [0.00116156 0.00235234]
# external_force:
# [-6.05320052e-05 -2.79864736e-04]
# Loss: 0.0033
# ---
# Epoch 2690
# K_lin:
# [[ 0.00122311 -0.00015612]
#  [-0.00015612 -0.01176871]]
# k_duffing:
# [0.00110162 0.00227758]
# external_force:
# [-5.74098076e-05 -2.70969562e-04]
# Loss: 0.0032
# ---
# Epoch 2700
# K_lin:
# [[ 0.00116577 -0.00015224]
#  [-0.00015224 -0.01139265]]
# k_duffing:
# [0.00104431 0.00220479]
# external_force:
# [-5.44245741e-05 -2.62310190e-04]
# Loss: 0.0031
# ---
# Epoch 2710
# K_lin:
# [[ 0.00111096 -0.00014842]
#  [-0.00014842 -0.01102661]]
# k_duffing:
# [0.00098953 0.00213395]
# external_force:
# [-5.15711321e-05 -2.53881901e-04]
# Loss: 0.0030
# ---
# Epoch 2720
# K_lin:
# [[ 0.00105858 -0.00014464]
#  [-0.00014464 -0.01067041]]
# k_duffing:
# [0.00093718 0.00206501]
# external_force:
# [-4.88444660e-05 -2.45680026e-04]
# Loss: 0.0029
# ---
# Epoch 2730
# K_lin:
# [[ 0.00100854 -0.00014092]
#  [-0.00014092 -0.01032384]]
# k_duffing:
# [0.00088718 0.00199793]
# external_force:
# [-4.62397149e-05 -2.37699949e-04]
# Loss: 0.0029
# ---
# Epoch 2740
# K_lin:
# [[ 0.00096074 -0.00013725]
#  [-0.00013725 -0.0099867 ]]
# k_duffing:
# [0.00083942 0.00193268]
# external_force:
# [-4.37521687e-05 -2.29937101e-04]
# Loss: 0.0028
# ---
# Epoch 2750
# K_lin:
# [[ 0.00091511 -0.00013363]
#  [-0.00013363 -0.0096588 ]]
# k_duffing:
# [0.00079383 0.00186922]
# external_force:
# [-4.13772650e-05 -2.22386971e-04]
# Loss: 0.0027
# ---
# Epoch 2760
# K_lin:
# [[ 0.00087155 -0.00013007]
#  [-0.00013007 -0.00933994]]
# k_duffing:
# [0.00075031 0.00180751]
# external_force:
# [-3.91105863e-05 -2.15045095e-04]
# Loss: 0.0026
# ---
# Epoch 2770
# K_lin:
# [[ 0.00082999 -0.00012656]
#  [-0.00012656 -0.00902994]]
# k_duffing:
# [0.00070879 0.00174751]
# external_force:
# [-3.69478564e-05 -2.07907068e-04]
# Loss: 0.0026
# ---
# Epoch 2780
# K_lin:
# [[ 0.00079034 -0.00012311]
#  [-0.00012311 -0.00872859]]
# k_duffing:
# [0.00066918 0.00168919]
# external_force:
# [-3.48849375e-05 -2.00968531e-04]
# Loss: 0.0025
# ---
# Epoch 2790
# K_lin:
# [[ 0.00075253 -0.00011972]
#  [-0.00011972 -0.00843573]]
# k_duffing:
# [0.00063142 0.00163251]
# external_force:
# [-3.29178268e-05 -1.94225186e-04]
# Loss: 0.0024
# ---
# Epoch 2800
# K_lin:
# [[ 0.00071648 -0.00011638]
#  [-0.00011638 -0.00815115]]
# k_duffing:
# [0.00059542 0.00157744]
# external_force:
# [-3.10426536e-05 -1.87672785e-04]
# Loss: 0.0023
# ---
# Epoch 2810
# K_lin:
# [[ 0.00068212 -0.00011311]
#  [-0.00011311 -0.00787469]]
# k_duffing:
# [0.00056111 0.00152393]
# external_force:
# [-2.92556759e-05 -1.81307137e-04]
# Loss: 0.0023
# ---
# Epoch 2820
# K_lin:
# [[ 0.00064939 -0.00010989]
#  [-0.00010989 -0.00760616]]
# k_duffing:
# [0.00052843 0.00147196]
# external_force:
# [-2.75532778e-05 -1.75124103e-04]
# Loss: 0.0022
# ---
# Epoch 2830
# K_lin:
# [[ 0.0006182  -0.00010673]
#  [-0.00010673 -0.00734538]]
# k_duffing:
# [0.00049731 0.00142149]
# external_force:
# [-2.59319659e-05 -1.69119604e-04]
# Loss: 0.0021
# ---
# Epoch 2840
# K_lin:
# [[ 0.00058851 -0.00010364]
#  [-0.00010364 -0.00709217]]
# k_duffing:
# [0.00046767 0.00137249]
# external_force:
# ...
# [ 6.05904407e-08 -7.48925289e-09]
# external_force:
# [ 2.56804474e-08 -3.31587043e-09]
# Loss: 0.0000
# ---
# Epoch 56300
# K_lin:
# [[-4.47200482e-09  3.47461039e-09]
#  [ 3.47461039e-09 -8.90642024e-09]]
# k_duffing:
# [-4.64905523e-09 -1.02627447e-08]
# external_force:
# [-1.91107072e-09 -3.81064542e-09]
# Loss: -0.0000
# ---
# Epoch 56310
# K_lin:
# [[-4.30254198e-08  2.49608540e-08]
#  [ 2.49608540e-08 -4.02652191e-08]]
# k_duffing:
# [-4.46728607e-08 -4.63401401e-08]
# external_force:
# [-1.78846449e-08 -1.78908235e-08]
# Loss: -0.0000
# ---
# Epoch 56320
# K_lin:
# [[-1.17427030e-07  1.19962182e-07]
#  [ 1.19962182e-07 -3.01758332e-07]]
# k_duffing:
# [-1.21960829e-07 -3.48177196e-07]
# external_force:
# [-4.41238593e-08 -1.32535831e-07]
# Loss: -0.0000
# ---
# Epoch 56330
# K_lin:
# [[-9.89802528e-07  1.15147284e-06]
#  [ 1.15147284e-06 -3.11948040e-06]]
# k_duffing:
# [-1.02816060e-06 -3.60262918e-06]
# external_force:
# [-3.57533780e-07 -1.35761517e-06]
# Loss: -0.0000
# ---
# Epoch 56340
# K_lin:
# [[-1.27294263e-05  1.54804514e-05]
#  [ 1.54804514e-05 -4.31255079e-05]]
# k_duffing:
# [-1.32237200e-05 -4.98193351e-05]
# external_force:
# [-4.50309890e-06 -1.86893095e-05]
# Loss: -0.0001
# ---
# Epoch 56350
# K_lin:
# [[-1.08083258e-04  3.46332286e-05]
#  [ 3.46332286e-05  1.83454709e-06]]
# k_duffing:
# [-1.12122462e-04  2.40432170e-06]
# external_force:
# [-5.07310852e-05 -1.16813066e-06]
# Loss: -0.0002
# ---
# Epoch 56360
# K_lin:
# [[-1.35231180e-05  1.86033874e-05]
#  [ 1.86033874e-05 -3.42638879e-05]]
# k_duffing:
# [-1.39821821e-05 -3.89188929e-05]
# external_force:
# [-3.82348749e-06 -2.14604488e-05]
# Loss: -0.0001
# ---
# Epoch 56370
# K_lin:
# [[ 1.52498413e-05  3.50105632e-06]
#  [ 3.50105632e-06 -2.39753052e-05]]
# k_duffing:
# [ 1.57284945e-05 -2.72914203e-05]
# external_force:
# [ 5.92250300e-06 -1.28723559e-05]
# Loss: -0.0000
# ---
# Epoch 56380
# K_lin:
# [[ 1.53290723e-05 -3.93136007e-07]
#  [-3.93136007e-07 -1.55687315e-05]]
# k_duffing:
# [ 1.59670662e-05 -1.77549291e-05]
# external_force:
# [ 1.19265764e-05 -8.58244946e-06]
# Loss: -0.0000
# ---
# Epoch 56390
# K_lin:
# [[ 1.30148645e-05 -8.00759287e-07]
#  [-8.00759287e-07 -1.04103657e-05]]
# k_duffing:
# [ 1.35292834e-05 -1.18884559e-05]
# external_force:
# [ 8.96764512e-06 -6.40801202e-06]
# Loss: -0.0000
# ---
# Epoch 56400
# K_lin:
# [[ 1.04118221e-05 -2.13983214e-06]
#  [-2.13983214e-06 -6.84462358e-06]]
# k_duffing:
# [ 1.07875509e-05 -7.83576058e-06]
# external_force:
# [ 5.51011860e-06 -3.96067334e-06]
# Loss: 0.0000
# ---
# Epoch 56410
# K_lin:
# [[ 7.73948937e-06 -1.58675386e-06]
#  [-1.58675386e-06 -3.84807633e-06]]
# k_duffing:
# [ 8.03797480e-06 -4.40937179e-06]
# external_force:
# [ 4.83194068e-06 -2.00517664e-06]
# Loss: 0.0000
# ---
# Epoch 56420
# K_lin:
# [[ 4.83612754e-06 -1.56289938e-06]
#  [-1.56289938e-06 -1.40980405e-06]]
# k_duffing:
# [ 5.02648272e-06 -1.62702558e-06]
# external_force:
# [ 3.07857249e-06 -8.38981753e-07]
# Loss: 0.0000
# ---
# Epoch 56430
# K_lin:
# [[ 2.05991317e-06 -9.09470997e-07]
#  [-9.09470997e-07  1.34251855e-07]]
# k_duffing:
# [2.13215529e-06 1.44243592e-07]
# external_force:
# [9.19384759e-07 1.27667115e-08]
# Loss: 0.0000
# ---
# Epoch 56440
# K_lin:
# [[-2.07452477e-07 -1.45369793e-07]
#  [-1.45369793e-07  5.77258319e-07]]
# k_duffing:
# [-2.14994939e-07  6.59391120e-07]
# external_force:
# [-1.28347241e-07  3.38568529e-07]
# Loss: -0.0000
# ---
# Epoch 56450
# K_lin:
# [[-1.16138088e-06  3.87020475e-07]
#  [ 3.87020475e-07  2.71714783e-07]]
# k_duffing:
# [-1.20316869e-06  3.14988989e-07]
# external_force:
# [-5.60157262e-07  1.53925702e-07]
# Loss: -0.0000
# ---
# Epoch 56460
# K_lin:
# [[-7.71097327e-07  3.40777159e-07]
#  [ 3.40777159e-07 -6.14869267e-08]]
# k_duffing:
# [-8.00710848e-07 -6.71731530e-08]
# external_force:
# [-4.32287667e-07 -3.92447272e-08]
# Loss: -0.0000
# ---
# Epoch 56470
# K_lin:
# [[ 5.53015259e-08 -1.18247685e-08]
#  [-1.18247685e-08 -5.53946510e-08]]
# k_duffing:
# [ 5.69569389e-08 -6.35994724e-08]
# external_force:
# [ 1.34346507e-08 -2.43246369e-08]
# Loss: 0.0000
# ---
# Epoch 56480
# K_lin:
# [[ 3.31116319e-07 -1.34610097e-07]
#  [-1.34610097e-07  2.43839678e-08]]
# k_duffing:
# [3.4373917e-07 2.6656404e-08]
# external_force:
# [1.79607794e-07 1.22100145e-08]
# Loss: 0.0000
# ---
# Epoch 56490
# K_lin:
# [[ 4.80736248e-08 -1.53083063e-08]
#  [-1.53083063e-08 -1.35034234e-08]]
# k_duffing:
# [ 5.00036567e-08 -1.56762997e-08]
# external_force:
# [ 3.02019480e-08 -9.57590471e-09]
# Loss: -0.0000
# ---
# Epoch 56500
# K_lin:
# [[-1.10289987e-07  4.27136049e-08]
#  [ 4.27136049e-08 -1.52300864e-09]]
# k_duffing:
# [-1.14518576e-07 -1.31677479e-09]
# external_force:
# [-5.96807885e-08  8.42747629e-10]
# Loss: -0.0000
# ---
# Epoch 56510
# K_lin:
# [[-8.87170747e-09 -3.95563399e-11]
#  [-3.95563399e-11  1.19732025e-08]]
# k_duffing:
# [-9.24456492e-09  1.37627056e-08]
# external_force:
# [-6.30966309e-09  6.11995504e-09]
# Loss: 0.0000
# ---
# Epoch 56520
# K_lin:
# [[ 3.71609687e-08 -1.10954458e-08]
#  [-1.10954458e-08 -1.03512264e-08]]
# k_duffing:
# [ 3.85858487e-08 -1.20198659e-08]
# external_force:
# [ 2.02119194e-08 -5.70694072e-09]
# Loss: 0.0000
# ---
# Epoch 56530
# K_lin:
# [[-8.62126177e-09  1.79712824e-09]
#  [ 1.79712824e-09  5.44267659e-09]]
# k_duffing:
# [-8.93464470e-09  6.28440368e-09]
# external_force:
# [-3.80170979e-09  2.96105629e-09]
# Loss: -0.0000
# ---
# Epoch 56540
# K_lin:
# [[-9.04419435e-09  4.10593414e-09]
#  [ 4.10593414e-09 -2.51646250e-09]]
# k_duffing:
# [-9.40245559e-09 -2.85709616e-09]
# external_force:
# [-4.78097736e-09 -1.21939395e-09]
# Loss: -0.0000
# ---
# Epoch 56550
# K_lin:
# [[ 9.25960596e-09 -3.88523702e-09]
#  [-3.88523702e-09  1.10089110e-09]]
# k_duffing:
# [9.59584982e-09 1.22935307e-09]
# external_force:
# [4.03528492e-09 4.24455040e-10]
# Loss: 0.0000
# ---
# Epoch 56560
# K_lin:
# [[-4.44958568e-09  1.68294339e-09]
#  [ 1.68294339e-09  7.48516629e-11]]
# k_duffing:
# [-4.61681554e-09  1.04153351e-10]
# external_force:
# [-1.89401730e-09  1.17821535e-10]
# Loss: -0.0000
# ---
# Epoch 56570
# K_lin:
# [[ 1.13984182e-09 -1.53820288e-10]
#  [-1.53820288e-10 -8.26615643e-10]]
# k_duffing:
# [ 1.18131958e-09 -9.54830290e-10]
# external_force:
# [ 6.53767140e-10 -4.21562651e-10]
# Loss: 0.0000
# ---
# Epoch 56580
# K_lin:
# [[-1.02598765e-10 -2.27397751e-13]
#  [-2.27397751e-13  5.55901083e-11]]
# k_duffing:
# [-1.11704128e-10  6.46210685e-11]
# external_force:
# [-5.70477399e-11  3.60269216e-11]
# Loss: -0.0000
# ---
# Epoch 56590
# K_lin:
# [[-4.40383886e-11 -9.72583419e-11]
#  [-9.72583419e-11  4.19679352e-10]]
# k_duffing:
# [-5.28718805e-11  4.84241639e-10]
# external_force:
# [-8.38557898e-11  1.92407304e-10]
# Loss: 0.0000
# ---
# Epoch 56600
# K_lin:
# [[ 2.78930312e-10 -3.72199792e-10]
#  [-3.72199792e-10  9.76220853e-10]]
# k_duffing:
# [2.87358990e-10 1.12500092e-09]
# external_force:
# [8.89543817e-11 4.30704339e-10]
# Loss: 0.0000
# ---
# Epoch 56610
# K_lin:
# [[ 8.10887801e-10 -1.35498738e-09]
#  [-1.35498738e-09  3.89933442e-09]]
# k_duffing:
# [8.33953047e-10 4.49736625e-09]
# external_force:
# [2.85491333e-10 1.73005824e-09]
# Loss: 0.0000
# ---
# Epoch 56620
# K_lin:
# [[ 4.35519915e-09 -8.19637744e-09]
#  [-8.19637744e-09  2.47807053e-08]]
# k_duffing:
# [4.52264043e-09 2.86025461e-08]
# external_force:
# [1.40955562e-09 1.08549346e-08]
# Loss: 0.0000
# ---
# Epoch 56630
# K_lin:
# [[ 3.96260755e-08 -7.46196764e-08]
#  [-7.46196764e-08  2.29697397e-07]]
# k_duffing:
# [4.11564770e-08 2.65316919e-07]
# external_force:
# [1.26370442e-08 9.96302133e-08]
# Loss: 0.0000
# ---
# Epoch 56640
# K_lin:
# [[ 4.80401196e-07 -9.36897609e-07]
#  [-9.36897609e-07  2.95864546e-06]]
# k_duffing:
# [4.99053941e-07 3.41997429e-06]
# external_force:
# [1.49998467e-07 1.27056290e-06]
# Loss: 0.0000
# ---
# Epoch 56650
# K_lin:
# [[ 7.84791152e-06 -1.56209466e-05]
#  [-1.56209466e-05  4.99444632e-05]]
# k_duffing:
# [8.15364639e-06 5.77390560e-05]
# external_force:
# [2.40723395e-06 2.13835002e-05]
# Loss: 0.0001
# ---
# Epoch 56660
# K_lin:
# [[ 8.05322612e-05 -6.47463107e-06]
#  [-6.47463107e-06 -5.29926244e-05]]
# k_duffing:
# [ 8.34210945e-05 -6.06630571e-05]
# external_force:
# [ 3.41550811e-05 -2.99632937e-05]
# Loss: 0.0001
# ---
# Epoch 56670
# K_lin:
# [[-1.23785121e-05  1.42136425e-05]
#  [ 1.42136425e-05 -2.05135280e-05]]
# k_duffing:
# [-1.29374263e-05 -2.31990926e-05]
# external_force:
# [-8.71910777e-06 -8.92272403e-06]
# Loss: 0.0000
# ---
# Epoch 56680
# K_lin:
# [[-1.52086365e-05  1.59925303e-05]
#  [ 1.59925303e-05 -2.19546979e-05]]
# k_duffing:
# [-1.56805637e-05 -2.48290988e-05]
# external_force:
# [-2.41427279e-06 -1.27339717e-05]
# Loss: -0.0000
# ---
# Epoch 56690
# K_lin:
# [[ 1.49691338e-05  5.47160445e-06]
#  [ 5.47160445e-06 -1.83024523e-05]]
# k_duffing:
# [ 1.56056143e-05 -2.07798614e-05]
# external_force:
# [ 1.16238819e-05 -1.18420044e-05]
# Loss: 0.0000
# ---
# Epoch 56700
# K_lin:
# [[ 3.94523609e-06  4.85598902e-06]
#  [ 4.85598902e-06 -1.29731074e-05]]
# k_duffing:
# [ 4.10672897e-06 -1.47227443e-05]
# external_force:
# [ 3.19133926e-06 -7.67151026e-06]
# Loss: -0.0000
# ---
# Epoch 56710
# K_lin:
# [[-3.35985423e-06  5.35902742e-06]
#  [ 5.35902742e-06 -8.28103398e-06]]
# k_duffing:
# [-3.49217540e-06 -9.37785258e-06]
# external_force:
# [-1.37502960e-06 -4.38561936e-06]
# Loss: -0.0000
# ---
# Epoch 56720
# K_lin:
# [[ 3.39178317e-06  1.11819635e-06]
#  [ 1.11819635e-06 -4.85123311e-06]]
# k_duffing:
# [ 3.52800797e-06 -5.51768719e-06]
# external_force:
# [ 2.24184678e-06 -2.76455181e-06]
# Loss: -0.0000
# ---
# Epoch 56730
# K_lin:
# [[ 6.46491719e-08  1.39338965e-06]
#  [ 1.39338965e-06 -2.80426620e-06]]
# k_duffing:
# [ 7.55967149e-08 -3.18530095e-06]
# external_force:
# [ 5.31837217e-07 -1.70295406e-06]
# Loss: -0.0000
# ---
# Epoch 56740
# K_lin:
# [[-1.55694841e-07  6.76315387e-07]
#  [ 6.76315387e-07 -1.43040526e-06]]
# k_duffing:
# [-1.59376188e-07 -1.62553276e-06]
# external_force:
# [ 8.44703742e-08 -7.84979555e-07]
# Loss: -0.0000
# ---
# Epoch 56750
# K_lin:
# [[ 5.77524850e-07  3.37395617e-08]
#  [ 3.37395617e-08 -4.82639682e-07]]
# k_duffing:
# [ 5.97459550e-07 -5.50252511e-07]
# external_force:
# [ 2.25585942e-07 -2.25468469e-07]
# Loss: 0.0000
# ---
# Epoch 56760
# K_lin:
# [[-3.60645405e-07  8.99923753e-08]
#  [ 8.99923753e-08  6.98282536e-08]]
# k_duffing:
# [-3.74991868e-07  8.05197326e-08]
# external_force:
# [-1.99580127e-07  2.61744528e-08]
# Loss: 0.0000
# ---
# Epoch 56770
# K_lin:
# [[ 1.63055042e-07 -1.86349245e-07]
#  [-1.86349245e-07  3.03012245e-07]]
# k_duffing:
# [1.69465283e-07 3.44474519e-07]
# external_force:
# [6.95273117e-08 1.49892511e-07]
# Loss: 0.0000
# ---
# Epoch 56780
# K_lin:
# [[-1.62436666e-07 -3.79040798e-08]
#  [-3.79040798e-08  2.26566715e-07]]
# k_duffing:
# [-1.68169132e-07  2.58829286e-07]
# external_force:
# [-6.85295746e-08  1.28818728e-07]
# Loss: 0.0000
# ---
# Epoch 56790
# K_lin:
# [[ 3.66728154e-08 -2.85829906e-08]
#  [-2.85829906e-08  3.84616771e-08]]
# k_duffing:
# [3.81117466e-08 4.37501795e-08]
# external_force:
# [1.68727069e-08 2.14020556e-08]
# Loss: -0.0000
# ---
# Epoch 56800
# K_lin:
# [[ 2.27776362e-08  2.06841069e-08]
#  [ 2.06841069e-08 -7.09859972e-08]]
# k_duffing:
# [ 2.35248936e-08 -8.11183464e-08]
# external_force:
# [ 8.97637006e-09 -4.00802764e-08]
# Loss: -0.0000
# ---
# Epoch 56810
# K_lin:
# [[-2.59841966e-08  2.13073906e-08]
#  [ 2.13073906e-08 -3.33107086e-08]]
# k_duffing:
# [-2.70502469e-08 -3.79576183e-08]
# external_force:
# [-1.29181627e-08 -1.60800930e-08]
# Loss: -0.0000
# ---
# Epoch 56820
# K_lin:
# [[ 1.40009370e-08 -1.45727023e-08]
#  [-1.45727023e-08  2.56400396e-08]]
# k_duffing:
# [1.45078245e-08 2.92637979e-08]
# external_force:
# [4.09706509e-09 1.36084474e-08]
# Loss: 0.0000
# ---
# Epoch 56830
# K_lin:
# [[ 8.62113459e-09 -4.43770791e-09]
#  [-4.43770791e-09  6.39019248e-09]]
# k_duffing:
# [8.95249613e-09 7.28534513e-09]
# external_force:
# [3.91590399e-09 2.53533696e-09]
# Loss: 0.0000
# ---
# Epoch 56840
# K_lin:
# [[-3.59919808e-09  5.24835725e-09]
#  [ 5.24835725e-09 -1.13107936e-08]]
# k_duffing:
# [-3.71677120e-09 -1.29329569e-08]
# external_force:
# [-2.32734968e-10 -5.47407505e-09]
# Loss: -0.0000
# ---
# Epoch 56850
# K_lin:
# [[-1.08827810e-08  1.05912653e-09]
#  [ 1.05912653e-09  5.00186245e-09]]
# k_duffing:
# [-1.12730331e-08  5.75620363e-09]
# external_force:
# [-4.14594591e-09  2.63529594e-09]
# Loss: 0.0000
# ---
# Epoch 56860
# K_lin:
# [[-1.46546460e-08  4.59491474e-09]
#  [ 4.59491474e-09 -1.45975817e-09]]
# k_duffing:
# [-1.52079490e-08 -1.63554099e-09]
# external_force:
# [-5.71243079e-09 -7.98527492e-10]
# Loss: -0.0000
# ---
# Epoch 56870
# K_lin:
# [[-3.72604696e-08  1.05474952e-08]
#  [ 1.05474952e-08 -1.31913493e-09]]
# k_duffing:
# [-3.86521472e-08 -1.41675416e-09]
# external_force:
# [-1.44366236e-08 -4.91739705e-10]
# Loss: -0.0000
# ---
# Epoch 56880
# K_lin:
# [[-1.42992886e-07  3.96563653e-08]
#  [ 3.96563653e-08 -3.79690673e-09]]
# k_duffing:
# [-1.48317787e-07 -3.99635195e-09]
# external_force:
# [-5.43961672e-08 -1.38180310e-09]
# Loss: -0.0000
# ---
# Epoch 56890
# K_lin:
# [[-7.60408761e-07  2.10154630e-07]
#  [ 2.10154630e-07 -2.25191729e-08]]
# k_duffing:
# [-7.88708551e-07 -2.39516408e-08]
# external_force:
# [-2.85307166e-07 -8.52328486e-09]
# Loss: -0.0000
# ---
# Epoch 56900
# K_lin:
# [[-5.34782962e-06  1.46794928e-06]
#  [ 1.46794928e-06 -1.64299753e-07]]
# k_duffing:
# [-5.54699089e-06 -1.75466287e-07]
# external_force:
# [-1.98272255e-06 -6.19756367e-08]
# Loss: -0.0000
# ---
# Epoch 56910
# K_lin:
# [[-4.57489056e-05  1.27091309e-05]
#  [ 1.27091309e-05 -1.51885471e-06]]
# k_duffing:
# [-4.74520925e-05 -1.63070560e-06]
# external_force:
# [-1.70646713e-05 -5.74655703e-07]
# Loss: -0.0000
# ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[57], line 34
#      31 params = flattened_args_initial  # Use the flattened initial parameters
#      33 for epoch in range(n_epochs):
# ---> 34     key, subkey = jr.split(key)
#      35     params, opt_state, key, loss = training_step(params, opt_state, samples, batch_size, subkey)
#      37     # Store parameters and loss
#
# File ~/miniconda3/envs/jax-env/lib/python3.12/site-packages/jax/_src/random.py:277, in split(key, num)
#     266 """Splits a PRNG key into `num` new keys by adding a leading axis.
#     267
#     268 Args:
#    (...)
#     274   An array-like object of `num` new PRNG keys.
#     275 """
#     276 typed_key, wrapped = _check_prng_key("split", key)
# --> 277 return _return_prng_keys(wrapped, _split(typed_key, num))
#
# File ~/miniconda3/envs/jax-env/lib/python3.12/site-packages/jax/_src/random.py:263, in _split(key, num)
#     260   raise TypeError("split accepts a single key, but was given a key array of "
#     261                   f"shape {key.shape} != (). Use jax.vmap for batching.")
#     262 shape = tuple(num) if isinstance(num, Sequence) else (num,)
# --> 263 return prng.random_split(key, shape=shape)
#
# File ~/miniconda3/envs/jax-env/lib/python3.12/site-packages/jax/_src/prng.py:569, in random_split(keys, shape)
#     568 def random_split(keys, shape: Shape):
# --> 569   return random_split_p.bind(keys, shape=shape)
#
# File ~/miniconda3/envs/jax-env/lib/python3.12/site-packages/jax/_src/core.py:429, in Primitive.bind(self, *args, **params)
#     426 def bind(self, *args, **params):
#     427   assert (not config.enable_checks.value or
#     428           all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> 429   return self.bind_with_trace(find_top_trace(args), args, params)
#
# File ~/miniconda3/envs/jax-env/lib/python3.12/site-packages/jax/_src/core.py:433, in Primitive.bind_with_trace(self, trace, args, params)
#     431 def bind_with_trace(self, trace, args, params):
#     432   with pop_level(trace.level):
# --> 433     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     434   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniconda3/envs/jax-env/lib/python3.12/site-packages/jax/_src/core.py:939, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     937   return call_impl_with_key_reuse_checks(primitive, primitive.impl, *tracers, **params)
#     938 else:
# --> 939   return primitive.impl(*tracers, **params)
#
# File ~/miniconda3/envs/jax-env/lib/python3.12/site-packages/jax/_src/prng.py:583, in random_split_impl(keys, shape)
#     579 @random_split_p.def_impl
#     580 def random_split_impl(keys, *, shape):
#     581   base_arr = random_split_impl_base(
#     582       keys._impl, keys._base_array, keys.ndim, shape=shape)
# --> 583   return PRNGKeyArray(keys._impl, base_arr)
#
# File ~/miniconda3/envs/jax-env/lib/python3.12/site-packages/jax/_src/prng.py:157, in PRNGKeyArray.__init__(self, impl, key_data)
#     154 _consumed: bool | np.ndarray  # Used in jax.experimental.key_reuse.
#     155 _source_info: None | source_info_util.SourceInfo = None
# --> 157 def __init__(self, impl, key_data: Any):
#     158   assert not isinstance(key_data, core.Tracer)
#     159   _check_prng_key_data(impl, key_data)
#
# KeyboardInterrupt:

# %%
# Convert histories to arrays for plotting
slicing = 100
params_history = jnp.array(params_history[::slicing])
K_lin_history = jnp.zeros((len(params_history), N_osc, N_osc))
k_duffing_history = jnp.zeros((len(params_history), N_osc))
external_force_history = jnp.zeros((len(params_history), N_osc))
for i in range(len(params_history)):
    params_history_i = unflatten(params_history[i])
    K_lin_history=K_lin_history.at[i,:,:].set(params_history_i[0])
    k_duffing_history=k_duffing_history.at[i,:].set(params_history_i[1])
    external_force_history=external_force_history.at[i,:].set(params_history_i[2])
loss_history = jnp.array(loss_history[::slicing])

# %%
# Plot parameter evolution and loss
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(25, 5))

# Plot K_lin evolution
for i in range(N_osc):
    for j in range(N_osc):
        ax1.plot(K_lin_history[:, i, j], 
                label=f'K_lin[{i},{j}]')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Coupling Strength')
ax1.set_title('Evolution of Coupling Matrix K_lin')
ax1.legend()
ax1.grid(True)

# Plot k_duffing evolution
for i in range(N_osc):
    ax2.plot(k_duffing_history[:, i], label=f'k_duffing[{i}]')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Duffing Strength')
ax2.set_title('Evolution of Duffing Vector k_duffing')
ax2.legend()
ax2.grid(True)

# Plot external force evolution
for i in range(N_osc):
    ax3.plot(external_force_history[:, i], label=f'external_force[{i}]')
ax3.set_xlabel('Epoch')
ax3.set_ylabel('Force')
ax3.set_title('Evolution of External Force Vector')
ax3.legend()
ax3.grid(True)

# Plot loss evolution
ax4.plot(loss_history, label='Log Likelihood')
ax4.set_xlabel('Epoch')
ax4.set_ylabel('Log Likelihood')
ax4.set_title('Evolution of Log Likelihood')
ax4.legend()
ax4.grid(True)

plt.tight_layout()
plt.show()

# %%
# Create figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# Plot initial energy landscape
energy_initial = jnp.zeros((n_points, n_points))
energy_final = jnp.zeros((n_points, n_points))
for i in range(n_points):
    for j in range(n_points):
        x = jnp.array([X1[i,j], X2[i,j]])
        energy_initial = energy_initial.at[i,j].set(energy_fn(x, flattened_args_initial))
        energy_final = energy_final.at[i,j].set(energy_fn(x, params))

contour1 = ax1.contourf(X1, X2, energy_initial, levels=20, cmap='RdYlBu', alpha=0.7)
plt.colorbar(contour1, ax=ax1, label='Energy')
ax1.scatter(samples[:, 0], samples[:, 1], c='black', s=1, alpha=0.9, label='Training Samples')
ax1.set_xlabel('θ₁')
ax1.set_ylabel('θ₂')
ax1.set_title('Initial Energy Landscape')
ax1.legend()


contour2 = ax2.contourf(X1, X2, energy_final, levels=20, cmap='RdYlBu', alpha=0.7)
plt.colorbar(contour2, ax=ax2, label='Energy')
ax2.scatter(samples[:, 0], samples[:, 1], c='black', s=1, alpha=0.9, label='Training Samples')
ax2.set_xlabel('θ₁')
ax2.set_ylabel('θ₂')
ax2.set_title('Final Energy Landscape')
ax2.legend()

plt.tight_layout()
plt.show()

# %%
def drift_x_fn(t, state, args):
    """
    Drift function for the XY model with effective temperature
    Args:
        t: time
        state: array of phases (shape: N_osc)
        args: tuple containing (W, h)
    Returns:
        Array of phase velocities
    """
    W, h = args
    # Compute force from energy gradient
    dE_dtheta = jax.grad(XY_energy, argnums=0)(state, W, h)
    
    # Damping term
    gamma = 1.0  # Damping coefficient, adjust as needed
    
    dtheta_dt = -gamma * dE_dtheta
    
    return dtheta_dt

def diffusion_x_fn(t, state, args):
    """
    Diffusion function for the XY model with effective temperature
    Args:
        t: time
        state: array of phases (shape: N_osc)
        args: additional arguments
    Returns:
        Noise matrix (shape: N_osc x 1)
    """
    T_eff = 1.0  # Effective temperature, adjust as needed
    gamma = 1.0  # Same damping coefficient as in drift
    
    noise_strength = jnp.sqrt(2 * gamma * T_eff)
    noise_matrix = jnp.eye(N_osc)
    return noise_strength * noise_matrix

# %%
# Calculate characteristic time scales
gamma = 1.0
T_eff = 1.0
J = jnp.max(jnp.abs(W))  # Coupling strength

tau_relax = 1/gamma
tau_diffusion = gamma/(2*T_eff)

print(f"Relaxation time scale: {tau_relax:.2f}")
print(f"Diffusion time scale: {tau_diffusion:.2f}")

# Set simulation time accordingly
t0 = 0.0
t1 = 100 * max(tau_relax, tau_diffusion)  # Simulate for 10x the longest time scale
dt0 = min(tau_relax, tau_diffusion) / 10  # Initial time step should be smaller than fastest time scale

print(f"\nSuggested simulation parameters:")
print(f"Total time: {t1:.2f}")
print(f"Initial dt: {dt0:.2f}")

ts = jnp.linspace(t0, t1, 10000)
dt = ts[1] - ts[0]

y0_x = jnp.array([jnp.pi,jnp.pi])

# %%
# Update shape to match number of oscillators
w_shape = (N_osc,)  # state is just phases for each oscillator
brownian_motion = diffrax.VirtualBrownianTree(
    t0, t1, 1.e-11, w_shape, jr.PRNGKey(0), diffrax.SpaceTimeLevyArea
)
terms_x = MultiTerm(ODETerm(drift_x_fn), ControlTerm(diffusion_x_fn, brownian_motion))
saveat = diffrax.SaveAt(ts=ts)


# sample 1000 points
solution_x = diffrax.diffeqsolve(
    terms_x,
    solver=diffrax.SRA1(),
    t0=t0,
    t1=t1,
    dt0=dt0,
    y0=y0_x,
    args=(),
    saveat=saveat,
    progress_meter=diffrax.TqdmProgressMeter(),
    max_steps=1000000000,
    stepsize_controller=diffrax.PIDController(rtol=1e-3, atol=1e-6),  # Enable adaptive stepping
)
sde_samples_x = solution_x.ys

# %%
# # Calculate number of timesteps corresponding to one relaxation time
# relax_steps = int(1/(gamma * dt))

# # Thin the samples by taking every relax_steps point
# sde_samples_x = solution_x.ys[::relax_steps]
# ts = ts[::relax_steps]

# %%
# Create figure with a grid of subplots
fig = plt.figure(figsize=(16, 12))
gs = plt.GridSpec(2, 2, height_ratios=[2, 1])

# Top left: Phase trajectories
ax1 = fig.add_subplot(gs[0, 0])
# Mod 2π for time trajectories
ax1.plot(ts, jnp.mod(sde_samples_x[:, 0], 2*jnp.pi), label='θ₁(t)')
ax1.plot(ts, jnp.mod(sde_samples_x[:, 1], 2*jnp.pi), label='θ₂(t)')
ax1.set_xlabel('Time')
ax1.set_ylabel('Phase (rad)')
ax1.set_title('SDE Simulation: Phase vs Time')
ax1.grid(True)
ax1.legend()

# Top right: Phase space with Energy contour
ax2 = fig.add_subplot(gs[0, 1])
contour = ax2.contourf(X1, X2, energy, levels=20, cmap='RdYlBu')
plt.colorbar(contour, ax=ax2, label='Energy')

# Mod 2π for phase space trajectory
wrapped_x = jnp.mod(sde_samples_x, 2*jnp.pi)
ax2.scatter(wrapped_x[:, 0], wrapped_x[:, 1], c='g', s=1, alpha=0.9999, label='Trajectory')
ax2.plot(wrapped_x[0, 0], wrapped_x[0, 1], 'go', label='Start', markersize=10)


ax2.set_xlabel('θ₁')
ax2.set_ylabel('θ₂')
ax2.set_title('Phase Space (Torus)')
ax2.legend()

# Bottom left: θ₁ histogram (mod 2π)
ax3 = fig.add_subplot(gs[1, 0])
ax3.hist(wrapped_x[:, 0], bins=50, density=True, alpha=0.7, label='θ₁ distribution')
ax3.set_xlabel('θ₁')
ax3.set_ylabel('Probability Density')
ax3.grid(True)
ax3.legend()

# Bottom right: θ₂ histogram (mod 2π)
ax4 = fig.add_subplot(gs[1, 1])
ax4.hist(wrapped_x[:, 1], bins=50, density=True, alpha=0.7, label='θ₂ distribution')
ax4.set_xlabel('θ₂')
ax4.set_ylabel('Probability Density')
ax4.grid(True)
ax4.legend()

plt.tight_layout()
# Add title with parameters
title = f'T_eff={T_eff}, γ={gamma}'
plt.suptitle(title, y=1.02)

plt.show()
