# %%
import jax
from jax import flatten_util, vmap 
import jax.numpy as jnp
import jax.random as jr
import diffrax
from diffrax import ControlTerm, MultiTerm, ODETerm
import matplotlib.pyplot as plt
from functools import partial
import optax
from helper_fns_general import sample_gaussian_mixture, normalize_samples, CD1_gradient, setup_score_matching_loss, grad_loss
jax.config.update("jax_enable_x64", True)

# %% [markdown]
# ### Generate samples from a Gaussian mixture

# %%
# Set random seed
key = jr.PRNGKey(0)

# Parameters
N = 2  # number of dimensions
N_mixgauss = 3  # number of mixture components
n_samples = 10000

# Define mixture weights (must sum to 1)
weights = jnp.array([0.5, 0.5])

# Define means
means = jnp.array([
    [2.0, 0.0],   # mean of first Gaussian
    [-0.0, -1.0],  # mean of second Gaussian
])

# Define covariance matrices
covs = 0.1*jnp.array([
    [[1, 0.0],    # covariance of first Gaussian
        [0.0, 1]],
    [[1, -0.0],   # covariance of second Gaussian
        [-0.0, 1]],
])

# Generate samples
samples = sample_gaussian_mixture(key, n_samples, weights, means, covs)
# Normalize samples
# samples = normalize_samples(samples_raw)
# Out:
# CUDA backend failed to initialize: Unable to use CUDA because of the following issues with CUDA components:
# Outdated cuDNN installation found.
# Version JAX was built against: 8907
# Minimum supported: 9100
# Installed version: 8907
# The local installation version must be no lower than 9100..(Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %% [markdown]
# ### Plot samples and marginal distributions

# %%
# Plot samples and marginal distributions
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# First subplot: Scatter plot of samples
ax1.scatter(samples[:, 0], samples[:, 1], alpha=0.5)
ax1.set_title('Samples')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')

# Second subplot: Combined marginal distributions
ax2.hist(samples[:, 0], bins=50, density=True, alpha=0.7, label='X distribution')
ax2.hist(samples[:, 1], bins=50, density=True, alpha=0.7, label='Y distribution')
ax2.set_title('Marginal Distributions')
ax2.set_xlabel('Value')
ax2.set_ylabel('Density')
ax2.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Define energy function of duffing oscillator network

# %%
def energy_self_oscillator(x, k_lin, k_duff):
    return 1 / 2 * k_lin * x**2 + 1 / 4 * k_duff * x**4

def energy_self_network(x, k_lin, k_duff):
    return jnp.sum(vmap(energy_self_oscillator)(x, k_lin, k_duff))


def energy_coupling_pair(x, y, c_lin, c_optomech):
    return c_lin * x * (x - y) + c_lin * y * (y - x) + c_optomech * (x**2) * y

def energy_coupling_network(x, c_lin, c_optomech, connectivity):
    # get contribution to total energy from each pair of oscillators
    
    def _coupling_energy_pair(x, c_lin, c_optomech, pair):
        # get energy of one pair of oscillators
        i, j = pair
        return energy_coupling_pair(x[i], x[j], c_lin, c_optomech)

    # get energy of all pairs of oscillators
    return jnp.sum(
        vmap(_coupling_energy_pair, in_axes=(None, 0, 0, 0))(
            x, c_lin, c_optomech, connectivity
        )
    )

def _energy_duffing_network(x, k_lin, k_duff, c_lin, c_optomech, connectivity, k_b=1.0, T=1.0):
    # returns energy of network of oscillators given input parameters
    return (
        energy_self_network(x, k_lin, k_duff) +
        energy_coupling_network(x, c_lin, c_optomech, connectivity)
    ) / (k_b * T)

# %% [markdown]
# ### Define initial parameters

# %%
N_osc = 2

k_lin_0 = jnp.array([-10., -10.])
k_duff_0 = jnp.array([10., 10.])
c_lin_0 = jnp.array([1.,])
c_optomech_0 = jnp.array([0.,])
connectivity = jnp.array([[0, 1]])

args_initial = (k_lin_0, k_duff_0, c_lin_0, c_optomech_0)

flattened_args_initial, unflatten = flatten_util.ravel_pytree(args_initial)

# %% [markdown]
# ### Bringe energy into correct form

# %%
def energy_duffing_network(x, flattened_args, connectivity):
    k_lin, k_duffing, c_lin, c_optomech = unflatten(flattened_args)
    return _energy_duffing_network(x, k_lin, k_duffing, c_lin, c_optomech, connectivity)
energy_fn = lambda x, flattened_args: energy_duffing_network(x, flattened_args, connectivity)

# %% [markdown]
# ### Plot energy landscape

# %%
# Create a grid of phase values
n_points = 30
x1 = jnp.linspace(-5, 5, n_points)*2
x2 = jnp.linspace(-5, 5, n_points)*2
X1, X2 = jnp.meshgrid(x1, x2)

# Compute energy for each point in the grid
energy = jnp.zeros((n_points, n_points))
for i in range(n_points):
    for j in range(n_points):
        x = jnp.array([X1[i,j], X2[i,j]])
        energy = energy.at[i,j].set(energy_fn(x, flattened_args_initial))

# Create the contour plot
plt.figure(figsize=(10, 8))
plt.contourf(X1, X2, energy, levels=20, cmap='viridis')
plt.colorbar(label='Energy')
# Add scatter plot of samples
plt.scatter(samples[:, 0], samples[:, 1], c='black', s=1, alpha=0.5, label='Samples')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('XY Model Energy Landscape for initial parameters')
plt.legend()
plt.show()

# %% [markdown]
# ### Test minus CD1 gradient vs score matching gradient (eq. 10 in Connections Between Score Matching, Contrastive Divergence, and Pseudolikelihood for Continuous-Valued Variables)

# %%
# Compare gradient differences with score_matching_loss for different dt values
dt_values = jnp.logspace(-18, 1, 30)  # logarithmically spaced dt values
key = jr.PRNGKey(1)

# Get score matching gradient results (only need to compute once)
score_matching_loss = setup_score_matching_loss(energy_fn, samples)
score_matching_grad = grad_loss(score_matching_loss, flattened_args_initial)

# Initialize arrays to store results
n_params = len(flattened_args_initial)
relative_differences = jnp.zeros((len(dt_values), n_params))
total_relative_differences = jnp.zeros(len(dt_values))  # New array for total differences

# Loop over dt values
for i, dt in enumerate(dt_values):
    key, subkey = jr.split(key)
    
    # Get CD1 gradient for this dt
    cd1_grad = -CD1_gradient(energy_fn, samples, flattened_args_initial, 
                            dt=dt, D=1, key=subkey, num_noise_samples=0)
    
    # Calculate relative difference for each parameter
    rel_diff = jnp.abs(cd1_grad - score_matching_grad) / jnp.abs(score_matching_grad)
    relative_differences = relative_differences.at[i].set(rel_diff)
    
    # Calculate total relative difference using L2 norm
    total_rel_diff = jnp.linalg.norm(cd1_grad - score_matching_grad) / jnp.linalg.norm(score_matching_grad)
    total_relative_differences = total_relative_differences.at[i].set(total_rel_diff)

# Create figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 6))

# First subplot: Individual parameter differences
param_names = ['k_lin_1', 'k_lin_2', 'k_duff_1', 'k_duff_2', 'c_lin', 'c_optomech']
for param_idx in range(n_params):
    ax1.loglog(dt_values, relative_differences[:, param_idx], 'o-', 
               label=param_names[param_idx])

ax1.set_xlabel('dt')
ax1.set_ylabel('Relative Difference')
ax1.set_title('Individual Parameter Relative Differences')
ax1.grid(True)
ax1.legend()

# Second subplot: Total gradient difference
ax2.loglog(dt_values, total_relative_differences, 'o-', color='black', label='Total gradient')
ax2.set_xlabel('dt')
ax2.set_ylabel('Total Relative Difference')
ax2.set_title('Total Gradient Relative Difference (L2 norm)')
ax2.grid(True)
ax2.legend()

plt.tight_layout()
plt.show()

# Print the minimum relative differences
print("\nIndividual parameter minimum differences:")
for param_idx in range(n_params):
    min_idx = jnp.argmin(relative_differences[:, param_idx])
    print(f"\n{param_names[param_idx]}:")
    print(f"Minimum relative difference: {relative_differences[min_idx, param_idx]:.2e}")
    print(f"Optimal dt: {dt_values[min_idx]:.2e}")

print("\nTotal gradient minimum difference:")
min_total_idx = jnp.argmin(total_relative_differences)
print(f"Minimum total relative difference: {total_relative_differences[min_total_idx]:.2e}")
print(f"Optimal dt: {dt_values[min_total_idx]:.2e}")
# Out:
# Individual parameter minimum differences:
#
# k_lin_1:
# Minimum relative difference: 2.34e-05
# Optimal dt: 4.18e-16
#
# k_lin_2:
# Minimum relative difference: 2.43e-01
# Optimal dt: 2.40e-02
#
# k_duff_1:
# Minimum relative difference: 8.08e-03
# Optimal dt: 2.59e-04
#
# k_duff_2:
# Minimum relative difference: 2.72e-02
# Optimal dt: 2.40e-02
#
# c_lin:
# Minimum relative difference: 7.51e-03
# Optimal dt: 9.24e-17
#
# c_optomech:
# Minimum relative difference: 7.74e-02
# Optimal dt: 2.04e-17
#
# Total gradient minimum difference:
# Minimum total relative difference: 1.27e-02
# Optimal dt: 2.59e-04

# %%
# Define optimization parameters
learning_rate = 0.1
n_epochs = 2000
batch_size = 128

# Initialize optimizer
optimizer = optax.adam(learning_rate=learning_rate)
opt_state = optimizer.init(flattened_args_initial)

@partial(jax.jit, static_argnums=(3,))
def training_step(params, opt_state, samples, n_samples, key):
    """Single training step using CD-1"""
    # Get gradient of parameters
    key, subkey = jr.split(key)
    dparams = -CD1_gradient(energy_fn, samples, params, dt=2.59e-5, D=1, key=subkey, num_noise_samples=0)
    dparams_sm = grad_loss(score_matching_loss, params)
    
    # Compute relative difference between raw gradients
    rel_diff = jnp.linalg.norm(dparams - dparams_sm) / jnp.linalg.norm(dparams_sm)
    
    # Compute relative difference between normalized gradients
    norm_dparams = dparams / jnp.linalg.norm(dparams)
    norm_dparams_sm = dparams_sm / jnp.linalg.norm(dparams_sm)
    rel_diff_norm = jnp.linalg.norm(norm_dparams - norm_dparams_sm)
    
    # Compute log likelihood (negative energy)
    loss = score_matching_loss(params)
    
    # Apply updates
    updates, opt_state = optimizer.update(dparams_sm, opt_state)
    params = optax.apply_updates(params, updates)
    
    return params, opt_state, key, loss, rel_diff, rel_diff_norm

# Training loop
key = jr.PRNGKey(0)
params_history = []
loss_history = []
gradient_diff_history = []  # Raw gradient differences
gradient_diff_norm_history = []  # Normalized gradient differences

params = flattened_args_initial

for epoch in range(n_epochs):
    key, subkey = jr.split(key)
    params, opt_state, key, loss, rel_diff, rel_diff_norm = training_step(
        params, opt_state, samples, batch_size, subkey)
    
    # Store parameters, loss, and both gradient differences
    params_history.append(params)
    loss_history.append(loss)
    gradient_diff_history.append(rel_diff)
    gradient_diff_norm_history.append(rel_diff_norm)
    
    if epoch % 10 == 0:
        k_lin, k_duffing, c_lin, c_optomech = unflatten(params)
        print(f"Epoch {epoch}")
        print(f"k_lin:\n{k_lin}")
        print(f"k_duffing:\n{k_duffing}")
        print(f"c_lin:\n{c_lin}")
        print(f"c_optomech:\n{c_optomech}")
        print(f"Loss: {loss:.4f}")
        print(f"Raw gradient relative difference: {rel_diff:.4e}")
        print(f"Normalized gradient relative difference: {rel_diff_norm:.4e}")
        print("---")
# Out:
# Epoch 0
# k_lin:
# [-10.1 -10.1]
# k_duffing:
# [9.9 9.9]
# c_lin:
# [0.9]
# c_optomech:
# [0.1]
# Loss: 1544.4118
# Raw gradient relative difference: 1.8379e-02
# Normalized gradient relative difference: 5.9008e-03
# ---
# Epoch 10
# k_lin:
# [-11.08940224 -10.97985002]
# k_duffing:
# [8.90986882 8.94673749]
# c_lin:
# [-0.08170716]
# c_optomech:
# [0.43642292]
# Loss: 1004.0382
# Raw gradient relative difference: 2.3636e-02
# Normalized gradient relative difference: 8.5146e-03
# ---
# Epoch 20
# k_lin:
# [-12.02684305 -11.03107986]
# k_duffing:
# [7.968007   8.27121912]
# c_lin:
# [-0.98522179]
# c_optomech:
# [-0.4027388]
# Loss: 610.8521
# Raw gradient relative difference: 3.1342e-02
# Normalized gradient relative difference: 1.1928e-02
# ---
# Epoch 30
# k_lin:
# [-12.86574897 -10.20166066]
# k_duffing:
# [7.11708894 8.07917559]
# c_lin:
# [-1.76265991]
# c_optomech:
# [-1.38245496]
# Loss: 348.1068
# Raw gradient relative difference: 4.3474e-02
# Normalized gradient relative difference: 1.7078e-02
# ---
# Epoch 40
# k_lin:
# [-13.56768562  -9.08636057]
# k_duffing:
# [6.39131859 8.26522648]
# c_lin:
# [-2.3825124]
# c_optomech:
# [-2.18846117]
# Loss: 192.1657
# Raw gradient relative difference: 6.3754e-02
# Normalized gradient relative difference: 2.5822e-02
# ---
# Epoch 50
# k_lin:
# [-14.11013498  -7.9584881 ]
# k_duffing:
# [5.80960334 8.55407754]
# c_lin:
# [-2.8286271]
# c_optomech:
# [-2.69745271]
# Loss: 111.6371
# Raw gradient relative difference: 9.9699e-02
# Normalized gradient relative difference: 4.2952e-02
# ---
# Epoch 60
# k_lin:
# [-14.49047879  -6.93927365]
# k_duffing:
# [5.37260567 8.7081778 ]
# c_lin:
# [-3.09967922]
# c_optomech:
# [-2.96553811]
# Loss: 75.9107
# Raw gradient relative difference: 1.6528e-01
# Normalized gradient relative difference: 8.0611e-02
# ---
# Epoch 70
# k_lin:
# [-14.72521261  -6.0726978 ]
# k_duffing:
# [5.06413989 8.61259961]
# c_lin:
# [-3.21294472]
# c_optomech:
# [-3.0983845]
# Loss: 61.8343
# Raw gradient relative difference: 2.7590e-01
# Normalized gradient relative difference: 1.6139e-01
# ---
# Epoch 80
# k_lin:
# [-14.84415872  -5.34607184]
# k_duffing:
# [4.85665219 8.28412563]
# c_lin:
# [-3.20275577]
# c_optomech:
# [-3.12721377]
# Loss: 55.8060
# Raw gradient relative difference: 4.1073e-01
# Normalized gradient relative difference: 2.8937e-01
# ---
# Epoch 90
# k_lin:
# [-14.88184561  -4.71736326]
# k_duffing:
# [4.71879181 7.81178214]
# c_lin:
# [-3.10860248]
# c_optomech:
# [-3.05555658]
# Loss: 51.8875
# Raw gradient relative difference: 5.0195e-01
# Normalized gradient relative difference: 3.9954e-01
# ---
# Epoch 100
# k_lin:
# [-14.86985509  -4.14658375]
# k_duffing:
# [4.62205603 7.28367396]
# c_lin:
# [-2.96445561]
# c_optomech:
# [-2.92126952]
# Loss: 48.3149
# Raw gradient relative difference: 5.4263e-01
# Normalized gradient relative difference: 4.4832e-01
# ---
# Epoch 110
# k_lin:
# [-14.8324338   -3.61258517]
# k_duffing:
# [4.54466925 6.75243935]
# c_lin:
# [-2.79619587]
# c_optomech:
# [-2.76659222]
# Loss: 44.8707
# Raw gradient relative difference: 5.6381e-01
# Normalized gradient relative difference: 4.5588e-01
# ---
# Epoch 120
# k_lin:
# [-14.78525925  -3.11058347]
# k_duffing:
# [4.47268879 6.23894957]
# c_lin:
# [-2.62180664]
# c_optomech:
# [-2.60745162]
# Loss: 41.6395
# Raw gradient relative difference: 5.7763e-01
# Normalized gradient relative difference: 4.4607e-01
# ---
# Epoch 130
# k_lin:
# [-14.73638347  -2.64176755]
# k_duffing:
# [4.39911877 5.74960591]
# c_lin:
# [-2.45120503]
# c_optomech:
# [-2.44936808]
# Loss: 38.6638
# Raw gradient relative difference: 5.9031e-01
# Normalized gradient relative difference: 4.3576e-01
# ---
# Epoch 140
# k_lin:
# [-14.68841089  -2.20688137]
# k_duffing:
# [4.32190904 5.28767399]
# c_lin:
# [-2.28787646]
# c_optomech:
# [-2.29870486]
# Loss: 35.9356
# Raw gradient relative difference: 6.0824e-01
# Normalized gradient relative difference: 4.3318e-01
# ---
# Epoch 150
# k_lin:
# [-14.64092931  -1.80568011]
# k_duffing:
# [4.24173961 4.85548286]
# c_lin:
# [-2.13196792]
# c_optomech:
# [-2.15661122]
# Loss: 33.4370
# Raw gradient relative difference: 6.3411e-01
# Normalized gradient relative difference: 4.3945e-01
# ---
# Epoch 160
# k_lin:
# [-14.5924231   -1.43815118]
# k_duffing:
# [4.16027194 4.45352452]
# c_lin:
# [-1.98247945]
# c_optomech:
# [-2.02041879]
# Loss: 31.1540
# Raw gradient relative difference: 6.6710e-01
# Normalized gradient relative difference: 4.5258e-01
# ---
# Epoch 170
# k_lin:
# [-14.54141989  -1.10483764]
# k_duffing:
# [4.07909796 4.0805354 ]
# c_lin:
# [-1.83831862]
# c_optomech:
# [-1.88900413]
# Loss: 29.0742
# Raw gradient relative difference: 7.0542e-01
# Normalized gradient relative difference: 4.6961e-01
# ---
# Epoch 180
# k_lin:
# [-14.48697563  -0.80625953]
# k_duffing:
# [3.99930052 3.73468318]
# c_lin:
# [-1.69886025]
# c_optomech:
# [-1.76211652]
# Loss: 27.1849
# Raw gradient relative difference: 7.4746e-01
# Normalized gradient relative difference: 4.8787e-01
# ---
# Epoch 190
# k_lin:
# [-14.42870803  -0.54224473]
# k_duffing:
# [3.9214266 3.41469  ]
# c_lin:
# [-1.56400668]
# c_optomech:
# [-1.63932997]
# Loss: 25.4721
# Raw gradient relative difference: 7.9203e-01
# Normalized gradient relative difference: 5.0585e-01
# ---
# Epoch 200
# k_lin:
# [-14.36661766  -0.31178013]
# k_duffing:
# [3.8456528  3.12005561]
# c_lin:
# [-1.43394428]
# c_optomech:
# [-1.52077804]
# Loss: 23.9212
# Raw gradient relative difference: 8.3869e-01
# Normalized gradient relative difference: 5.2293e-01
# ---
# Epoch 210
# k_lin:
# [-14.3008843   -0.11334235]
# k_duffing:
# [3.77197385 2.85054313]
# c_lin:
# [-1.30895363]
# c_optomech:
# [-1.40684273]
# Loss: 22.5179
# Raw gradient relative difference: 8.8763e-01
# Normalized gradient relative difference: 5.3908e-01
# ---
# Epoch 220
# k_lin:
# [-14.23172254   0.05476484]
# k_duffing:
# [3.70033695 2.60568555]
# c_lin:
# [-1.18929393]
# c_optomech:
# [-1.29771659]
# Loss: 21.2482
# Raw gradient relative difference: 9.3923e-01
# Normalized gradient relative difference: 5.5461e-01
# ---
# Epoch 230
# k_lin:
# [-14.15931205   0.19430027]
# k_duffing:
# [3.63070693 2.38467167]
# c_lin:
# [-1.07512868]
# c_optomech:
# [-1.19355628]
# Loss: 20.0988
# Raw gradient relative difference: 9.9385e-01
# Normalized gradient relative difference: 5.6980e-01
# ---
# Epoch 240
# k_lin:
# [-14.08378632   0.30710046]
# k_duffing:
# [3.56307799 2.18644841]
# c_lin:
# [-0.96651989]
# c_optomech:
# [-1.0944486]
# Loss: 19.0571
# Raw gradient relative difference: 1.0518e+00
# Normalized gradient relative difference: 5.8475e-01
# ---
# Epoch 250
# k_lin:
# [-14.00524966   0.39509324]
# k_duffing:
# [3.49745948 2.00983031]
# c_lin:
# [-0.86345449]
# c_optomech:
# [-1.00036481]
# Loss: 18.1114
# Raw gradient relative difference: 1.1130e+00
# Normalized gradient relative difference: 5.9946e-01
# ---
# Epoch 260
# k_lin:
# [-13.92379807   0.46027461]
# k_duffing:
# [3.43385793 1.85355072]
# c_lin:
# [-0.76586997]
# c_optomech:
# [-0.91124507]
# Loss: 17.2512
# Raw gradient relative difference: 1.1776e+00
# Normalized gradient relative difference: 6.1378e-01
# ---
# Epoch 270
# k_lin:
# [-13.83953279   0.50467051]
# k_duffing:
# [3.37226576 1.71628269]
# c_lin:
# [-0.67367598]
# c_optomech:
# [-0.82700743]
# Loss: 16.4665
# Raw gradient relative difference: 1.2455e+00
# Normalized gradient relative difference: 6.2759e-01
# ---
# Epoch 280
# k_lin:
# [-13.75256433   0.53030864]
# k_duffing:
# [3.31265857 1.5966657 ]
# c_lin:
# [-0.58676482]
# c_optomech:
# [-0.74754775]
# Loss: 15.7487
# Raw gradient relative difference: 1.3165e+00
# Normalized gradient relative difference: 6.4079e-01
# ---
# Epoch 290
# k_lin:
# [-13.66301043   0.53919769]
# k_duffing:
# [3.25499786 1.49333499]
# c_lin:
# [-0.50501338]
# c_optomech:
# [-0.67275421]
# Loss: 15.0898
# Raw gradient relative difference: 1.3905e+00
# Normalized gradient relative difference: 6.5333e-01
# ---
# Epoch 300
# k_lin:
# [-13.57099229   0.53330457]
# k_duffing:
# [3.19923534 1.40493982]
# c_lin:
# [-0.42828411]
# c_optomech:
# [-0.60250103]
# Loss: 14.4829
# Raw gradient relative difference: 1.4675e+00
# Normalized gradient relative difference: 6.6518e-01
# ---
# Epoch 310
# k_lin:
# [-13.4766315    0.51453101]
# k_duffing:
# [3.14531653 1.33015391]
# c_lin:
# [-0.35642603]
# c_optomech:
# [-0.53664955]
# Loss: 13.9218
# Raw gradient relative difference: 1.5473e+00
# Normalized gradient relative difference: 6.7635e-01
# ---
# Epoch 320
# k_lin:
# [-13.38004837   0.48469468]
# k_duffing:
# [3.09318286 1.26768567]
# c_lin:
# [-0.28927669]
# c_optomech:
# [-0.4750519]
# Loss: 13.4011
# Raw gradient relative difference: 1.6296e+00
# Normalized gradient relative difference: 6.8683e-01
# ---
# Epoch 330
# k_lin:
# [-13.28136139   0.44551588]
# k_duffing:
# [3.04277292 1.21629002]
# c_lin:
# [-0.22666503]
# c_optomech:
# [-0.41755178]
# Loss: 12.9158
# Raw gradient relative difference: 1.7144e+00
# Normalized gradient relative difference: 6.9665e-01
# ---
# Epoch 340
# k_lin:
# [-13.1806871    0.39860812]
# k_duffing:
# [2.99402302 1.17477918]
# c_lin:
# [-0.16841399]
# c_optomech:
# [-0.36398773]
# Loss: 12.4618
# Raw gradient relative difference: 1.8013e+00
# Normalized gradient relative difference: 7.0583e-01
# ---
# Epoch 350
# k_lin:
# [-13.07814002   0.34547106]
# k_duffing:
# [2.94686782 1.14203034]
# c_lin:
# [-0.11434304]
# c_optomech:
# [-0.31419534]
# Loss: 12.0355
# Raw gradient relative difference: 1.8900e+00
# Normalized gradient relative difference: 7.1439e-01
# ---
# Epoch 360
# k_lin:
# [-12.97383246   0.2874857 ]
# k_duffing:
# [2.90124098 1.11699054]
# c_lin:
# [-0.06427002]
# c_optomech:
# [-0.26800882]
# Loss: 11.6335
# Raw gradient relative difference: 1.9803e+00
# Normalized gradient relative difference: 7.2237e-01
# ---
# Epoch 370
# k_lin:
# [-12.86787418   0.22591201]
# k_duffing:
# [2.8570758  1.09867988]
# c_lin:
# [-0.01801277]
# c_optomech:
# [-0.22526259]
# Loss: 11.2531
# Raw gradient relative difference: 2.0719e+00
# Normalized gradient relative difference: 7.2981e-01
# ---
# Epoch 380
# k_lin:
# [-12.76037215   0.16188885]
# k_duffing:
# [2.81430588 1.08619312]
# c_lin:
# [0.02460974]
# c_optomech:
# [-0.18579228]
# Loss: 10.8919
# Raw gradient relative difference: 2.1645e+00
# Normalized gradient relative difference: 7.3675e-01
# ---
# Epoch 390
# k_lin:
# [-12.65143032   0.09643563]
# k_duffing:
# [2.7728656  1.07870002]
# c_lin:
# [0.0637763]
# c_optomech:
# [-0.14943564]
# Loss: 10.5476
# Raw gradient relative difference: 2.2576e+00
# Normalized gradient relative difference: 7.4325e-01
# ---
# Epoch 400
# k_lin:
# [-12.54114948   0.03045553]
# k_duffing:
# [2.73269056 1.07544437]
# c_lin:
# [0.0996626]
# c_optomech:
# [-0.11603341]
# Loss: 10.2185
# Raw gradient relative difference: 2.3512e+00
# Normalized gradient relative difference: 7.4936e-01
# ---
# Epoch 410
# k_lin:
# [-12.42962722  -0.03526012]
# k_duffing:
# [2.69371789 1.07574218]
# c_lin:
# [0.1324405]
# c_optomech:
# [-0.08542992]
# Loss: 9.9029
# Raw gradient relative difference: 2.4448e+00
# Normalized gradient relative difference: 7.5511e-01
# ---
# Epoch 420
# k_lin:
# [-12.31695792  -0.10002629]
# k_duffing:
# [2.65588647 1.07897909]
# c_lin:
# [0.1622774]
# c_optomech:
# [-0.05747364]
# Loss: 9.5993
# Raw gradient relative difference: 2.5382e+00
# Normalized gradient relative difference: 7.6055e-01
# ---
# Epoch 430
# k_lin:
# [-12.20323271  -0.16325805]
# k_duffing:
# [2.61913711 1.08460719]
# c_lin:
# [0.1893358]
# c_optomech:
# [-0.03201763]
# Loss: 9.3066
# Raw gradient relative difference: 2.6311e+00
# Normalized gradient relative difference: 7.6573e-01
# ---
# Epoch 440
# k_lin:
# [-12.08853957  -0.22446387]
# k_duffing:
# [2.58341274 1.09214136]
# c_lin:
# [0.21377293]
# c_optomech:
# [-0.00891978]
# Loss: 9.0237
# Raw gradient relative difference: 2.7234e+00
# Normalized gradient relative difference: 7.7068e-01
# ---
# Epoch 450
# k_lin:
# [-11.97296329  -0.28323852]
# k_duffing:
# [2.54865849 1.10115527]
# c_lin:
# [0.23574052]
# c_optomech:
# [0.01195692]
# Loss: 8.7496
# Raw gradient relative difference: 2.8149e+00
# Normalized gradient relative difference: 7.7543e-01
# ---
# Epoch 460
# k_lin:
# [-11.85658562  -0.33925584]
# k_duffing:
# [2.51482177 1.11127721]
# c_lin:
# [0.25538463]
# c_optomech:
# [0.03074426]
# Loss: 8.4836
# Raw gradient relative difference: 2.9054e+00
# Normalized gradient relative difference: 7.8001e-01
# ---
# Epoch 470
# k_lin:
# [-11.73948528  -0.39226148]
# k_duffing:
# [2.48185228 1.12218578]
# c_lin:
# [0.27284556]
# c_optomech:
# [0.04756875]
# Loss: 8.2248
# Raw gradient relative difference: 2.9949e+00
# Normalized gradient relative difference: 7.8444e-01
# ---
# Epoch 480
# k_lin:
# [-11.62173811  -0.44206567]
# k_duffing:
# [2.44970209 1.13360562]
# c_lin:
# [0.28825778]
# c_optomech:
# [0.06255156]
# Loss: 7.9728
# Raw gradient relative difference: 3.0832e+00
# Normalized gradient relative difference: 7.8874e-01
# ---
# Epoch 490
# k_lin:
# [-11.5034171  -0.4885363]
# k_duffing:
# [2.41832556 1.14530315]
# c_lin:
# [0.30174996]
# c_optomech:
# [0.07580855]
# Loss: 7.7269
# Raw gradient relative difference: 3.1704e+00
# Normalized gradient relative difference: 7.9293e-01
# ---
# Epoch 500
# k_lin:
# [-11.38459253  -0.53159216]
# k_duffing:
# [2.38767936 1.15708249]
# c_lin:
# [0.31344501]
# c_optomech:
# [0.08745032]
# Loss: 7.4868
# Raw gradient relative difference: 3.2564e+00
# Normalized gradient relative difference: 7.9701e-01
# ---
# Epoch 510
# k_lin:
# [-11.26533208  -0.57119655]
# k_duffing:
# [2.35772245 1.16878144]
# c_lin:
# [0.32346018]
# c_optomech:
# [0.09758231]
# Loss: 7.2520
# Raw gradient relative difference: 3.3413e+00
# Normalized gradient relative difference: 8.0100e-01
# ---
# Epoch 520
# k_lin:
# [-11.14570089  -0.60735127]
# k_duffing:
# [2.32841598 1.18026778]
# c_lin:
# [0.33190711]
# c_optomech:
# [0.10630486]
# Loss: 7.0221
# Raw gradient relative difference: 3.4250e+00
# Normalized gradient relative difference: 8.0490e-01
# ---
# Epoch 530
# k_lin:
# [-11.02576169  -0.64009106]
# k_duffing:
# [2.29972327 1.19143569]
# c_lin:
# [0.338892]
# c_optomech:
# [0.11371335]
# Loss: 6.7970
# Raw gradient relative difference: 3.5077e+00
# Normalized gradient relative difference: 8.0873e-01
# ---
# Epoch 540
# k_lin:
# [-10.90557489  -0.66947834]
# k_duffing:
# [2.27160977 1.20220249]
# c_lin:
# [0.34451572]
# c_optomech:
# [0.11989835]
# Loss: 6.5763
# Raw gradient relative difference: 3.5895e+00
# Normalized gradient relative difference: 8.1247e-01
# ---
# Epoch 550
# k_lin:
# [-10.78519868  -0.69559856]
# k_duffing:
# [2.24404294 1.21250557]
# c_lin:
# [0.348874]
# c_optomech:
# [0.12494573]
# Loss: 6.3599
# Raw gradient relative difference: 3.6703e+00
# Normalized gradient relative difference: 8.1613e-01
# ---
# Epoch 560
# k_lin:
# [-10.66468911  -0.71855584]
# k_duffing:
# [2.21699222 1.22229961]
# c_lin:
# [0.35205753]
# c_optomech:
# [0.1289368]
# Loss: 6.1476
# Raw gradient relative difference: 3.7505e+00
# Normalized gradient relative difference: 8.1972e-01
# ---
# Epoch 570
# k_lin:
# [-10.54410018  -0.73846912]
# k_duffing:
# [2.19042896 1.23155405]
# c_lin:
# [0.35415214]
# c_optomech:
# [0.13194851]
# Loss: 5.9391
# Raw gradient relative difference: 3.8299e+00
# Normalized gradient relative difference: 8.2323e-01
# ---
# Epoch 580
# k_lin:
# [-10.42348393  -0.75546869]
# k_duffing:
# [2.16432634 1.24025079]
# c_lin:
# [0.35523902]
# c_optomech:
# [0.13405357]
# Loss: 5.7345
# Raw gradient relative difference: 3.9089e+00
# Normalized gradient relative difference: 8.2667e-01
# ---
# Epoch 590
# k_lin:
# [-10.3028905   -0.76969316]
# k_duffing:
# [2.13865927 1.24838216]
# c_lin:
# [0.3553948]
# c_optomech:
# [0.1353206]
# Loss: 5.5336
# Raw gradient relative difference: 3.9874e+00
# Normalized gradient relative difference: 8.3004e-01
# ---
# Epoch 600
# k_lin:
# [-10.18236825  -0.78128676]
# k_duffing:
# [2.11340438 1.25594907]
# c_lin:
# [0.35469178]
# c_optomech:
# [0.13581431]
# Loss: 5.3363
# Raw gradient relative difference: 4.0657e+00
# Normalized gradient relative difference: 8.3333e-01
# ---
# Epoch 610
# k_lin:
# [-10.06196375  -0.79039699]
# k_duffing:
# [2.08853989 1.26295941]
# c_lin:
# [0.35319809]
# c_optomech:
# [0.13559563]
# Loss: 5.1425
# Raw gradient relative difference: 4.1439e+00
# Normalized gradient relative difference: 8.3655e-01
# ---
# Epoch 620
# k_lin:
# [-9.94172194 -0.7971727 ]
# k_duffing:
# [2.06404556 1.26942666]
# c_lin:
# [0.35097785]
# c_optomech:
# [0.1347219]
# Loss: 4.9522
# Raw gradient relative difference: 4.2220e+00
# Normalized gradient relative difference: 8.3969e-01
# ---
# Epoch 630
# k_lin:
# [-9.8216861  -0.80176228]
# k_duffing:
# [2.03990263 1.27536864]
# c_lin:
# [0.34809131]
# c_optomech:
# [0.13324697]
# Loss: 4.7653
# Raw gradient relative difference: 4.3002e+00
# Normalized gradient relative difference: 8.4277e-01
# ---
# Epoch 640
# k_lin:
# [-9.701898   -0.80431235]
# k_duffing:
# [2.01609372 1.28080647]
# c_lin:
# [0.34459507]
# c_optomech:
# [0.1312214]
# Loss: 4.5819
# Raw gradient relative difference: 4.3787e+00
# Normalized gradient relative difference: 8.4577e-01
# ---
# Epoch 650
# k_lin:
# [-9.58239787 -0.80496649]
# k_duffing:
# [1.99260281 1.28576365]
# c_lin:
# [0.34054219]
# c_optomech:
# [0.12869259]
# Loss: 4.4017
# Raw gradient relative difference: 4.4575e+00
# Normalized gradient relative difference: 8.4870e-01
# ---
# Epoch 660
# k_lin:
# [-9.46322451 -0.80386436]
# k_duffing:
# [1.96941512 1.29026532]
# c_lin:
# [0.33598239]
# c_optomech:
# [0.12570491]
# Loss: 4.2249
# Raw gradient relative difference: 4.5368e+00
# Normalized gradient relative difference: 8.5157e-01
# ---
# Epoch 670
# k_lin:
# [-9.34441531 -0.80114092]
# k_duffing:
# [1.94651709 1.29433759]
# c_lin:
# [0.33096218]
# c_optomech:
# [0.12229985]
# Loss: 4.0515
# Raw gradient relative difference: 4.6167e+00
# Normalized gradient relative difference: 8.5437e-01
# ---
# Epoch 680
# k_lin:
# [-9.22600631 -0.79692584]
# k_duffing:
# [1.92389627 1.29800704]
# c_lin:
# [0.32552501]
# c_optomech:
# [0.11851618]
# Loss: 3.8813
# Raw gradient relative difference: 4.6973e+00
# Normalized gradient relative difference: 8.5711e-01
# ---
# Epoch 690
# k_lin:
# [-9.10803224 -0.79134308]
# k_duffing:
# [1.90154131 1.30130023]
# c_lin:
# [0.31971143]
# c_optomech:
# [0.11439005]
# Loss: 3.7143
# Raw gradient relative difference: 4.7787e+00
# Normalized gradient relative difference: 8.5979e-01
# ---
# Epoch 700
# k_lin:
# [-8.99052656 -0.78451062]
# k_duffing:
# [1.87944184 1.30424343]
# c_lin:
# [0.31355924]
# c_optomech:
# [0.10995515]
# Loss: 3.5506
# Raw gradient relative difference: 4.8610e+00
# Normalized gradient relative difference: 8.6241e-01
# ---
# Epoch 710
# k_lin:
# [-8.87352148 -0.77654024]
# k_duffing:
# [1.85758847 1.30686226]
# c_lin:
# [0.30710363]
# c_optomech:
# [0.10524281]
# Loss: 3.3902
# Raw gradient relative difference: 4.9444e+00
# Normalized gradient relative difference: 8.6497e-01
# ---
# Epoch 720
# k_lin:
# [-8.75704806 -0.76753749]
# k_duffing:
# [1.83597269 1.30918151]
# c_lin:
# [0.30037732]
# c_optomech:
# [0.10028218]
# Loss: 3.2330
# Raw gradient relative difference: 5.0289e+00
# Normalized gradient relative difference: 8.6747e-01
# ---
# Epoch 730
# k_lin:
# [-8.64113615 -0.75760164]
# k_duffing:
# [1.81458683 1.311225  ]
# c_lin:
# [0.29341067]
# c_optomech:
# [0.09510028]
# Loss: 3.0789
# Raw gradient relative difference: 5.1146e+00
# Normalized gradient relative difference: 8.6992e-01
# ---
# Epoch 740
# k_lin:
# [-8.52581451 -0.74682577]
# k_duffing:
# [1.793424   1.31301542]
# c_lin:
# [0.28623186]
# c_optomech:
# [0.08972217]
# Loss: 2.9281
# Raw gradient relative difference: 5.2017e+00
# Normalized gradient relative difference: 8.7233e-01
# ---
# Epoch 750
# k_lin:
# [-8.4111108  -0.73529687]
# k_duffing:
# [1.77247806 1.31457428]
# c_lin:
# [0.27886696]
# c_optomech:
# [0.08417104]
# Loss: 2.7804
# Raw gradient relative difference: 5.2902e+00
# Normalized gradient relative difference: 8.7468e-01
# ---
# Epoch 760
# k_lin:
# [-8.29705162 -0.72309605]
# k_duffing:
# [1.75174351 1.31592185]
# c_lin:
# [0.27134009]
# c_optomech:
# [0.07846833]
# Loss: 2.6359
# Raw gradient relative difference: 5.3803e+00
# Normalized gradient relative difference: 8.7699e-01
# ---
# Epoch 770
# k_lin:
# [-8.18366254 -0.7102987 ]
# k_duffing:
# [1.73121552 1.31707715]
# c_lin:
# [0.26367356]
# c_optomech:
# [0.07263384]
# Loss: 2.4945
# Raw gradient relative difference: 5.4720e+00
# Normalized gradient relative difference: 8.7925e-01
# ---
# Epoch 780
# k_lin:
# [-8.07096813 -0.6969747 ]
# k_duffing:
# [1.71088983 1.31805795]
# c_lin:
# [0.25588791]
# c_optomech:
# [0.06668581]
# Loss: 2.3562
# Raw gradient relative difference: 5.5655e+00
# Normalized gradient relative difference: 8.8148e-01
# ---
# Epoch 790
# k_lin:
# [-7.95899196 -0.68318874]
# k_duffing:
# [1.69076272 1.31888077]
# c_lin:
# [0.24800208]
# c_optomech:
# [0.06064107]
# Loss: 2.2210
# Raw gradient relative difference: 5.6607e+00
# Normalized gradient relative difference: 8.8366e-01
# ---
# Epoch 800
# k_lin:
# [-7.8477567 -0.6690005]
# k_duffing:
# [1.67083096 1.31956092]
# c_lin:
# [0.2400335]
# c_optomech:
# [0.05451506]
# Loss: 2.0889
# Raw gradient relative difference: 5.7579e+00
# Normalized gradient relative difference: 8.8581e-01
# ---
# Epoch 810
# k_lin:
# [-7.73728405 -0.65446495]
# k_duffing:
# [1.65109178 1.32011257]
# c_lin:
# [0.2319982]
# c_optomech:
# [0.04832197]
# Loss: 1.9598
# Raw gradient relative difference: 5.8571e+00
# Normalized gradient relative difference: 8.8792e-01
# ---
# Epoch 820
# k_lin:
# [-7.62759482 -0.63963262]
# k_duffing:
# [1.63154283 1.32054876]
# c_lin:
# [0.22391086]
# c_optomech:
# [0.04207483]
# Loss: 1.8337
# Raw gradient relative difference: 5.9584e+00
# Normalized gradient relative difference: 8.8999e-01
# ---
# Epoch 830
# k_lin:
# [-7.51870897 -0.62454986]
# k_duffing:
# [1.61218213 1.32088144]
# c_lin:
# [0.21578498]
# c_optomech:
# [0.03578556]
# Loss: 1.7106
# Raw gradient relative difference: 6.0620e+00
# Normalized gradient relative difference: 8.9204e-01
# ---
# Epoch 840
# k_lin:
# [-7.41064557 -0.60925911]
# k_duffing:
# [1.59300805 1.3211216 ]
# c_lin:
# [0.20763289]
# c_optomech:
# [0.02946509]
# Loss: 1.5905
# Raw gradient relative difference: 6.1678e+00
# Normalized gradient relative difference: 8.9405e-01
# ---
# Epoch 850
# k_lin:
# [-7.30342288 -0.59379917]
# k_duffing:
# [1.57401926 1.32127924]
# c_lin:
# [0.19946587]
# c_optomech:
# [0.02312337]
# Loss: 1.4734
# Raw gradient relative difference: 6.2760e+00
# Normalized gradient relative difference: 8.9604e-01
# ---
# Epoch 860
# k_lin:
# [-7.19705833 -0.57820544]
# k_duffing:
# [1.55521471 1.32136351]
# c_lin:
# [0.19129422]
# c_optomech:
# [0.01676952]
# Loss: 1.3591
# Raw gradient relative difference: 6.3868e+00
# Normalized gradient relative difference: 8.9799e-01
# ---
# Epoch 870
# k_lin:
# [-7.09156856 -0.56251015]
# k_duffing:
# [1.53659361 1.32138269]
# c_lin:
# [0.18312737]
# c_optomech:
# [0.01041182]
# Loss: 1.2477
# Raw gradient relative difference: 6.5001e+00
# Normalized gradient relative difference: 8.9992e-01
# ---
# Epoch 880
# k_lin:
# [-6.98696946 -0.54674263]
# k_duffing:
# [1.51815538 1.32134432]
# c_lin:
# [0.17497386]
# c_optomech:
# [0.00405783]
# Loss: 1.1391
# Raw gradient relative difference: 6.6162e+00
# Normalized gradient relative difference: 9.0182e-01
# ---
# Epoch 890
# k_lin:
# [-6.88327612 -0.53092949]
# k_duffing:
# [1.49989962 1.32125522]
# c_lin:
# [0.1668415]
# c_optomech:
# [-0.00228558]
# Loss: 1.0333
# Raw gradient relative difference: 6.7351e+00
# Normalized gradient relative difference: 9.0370e-01
# ---
# Epoch 900
# k_lin:
# [-6.78050292 -0.51509489]
# k_duffing:
# [1.48182614 1.32112155]
# c_lin:
# [0.15873738]
# c_optomech:
# [-0.00861218]
# Loss: 0.9303
# Raw gradient relative difference: 6.8569e+00
# Normalized gradient relative difference: 9.0555e-01
# ---
# Epoch 910
# k_lin:
# [-6.67866351 -0.49926066]
# k_duffing:
# [1.46393485 1.32094886]
# c_lin:
# [0.15066792]
# c_optomech:
# [-0.01491631]
# Loss: 0.8301
# Raw gradient relative difference: 6.9817e+00
# Normalized gradient relative difference: 9.0738e-01
# ---
# Epoch 920
# k_lin:
# [-6.57777083 -0.48344656]
# k_duffing:
# [1.44622581 1.32074216]
# c_lin:
# [0.14263898]
# c_optomech:
# [-0.02119285]
# Loss: 0.7325
# Raw gradient relative difference: 7.1096e+00
# Normalized gradient relative difference: 9.0919e-01
# ---
# Epoch 930
# k_lin:
# [-6.47783714 -0.4676704 ]
# k_duffing:
# [1.4286992  1.32050593]
# c_lin:
# [0.13465583]
# c_optomech:
# [-0.02743715]
# Loss: 0.6376
# Raw gradient relative difference: 7.2408e+00
# Normalized gradient relative difference: 9.1097e-01
# ---
# Epoch 940
# k_lin:
# [-6.37887401 -0.45194826]
# k_duffing:
# [1.41135526 1.3202442 ]
# c_lin:
# [0.12672326]
# c_optomech:
# [-0.03364503]
# Loss: 0.5453
# Raw gradient relative difference: 7.3754e+00
# Normalized gradient relative difference: 9.1274e-01
# ---
# Epoch 950
# k_lin:
# [-6.28089236 -0.43629459]
# k_duffing:
# [1.39419431 1.31996057]
# c_lin:
# [0.11884559]
# c_optomech:
# [-0.03981271]
# Loss: 0.4555
# Raw gradient relative difference: 7.5134e+00
# Normalized gradient relative difference: 9.1448e-01
# ---
# Epoch 960
# k_lin:
# [-6.18390245 -0.42072237]
# k_duffing:
# [1.37721674 1.31965826]
# c_lin:
# [0.11102672]
# c_optomech:
# [-0.04593676]
# Loss: 0.3683
# Raw gradient relative difference: 7.6550e+00
# Normalized gradient relative difference: 9.1620e-01
# ---
# Epoch 970
# k_lin:
# [-6.08791392 -0.40524326]
# k_duffing:
# [1.36042296 1.31934014]
# c_lin:
# [0.10327016]
# c_optomech:
# [-0.05201414]
# Loss: 0.2836
# Raw gradient relative difference: 7.8003e+00
# Normalized gradient relative difference: 9.1791e-01
# ---
# Epoch 980
# k_lin:
# [-5.99293576 -0.3898677 ]
# k_duffing:
# [1.34381345 1.31900877]
# c_lin:
# [0.09557909]
# c_optomech:
# [-0.05804207]
# Loss: 0.2013
# Raw gradient relative difference: 7.9495e+00
# Normalized gradient relative difference: 9.1959e-01
# ---
# Epoch 990
# k_lin:
# [-5.8989764  -0.37460503]
# k_duffing:
# [1.32738866 1.31866642]
# c_lin:
# [0.08795633]
# c_optomech:
# [-0.06401809]
# Loss: 0.1215
# Raw gradient relative difference: 8.1027e+00
# Normalized gradient relative difference: 9.2126e-01
# ---
# Epoch 1000
# k_lin:
# [-5.80604362 -0.35946358]
# k_duffing:
# [1.31114907 1.3183151 ]
# c_lin:
# [0.08040444]
# c_optomech:
# [-0.06993997]
# Loss: 0.0440
# Raw gradient relative difference: 8.2600e+00
# Normalized gradient relative difference: 9.2290e-01
# ---
# Epoch 1010
# k_lin:
# [-5.71414464 -0.34445079]
# k_duffing:
# [1.29509518 1.3179566 ]
# c_lin:
# [0.0729257]
# c_optomech:
# [-0.07580573]
# Loss: -0.0312
# Raw gradient relative difference: 8.4215e+00
# Normalized gradient relative difference: 9.2453e-01
# ---
# Epoch 1020
# k_lin:
# [-5.62328613 -0.32957326]
# k_duffing:
# [1.27922744 1.31759249]
# c_lin:
# [0.06552215]
# c_optomech:
# [-0.0816136]
# Loss: -0.1041
# Raw gradient relative difference: 8.5874e+00
# Normalized gradient relative difference: 9.2613e-01
# ---
# Epoch 1030
# k_lin:
# [-5.53347415 -0.31483686]
# k_duffing:
# [1.26354631 1.31722416]
# c_lin:
# [0.0581956]
# c_optomech:
# [-0.087362]
# Loss: -0.1748
# Raw gradient relative difference: 8.7579e+00
# Normalized gradient relative difference: 9.2772e-01
# ---
# Epoch 1040
# k_lin:
# [-5.44471424 -0.30024679]
# k_duffing:
# [1.24805221 1.31685285]
# c_lin:
# [0.05094768]
# c_optomech:
# [-0.09304954]
# Loss: -0.2433
# Raw gradient relative difference: 8.9331e+00
# Normalized gradient relative difference: 9.2930e-01
# ---
# Epoch 1050
# k_lin:
# [-5.35701139 -0.28580764]
# k_duffing:
# [1.23274556 1.31647962]
# c_lin:
# [0.04377981]
# c_optomech:
# [-0.09867497]
# Loss: -0.3096
# Raw gradient relative difference: 9.1131e+00
# Normalized gradient relative difference: 9.3085e-01
# ---
# Epoch 1060
# k_lin:
# [-5.27037007 -0.27152345]
# k_duffing:
# [1.2176267  1.31610544]
# c_lin:
# [0.03669325]
# c_optomech:
# [-0.1042372]
# Loss: -0.3739
# Raw gradient relative difference: 9.2981e+00
# Normalized gradient relative difference: 9.3238e-01
# ---
# Epoch 1070
# k_lin:
# [-5.18479422 -0.25739776]
# k_duffing:
# [1.20269597 1.31573111]
# c_lin:
# [0.02968912]
# c_optomech:
# [-0.10973528]
# Loss: -0.4361
# Raw gradient relative difference: 9.4883e+00
# Normalized gradient relative difference: 9.3390e-01
# ---
# Epoch 1080
# k_lin:
# [-5.10028726 -0.24343369]
# k_duffing:
# [1.18795365 1.31535738]
# c_lin:
# [0.02276838]
# c_optomech:
# [-0.11516836]
# Loss: -0.4963
# Raw gradient relative difference: 9.6839e+00
# Normalized gradient relative difference: 9.3540e-01
# ---
# Epoch 1090
# k_lin:
# [-5.01685215 -0.22963393]
# k_duffing:
# [1.17339996 1.31498487]
# c_lin:
# [0.01593188]
# c_optomech:
# [-0.1205357]
# Loss: -0.5545
# Raw gradient relative difference: 9.8850e+00
# Normalized gradient relative difference: 9.3688e-01
# ---
# Epoch 1100
# k_lin:
# [-4.93449131 -0.2160008 ]
# k_duffing:
# [1.1590351  1.31461413]
# c_lin:
# [0.00918034]
# c_optomech:
# [-0.12583669]
# Loss: -0.6108
# Raw gradient relative difference: 1.0092e+01
# Normalized gradient relative difference: 9.3834e-01
# ---
# Epoch 1110
# k_lin:
# [-4.85320672 -0.20253632]
# k_duffing:
# [1.14485919 1.31424564]
# c_lin:
# [0.00251439]
# c_optomech:
# [-0.13107078]
# Loss: -0.6652
# Raw gradient relative difference: 1.0305e+01
# Normalized gradient relative difference: 9.3979e-01
# ---
# Epoch 1120
# k_lin:
# [-4.77299987 -0.1892422 ]
# k_duffing:
# [1.1308723  1.31387981]
# c_lin:
# [-0.00406546]
# c_optomech:
# [-0.13623752]
# Loss: -0.7178
# Raw gradient relative difference: 1.0523e+01
# Normalized gradient relative difference: 9.4122e-01
# ---
# Epoch 1130
# k_lin:
# [-4.69387179 -0.17611986]
# k_duffing:
# [1.11707446 1.31351699]
# c_lin:
# [-0.01055878]
# c_optomech:
# [-0.14133653]
# Loss: -0.7686
# Raw gradient relative difference: 1.0749e+01
# Normalized gradient relative difference: 9.4263e-01
# ---
# Epoch 1140
# k_lin:
# [-4.61582306 -0.16317051]
# k_duffing:
# [1.10346563 1.31315751]
# c_lin:
# [-0.01696521]
# c_optomech:
# [-0.14636751]
# Loss: -0.8177
# Raw gradient relative difference: 1.0980e+01
# Normalized gradient relative difference: 9.4402e-01
# ---
# Epoch 1150
# k_lin:
# [-4.53885384 -0.15039511]
# k_duffing:
# [1.09004572 1.31280162]
# c_lin:
# [-0.02328449]
# c_optomech:
# [-0.15133021]
# Loss: -0.8650
# Raw gradient relative difference: 1.1219e+01
# Normalized gradient relative difference: 9.4539e-01
# ---
# Epoch 1160
# k_lin:
# [-4.46296382 -0.13779444]
# k_duffing:
# [1.07681456 1.31244954]
# c_lin:
# [-0.02951641]
# c_optomech:
# [-0.15622444]
# Loss: -0.9107
# Raw gradient relative difference: 1.1464e+01
# Normalized gradient relative difference: 9.4675e-01
# ---
# Epoch 1170
# k_lin:
# [-4.38815229 -0.12536908]
# k_duffing:
# [1.06377195 1.31210147]
# c_lin:
# [-0.03566085]
# c_optomech:
# [-0.16105009]
# Loss: -0.9548
# Raw gradient relative difference: 1.1717e+01
# Normalized gradient relative difference: 9.4809e-01
# ---
# Epoch 1180
# k_lin:
# [-4.31441812 -0.11311945]
# k_duffing:
# [1.0509176  1.31175756]
# c_lin:
# [-0.04171772]
# c_optomech:
# [-0.16580707]
# Loss: -0.9973
# Raw gradient relative difference: 1.1977e+01
# Normalized gradient relative difference: 9.4941e-01
# ---
# Epoch 1190
# k_lin:
# [-4.24175978 -0.10104582]
# k_duffing:
# [1.03825119 1.31141797]
# c_lin:
# [-0.047687]
# c_optomech:
# [-0.17049535]
# Loss: -1.0383
# Raw gradient relative difference: 1.2245e+01
# Normalized gradient relative difference: 9.5071e-01
# ---
# Epoch 1200
# k_lin:
# [-4.17017534 -0.08914832]
# k_duffing:
# [1.02577231 1.31108279]
# c_lin:
# [-0.05356874]
# c_optomech:
# [-0.17511494]
# Loss: -1.0778
# Raw gradient relative difference: 1.2521e+01
# Normalized gradient relative difference: 9.5200e-01
# ---
# Epoch 1210
# k_lin:
# [-4.09966248 -0.07742694]
# k_duffing:
# [1.01348052 1.31075213]
# c_lin:
# [-0.05936301]
# c_optomech:
# [-0.17966591]
# Loss: -1.1158
# Raw gradient relative difference: 1.2805e+01
# Normalized gradient relative difference: 9.5326e-01
# ---
# Epoch 1220
# k_lin:
# [-4.03021851 -0.06588156]
# k_duffing:
# [1.0013753  1.31042605]
# c_lin:
# [-0.06506994]
# c_optomech:
# [-0.18414833]
# Loss: -1.1525
# Raw gradient relative difference: 1.3098e+01
# Normalized gradient relative difference: 9.5451e-01
# ---
# Epoch 1230
# k_lin:
# [-3.96184037 -0.05451196]
# k_duffing:
# [0.98945609 1.31010463]
# c_lin:
# [-0.07068972]
# c_optomech:
# [-0.18856234]
# Loss: -1.1877
# Raw gradient relative difference: 1.3400e+01
# Normalized gradient relative difference: 9.5574e-01
# ---
# Epoch 1240
# k_lin:
# [-3.89452463 -0.04331781]
# k_duffing:
# [0.97772224 1.30978791]
# c_lin:
# [-0.07622254]
# c_optomech:
# [-0.19290809]
# Loss: -1.2217
# Raw gradient relative difference: 1.3711e+01
# Normalized gradient relative difference: 9.5696e-01
# ---
# Epoch 1250
# k_lin:
# [-3.82826753 -0.03229868]
# k_duffing:
# [0.96617308 1.30947592]
# c_lin:
# [-0.08166866]
# c_optomech:
# [-0.19718579]
# Loss: -1.2543
# Raw gradient relative difference: 1.4031e+01
# Normalized gradient relative difference: 9.5815e-01
# ---
# Epoch 1260
# k_lin:
# [-3.76306494 -0.02145406]
# k_duffing:
# [0.95480787 1.30916869]
# c_lin:
# [-0.08702838]
# c_optomech:
# [-0.20139565]
# Loss: -1.2857
# Raw gradient relative difference: 1.4361e+01
# Normalized gradient relative difference: 9.5933e-01
# ---
# Epoch 1270
# k_lin:
# [-3.69891243 -0.01078336]
# k_duffing:
# [0.94362581 1.30886624]
# c_lin:
# [-0.09230201]
# c_optomech:
# [-0.20553791]
# Loss: -1.3158
# Raw gradient relative difference: 1.4702e+01
# Normalized gradient relative difference: 9.6049e-01
# ---
# Epoch 1280
# k_lin:
# [-3.63580521e+00 -2.85909609e-04]
# k_duffing:
# [0.93262605 1.30856859]
# c_lin:
# [-0.09748992]
# c_optomech:
# [-0.20961286]
# Loss: -1.3448
# Raw gradient relative difference: 1.5053e+01
# Normalized gradient relative difference: 9.6163e-01
# ---
# Epoch 1290
# k_lin:
# [-3.57373821  0.01003903]
# k_duffing:
# [0.9218077  1.30827573]
# c_lin:
# [-0.10259248]
# c_optomech:
# [-0.2136208]
# Loss: -1.3727
# Raw gradient relative difference: 1.5415e+01
# Normalized gradient relative difference: 9.6276e-01
# ---
# Epoch 1300
# k_lin:
# [-3.51270604  0.02019227]
# k_duffing:
# [0.91116979 1.30798765]
# c_lin:
# [-0.10761012]
# c_optomech:
# [-0.21756204]
# Loss: -1.3994
# Raw gradient relative difference: 1.5788e+01
# Normalized gradient relative difference: 9.6387e-01
# ---
# Epoch 1310
# k_lin:
# [-3.45270301  0.03017468]
# k_duffing:
# [0.90071133 1.30770436]
# c_lin:
# [-0.11254328]
# c_optomech:
# [-0.22143695]
# Loss: -1.4251
# Raw gradient relative difference: 1.6173e+01
# Normalized gradient relative difference: 9.6496e-01
# ---
# Epoch 1320
# k_lin:
# [-3.39372314  0.03998719]
# k_duffing:
# [0.89043127 1.30742585]
# c_lin:
# [-0.11739243]
# c_optomech:
# [-0.22524588]
# Loss: -1.4497
# Raw gradient relative difference: 1.6570e+01
# Normalized gradient relative difference: 9.6603e-01
# ---
# Epoch 1330
# k_lin:
# [-3.33576017  0.04963078]
# k_duffing:
# [0.88032851 1.30715208]
# c_lin:
# [-0.12215807]
# c_optomech:
# [-0.22898922]
# Loss: -1.4733
# Raw gradient relative difference: 1.6980e+01
# Normalized gradient relative difference: 9.6708e-01
# ---
# Epoch 1340
# k_lin:
# [-3.27880759  0.05910649]
# k_duffing:
# [0.87040189 1.30688305]
# c_lin:
# [-0.12684073]
# c_optomech:
# [-0.23266739]
# Loss: -1.4959
# Raw gradient relative difference: 1.7403e+01
# Normalized gradient relative difference: 9.6812e-01
# ---
# Epoch 1350
# k_lin:
# [-3.22285861  0.06841543]
# k_duffing:
# [0.86065024 1.30661873]
# c_lin:
# [-0.13144094]
# c_optomech:
# [-0.23628081]
# Loss: -1.5176
# Raw gradient relative difference: 1.7840e+01
# Normalized gradient relative difference: 9.6914e-01
# ---
# Epoch 1360
# k_lin:
# [-3.16790618  0.07755872]
# k_duffing:
# [0.85107233 1.3063591 ]
# c_lin:
# [-0.13595928]
# c_optomech:
# [-0.23982993]
# Loss: -1.5384
# Raw gradient relative difference: 1.8290e+01
# Normalized gradient relative difference: 9.7014e-01
# ---
# Epoch 1370
# k_lin:
# [-3.11394302  0.08653755]
# k_duffing:
# [0.84166687 1.30610412]
# c_lin:
# [-0.14039634]
# c_optomech:
# [-0.2433152]
# Loss: -1.5583
# Raw gradient relative difference: 1.8756e+01
# Normalized gradient relative difference: 9.7113e-01
# ---
# Epoch 1380
# k_lin:
# [-3.06096161  0.09535314]
# k_duffing:
# [0.83243255 1.30585376]
# c_lin:
# [-0.14475273]
# c_optomech:
# [-0.24673712]
# Loss: -1.5774
# Raw gradient relative difference: 1.9236e+01
# Normalized gradient relative difference: 9.7210e-01
# ---
# Epoch 1390
# k_lin:
# [-3.0089542   0.10400678]
# k_duffing:
# [0.82336802 1.30560801]
# c_lin:
# [-0.14902907]
# c_optomech:
# [-0.25009616]
# Loss: -1.5956
# Raw gradient relative difference: 1.9732e+01
# Normalized gradient relative difference: 9.7305e-01
# ---
# Epoch 1400
# k_lin:
# [-2.95791284  0.11249976]
# k_duffing:
# [0.81447189 1.3053668 ]
# c_lin:
# [-0.15322602]
# c_optomech:
# [-0.25339285]
# Loss: -1.6131
# Raw gradient relative difference: 2.0244e+01
# Normalized gradient relative difference: 9.7399e-01
# ---
# Epoch 1410
# k_lin:
# [-2.90782934  0.12083344]
# k_duffing:
# [0.80574273 1.30513012]
# c_lin:
# [-0.15734425]
# c_optomech:
# [-0.2566277]
# Loss: -1.6298
# Raw gradient relative difference: 2.0774e+01
# Normalized gradient relative difference: 9.7490e-01
# ---
# Epoch 1420
# k_lin:
# [-2.85869534  0.12900919]
# k_duffing:
# [0.79717908 1.30489793]
# c_lin:
# [-0.16138443]
# c_optomech:
# [-0.25980126]
# Loss: -1.6457
# Raw gradient relative difference: 2.1321e+01
# Normalized gradient relative difference: 9.7581e-01
# ---
# Epoch 1430
# k_lin:
# [-2.81050225  0.13702843]
# k_duffing:
# [0.78877944 1.30467018]
# c_lin:
# [-0.16534728]
# c_optomech:
# [-0.26291407]
# Loss: -1.6610
# Raw gradient relative difference: 2.1886e+01
# Normalized gradient relative difference: 9.7669e-01
# ---
# Epoch 1440
# k_lin:
# [-2.76324133  0.14489261]
# k_duffing:
# [0.78054229 1.30444684]
# c_lin:
# [-0.1692335]
# c_optomech:
# [-0.26596669]
# Loss: -1.6756
# Raw gradient relative difference: 2.2470e+01
# Normalized gradient relative difference: 9.7756e-01
# ---
# Epoch 1450
# k_lin:
# [-2.71690365  0.15260321]
# k_duffing:
# [0.77246606 1.30422786]
# c_lin:
# [-0.17304382]
# c_optomech:
# [-0.2689597]
# Loss: -1.6895
# Raw gradient relative difference: 2.3074e+01
# Normalized gradient relative difference: 9.7841e-01
# ---
# Epoch 1460
# k_lin:
# [-2.6714801   0.16016174]
# k_duffing:
# [0.76454917 1.3040132 ]
# c_lin:
# [-0.176779]
# c_optomech:
# [-0.27189369]
# Loss: -1.7027
# Raw gradient relative difference: 2.3698e+01
# Normalized gradient relative difference: 9.7925e-01
# ---
# Epoch 1470
# k_lin:
# [-2.62696145  0.16756972]
# k_duffing:
# [0.75679001 1.30380282]
# c_lin:
# [-0.18043979]
# c_optomech:
# [-0.27476924]
# Loss: -1.7154
# Raw gradient relative difference: 2.4343e+01
# Normalized gradient relative difference: 9.8007e-01
# ---
# Epoch 1480
# k_lin:
# [-2.58333826  0.17482873]
# k_duffing:
# [0.74918693 1.30359667]
# c_lin:
# [-0.18402697]
# c_optomech:
# [-0.27758697]
# Loss: -1.7275
# Raw gradient relative difference: 2.5011e+01
# Normalized gradient relative difference: 9.8087e-01
# ---
# Epoch 1490
# k_lin:
# [-2.540601    0.18194034]
# k_duffing:
# [0.74173827 1.30339472]
# c_lin:
# [-0.18754131]
# c_optomech:
# [-0.28034749]
# Loss: -1.7390
# Raw gradient relative difference: 2.5701e+01
# Normalized gradient relative difference: 9.8166e-01
# ---
# Epoch 1500
# k_lin:
# [-2.49873998  0.18890617]
# k_duffing:
# [0.73444234 1.30319691]
# c_lin:
# [-0.19098361]
# c_optomech:
# [-0.28305143]
# Loss: -1.7500
# Raw gradient relative difference: 2.6416e+01
# Normalized gradient relative difference: 9.8243e-01
# ---
# Epoch 1510
# k_lin:
# [-2.45774537  0.19572785]
# k_duffing:
# [0.72729742 1.30300319]
# c_lin:
# [-0.19435468]
# c_optomech:
# [-0.28569941]
# Loss: -1.7605
# Raw gradient relative difference: 2.7155e+01
# Normalized gradient relative difference: 9.8319e-01
# ---
# Epoch 1520
# k_lin:
# [-2.41760724  0.20240703]
# k_duffing:
# [0.72030179 1.30281353]
# c_lin:
# [-0.19765533]
# c_optomech:
# [-0.28829208]
# Loss: -1.7704
# Raw gradient relative difference: 2.7920e+01
# Normalized gradient relative difference: 9.8393e-01
# ---
# Epoch 1530
# k_lin:
# [-2.37831556  0.20894537]
# k_duffing:
# [0.71345369 1.30262786]
# c_lin:
# [-0.20088639]
# c_optomech:
# [-0.29083009]
# Loss: -1.7799
# Raw gradient relative difference: 2.8711e+01
# Normalized gradient relative difference: 9.8466e-01
# ---
# Epoch 1540
# k_lin:
# [-2.33986015  0.21534456]
# k_duffing:
# [0.70675135 1.30244616]
# c_lin:
# [-0.20404869]
# c_optomech:
# [-0.29331409]
# Loss: -1.7890
# Raw gradient relative difference: 2.9531e+01
# Normalized gradient relative difference: 9.8537e-01
# ---
# Epoch 1550
# k_lin:
# [-2.30223078  0.22160632]
# k_duffing:
# [0.70019299 1.30226835]
# c_lin:
# [-0.20714307]
# c_optomech:
# [-0.29574475]
# Loss: -1.7976
# Raw gradient relative difference: 3.0379e+01
# Normalized gradient relative difference: 9.8607e-01
# ---
# Epoch 1560
# k_lin:
# [-2.2654171   0.22773235]
# k_duffing:
# [0.6937768  1.30209441]
# c_lin:
# [-0.21017039]
# c_optomech:
# [-0.29812272]
# Loss: -1.8057
# Raw gradient relative difference: 3.1258e+01
# Normalized gradient relative difference: 9.8675e-01
# ---
# Epoch 1570
# k_lin:
# [-2.22940869  0.23372439]
# k_duffing:
# [0.68750097 1.30192427]
# c_lin:
# [-0.21313149]
# c_optomech:
# [-0.30044868]
# Loss: -1.8135
# Raw gradient relative difference: 3.2168e+01
# Normalized gradient relative difference: 9.8742e-01
# ---
# Epoch 1580
# k_lin:
# [-2.19419505  0.23958419]
# k_duffing:
# [0.68136366 1.30175789]
# c_lin:
# [-0.21602725]
# c_optomech:
# [-0.30272331]
# Loss: -1.8209
# Raw gradient relative difference: 3.3111e+01
# Normalized gradient relative difference: 9.8807e-01
# ---
# Epoch 1590
# k_lin:
# [-2.15976563  0.2453135 ]
# k_duffing:
# [0.67536303 1.30159522]
# c_lin:
# [-0.21885852]
# c_optomech:
# [-0.30494729]
# Loss: -1.8279
# Raw gradient relative difference: 3.4087e+01
# Normalized gradient relative difference: 9.8871e-01
# ---
# Epoch 1600
# k_lin:
# [-2.12610979  0.25091409]
# k_duffing:
# [0.66949723 1.3014362 ]
# c_lin:
# [-0.22162619]
# c_optomech:
# [-0.30712131]
# Loss: -1.8345
# Raw gradient relative difference: 3.5100e+01
# Normalized gradient relative difference: 9.8934e-01
# ---
# Epoch 1610
# k_lin:
# [-2.09321685  0.25638773]
# k_duffing:
# [0.6637644 1.3012808]
# c_lin:
# [-0.22433112]
# c_optomech:
# [-0.30924605]
# Loss: -1.8408
# Raw gradient relative difference: 3.6149e+01
# Normalized gradient relative difference: 9.8995e-01
# ---
# Epoch 1620
# k_lin:
# [-2.06107609  0.26173622]
# k_duffing:
# [0.65816268 1.30112894]
# c_lin:
# [-0.22697421]
# c_optomech:
# [-0.31132222]
# Loss: -1.8468
# Raw gradient relative difference: 3.7236e+01
# Normalized gradient relative difference: 9.9055e-01
# ---
# Epoch 1630
# k_lin:
# [-2.02967673  0.26696133]
# k_duffing:
# [0.65269017 1.3009806 ]
# c_lin:
# [-0.22955634]
# c_optomech:
# [-0.31335049]
# Loss: -1.8525
# Raw gradient relative difference: 3.8364e+01
# Normalized gradient relative difference: 9.9113e-01
# ---
# Epoch 1640
# k_lin:
# [-1.99900798  0.27206488]
# k_duffing:
# [0.647345  1.3008357]
# c_lin:
# [-0.23207838]
# c_optomech:
# [-0.31533158]
# Loss: -1.8579
# Raw gradient relative difference: 3.9533e+01
# Normalized gradient relative difference: 9.9170e-01
# ---
# Epoch 1650
# k_lin:
# [-1.969059    0.27704865]
# k_duffing:
# [0.64212528 1.30069421]
# c_lin:
# [-0.23454125]
# c_optomech:
# [-0.31726617]
# Loss: -1.8630
# Raw gradient relative difference: 4.0745e+01
# Normalized gradient relative difference: 9.9226e-01
# ---
# Epoch 1660
# k_lin:
# [-1.93981894  0.28191446]
# k_duffing:
# [0.63702912 1.30055607]
# c_lin:
# [-0.23694581]
# c_optomech:
# [-0.31915498]
# Loss: -1.8678
# Raw gradient relative difference: 4.2003e+01
# Normalized gradient relative difference: 9.9281e-01
# ---
# Epoch 1670
# k_lin:
# [-1.91127694  0.28666412]
# k_duffing:
# [0.63205462 1.30042123]
# c_lin:
# [-0.23929298]
# c_optomech:
# [-0.32099869]
# Loss: -1.8724
# Raw gradient relative difference: 4.3309e+01
# Normalized gradient relative difference: 9.9334e-01
# ---
# Epoch 1680
# k_lin:
# [-1.88342212  0.29129942]
# k_duffing:
# [0.6271999  1.30028963]
# c_lin:
# [-0.24158364]
# c_optomech:
# [-0.32279802]
# Loss: -1.8767
# Raw gradient relative difference: 4.4663e+01
# Normalized gradient relative difference: 9.9386e-01
# ---
# Epoch 1690
# k_lin:
# [-1.85624359  0.29582219]
# k_duffing:
# [0.62246304 1.30016123]
# c_lin:
# [-0.24381869]
# c_optomech:
# [-0.32455367]
# Loss: -1.8808
# Raw gradient relative difference: 4.6069e+01
# Normalized gradient relative difference: 9.9436e-01
# ---
# Epoch 1700
# k_lin:
# [-1.82973049  0.30023423]
# k_duffing:
# [0.61784217 1.30003598]
# c_lin:
# [-0.24599902]
# c_optomech:
# [-0.32626634]
# Loss: -1.8847
# Raw gradient relative difference: 4.7528e+01
# Normalized gradient relative difference: 9.9486e-01
# ---
# Epoch 1710
# k_lin:
# [-1.80387194  0.30453734]
# k_duffing:
# [0.61333537 1.29991382]
# c_lin:
# [-0.24812552]
# c_optomech:
# [-0.32793672]
# Loss: -1.8884
# Raw gradient relative difference: 4.9044e+01
# Normalized gradient relative difference: 9.9534e-01
# ---
# Epoch 1720
# k_lin:
# [-1.77865709  0.30873335]
# k_duffing:
# [0.60894076 1.2997947 ]
# c_lin:
# [-0.2501991]
# c_optomech:
# [-0.32956553]
# Loss: -1.8918
# Raw gradient relative difference: 5.0617e+01
# Normalized gradient relative difference: 9.9581e-01
# ---
# Epoch 1730
# k_lin:
# [-1.7540751   0.31282404]
# k_duffing:
# [0.60465646 1.29967857]
# c_lin:
# [-0.25222063]
# c_optomech:
# [-0.33115346]
# Loss: -1.8951
# Raw gradient relative difference: 5.2252e+01
# Normalized gradient relative difference: 9.9627e-01
# ---
# Epoch 1740
# k_lin:
# [-1.73011516  0.31681122]
# k_duffing:
# [0.60048057 1.29956539]
# c_lin:
# [-0.25419101]
# c_optomech:
# [-0.33270121]
# Loss: -1.8982
# Raw gradient relative difference: 5.3950e+01
# Normalized gradient relative difference: 9.9672e-01
# ---
# Epoch 1750
# k_lin:
# [-1.70676649  0.32069668]
# k_duffing:
# [0.59641122 1.29945509]
# c_lin:
# [-0.25611112]
# c_optomech:
# [-0.33420947]
# Loss: -1.9011
# Raw gradient relative difference: 5.5715e+01
# Normalized gradient relative difference: 9.9716e-01
# ---
# Epoch 1760
# k_lin:
# [-1.68401833  0.32448222]
# k_duffing:
# [0.59244653 1.29934762]
# c_lin:
# [-0.25798185]
# c_optomech:
# [-0.33567895]
# Loss: -1.9039
# Raw gradient relative difference: 5.7549e+01
# Normalized gradient relative difference: 9.9758e-01
# ---
# Epoch 1770
# k_lin:
# [-1.66186    0.3281696]
# k_duffing:
# [0.58858464 1.29924295]
# c_lin:
# [-0.25980408]
# c_optomech:
# [-0.33711032]
# Loss: -1.9064
# Raw gradient relative difference: 5.9455e+01
# Normalized gradient relative difference: 9.9800e-01
# ---
# Epoch 1780
# k_lin:
# [-1.64028081  0.33176061]
# k_duffing:
# [0.58482369 1.29914101]
# c_lin:
# [-0.26157868]
# c_optomech:
# [-0.33850429]
# Loss: -1.9089
# Raw gradient relative difference: 6.1437e+01
# Normalized gradient relative difference: 9.9840e-01
# ---
# Epoch 1790
# k_lin:
# [-1.61927015  0.33525701]
# k_duffing:
# [0.58116182 1.29904176]
# c_lin:
# [-0.26330653]
# c_optomech:
# [-0.33986153]
# Loss: -1.9112
# Raw gradient relative difference: 6.3497e+01
# Normalized gradient relative difference: 9.9880e-01
# ---
# Epoch 1800
# k_lin:
# [-1.59881747  0.33866056]
# k_duffing:
# [0.57759721 1.29894514]
# c_lin:
# [-0.26498849]
# c_optomech:
# [-0.34118273]
# Loss: -1.9134
# Raw gradient relative difference: 6.5641e+01
# Normalized gradient relative difference: 9.9918e-01
# ---
# Epoch 1810
# k_lin:
# [-1.57891225  0.34197301]
# k_duffing:
# [0.57412801 1.29885111]
# c_lin:
# [-0.26662543]
# c_optomech:
# [-0.34246856]
# Loss: -1.9154
# Raw gradient relative difference: 6.7871e+01
# Normalized gradient relative difference: 9.9955e-01
# ---
# Epoch 1820
# k_lin:
# [-1.55954406  0.34519609]
# k_duffing:
# [0.5707524  1.29875962]
# c_lin:
# [-0.26821822]
# c_optomech:
# [-0.3437197]
# Loss: -1.9173
# Raw gradient relative difference: 7.0191e+01
# Normalized gradient relative difference: 9.9992e-01
# ---
# Epoch 1830
# k_lin:
# [-1.54070252  0.34833153]
# k_duffing:
# [0.56746859 1.29867061]
# c_lin:
# [-0.26976769]
# c_optomech:
# [-0.34493683]
# Loss: -1.9191
# Raw gradient relative difference: 7.2605e+01
# Normalized gradient relative difference: 1.0003e+00
# ---
# Epoch 1840
# k_lin:
# [-1.52237731  0.35138106]
# k_duffing:
# [0.56427477 1.29858405]
# c_lin:
# [-0.2712747]
# c_optomech:
# [-0.3461206]
# Loss: -1.9208
# Raw gradient relative difference: 7.5119e+01
# Normalized gradient relative difference: 1.0006e+00
# ---
# Epoch 1850
# k_lin:
# [-1.50455821  0.35434636]
# k_duffing:
# [0.56116915 1.29849988]
# c_lin:
# [-0.27274009]
# c_optomech:
# [-0.34727168]
# Loss: -1.9224
# Raw gradient relative difference: 7.7735e+01
# Normalized gradient relative difference: 1.0009e+00
# ---
# Epoch 1860
# k_lin:
# [-1.48723506  0.35722913]
# k_duffing:
# [0.55814997 1.29841805]
# c_lin:
# [-0.2741647]
# c_optomech:
# [-0.34839072]
# Loss: -1.9239
# Raw gradient relative difference: 8.0460e+01
# Normalized gradient relative difference: 1.0013e+00
# ---
# Epoch 1870
# k_lin:
# [-1.47039778  0.36003104]
# k_duffing:
# [0.55521548 1.29833851]
# c_lin:
# [-0.27554935]
# c_optomech:
# [-0.34947838]
# Loss: -1.9253
# Raw gradient relative difference: 8.3298e+01
# Normalized gradient relative difference: 1.0016e+00
# ---
# Epoch 1880
# k_lin:
# [-1.45403638  0.36275377]
# k_duffing:
# [0.55236392 1.29826122]
# c_lin:
# [-0.27689487]
# c_optomech:
# [-0.3505353]
# Loss: -1.9266
# Raw gradient relative difference: 8.6254e+01
# Normalized gradient relative difference: 1.0019e+00
# ---
# Epoch 1890
# k_lin:
# [-1.43814095  0.36539895]
# k_duffing:
# [0.54959357 1.29818614]
# c_lin:
# [-0.27820207]
# c_optomech:
# [-0.35156211]
# Loss: -1.9279
# Raw gradient relative difference: 8.9334e+01
# Normalized gradient relative difference: 1.0022e+00
# ---
# Epoch 1900
# k_lin:
# [-1.42270168  0.36796822]
# k_duffing:
# [0.54690273 1.29811321]
# c_lin:
# [-0.27947175]
# c_optomech:
# [-0.35255946]
# Loss: -1.9290
# Raw gradient relative difference: 9.2544e+01
# Normalized gradient relative difference: 1.0025e+00
# ---
# Epoch 1910
# k_lin:
# [-1.40770884  0.37046321]
# k_duffing:
# [0.54428969 1.29804239]
# c_lin:
# [-0.28070473]
# c_optomech:
# [-0.35352797]
# Loss: -1.9301
# Raw gradient relative difference: 9.5891e+01
# Normalized gradient relative difference: 1.0028e+00
# ---
# Epoch 1920
# k_lin:
# [-1.39315281  0.3728855 ]
# k_duffing:
# [0.54175279 1.29797363]
# c_lin:
# [-0.28190178]
# c_optomech:
# [-0.35446827]
# Loss: -1.9312
# Raw gradient relative difference: 9.9379e+01
# Normalized gradient relative difference: 1.0030e+00
# ---
# Epoch 1930
# k_lin:
# [-1.37902406  0.37523669]
# k_duffing:
# [0.53929035 1.29790689]
# c_lin:
# [-0.28306369]
# c_optomech:
# [-0.35538096]
# Loss: -1.9321
# Raw gradient relative difference: 1.0302e+02
# Normalized gradient relative difference: 1.0033e+00
# ---
# Epoch 1940
# k_lin:
# [-1.36531316  0.37751835]
# k_duffing:
# [0.53690074 1.29784212]
# c_lin:
# [-0.28419124]
# c_optomech:
# [-0.35626666]
# Loss: -1.9330
# Raw gradient relative difference: 1.0681e+02
# Normalized gradient relative difference: 1.0036e+00
# ---
# Epoch 1950
# k_lin:
# [-1.35201079  0.37973202]
# k_duffing:
# [0.53458233 1.29777929]
# c_lin:
# [-0.28528519]
# c_optomech:
# [-0.35712598]
# Loss: -1.9338
# Raw gradient relative difference: 1.1077e+02
# Normalized gradient relative difference: 1.0038e+00
# ---
# Epoch 1960
# k_lin:
# [-1.33910772  0.38187924]
# k_duffing:
# [0.53233351 1.29771834]
# c_lin:
# [-0.28634631]
# c_optomech:
# [-0.35795949]
# Loss: -1.9346
# Raw gradient relative difference: 1.1490e+02
# Normalized gradient relative difference: 1.0041e+00
# ---
# Epoch 1970
# k_lin:
# [-1.32659485  0.38396153]
# k_duffing:
# [0.5301527  1.29765923]
# c_lin:
# [-0.28737534]
# c_optomech:
# [-0.35876781]
# Loss: -1.9354
# Raw gradient relative difference: 1.1921e+02
# Normalized gradient relative difference: 1.0043e+00
# ---
# Epoch 1980
# k_lin:
# [-1.31446318  0.38598039]
# k_duffing:
# [0.52803832 1.29760193]
# c_lin:
# [-0.28837302]
# c_optomech:
# [-0.35955149]
# Loss: -1.9360
# Raw gradient relative difference: 1.2371e+02
# Normalized gradient relative difference: 1.0045e+00
# ---
# Epoch 1990
# k_lin:
# [-1.30270381  0.38793729]
# k_duffing:
# [0.52598884 1.29754638]
# c_lin:
# [-0.28934008]
# c_optomech:
# [-0.36031113]
# Loss: -1.9367
# Raw gradient relative difference: 1.2841e+02
# Normalized gradient relative difference: 1.0047e+00
# ---

# %%
# Convert histories to arrays for plotting
slicing = 1
params_history = jnp.array(params_history[::slicing])
k_lin_history = jnp.zeros((len(params_history), N_osc))
k_duff_history = jnp.zeros((len(params_history), N_osc))
c_lin_history = jnp.zeros((len(params_history), 1))
c_optomech_history = jnp.zeros((len(params_history), 1))

for i in range(len(params_history)):
    k_lin, k_duff, c_lin, c_optomech = unflatten(params_history[i])
    k_lin_history = k_lin_history.at[i].set(k_lin)
    k_duff_history = k_duff_history.at[i].set(k_duff)
    c_lin_history = c_lin_history.at[i].set(c_lin)
    c_optomech_history = c_optomech_history.at[i].set(c_optomech)

loss_history = jnp.array(loss_history[::slicing])
gradient_diff_history = jnp.array(gradient_diff_history[::slicing])
gradient_diff_norm_history = jnp.array(gradient_diff_norm_history[::slicing])

# Create figure with 3 rows and 2 columns
fig, axes = plt.subplots(3, 2, figsize=(20, 24))

# Plot k_lin evolution
for i in range(N_osc):
    axes[0, 0].plot(k_lin_history[:, i], label=f'k_lin[{i}]')
axes[0, 0].set_title(f'Evolution of k_lin\nFinal values:\n' + 
                     '\n'.join([f'k_lin[{i}] = {k_lin_history[-1,i]:.3f}' 
                               for i in range(N_osc)]))
axes[0, 0].set_xlabel('Epoch')
axes[0, 0].set_ylabel('Linear Strength')
axes[0, 0].legend()
axes[0, 0].grid(True)

# Plot k_duff evolution
for i in range(N_osc):
    axes[0, 1].plot(k_duff_history[:, i], label=f'k_duff[{i}]')
axes[0, 1].set_title(f'Evolution of k_duff\nFinal values:\n' + 
                     '\n'.join([f'k_duff[{i}] = {k_duff_history[-1,i]:.3f}' 
                               for i in range(N_osc)]))
axes[0, 1].set_xlabel('Epoch')
axes[0, 1].set_ylabel('Duffing Strength')
axes[0, 1].legend()
axes[0, 1].grid(True)

# Plot c_lin and c_optomech evolution
axes[1, 0].plot(c_lin_history, label='c_lin')
axes[1, 0].plot(c_optomech_history, label='c_optomech')
axes[1, 0].set_title(f'Evolution of Coupling Parameters\nFinal values:\n' +
                     f'c_lin = {c_lin_history[-1,0]:.3f}\n' +
                     f'c_optomech = {c_optomech_history[-1,0]:.3f}')
axes[1, 0].set_xlabel('Epoch')
axes[1, 0].set_ylabel('Coupling Strength')
axes[1, 0].legend()
axes[1, 0].grid(True)

# Plot loss evolution
axes[1, 1].plot(loss_history, label='Loss')
axes[1, 1].set_title(f'Evolution of Loss\nFinal value: {loss_history[-1]:.3f}')
axes[1, 1].set_xlabel('Epoch')
axes[1, 1].set_ylabel('Loss')
axes[1, 1].legend()
axes[1, 1].grid(True)

# Plot raw gradient difference evolution
axes[2, 0].semilogy(gradient_diff_history, label='Raw Gradient Difference')
axes[2, 0].set_title('Evolution of Raw Gradient Difference\n' +
                     f'Final value: {gradient_diff_history[-1]:.2e}')
axes[2, 0].set_xlabel('Epoch')
axes[2, 0].set_ylabel('Relative Difference')
axes[2, 0].legend()
axes[2, 0].grid(True)

# Plot normalized gradient difference evolution
axes[2, 1].semilogy(gradient_diff_norm_history, label='Normalized Gradient Difference')
axes[2, 1].set_title('Evolution of Normalized Gradient Difference\n' +
                     f'Final value: {gradient_diff_norm_history[-1]:.2e}')
axes[2, 1].set_xlabel('Epoch')
axes[2, 1].set_ylabel('Relative Difference')
axes[2, 1].legend()
axes[2, 1].grid(True)

plt.tight_layout()
plt.show()

# %%
# Create figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# Plot initial energy landscape
energy_initial = jnp.zeros((n_points, n_points))
energy_final = jnp.zeros((n_points, n_points))
for i in range(n_points):
    for j in range(n_points):
        x = jnp.array([X1[i,j], X2[i,j]])
        energy_initial = energy_initial.at[i,j].set(energy_fn(x, flattened_args_initial))
        energy_final = energy_final.at[i,j].set(energy_fn(x, params))

contour1 = ax1.contourf(X1, X2, energy_initial, levels=20, cmap='viridis', alpha=0.7)
plt.colorbar(contour1, ax=ax1, label='Energy')
ax1.scatter(samples[:, 0], samples[:, 1], c='black', s=1, alpha=0.9, label='Training Samples')
ax1.set_xlabel('x₁')
ax1.set_ylabel('x₂')
ax1.set_title('Initial Energy Landscape')
ax1.legend()


contour2 = ax2.contourf(X1, X2, energy_final, levels=20, cmap='viridis', alpha=0.7)
plt.colorbar(contour2, ax=ax2, label='Energy')
ax2.scatter(samples[:, 0], samples[:, 1], c='black', s=1, alpha=0.9, label='Training Samples')
ax2.set_xlabel('x₁')
ax2.set_ylabel('x₂')
ax2.set_title('Final Energy Landscape')
ax2.legend()

plt.tight_layout()
plt.show()

# %%
# def drift_x_fn(t, state, args):
#     """
#     Drift function for the XY model with effective temperature
#     Args:
#         t: time
#         state: array of phases (shape: N_osc)
#         args: tuple containing (W, h)
#     Returns:
#         Array of phase velocities
#     """
#     W, h = args
#     # Compute force from energy gradient
#     dE_dtheta = jax.grad(XY_energy, argnums=0)(state, W, h)
    
#     # Damping term
#     gamma = 1.0  # Damping coefficient, adjust as needed
    
#     dtheta_dt = -gamma * dE_dtheta
    
#     return dtheta_dt

# def diffusion_x_fn(t, state, args):
#     """
#     Diffusion function for the XY model with effective temperature
#     Args:
#         t: time
#         state: array of phases (shape: N_osc)
#         args: additional arguments
#     Returns:
#         Noise matrix (shape: N_osc x 1)
#     """
#     T_eff = 1.0  # Effective temperature, adjust as needed
#     gamma = 1.0  # Same damping coefficient as in drift
    
#     noise_strength = jnp.sqrt(2 * gamma * T_eff)
#     noise_matrix = jnp.eye(N_osc)
#     return noise_strength * noise_matrix

# %%
# # Calculate characteristic time scales
# gamma = 1.0
# T_eff = 1.0
# J = jnp.max(jnp.abs(W))  # Coupling strength

# tau_relax = 1/gamma
# tau_diffusion = gamma/(2*T_eff)

# print(f"Relaxation time scale: {tau_relax:.2f}")
# print(f"Diffusion time scale: {tau_diffusion:.2f}")

# # Set simulation time accordingly
# t0 = 0.0
# t1 = 100 * max(tau_relax, tau_diffusion)  # Simulate for 10x the longest time scale
# dt0 = min(tau_relax, tau_diffusion) / 10  # Initial time step should be smaller than fastest time scale

# print(f"\nSuggested simulation parameters:")
# print(f"Total time: {t1:.2f}")
# print(f"Initial dt: {dt0:.2f}")

# ts = jnp.linspace(t0, t1, 10000)
# dt = ts[1] - ts[0]

# y0_x = jnp.array([jnp.pi,jnp.pi])

# %%
# # Update shape to match number of oscillators
# w_shape = (N_osc,)  # state is just phases for each oscillator
# brownian_motion = diffrax.VirtualBrownianTree(
#     t0, t1, 1.e-11, w_shape, jr.PRNGKey(0), diffrax.SpaceTimeLevyArea
# )
# terms_x = MultiTerm(ODETerm(drift_x_fn), ControlTerm(diffusion_x_fn, brownian_motion))
# saveat = diffrax.SaveAt(ts=ts)


# # sample 1000 points
# solution_x = diffrax.diffeqsolve(
#     terms_x,
#     solver=diffrax.SRA1(),
#     t0=t0,
#     t1=t1,
#     dt0=dt0,
#     y0=y0_x,
#     args=(),
#     saveat=saveat,
#     progress_meter=diffrax.TqdmProgressMeter(),
#     max_steps=1000000000,
#     stepsize_controller=diffrax.PIDController(rtol=1e-3, atol=1e-6),  # Enable adaptive stepping
# )
# sde_samples_x = solution_x.ys

# %%
# # Calculate number of timesteps corresponding to one relaxation time
# relax_steps = int(1/(gamma * dt))

# # Thin the samples by taking every relax_steps point
# sde_samples_x = solution_x.ys[::relax_steps]
# ts = ts[::relax_steps]

# %%
# # Create figure with a grid of subplots
# fig = plt.figure(figsize=(16, 12))
# gs = plt.GridSpec(2, 2, height_ratios=[2, 1])

# # Top left: Phase trajectories
# ax1 = fig.add_subplot(gs[0, 0])
# # Mod 2π for time trajectories
# ax1.plot(ts, jnp.mod(sde_samples_x[:, 0], 2*jnp.pi), label='θ₁(t)')
# ax1.plot(ts, jnp.mod(sde_samples_x[:, 1], 2*jnp.pi), label='θ₂(t)')
# ax1.set_xlabel('Time')
# ax1.set_ylabel('Phase (rad)')
# ax1.set_title('SDE Simulation: Phase vs Time')
# ax1.grid(True)
# ax1.legend()

# # Top right: Phase space with Energy contour
# ax2 = fig.add_subplot(gs[0, 1])
# contour = ax2.contourf(X1, X2, energy, levels=20, cmap='RdYlBu')
# plt.colorbar(contour, ax=ax2, label='Energy')

# # Mod 2π for phase space trajectory
# wrapped_x = jnp.mod(sde_samples_x, 2*jnp.pi)
# ax2.scatter(wrapped_x[:, 0], wrapped_x[:, 1], c='g', s=1, alpha=0.9999, label='Trajectory')
# ax2.plot(wrapped_x[0, 0], wrapped_x[0, 1], 'go', label='Start', markersize=10)


# ax2.set_xlabel('θ₁')
# ax2.set_ylabel('θ₂')
# ax2.set_title('Phase Space (Torus)')
# ax2.legend()

# # Bottom left: θ₁ histogram (mod 2π)
# ax3 = fig.add_subplot(gs[1, 0])
# ax3.hist(wrapped_x[:, 0], bins=50, density=True, alpha=0.7, label='θ₁ distribution')
# ax3.set_xlabel('θ₁')
# ax3.set_ylabel('Probability Density')
# ax3.grid(True)
# ax3.legend()

# # Bottom right: θ₂ histogram (mod 2π)
# ax4 = fig.add_subplot(gs[1, 1])
# ax4.hist(wrapped_x[:, 1], bins=50, density=True, alpha=0.7, label='θ₂ distribution')
# ax4.set_xlabel('θ₂')
# ax4.set_ylabel('Probability Density')
# ax4.grid(True)
# ax4.legend()

# plt.tight_layout()
# # Add title with parameters
# title = f'T_eff={T_eff}, γ={gamma}'
# plt.suptitle(title, y=1.02)

# plt.show()
