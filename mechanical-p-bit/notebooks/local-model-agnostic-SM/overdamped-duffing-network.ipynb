# %%
import jax
from jax import flatten_util, vmap 
import jax.numpy as jnp
import jax.random as jr
import diffrax
from diffrax import ControlTerm, MultiTerm, ODETerm
import matplotlib.pyplot as plt
from functools import partial
import optax
from helper_fns_general import sample_gaussian_mixture, normalize_samples, CD1_gradient, setup_score_matching_loss, grad_loss
jax.config.update("jax_enable_x64", True)

# %% [markdown]
# ### Generate samples from a Gaussian mixture

# %%
# Set random seed
key = jr.PRNGKey(0)

# Parameters
N = 2  # number of dimensions
N_mixgauss = 3  # number of mixture components
n_samples = 1000

# Define mixture weights (must sum to 1)
weights = jnp.array([0.5, 0.5])

# Define means
means = jnp.array([
    [2.0, 0.0],   # mean of first Gaussian
    [-0.0, -1.0],  # mean of second Gaussian
])

# Define covariance matrices
covs = 100*jnp.array([
    [[1, 0.0],    # covariance of first Gaussian
        [0.0, 1]],
    [[1, -0.0],   # covariance of second Gaussian
        [-0.0, 1]],
])

# Generate samples
samples = sample_gaussian_mixture(key, n_samples, weights, means, covs)
# Normalize samples
# samples = normalize_samples(samples_raw)
# Out:
# CUDA backend failed to initialize: Unable to use CUDA because of the following issues with CUDA components:
# Outdated cuDNN installation found.
# Version JAX was built against: 8907
# Minimum supported: 9100
# Installed version: 8907
# The local installation version must be no lower than 9100..(Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %% [markdown]
# ### Plot samples and marginal distributions

# %%
# Plot samples and marginal distributions
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# First subplot: Scatter plot of samples
ax1.scatter(samples[:, 0], samples[:, 1], alpha=0.5)
ax1.set_title('Samples')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')

# Second subplot: Combined marginal distributions
ax2.hist(samples[:, 0], bins=50, density=True, alpha=0.7, label='X distribution')
ax2.hist(samples[:, 1], bins=50, density=True, alpha=0.7, label='Y distribution')
ax2.set_title('Marginal Distributions')
ax2.set_xlabel('Value')
ax2.set_ylabel('Density')
ax2.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Define energy function of duffing oscillator network

# %%
def energy_self_oscillator(x, k_lin, k_duff):
    return 1 / 2 * k_lin * x**2 + 1 / 4 * k_duff * x**4

def energy_self_network(x, k_lin, k_duff):
    return jnp.sum(vmap(energy_self_oscillator)(x, k_lin, k_duff))


def energy_coupling_pair(x, y, c_lin, c_optomech):
    return c_lin * x * (x - y) + c_lin * y * (y - x) + c_optomech * (x**2) * y

def energy_coupling_network(x, c_lin, c_optomech, connectivity):
    # get contribution to total energy from each pair of oscillators
    
    def _coupling_energy_pair(x, c_lin, c_optomech, pair):
        # get energy of one pair of oscillators
        i, j = pair
        return energy_coupling_pair(x[i], x[j], c_lin, c_optomech)

    # get energy of all pairs of oscillators
    return jnp.sum(
        vmap(_coupling_energy_pair, in_axes=(None, 0, 0, 0))(
            x, c_lin, c_optomech, connectivity
        )
    )

def _energy_duffing_network(x, k_lin, k_duff, c_lin, c_optomech, connectivity, k_b=1.0, T=1.0):
    # returns energy of network of oscillators given input parameters
    return (
        energy_self_network(x, k_lin, k_duff) +
        energy_coupling_network(x, c_lin, c_optomech, connectivity)
    ) / (k_b * T)

# %% [markdown]
# ### Define initial parameters

# %%
N_osc = 2

k_lin_0 = jnp.array([-10., -10.])
k_duff_0 = jnp.array([10., 10.])
c_lin_0 = jnp.array([1.,])
c_optomech_0 = jnp.array([0.,])
connectivity = jnp.array([[0, 1]])

args_initial = (k_lin_0, k_duff_0, c_lin_0, c_optomech_0)

flattened_args_initial, unflatten = flatten_util.ravel_pytree(args_initial)

# %% [markdown]
# ### Bringe energy into correct form

# %%
def energy_duffing_network(x, flattened_args, connectivity):
    k_lin, k_duffing, c_lin, c_optomech = unflatten(flattened_args)
    return _energy_duffing_network(x, k_lin, k_duffing, c_lin, c_optomech, connectivity)
energy_fn = lambda x, flattened_args: energy_duffing_network(x, flattened_args, connectivity)

# %% [markdown]
# ### Plot energy landscape

# %%
# Create a grid of phase values
n_points = 30
x1 = jnp.linspace(-5, 5, n_points)*10
x2 = jnp.linspace(-5, 5, n_points)*10
X1, X2 = jnp.meshgrid(x1, x2)

# Compute energy for each point in the grid
energy = jnp.zeros((n_points, n_points))
for i in range(n_points):
    for j in range(n_points):
        x = jnp.array([X1[i,j], X2[i,j]])
        energy = energy.at[i,j].set(energy_fn(x, flattened_args_initial))

# Create the contour plot
plt.figure(figsize=(10, 8))
plt.contourf(X1, X2, energy, levels=20, cmap='viridis')
plt.colorbar(label='Energy')
# Add scatter plot of samples
plt.scatter(samples[:, 0], samples[:, 1], c='black', s=1, alpha=0.5, label='Samples')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('XY Model Energy Landscape for initial parameters')
plt.legend()
plt.show()

# %% [markdown]
# ### Test minus CD1 gradient vs score matching gradient (eq. 10 in Connections Between Score Matching, Contrastive Divergence, and Pseudolikelihood for Continuous-Valued Variables)

# %%
# Compare gradient differences with score_matching_loss for different dt values
dt_values = jnp.logspace(-18, 1, 30)  # logarithmically spaced dt values
key = jr.PRNGKey(1)

# Get score matching gradient results (only need to compute once)
score_matching_loss = setup_score_matching_loss(energy_fn, samples)
score_matching_grad = grad_loss(score_matching_loss, flattened_args_initial)

# Initialize arrays to store results
n_params = len(flattened_args_initial)
relative_differences = jnp.zeros((len(dt_values), n_params))
total_relative_differences = jnp.zeros(len(dt_values))  # New array for total differences

# Loop over dt values
for i, dt in enumerate(dt_values):
    key, subkey = jr.split(key)
    
    # Get CD1 gradient for this dt
    cd1_grad = -CD1_gradient(energy_fn, samples, flattened_args_initial, 
                            dt=dt, D=1, key=subkey, num_noise_samples=0)
    
    # Calculate relative difference for each parameter
    rel_diff = jnp.abs(cd1_grad - score_matching_grad) / jnp.abs(score_matching_grad)
    relative_differences = relative_differences.at[i].set(rel_diff)
    
    # Calculate total relative difference using L2 norm
    total_rel_diff = jnp.linalg.norm(cd1_grad - score_matching_grad) / jnp.linalg.norm(score_matching_grad)
    total_relative_differences = total_relative_differences.at[i].set(total_rel_diff)

# Create figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 6))

# First subplot: Individual parameter differences
param_names = ['k_lin_1', 'k_lin_2', 'k_duff_1', 'k_duff_2', 'c_lin', 'c_optomech']
for param_idx in range(n_params):
    ax1.loglog(dt_values, relative_differences[:, param_idx], 'o-', 
               label=param_names[param_idx])

ax1.set_xlabel('dt')
ax1.set_ylabel('Relative Difference')
ax1.set_title('Individual Parameter Relative Differences')
ax1.grid(True)
ax1.legend()

# Second subplot: Total gradient difference
ax2.loglog(dt_values, total_relative_differences, 'o-', color='black', label='Total gradient')
ax2.set_xlabel('dt')
ax2.set_ylabel('Total Relative Difference')
ax2.set_title('Total Gradient Relative Difference (L2 norm)')
ax2.grid(True)
ax2.legend()

plt.tight_layout()
plt.show()

# Print the minimum relative differences
print("\nIndividual parameter minimum differences:")
for param_idx in range(n_params):
    min_idx = jnp.argmin(relative_differences[:, param_idx])
    print(f"\n{param_names[param_idx]}:")
    print(f"Minimum relative difference: {relative_differences[min_idx, param_idx]:.2e}")
    print(f"Optimal dt: {dt_values[min_idx]:.2e}")

print("\nTotal gradient minimum difference:")
min_total_idx = jnp.argmin(total_relative_differences)
print(f"Minimum total relative difference: {total_relative_differences[min_total_idx]:.2e}")
print(f"Optimal dt: {dt_values[min_total_idx]:.2e}")
# Out:
# Individual parameter minimum differences:
#
# k_lin_1:
# Minimum relative difference: 1.43e-06
# Optimal dt: 1.49e-09
#
# k_lin_2:
# Minimum relative difference: 8.93e-07
# Optimal dt: 1.49e-09
#
# k_duff_1:
# Minimum relative difference: 5.50e-07
# Optimal dt: 3.29e-10
#
# k_duff_2:
# Minimum relative difference: 2.93e-07
# Optimal dt: 3.29e-10
#
# c_lin:
# Minimum relative difference: 1.07e-06
# Optimal dt: 1.49e-09
#
# c_optomech:
# Minimum relative difference: 8.76e-07
# Optimal dt: 1.74e-13
#
# Total gradient minimum difference:
# Minimum total relative difference: 4.11e-07
# Optimal dt: 3.29e-10

# %%
# Define optimization parameters
learning_rate = 0.01
n_epochs = 20000
batch_size = 128

# Initialize optimizer
optimizer = optax.adam(learning_rate=learning_rate)
opt_state = optimizer.init(flattened_args_initial)


@partial(jax.jit, static_argnums=(3,))
def training_step(params, opt_state, samples, n_samples, key):
    """Single training step using CD-1"""
    # Get gradient of parameters
    key, subkey = jr.split(key)
    dparams_CD1 = -CD1_gradient(energy_fn, samples, params, dt=2.59e-5, D=1, key=subkey, num_noise_samples=0)
    dparams_sm = grad_loss(score_matching_loss, params)
    
    # Compute relative difference between raw gradients
    rel_diff = jnp.linalg.norm(dparams_CD1 - dparams_sm) / jnp.linalg.norm(dparams_sm)
    
    # Compute relative difference between normalized gradients
    norm_dparams = dparams_CD1 / jnp.linalg.norm(dparams_CD1)
    norm_dparams_sm = dparams_sm / jnp.linalg.norm(dparams_sm)
    rel_diff_norm = jnp.linalg.norm(norm_dparams - norm_dparams_sm)
    
    # Store norms of both gradients
    sm_grad_norm = jnp.linalg.norm(dparams_sm)
    cd1_grad_norm = jnp.linalg.norm(dparams_CD1)
    
    # Compute log likelihood (negative energy)
    loss = score_matching_loss(params)
    
    # Apply updates
    updates, opt_state = optimizer.update(dparams_sm, opt_state)
    params = optax.apply_updates(params, updates)
    
    return params, opt_state, key, loss, rel_diff, rel_diff_norm, sm_grad_norm, cd1_grad_norm

# Training loop
key = jr.PRNGKey(0)
params_history = []
loss_history = []
gradient_diff_history = []  # Raw gradient differences
gradient_diff_norm_history = []  # Normalized gradient differences
sm_grad_norm_history = []  # Score matching gradient norm history
cd1_grad_norm_history = []  # CD1 gradient norm history

params = flattened_args_initial

for epoch in range(n_epochs):
    key, subkey = jr.split(key)
    params, opt_state, key, loss, rel_diff, rel_diff_norm, sm_grad_norm, cd1_grad_norm = training_step(
        params, opt_state, samples, batch_size, subkey)
    
    # Store parameters, loss, and gradient information
    params_history.append(params)
    loss_history.append(loss)
    gradient_diff_history.append(rel_diff)
    gradient_diff_norm_history.append(rel_diff_norm)
    sm_grad_norm_history.append(sm_grad_norm)
    cd1_grad_norm_history.append(cd1_grad_norm)
    
    if epoch % 10 == 0:
        k_lin, k_duffing, c_lin, c_optomech = unflatten(params)
        print(f"Epoch {epoch}")
        print(f"k_lin:\n{k_lin}")
        print(f"k_duffing:\n{k_duffing}")
        print(f"c_lin:\n{c_lin}")
        print(f"c_optomech:\n{c_optomech}")
        print(f"Loss: {loss:.4f}")
        print(f"Raw gradient relative difference: {rel_diff:.4e}")
        print(f"Normalized gradient relative difference: {rel_diff_norm:.4e}")
        print(f"Score matching gradient norm: {sm_grad_norm:.4e}")
        print(f"CD1 gradient norm: {cd1_grad_norm:.4e}")
        print("---")
# Out:
# Epoch 0
# k_lin:
# [-10.03162288 -10.03162265]
# k_duffing:
# [9.96837712 9.96837735]
# c_lin:
# [0.96837723]
# c_optomech:
# [-0.03162262]
# Loss: 1686738626.6501
# Raw gradient relative difference: 1.2936e-01
# Normalized gradient relative difference: 1.7689e-02
# Score matching gradient norm: 2.4056e+08
# CD1 gradient norm: 2.0970e+08
# ---
# Epoch 10
# k_lin:
# [-10.61686099 -10.61686231]
# k_duffing:
# [9.38313138 9.38313184]
# c_lin:
# [0.38313809]
# c_optomech:
# [-0.61491292]
# Loss: 1504161319.6637
# Raw gradient relative difference: 1.2272e-01
# Normalized gradient relative difference: 1.6732e-02
# Score matching gradient norm: 2.2717e+08
# CD1 gradient norm: 1.9952e+08
# ---
# Epoch 20
# k_lin:
# [-11.24841741 -11.24843321]
# k_duffing:
# [8.75152406 8.7515218 ]
# c_lin:
# [-0.24842699]
# c_optomech:
# [-1.23301843]
# Loss: 1306529151.5212
# Raw gradient relative difference: 1.1497e-01
# Normalized gradient relative difference: 1.5622e-02
# Score matching gradient norm: 2.1172e+08
# CD1 gradient norm: 1.8758e+08
# ---
# Epoch 30
# k_lin:
# [-11.80689132 -11.8069406 ]
# k_duffing:
# [8.19293237 8.19292334]
# c_lin:
# [-0.80691934]
# c_optomech:
# [-1.75929995]
# Loss: 1142363182.2869
# Raw gradient relative difference: 1.0802e-01
# Normalized gradient relative difference: 1.4630e-02
# Score matching gradient norm: 1.9796e+08
# CD1 gradient norm: 1.7676e+08
# ---
# Epoch 40
# k_lin:
# [-12.29055466 -12.29065618]
# k_duffing:
# [7.70908318 7.7090629 ]
# c_lin:
# [-1.29060785]
# c_optomech:
# [-2.19067268]
# Loss: 1009098159.0958
# Raw gradient relative difference: 1.0194e-01
# Normalized gradient relative difference: 1.3768e-02
# Score matching gradient norm: 1.8605e+08
# CD1 gradient norm: 1.6724e+08
# ---
# Epoch 50
# k_lin:
# [-12.71330853 -12.71347814]
# k_duffing:
# [7.28608337 7.28604735]
# c_lin:
# [-1.71338852]
# c_optomech:
# [-2.54258154]
# Loss: 899531734.1320
# Raw gradient relative difference: 9.6595e-02
# Normalized gradient relative difference: 1.3013e-02
# Score matching gradient norm: 1.7565e+08
# CD1 gradient norm: 1.5883e+08
# ---
# Epoch 60
# k_lin:
# [-13.08836371 -13.08861399]
# k_duffing:
# [6.91073145 6.91067525]
# c_lin:
# [-2.08846699]
# c_optomech:
# [-2.83054319]
# Loss: 807732095.5646
# Raw gradient relative difference: 9.1831e-02
# Normalized gradient relative difference: 1.2343e-02
# Score matching gradient norm: 1.6644e+08
# CD1 gradient norm: 1.5128e+08
# ---
# Epoch 70
# k_lin:
# [-13.42582054 -13.42616133]
# k_duffing:
# [6.57293484 6.57285407]
# c_lin:
# [-2.42593925]
# c_optomech:
# [-3.06683732]
# Loss: 729455750.6602
# Raw gradient relative difference: 8.7525e-02
# Normalized gradient relative difference: 1.1739e-02
# Score matching gradient norm: 1.5816e+08
# CD1 gradient norm: 1.4443e+08
# ---
# Epoch 80
# k_lin:
# [-13.7330429  -13.73348191]
# k_duffing:
# [6.26533552 6.26522585]
# c_lin:
# [-2.7331656]
# c_optomech:
# [-3.26064897]
# Loss: 661729310.0478
# Raw gradient relative difference: 8.3588e-02
# Normalized gradient relative difference: 1.1189e-02
# Score matching gradient norm: 1.5063e+08
# CD1 gradient norm: 1.3815e+08
# ---
# Epoch 90
# k_lin:
# [-14.01539975 -14.01594308]
# k_duffing:
# [5.98256875 5.98242584]
# c_lin:
# [-3.01551212]
# c_optomech:
# [-3.41882968]
# Loss: 602439835.5326
# Raw gradient relative difference: 7.9955e-02
# Normalized gradient relative difference: 1.0684e-02
# Score matching gradient norm: 1.4372e+08
# CD1 gradient norm: 1.3232e+08
# ---
# Epoch 100
# k_lin:
# [-14.2768731 -14.2775256]
# k_duffing:
# [5.72065556 5.72047505]
# c_lin:
# [-3.27695838]
# c_optomech:
# [-3.54658997]
# Loss: 550047549.9194
# Raw gradient relative difference: 7.6578e-02
# Normalized gradient relative difference: 1.0215e-02
# Score matching gradient norm: 1.3732e+08
# CD1 gradient norm: 1.2689e+08
# ---
# Epoch 110
# k_lin:
# [-14.52048379 -14.52124935]
# k_duffing:
# [5.47657732 5.47635483]
# c_lin:
# [-3.52052314]
# c_optomech:
# [-3.64800651]
# Loss: 503399362.6351
# Raw gradient relative difference: 7.3421e-02
# Normalized gradient relative difference: 9.7786e-03
# Score matching gradient norm: 1.3136e+08
# CD1 gradient norm: 1.2179e+08
# ---
# Epoch 120
# k_lin:
# [-14.748577   -14.74945871]
# k_duffing:
# [5.24799048 5.24772158]
# c_lin:
# [-3.74854976]
# c_optomech:
# [-3.72636832]
# Loss: 461609325.8596
# Raw gradient relative difference: 7.0454e-02
# Normalized gradient relative difference: 9.3697e-03
# Score matching gradient norm: 1.2578e+08
# CD1 gradient norm: 1.1699e+08
# ---
# Epoch 130
# k_lin:
# [-14.96301283 -14.96401314]
# k_duffing:
# [5.03303613 5.03271639]
# c_lin:
# [-3.96289668]
# c_optomech:
# [-3.78440726]
# Loss: 423981059.8732
# Raw gradient relative difference: 6.7656e-02
# Normalized gradient relative difference: 8.9851e-03
# Score matching gradient norm: 1.2054e+08
# CD1 gradient norm: 1.1245e+08
# ---
# Epoch 140
# k_lin:
# [-15.16529514 -15.1664159 ]
# k_duffing:
# [4.83021138 4.82983632]
# c_lin:
# [-4.16506625]
# c_optomech:
# [-3.82445074]
# Loss: 389956281.5419
# Raw gradient relative difference: 6.5008e-02
# Normalized gradient relative difference: 8.6223e-03
# Score matching gradient norm: 1.1559e+08
# CD1 gradient norm: 1.0814e+08
# ---
# Epoch 150
# k_lin:
# [-15.35666025 -15.35790282]
# k_duffing:
# [4.63828063 4.63784575]
# c_lin:
# [-4.35629341]
# c_optomech:
# [-3.84852318]
# Loss: 359079765.6574
# Raw gradient relative difference: 6.2495e-02
# Normalized gradient relative difference: 8.2790e-03
# Score matching gradient norm: 1.1091e+08
# CD1 gradient norm: 1.0404e+08
# ---
# Epoch 160
# k_lin:
# [-15.53813949 -15.53950477]
# k_duffing:
# [4.45621312 4.45571392]
# c_lin:
# [-4.53760821]
# c_optomech:
# [-3.85841402]
# Loss: 330974871.3088
# Raw gradient relative difference: 6.0105e-02
# Normalized gradient relative difference: 7.9533e-03
# Score matching gradient norm: 1.0648e+08
# CD1 gradient norm: 1.0013e+08
# ---
# Epoch 170
# k_lin:
# [-15.71060423 -15.71209272]
# k_duffing:
# [4.28313793 4.28256991]
# c_lin:
# [-4.70988086]
# c_optomech:
# [-3.8557237]
# Loss: 305326028.7128
# Raw gradient relative difference: 5.7827e-02
# Normalized gradient relative difference: 7.6438e-03
# Score matching gradient norm: 1.0226e+08
# CD1 gradient norm: 9.6396e+07
# ---
# Epoch 180
# k_lin:
# [-15.87479897 -15.87641079]
# k_duffing:
# [4.11831094 4.11766962]
# c_lin:
# [-4.87385479]
# c_optomech:
# [-3.84189527]
# Loss: 281865927.2688
# Raw gradient relative difference: 5.5652e-02
# Normalized gradient relative difference: 7.3491e-03
# Score matching gradient norm: 9.8247e+07
# CD1 gradient norm: 9.2824e+07
# ---
# Epoch 190
# k_lin:
# [-16.03136618 -16.03310109]
# k_duffing:
# [3.96109    3.96037092]
# c_lin:
# [-5.03017147]
# c_optomech:
# [-3.81823647]
# Loss: 260365955.4357
# Raw gradient relative difference: 5.3573e-02
# Normalized gradient relative difference: 7.0681e-03
# Score matching gradient norm: 9.4419e+07
# CD1 gradient norm: 8.9403e+07
# ---
# Epoch 200
# k_lin:
# [-16.18086514 -16.18272256]
# k_duffing:
# [3.81091605 3.81011481]
# c_lin:
# [-5.17938929]
# c_optomech:
# [-3.78593573]
# Loss: 240628940.0432
# Raw gradient relative difference: 5.1582e-02
# Normalized gradient relative difference: 6.7997e-03
# Score matching gradient norm: 9.0764e+07
# CD1 gradient norm: 8.6121e+07
# ---
# Epoch 210
# k_lin:
# [-16.32378665 -16.32576571]
# k_duffing:
# [3.66729852 3.66641075]
# c_lin:
# [-5.32199825]
# c_optomech:
# [-3.74607403]
# Loss: 222483544.5519
# Raw gradient relative difference: 4.9674e-02
# Normalized gradient relative difference: 6.5431e-03
# Score matching gradient norm: 8.7269e+07
# CD1 gradient norm: 8.2970e+07
# ---
# Epoch 220
# k_lin:
# [-16.46056445 -16.46266398]
# k_duffing:
# [3.52980381 3.52882524]
# c_lin:
# [-5.45843137]
# c_optomech:
# [-3.6996344]
# Loss: 205779886.0691
# Raw gradient relative difference: 4.7844e-02
# Normalized gradient relative difference: 6.2975e-03
# Score matching gradient norm: 8.3923e+07
# CD1 gradient norm: 7.9941e+07
# ---
# Epoch 230
# k_lin:
# [-16.59158443 -16.59380299]
# k_duffing:
# [3.3980462  3.39697261]
# c_lin:
# [-5.58907388]
# c_optomech:
# [-3.64750965]
# Loss: 190386062.4623
# Raw gradient relative difference: 4.6086e-02
# Normalized gradient relative difference: 6.0622e-03
# Score matching gradient norm: 8.0718e+07
# CD1 gradient norm: 7.7029e+07
# ---
# Epoch 240
# k_lin:
# [-16.71719189 -16.71952777]
# k_duffing:
# [3.2716805  3.27050778]
# c_lin:
# [-5.71427051]
# c_optomech:
# [-3.59050924]
# Loss: 176185369.1545
# Raw gradient relative difference: 4.4397e-02
# Normalized gradient relative difference: 5.8365e-03
# Score matching gradient norm: 7.7644e+07
# CD1 gradient norm: 7.4226e+07
# ---
# Epoch 250
# k_lin:
# [-16.83769755 -16.84014881]
# k_duffing:
# [3.15039608 3.14912024]
# c_lin:
# [-5.83433147]
# c_optomech:
# [-3.52936545]
# Loss: 163074045.5573
# Raw gradient relative difference: 4.2773e-02
# Normalized gradient relative difference: 5.6200e-03
# Score matching gradient norm: 7.4695e+07
# CD1 gradient norm: 7.1526e+07
# ---
# Epoch 260
# k_lin:
# [-16.9533824  -16.95594685]
# k_duffing:
# [3.03391205 3.03252918]
# c_lin:
# [-5.94953731]
# c_optomech:
# [-3.46473913]
# Loss: 150959433.1662
# Raw gradient relative difference: 4.1210e-02
# Normalized gradient relative difference: 5.4121e-03
# Score matching gradient norm: 7.1862e+07
# CD1 gradient norm: 6.8925e+07
# ---
# Epoch 270
# k_lin:
# [-17.06450176 -17.06717698]
# k_duffing:
# [2.92197316 2.9204795 ]
# c_lin:
# [-6.06014297]
# c_optomech:
# [-3.39722522]
# Loss: 139758457.1469
# Raw gradient relative difference: 3.9706e-02
# Normalized gradient relative difference: 5.2124e-03
# Score matching gradient norm: 6.9140e+07
# CD1 gradient norm: 6.6418e+07
# ---
# Epoch 280
# k_lin:
# [-17.17128861 -17.17407199]
# k_duffing:
# [2.81434649 2.81273839]
# c_lin:
# [-6.16638111]
# c_optomech:
# [-3.32735796]
# Loss: 129396364.6835
# Raw gradient relative difference: 3.8257e-02
# Normalized gradient relative difference: 5.0204e-03
# Score matching gradient norm: 6.6524e+07
# CD1 gradient norm: 6.4000e+07
# ---
# Epoch 290
# k_lin:
# [-17.27395644 -17.27684514]
# k_duffing:
# [2.71081863 2.70909259]
# c_lin:
# [-6.26846492]
# c_optomech:
# [-3.25561588]
# Loss: 119805669.0054
# Raw gradient relative difference: 3.6861e-02
# Normalized gradient relative difference: 4.8357e-03
# Score matching gradient norm: 6.4007e+07
# CD1 gradient norm: 6.1667e+07
# ---
# Epoch 300
# k_lin:
# [-17.37270159 -17.37569258]
# k_duffing:
# [2.61119327 2.60934595]
# c_lin:
# [-6.36659053]
# c_optomech:
# [-3.18242657]
# Loss: 110925259.5686
# Raw gradient relative difference: 3.5516e-02
# Normalized gradient relative difference: 4.6580e-03
# Score matching gradient norm: 6.1585e+07
# CD1 gradient norm: 5.9416e+07
# ---
# Epoch 310
# k_lin:
# [-17.46770529 -17.47079535]
# k_duffing:
# [2.51528925 2.51331744]
# c_lin:
# [-6.46093897]
# c_optomech:
# [-3.10817115]
# Loss: 102699647.5188
# Raw gradient relative difference: 3.4218e-02
# Normalized gradient relative difference: 4.4869e-03
# Score matching gradient norm: 5.9254e+07
# CD1 gradient norm: 5.7243e+07
# ---
# Epoch 320
# k_lin:
# [-17.55913538 -17.56232111]
# k_duffing:
# [2.42293877 2.42083942]
# c_lin:
# [-6.55167795]
# c_optomech:
# [-3.03318855]
# Loss: 95078322.0977
# Raw gradient relative difference: 3.2967e-02
# Normalized gradient relative difference: 4.3222e-03
# Score matching gradient norm: 5.7009e+07
# CD1 gradient norm: 5.5145e+07
# ---
# Epoch 330
# k_lin:
# [-17.64714777 -17.6504256 ]
# k_duffing:
# [2.33398597 2.33175619]
# c_lin:
# [-6.63896326]
# c_optomech:
# [-2.95777944]
# Loss: 88015198.6519
# Raw gradient relative difference: 3.1760e-02
# Normalized gradient relative difference: 4.1636e-03
# Score matching gradient norm: 5.4847e+07
# CD1 gradient norm: 5.3120e+07
# ---
# Epoch 340
# k_lin:
# [-17.73188776 -17.73525393]
# k_duffing:
# [2.24828561 2.24592268]
# c_lin:
# [-6.72294013]
# c_optomech:
# [-2.8822099]
# Loss: 81468142.7505
# Raw gradient relative difference: 3.0596e-02
# Normalized gradient relative difference: 4.0107e-03
# Score matching gradient norm: 5.2764e+07
# CD1 gradient norm: 5.1163e+07
# ---
# Epoch 350
# k_lin:
# [-17.8134911 -17.8169417]
# k_duffing:
# [2.16570199 2.16320334]
# c_lin:
# [-6.80374425]
# c_optomech:
# [-2.80671482]
# Loss: 75398557.9164
# Raw gradient relative difference: 2.9473e-02
# Normalized gradient relative difference: 3.8634e-03
# Score matching gradient norm: 5.0757e+07
# CD1 gradient norm: 4.9274e+07
# ---
# Epoch 360
# k_lin:
# [-17.89208494 -17.89561591]
# k_duffing:
# [2.086108   2.08347123]
# c_lin:
# [-6.88150278]
# c_optomech:
# [-2.73150103]
# Loss: 69771026.8199
# Raw gradient relative difference: 2.8388e-02
# Normalized gradient relative difference: 3.7215e-03
# Score matching gradient norm: 4.8823e+07
# CD1 gradient norm: 4.7448e+07
# ---
# Epoch 370
# k_lin:
# [-17.96778873 -17.97139584]
# k_duffing:
# [2.00938427 2.00660715]
# c_lin:
# [-6.95633516]
# c_optomech:
# [-2.65675012]
# Loss: 64552997.6415
# Raw gradient relative difference: 2.7342e-02
# Normalized gradient relative difference: 3.5847e-03
# Score matching gradient norm: 4.6958e+07
# CD1 gradient norm: 4.5685e+07
# ---
# Epoch 380
# k_lin:
# [-18.0407149  -18.04439378]
# k_duffing:
# [1.93541841 1.93249889]
# c_lin:
# [-7.02835385]
# c_optomech:
# [-2.58262104]
# Loss: 59714508.7855
# Raw gradient relative difference: 2.6332e-02
# Normalized gradient relative difference: 3.4527e-03
# Score matching gradient norm: 4.5161e+07
# CD1 gradient norm: 4.3981e+07
# ---
# Epoch 390
# k_lin:
# [-18.1109695  -18.11471566]
# k_duffing:
# [1.86410444 1.86104061]
# c_lin:
# [-7.09766497]
# c_optomech:
# [-2.50925245]
# Loss: 55227946.3084
# Raw gradient relative difference: 2.5357e-02
# Normalized gradient relative difference: 3.3255e-03
# Score matching gradient norm: 4.3427e+07
# CD1 gradient norm: 4.2336e+07
# ---
# Epoch 400
# k_lin:
# [-18.17865283 -18.18246161]
# k_duffing:
# [1.79534213 1.79213227]
# c_lin:
# [-7.16436889]
# c_optomech:
# [-2.43676484]
# Loss: 51067829.3786
# Raw gradient relative difference: 2.4416e-02
# Normalized gradient relative difference: 3.2029e-03
# Score matching gradient norm: 4.1756e+07
# CD1 gradient norm: 4.0745e+07
# ---
# Epoch 410
# k_lin:
# [-18.24385988 -18.24772649]
# k_duffing:
# [1.72903657 1.72567912]
# c_lin:
# [-7.2285607]
# c_optomech:
# [-2.36526244]
# Loss: 47210619.8562
# Raw gradient relative difference: 2.3507e-02
# Normalized gradient relative difference: 3.0846e-03
# Score matching gradient norm: 4.0145e+07
# CD1 gradient norm: 3.9209e+07
# ---
# Epoch 420
# k_lin:
# [-18.30668078 -18.31060034]
# k_duffing:
# [1.66509768 1.66159125]
# c_lin:
# [-7.29033065]
# c_optomech:
# [-2.29483493]
# Loss: 43634552.7130
# Raw gradient relative difference: 2.2630e-02
# Normalized gradient relative difference: 2.9705e-03
# Score matching gradient norm: 3.8591e+07
# CD1 gradient norm: 3.7725e+07
# ---
# Epoch 430
# k_lin:
# [-18.36720125 -18.37116873]
# k_duffing:
# [1.60343983 1.5997832 ]
# c_lin:
# [-7.34976459]
# c_optomech:
# [-2.225559]
# Loss: 40319484.5261
# Raw gradient relative difference: 2.1783e-02
# Normalized gradient relative difference: 2.8604e-03
# Score matching gradient norm: 3.7093e+07
# CD1 gradient norm: 3.6292e+07
# ---
# Epoch 440
# k_lin:
# [-18.42550291 -18.42951317]
# k_duffing:
# [1.5439815  1.54017359]
# c_lin:
# [-7.40694429]
# c_optomech:
# [-2.15749971]
# Loss: 37246757.7066
# Raw gradient relative difference: 2.0966e-02
# Normalized gradient relative difference: 2.7543e-03
# Score matching gradient norm: 3.5648e+07
# CD1 gradient norm: 3.4907e+07
# ---
# Epoch 450
# k_lin:
# [-18.4816636  -18.48571138]
# k_duffing:
# [1.48664493 1.48268484]
# c_lin:
# [-7.46194774]
# c_optomech:
# [-2.09071172]
# Loss: 34399078.4739
# Raw gradient relative difference: 2.0177e-02
# Normalized gradient relative difference: 2.6520e-03
# Score matching gradient norm: 3.4254e+07
# CD1 gradient norm: 3.3569e+07
# ---
# Epoch 460
# k_lin:
# [-18.53575766 -18.53983761]
# k_duffing:
# [1.43135587 1.42724285]
# c_lin:
# [-7.51484948]
# c_optomech:
# [-2.02524045]
# Loss: 31760406.8812
# Raw gradient relative difference: 1.9415e-02
# Normalized gradient relative difference: 2.5532e-03
# Score matching gradient norm: 3.2910e+07
# CD1 gradient norm: 3.2277e+07
# ---
# Epoch 470
# k_lin:
# [-18.58785621 -18.59196287]
# k_duffing:
# [1.3780433  1.37377675]
# c_lin:
# [-7.56572081]
# c_optomech:
# [-1.96112299]
# Loss: 29315857.4395
# Raw gradient relative difference: 1.8680e-02
# Normalized gradient relative difference: 2.4580e-03
# Score matching gradient norm: 3.1615e+07
# CD1 gradient norm: 3.1029e+07
# ---
# Epoch 480
# k_lin:
# [-18.63802735 -18.64215517]
# k_duffing:
# [1.32663922 1.32221871]
# c_lin:
# [-7.61463004]
# c_optomech:
# [-1.89838905]
# Loss: 27051609.0936
# Raw gradient relative difference: 1.7971e-02
# Normalized gradient relative difference: 2.3662e-03
# Score matching gradient norm: 3.0365e+07
# CD1 gradient norm: 2.9824e+07
# ---
# Epoch 490
# k_lin:
# [-18.68633638 -18.69047971]
# k_duffing:
# [1.27707844 1.27250367]
# c_lin:
# [-7.66164269]
# c_optomech:
# [-1.83706171]
# Loss: 24954823.4746
# Raw gradient relative difference: 1.7287e-02
# Normalized gradient relative difference: 2.2777e-03
# Score matching gradient norm: 2.9161e+07
# CD1 gradient norm: 2.8661e+07
# ---
# Epoch 500
# k_lin:
# [-18.73284599 -18.7369991 ]
# k_duffing:
# [1.22929838 1.22456921]
# c_lin:
# [-7.70682166]
# c_optomech:
# [-1.77715815]
# Loss: 23013570.5011
# Raw gradient relative difference: 1.6626e-02
# Normalized gradient relative difference: 2.1923e-03
# Score matching gradient norm: 2.7999e+07
# CD1 gradient norm: 2.7538e+07
# ---
# Epoch 510
# k_lin:
# [-18.7776164  -18.78177347]
# k_duffing:
# [1.18323893 1.17835535]
# c_lin:
# [-7.75022743]
# c_optomech:
# [-1.71869024]
# Loss: 21216760.5201
# Raw gradient relative difference: 1.5989e-02
# Normalized gradient relative difference: 2.1100e-03
# Score matching gradient norm: 2.6880e+07
# CD1 gradient norm: 2.6453e+07
# ---
# Epoch 520
# k_lin:
# [-18.82070555 -18.8248607 ]
# k_duffing:
# [1.13884227 1.13380442]
# c_lin:
# [-7.79191818]
# c_optomech:
# [-1.66166517]
# Loss: 19554082.2892
# Raw gradient relative difference: 1.5375e-02
# Normalized gradient relative difference: 2.0307e-03
# Score matching gradient norm: 2.5800e+07
# CD1 gradient norm: 2.5407e+07
# ---
# Epoch 530
# k_lin:
# [-18.86216921 -18.86631649]
# k_duffing:
# [1.09605275 1.0908609 ]
# c_lin:
# [-7.83194995]
# c_optomech:
# [-1.60608589]
# Loss: 18015946.1855
# Raw gradient relative difference: 1.4782e-02
# Normalized gradient relative difference: 1.9542e-03
# Score matching gradient norm: 2.4760e+07
# CD1 gradient norm: 2.4397e+07
# ---
# Epoch 540
# k_lin:
# [-18.90206113 -18.9061945 ]
# k_duffing:
# [1.05481675 1.0494713 ]
# c_lin:
# [-7.87037673]
# c_optomech:
# [-1.55195159]
# Loss: 16593432.1080
# Raw gradient relative difference: 1.4210e-02
# Normalized gradient relative difference: 1.8804e-03
# Score matching gradient norm: 2.3758e+07
# CD1 gradient norm: 2.3423e+07
# ---
# Epoch 550
# k_lin:
# [-18.94043313 -18.94454651]
# k_duffing:
# [1.01508257 1.00958406]
# c_lin:
# [-7.90725063]
# c_optomech:
# [-1.49925812]
# Loss: 15278241.6011
# Raw gradient relative difference: 1.3659e-02
# Normalized gradient relative difference: 1.8094e-03
# Score matching gradient norm: 2.2792e+07
# CD1 gradient norm: 2.2483e+07
# ---
# Epoch 560
# k_lin:
# [-18.97733522 -18.98142247]
# k_duffing:
# [0.97680035 0.97114941]
# c_lin:
# [-7.94262194]
# c_optomech:
# [-1.44799835]
# Loss: 14062653.7887
# Raw gradient relative difference: 1.3127e-02
# Normalized gradient relative difference: 1.7409e-03
# Score matching gradient norm: 2.1861e+07
# CD1 gradient norm: 2.1576e+07
# ---
# Epoch 570
# k_lin:
# [-19.01281567 -19.0168706 ]
# k_duffing:
# [0.93992191 0.93411934]
# c_lin:
# [-7.97653924]
# c_optomech:
# [-1.39816245]
# Loss: 12939484.7510
# Raw gradient relative difference: 1.2615e-02
# Normalized gradient relative difference: 1.6749e-03
# Score matching gradient norm: 2.0964e+07
# CD1 gradient norm: 2.0702e+07
# ---
# Epoch 580
# k_lin:
# [-19.04692115 -19.05093752]
# k_duffing:
# [0.90440076 0.89844742]
# c_lin:
# [-8.00904946]
# c_optomech:
# [-1.34973825]
# Loss: 11902050.0251
# Raw gradient relative difference: 1.2121e-02
# Normalized gradient relative difference: 1.6114e-03
# Score matching gradient norm: 2.0100e+07
# CD1 gradient norm: 1.9859e+07
# ---
# Epoch 590
# k_lin:
# [-19.07969676 -19.08366829]
# k_duffing:
# [0.87019192 0.86408881]
# c_lin:
# [-8.04019803]
# c_optomech:
# [-1.30271148]
# Loss: 10944129.9406
# Raw gradient relative difference: 1.1645e-02
# Normalized gradient relative difference: 1.5502e-03
# Score matching gradient norm: 1.9268e+07
# CD1 gradient norm: 1.9046e+07
# ---
# Epoch 600
# k_lin:
# [-19.11118612 -19.1151065 ]
# k_duffing:
# [0.8372519  0.83100013]
# c_lin:
# [-8.07002886]
# c_optomech:
# [-1.25706599]
# Loss: 10059937.5376
# Raw gradient relative difference: 1.1187e-02
# Normalized gradient relative difference: 1.4912e-03
# Score matching gradient norm: 1.8467e+07
# CD1 gradient norm: 1.8263e+07
# ---
# Epoch 610
# k_lin:
# [-19.14143144 -19.14529433]
# k_duffing:
# [0.80553865 0.7991394 ]
# c_lin:
# [-8.09858448]
# c_optomech:
# [-1.21278401]
# Loss: 9244088.8405
# Raw gradient relative difference: 1.0745e-02
# Normalized gradient relative difference: 1.4344e-03
# Score matching gradient norm: 1.7696e+07
# CD1 gradient norm: 1.7508e+07
# ---
# Epoch 620
# k_lin:
# [-19.17047359 -19.1742726 ]
# k_duffing:
# [0.77501143 0.76846602]
# c_lin:
# [-8.12590607]
# c_optomech:
# [-1.16984631]
# Loss: 8491575.2860
# Raw gradient relative difference: 1.0320e-02
# Normalized gradient relative difference: 1.3798e-03
# Score matching gradient norm: 1.6954e+07
# CD1 gradient norm: 1.6780e+07
# ---
# Epoch 630
# k_lin:
# [-19.19835213 -19.20208088]
# k_duffing:
# [0.74563083 0.73894063]
# c_lin:
# [-8.15203351]
# c_optomech:
# [-1.12823239]
# Loss: 7797738.1228
# Raw gradient relative difference: 9.9103e-03
# Normalized gradient relative difference: 1.3272e-03
# Score matching gradient norm: 1.6239e+07
# CD1 gradient norm: 1.6079e+07
# ---
# Epoch 640
# k_lin:
# [-19.2251054  -19.22875747]
# k_duffing:
# [0.71735865 0.71052514]
# c_lin:
# [-8.17700547]
# c_optomech:
# [-1.08792063]
# Loss: 7158244.6224
# Raw gradient relative difference: 9.5159e-03
# Normalized gradient relative difference: 1.2766e-03
# Score matching gradient norm: 1.5551e+07
# CD1 gradient norm: 1.5405e+07
# ---
# Epoch 650
# k_lin:
# [-19.25077054 -19.25433951]
# k_duffing:
# [0.69015789 0.68318263]
# c_lin:
# [-8.20085942]
# c_optomech:
# [-1.04888847]
# Loss: 6569065.9542
# Raw gradient relative difference: 9.1363e-03
# Normalized gradient relative difference: 1.2279e-03
# Score matching gradient norm: 1.4890e+07
# CD1 gradient norm: 1.4755e+07
# ---
# Epoch 660
# k_lin:
# [-19.27538355 -19.27886299]
# k_duffing:
# [0.6639927  0.65687733]
# c_lin:
# [-8.22363167]
# c_optomech:
# [-1.01111252]
# Loss: 6026456.5929
# Raw gradient relative difference: 8.7710e-03
# Normalized gradient relative difference: 1.1810e-03
# Score matching gradient norm: 1.4253e+07
# CD1 gradient norm: 1.4129e+07
# ---
# Epoch 670
# k_lin:
# [-19.29897933 -19.30236281]
# k_duffing:
# [0.63882832 0.63157455]
# c_lin:
# [-8.24535747]
# c_optomech:
# [-0.97456869]
# Loss: 5526935.1401
# Raw gradient relative difference: 8.4195e-03
# Normalized gradient relative difference: 1.1360e-03
# Score matching gradient norm: 1.3641e+07
# CD1 gradient norm: 1.3527e+07
# ---
# Epoch 680
# k_lin:
# [-19.32159172 -19.3248728 ]
# k_duffing:
# [0.61463106 0.60724066]
# c_lin:
# [-8.26607098]
# c_optomech:
# [-0.93923227]
# Loss: 5067266.4518
# Raw gradient relative difference: 8.0814e-03
# Normalized gradient relative difference: 1.0927e-03
# Score matching gradient norm: 1.3052e+07
# CD1 gradient norm: 1.2948e+07
# ---
# Epoch 690
# k_lin:
# [-19.34325354 -19.34642579]
# k_duffing:
# [0.59136825 0.58384306]
# c_lin:
# [-8.28580535]
# c_optomech:
# [-0.9050781]
# Loss: 4644444.9741
# Raw gradient relative difference: 7.7562e-03
# Normalized gradient relative difference: 1.0510e-03
# Score matching gradient norm: 1.2486e+07
# CD1 gradient norm: 1.2390e+07
# ---
# Epoch 700
# k_lin:
# [-19.36399662 -19.36705362]
# k_duffing:
# [0.56900819 0.56135013]
# c_lin:
# [-8.30459275]
# c_optomech:
# [-0.87208059]
# Loss: 4255679.1988
# Raw gradient relative difference: 7.4435e-03
# Normalized gradient relative difference: 1.0110e-03
# Score matching gradient norm: 1.1942e+07
# CD1 gradient norm: 1.1854e+07
# ---
# Epoch 710
# k_lin:
# [-19.38385183 -19.38678717]
# k_duffing:
# [0.54752017 0.53973119]
# c_lin:
# [-8.32246437]
# c_optomech:
# [-0.84021386]
# Loss: 3898377.1566
# Raw gradient relative difference: 7.1430e-03
# Normalized gradient relative difference: 9.7259e-04
# Score matching gradient norm: 1.1419e+07
# CD1 gradient norm: 1.1338e+07
# ---
# Epoch 720
# k_lin:
# [-19.40284913 -19.4056564 ]
# k_duffing:
# [0.52687436 0.51895648]
# c_lin:
# [-8.3394505]
# c_optomech:
# [-0.8094518]
# Loss: 3570132.8756
# Raw gradient relative difference: 6.8541e-03
# Normalized gradient relative difference: 9.3567e-04
# Score matching gradient norm: 1.0917e+07
# CD1 gradient norm: 1.0842e+07
# ---
# Epoch 730
# k_lin:
# [-19.42101756 -19.4236904 ]
# k_duffing:
# [0.50704187 0.49899713]
# c_lin:
# [-8.35558053]
# c_optomech:
# [-0.77976812]
# Loss: 3268713.7355
# Raw gradient relative difference: 6.5765e-03
# Normalized gradient relative difference: 9.0023e-04
# Score matching gradient norm: 1.0434e+07
# CD1 gradient norm: 1.0366e+07
# ---
# Epoch 740
# k_lin:
# [-19.4383853  -19.44091737]
# k_duffing:
# [0.48799463 0.47982515]
# c_lin:
# [-8.37088296]
# c_optomech:
# [-0.75113646]
# Loss: 2992048.6572
# Raw gradient relative difference: 6.3098e-03
# Normalized gradient relative difference: 8.6620e-04
# Score matching gradient norm: 9.9703e+06
# CD1 gradient norm: 9.9080e+06
# ---
# Epoch 750
# k_lin:
# [-19.45497972 -19.45736467]
# k_duffing:
# [0.46970546 0.46141337]
# c_lin:
# [-8.38538548]
# c_optomech:
# [-0.7235304]
# Loss: 2738217.0689
# Raw gradient relative difference: 6.0537e-03
# Normalized gradient relative difference: 8.3355e-04
# Score matching gradient norm: 9.5252e+06
# CD1 gradient norm: 9.4681e+06
# ---
# Epoch 760
# k_lin:
# [-19.47082732 -19.47305888]
# k_duffing:
# [0.45214795 0.44373543]
# c_lin:
# [-8.39911493]
# c_optomech:
# [-0.69692357]
# Loss: 2505438.5977
# Raw gradient relative difference: 5.8077e-03
# Normalized gradient relative difference: 8.0223e-04
# Score matching gradient norm: 9.0978e+06
# CD1 gradient norm: 9.0455e+06
# ---
# Epoch 770
# k_lin:
# [-19.48595386 -19.48802574]
# k_duffing:
# [0.4352965  0.42676576]
# c_lin:
# [-8.41209737]
# c_optomech:
# [-0.67128964]
# Loss: 2292063.4371
# Raw gradient relative difference: 5.5717e-03
# Normalized gradient relative difference: 7.7220e-04
# Score matching gradient norm: 8.6876e+06
# CD1 gradient norm: 8.6397e+06
# ---
# Epoch 780
# k_lin:
# [-19.50038428 -19.50229027]
# k_duffing:
# [0.41912629 0.41047956]
# c_lin:
# [-8.42435808]
# c_optomech:
# [-0.64660243]
# Loss: 2096563.3459
# Raw gradient relative difference: 5.3451e-03
# Normalized gradient relative difference: 7.4341e-04
# Score matching gradient norm: 8.2940e+06
# CD1 gradient norm: 8.2501e+06
# ---
# Epoch 790
# k_lin:
# [-19.5141428  -19.51587671]
# k_duffing:
# [0.40361323 0.39485277]
# c_lin:
# [-8.43592159]
# c_optomech:
# [-0.62283592]
# Loss: 1917523.2381
# Raw gradient relative difference: 5.1277e-03
# Normalized gradient relative difference: 7.1582e-04
# Score matching gradient norm: 7.9163e+06
# CD1 gradient norm: 7.8761e+06
# ---
# Epoch 800
# k_lin:
# [-19.52725291 -19.5288086 ]
# k_duffing:
# [0.38873397 0.37986206]
# c_lin:
# [-8.44681171]
# c_optomech:
# [-0.59996426]
# Loss: 1753633.3227
# Raw gradient relative difference: 4.9192e-03
# Normalized gradient relative difference: 6.8940e-04
# Score matching gradient norm: 7.5540e+06
# CD1 gradient norm: 7.5172e+06
# ---
# Epoch 810
# k_lin:
# [-19.53973738 -19.54110873]
# k_duffing:
# [0.37446586 0.36548478]
# c_lin:
# [-8.45705151]
# c_optomech:
# [-0.57796186]
# Loss: 1603681.7612
# Raw gradient relative difference: 4.7192e-03
# Normalized gradient relative difference: 6.6410e-04
# Score matching gradient norm: 7.2066e+06
# CD1 gradient norm: 7.1730e+06
# ---
# Epoch 820
# k_lin:
# [-19.5516183  -19.55279926]
# k_duffing:
# [0.36078693 0.35169901]
# c_lin:
# [-8.46666339]
# c_optomech:
# [-0.5568034]
# Loss: 1466547.8069
# Raw gradient relative difference: 4.5275e-03
# Normalized gradient relative difference: 6.3989e-04
# Score matching gradient norm: 6.8736e+06
# CD1 gradient norm: 6.8428e+06
# ---
# Epoch 830
# k_lin:
# [-19.56291707 -19.56390163]
# k_duffing:
# [0.34767589 0.33848344]
# c_lin:
# [-8.47566906]
# c_optomech:
# [-0.53646386]
# Loss: 1341195.3960
# Raw gradient relative difference: 4.3438e-03
# Normalized gradient relative difference: 6.1673e-04
# Score matching gradient norm: 6.5543e+06
# CD1 gradient norm: 6.5262e+06
# ---
# Epoch 840
# k_lin:
# [-19.57365447 -19.57443666]
# k_duffing:
# [0.33511211 0.32581745]
# c_lin:
# [-8.48408957]
# c_optomech:
# [-0.51691852]
# Loss: 1226667.1622
# Raw gradient relative difference: 4.1678e-03
# Normalized gradient relative difference: 5.9459e-04
# Score matching gradient norm: 6.2484e+06
# CD1 gradient norm: 6.2226e+06
# ---
# Epoch 850
# k_lin:
# [-19.58385059 -19.58442452]
# k_duffing:
# [0.32307558 0.31368103]
# c_lin:
# [-8.49194535]
# c_optomech:
# [-0.49814303]
# Loss: 1122078.8473
# Raw gradient relative difference: 3.9992e-03
# Normalized gradient relative difference: 5.7343e-04
# Score matching gradient norm: 5.9553e+06
# CD1 gradient norm: 5.9317e+06
# ---
# Epoch 860
# k_lin:
# [-19.59352496 -19.59388476]
# k_duffing:
# [0.3115469 0.3020548]
# c_lin:
# [-8.49925617]
# c_optomech:
# [-0.4801134]
# Loss: 1026614.0835
# Raw gradient relative difference: 3.8377e-03
# Normalized gradient relative difference: 5.5323e-04
# Score matching gradient norm: 5.6746e+06
# CD1 gradient norm: 5.6530e+06
# ---
# Epoch 870
# k_lin:
# [-19.60269646 -19.60283633]
# k_duffing:
# [0.3005073  0.29091998]
# c_lin:
# [-8.50604122]
# c_optomech:
# [-0.46280604]
# Loss: 939519.5220
# Raw gradient relative difference: 3.6831e-03
# Normalized gradient relative difference: 5.3395e-04
# Score matching gradient norm: 5.4057e+06
# CD1 gradient norm: 5.3860e+06
# ---
# Epoch 880
# k_lin:
# [-19.61138339 -19.6112976 ]
# k_duffing:
# [0.28993858 0.28025834]
# c_lin:
# [-8.51231908]
# c_optomech:
# [-0.44619775]
# Loss: 860100.2894
# Raw gradient relative difference: 3.5352e-03
# Normalized gradient relative difference: 5.1556e-04
# Score matching gradient norm: 5.1484e+06
# CD1 gradient norm: 5.1303e+06
# ---
# Epoch 890
# k_lin:
# [-19.6196035  -19.61928635]
# k_duffing:
# [0.27982309 0.27005227]
# c_lin:
# [-8.51810775]
# c_optomech:
# [-0.43026575]
# Loss: 787715.7471
# Raw gradient relative difference: 3.3937e-03
# Normalized gradient relative difference: 4.9804e-04
# Score matching gradient norm: 4.9020e+06
# CD1 gradient norm: 4.8856e+06
# ---
# Epoch 900
# k_lin:
# [-19.62737394 -19.62681981]
# k_duffing:
# [0.27014379 0.26028468]
# c_lin:
# [-8.52342468]
# c_optomech:
# [-0.41498771]
# Loss: 721775.5386
# Raw gradient relative difference: 3.2584e-03
# Normalized gradient relative difference: 4.8135e-04
# Score matching gradient norm: 4.6663e+06
# CD1 gradient norm: 4.6513e+06
# ---
# Epoch 910
# k_lin:
# [-19.63471136 -19.63391468]
# k_duffing:
# [0.26088412 0.25093902]
# c_lin:
# [-8.52828674]
# c_optomech:
# [-0.40034172]
# Loss: 661735.9032
# Raw gradient relative difference: 3.1290e-03
# Normalized gradient relative difference: 4.6548e-04
# Score matching gradient norm: 4.4408e+06
# CD1 gradient norm: 4.4270e+06
# ---
# Epoch 920
# k_lin:
# [-19.64163183 -19.64058711]
# k_duffing:
# [0.2520281  0.24199928]
# c_lin:
# [-8.53271029]
# c_optomech:
# [-0.38630634]
# Loss: 607096.2414
# Raw gradient relative difference: 3.0053e-03
# Normalized gradient relative difference: 4.5039e-04
# Score matching gradient norm: 4.2251e+06
# CD1 gradient norm: 4.2126e+06
# ---
# Epoch 930
# k_lin:
# [-19.64815095 -19.64685274]
# k_duffing:
# [0.24356023 0.23344996]
# c_lin:
# [-8.53671116]
# c_optomech:
# [-0.37286058]
# Loss: 557395.9152
# Raw gradient relative difference: 2.8872e-03
# Normalized gradient relative difference: 4.3606e-04
# Score matching gradient norm: 4.0189e+06
# CD1 gradient norm: 4.0074e+06
# ---
# Epoch 940
# k_lin:
# [-19.65428378 -19.6527267 ]
# k_duffing:
# [0.23546554 0.22527605]
# c_lin:
# [-8.54030467]
# c_optomech:
# [-0.35998393]
# Loss: 512211.2682
# Raw gradient relative difference: 2.7744e-03
# Normalized gradient relative difference: 4.2248e-04
# Score matching gradient norm: 3.8218e+06
# CD1 gradient norm: 3.8113e+06
# ---
# Epoch 950
# k_lin:
# [-19.6600449  -19.65822365]
# k_duffing:
# [0.22772951 0.21746303]
# c_lin:
# [-8.54350563]
# c_optomech:
# [-0.34765635]
# Loss: 471152.8520
# Raw gradient relative difference: 2.6667e-03
# Normalized gradient relative difference: 4.0961e-04
# Score matching gradient norm: 3.6334e+06
# CD1 gradient norm: 3.6238e+06
# ---
# Epoch 960
# k_lin:
# [-19.66544842 -19.66335774]
# k_duffing:
# [0.22033814 0.20999687]
# c_lin:
# [-8.54632838]
# c_optomech:
# [-0.33585826]
# Loss: 433862.8454
# Raw gradient relative difference: 2.5639e-03
# Normalized gradient relative difference: 3.9743e-04
# Score matching gradient norm: 3.4534e+06
# CD1 gradient norm: 3.4446e+06
# ---
# Epoch 970
# k_lin:
# [-19.67050798 -19.66814268]
# k_duffing:
# [0.21327786 0.20286397]
# c_lin:
# [-8.54878678]
# c_optomech:
# [-0.32457058]
# Loss: 400012.6542
# Raw gradient relative difference: 2.4659e-03
# Normalized gradient relative difference: 3.8594e-04
# Score matching gradient norm: 3.2815e+06
# CD1 gradient norm: 3.2735e+06
# ---
# Epoch 980
# k_lin:
# [-19.67523675 -19.67259171]
# k_duffing:
# [0.20653556 0.1960512 ]
# c_lin:
# [-8.55089423]
# c_optomech:
# [-0.31377469]
# Loss: 369300.6794
# Raw gradient relative difference: 2.3724e-03
# Normalized gradient relative difference: 3.7511e-04
# Score matching gradient norm: 3.1173e+06
# CD1 gradient norm: 3.1100e+06
# ---
# Epoch 990
# k_lin:
# [-19.67964748 -19.67671765]
# k_duffing:
# [0.20009857 0.18954587]
# c_lin:
# [-8.55266369]
# c_optomech:
# [-0.30345247]
# Loss: 341450.2440
# Raw gradient relative difference: 2.2834e-03
# Normalized gradient relative difference: 3.6491e-04
# Score matching gradient norm: 2.9605e+06
# CD1 gradient norm: 2.9539e+06
# ---
# Epoch 1000
# k_lin:
# [-19.68375248 -19.68053287]
# k_duffing:
# [0.19395466 0.18333571]
# c_lin:
# [-8.55410767]
# c_optomech:
# [-0.29358626]
# Loss: 316207.6664
# Raw gradient relative difference: 2.1986e-03
# Normalized gradient relative difference: 3.5535e-04
# Score matching gradient norm: 2.8110e+06
# CD1 gradient norm: 2.8049e+06
# ---
# Epoch 1010
# k_lin:
# [-19.68756364 -19.68404931]
# k_duffing:
# [0.188092   0.17740887]
# c_lin:
# [-8.55523827]
# c_optomech:
# [-0.28415889]
# Loss: 293340.4731
# Raw gradient relative difference: 2.1178e-03
# Normalized gradient relative difference: 3.4639e-04
# Score matching gradient norm: 2.6682e+06
# CD1 gradient norm: 2.6627e+06
# ---
# Epoch 1020
# k_lin:
# [-19.69109243 -19.68727854]
# k_duffing:
# [0.18249915 0.17175388]
# c_lin:
# [-8.55606717]
# c_optomech:
# [-0.27515366]
# Loss: 272635.7390
# Raw gradient relative difference: 2.0410e-03
# Normalized gradient relative difference: 3.3804e-04
# Score matching gradient norm: 2.5321e+06
# CD1 gradient norm: 2.5270e+06
# ---
# Epoch 1030
# k_lin:
# [-19.69434996 -19.6902317 ]
# k_duffing:
# [0.17716511 0.16635969]
# c_lin:
# [-8.55660564]
# c_optomech:
# [-0.26655436]
# Loss: 253898.5488
# Raw gradient relative difference: 1.9680e-03
# Normalized gradient relative difference: 3.3026e-04
# Score matching gradient norm: 2.4023e+06
# CD1 gradient norm: 2.3976e+06
# ---
# Epoch 1040
# k_lin:
# [-19.69734691 -19.69291955]
# k_duffing:
# [0.17207921 0.16121562]
# c_lin:
# [-8.55686456]
# c_optomech:
# [-0.25834522]
# Loss: 236950.5705
# Raw gradient relative difference: 1.8986e-03
# Normalized gradient relative difference: 3.2306e-04
# Score matching gradient norm: 2.2785e+06
# CD1 gradient norm: 2.2742e+06
# ---
# Epoch 1050
# k_lin:
# [-19.70009361 -19.6953525 ]
# k_duffing:
# [0.1672312  0.15631137]
# c_lin:
# [-8.55685444]
# c_optomech:
# [-0.25051094]
# Loss: 221628.7334
# Raw gradient relative difference: 1.8327e-03
# Normalized gradient relative difference: 3.1643e-04
# Score matching gradient norm: 2.1605e+06
# CD1 gradient norm: 2.1566e+06
# ---
# Epoch 1060
# k_lin:
# [-19.70260003 -19.69754055]
# k_duffing:
# [0.16261115 0.15163699]
# c_lin:
# [-8.55658541]
# c_optomech:
# [-0.2430367]
# Loss: 207784.0047
# Raw gradient relative difference: 1.7702e-03
# Normalized gradient relative difference: 3.1034e-04
# Score matching gradient norm: 2.0481e+06
# CD1 gradient norm: 2.0445e+06
# ---
# Epoch 1070
# k_lin:
# [-19.70487577 -19.69949338]
# k_duffing:
# [0.15820951 0.14718289]
# c_lin:
# [-8.55606723]
# c_optomech:
# [-0.23590811]
# Loss: 195280.2563
# Raw gradient relative difference: 1.7109e-03
# Normalized gradient relative difference: 3.0480e-04
# Score matching gradient norm: 1.9410e+06
# CD1 gradient norm: 1.9378e+06
# ---
# Epoch 1080
# k_lin:
# [-19.70693009 -19.70122032]
# k_duffing:
# [0.15401707 0.14293982]
# c_lin:
# [-8.55530934]
# c_optomech:
# [-0.22911123]
# Loss: 183993.2169
# Raw gradient relative difference: 1.6548e-03
# Normalized gradient relative difference: 2.9980e-04
# Score matching gradient norm: 1.8391e+06
# CD1 gradient norm: 1.8361e+06
# ---
# Epoch 1090
# k_lin:
# [-19.70877191 -19.70273035]
# k_duffing:
# [0.15002493 0.13889884]
# c_lin:
# [-8.5543208]
# c_optomech:
# [-0.22263258]
# Loss: 173809.5029
# Raw gradient relative difference: 1.6017e-03
# Normalized gradient relative difference: 2.9533e-04
# Score matching gradient norm: 1.7420e+06
# CD1 gradient norm: 1.7392e+06
# ---
# Epoch 1100
# k_lin:
# [-19.71040984 -19.70403213]
# k_duffing:
# [0.14622453 0.13505137]
# c_lin:
# [-8.55311036]
# c_optomech:
# [-0.21645909]
# Loss: 164625.7235
# Raw gradient relative difference: 1.5515e-03
# Normalized gradient relative difference: 2.9138e-04
# Score matching gradient norm: 1.6496e+06
# CD1 gradient norm: 1.6471e+06
# ---
# Epoch 1110
# k_lin:
# [-19.71185215 -19.705134  ]
# k_duffing:
# [0.14260763 0.13138912]
# c_lin:
# [-8.55168646]
# c_optomech:
# [-0.21057812]
# Loss: 156347.6535
# Raw gradient relative difference: 1.5041e-03
# Normalized gradient relative difference: 2.8796e-04
# Score matching gradient norm: 1.5617e+06
# CD1 gradient norm: 1.5594e+06
# ---
# Epoch 1120
# k_lin:
# [-19.71310684 -19.70604401]
# k_duffing:
# [0.13916628 0.12790411]
# c_lin:
# [-8.5500572]
# c_optomech:
# [-0.20497746]
# Loss: 148889.4699
# Raw gradient relative difference: 1.4594e-03
# Normalized gradient relative difference: 2.8507e-04
# Score matching gradient norm: 1.4781e+06
# CD1 gradient norm: 1.4759e+06
# ---
# Epoch 1130
# k_lin:
# [-19.71418157 -19.7067699 ]
# k_duffing:
# [0.13589283 0.12458864]
# c_lin:
# [-8.54823039]
# c_optomech:
# [-0.1996453]
# Loss: 142173.0481
# Raw gradient relative difference: 1.4174e-03
# Normalized gradient relative difference: 2.8269e-04
# Score matching gradient norm: 1.3985e+06
# CD1 gradient norm: 1.3966e+06
# ---
# Epoch 1140
# k_lin:
# [-19.71508374 -19.70731911]
# k_duffing:
# [0.13277991 0.12143533]
# c_lin:
# [-8.54621356]
# c_optomech:
# [-0.19457023]
# Loss: 136127.3128
# Raw gradient relative difference: 1.3779e-03
# Normalized gradient relative difference: 2.8084e-04
# Score matching gradient norm: 1.3229e+06
# CD1 gradient norm: 1.3212e+06
# ---
# Epoch 1150
# k_lin:
# [-19.71582046 -19.70769881]
# k_duffing:
# [0.12982045 0.11843703]
# c_lin:
# [-8.54401392]
# c_optomech:
# [-0.18974124]
# Loss: 130687.6391
# Raw gradient relative difference: 1.3408e-03
# Normalized gradient relative difference: 2.7951e-04
# Score matching gradient norm: 1.2511e+06
# CD1 gradient norm: 1.2495e+06
# ---
# Epoch 1160
# k_lin:
# [-19.71639856 -19.7079159 ]
# k_duffing:
# [0.12700761 0.1155869 ]
# c_lin:
# [-8.54163845]
# c_optomech:
# [-0.1851477]
# Loss: 125795.3025
# Raw gradient relative difference: 1.3062e-03
# Normalized gradient relative difference: 2.7871e-04
# Score matching gradient norm: 1.1828e+06
# CD1 gradient norm: 1.1813e+06
# ---
# Epoch 1170
# k_lin:
# [-19.71682463 -19.70797701]
# k_duffing:
# [0.12433484 0.11287835]
# c_lin:
# [-8.53909381]
# c_optomech:
# [-0.18077937]
# Loss: 121396.9712
# Raw gradient relative difference: 1.2738e-03
# Normalized gradient relative difference: 2.7845e-04
# Score matching gradient norm: 1.1180e+06
# CD1 gradient norm: 1.1166e+06
# ---
# Epoch 1180
# k_lin:
# [-19.71710498 -19.70788851]
# k_duffing:
# [0.12179585 0.11030502]
# c_lin:
# [-8.53638643]
# c_optomech:
# [-0.17662635]
# Loss: 117444.2402
# Raw gradient relative difference: 1.2437e-03
# Normalized gradient relative difference: 2.7873e-04
# Score matching gradient norm: 1.0564e+06
# CD1 gradient norm: 1.0552e+06
# ---
# Epoch 1190
# k_lin:
# [-19.71724569 -19.70765654]
# k_duffing:
# [0.11938457 0.10786083]
# c_lin:
# [-8.5335225]
# c_optomech:
# [-0.17267913]
# Loss: 113893.2019
# Raw gradient relative difference: 1.2157e-03
# Normalized gradient relative difference: 2.7956e-04
# Score matching gradient norm: 9.9801e+05
# CD1 gradient norm: 9.9683e+05
# ---
# Epoch 1200
# k_lin:
# [-19.7172526  -19.70728697]
# k_duffing:
# [0.11709518 0.10553992]
# c_lin:
# [-8.53050793]
# c_optomech:
# [-0.16892853]
# Loss: 110704.0530
# Raw gradient relative difference: 1.1899e-03
# Normalized gradient relative difference: 2.8095e-04
# Score matching gradient norm: 9.4256e+05
# CD1 gradient norm: 9.4147e+05
# ---
# Epoch 1210
# k_lin:
# [-19.71713129 -19.70678546]
# k_duffing:
# [0.11492208 0.10333666]
# c_lin:
# [-8.52734841]
# c_optomech:
# [-0.16536572]
# Loss: 107840.7322
# Raw gradient relative difference: 1.1661e-03
# Normalized gradient relative difference: 2.8292e-04
# Score matching gradient norm: 8.8995e+05
# CD1 gradient norm: 8.8895e+05
# ---
# Epoch 1220
# k_lin:
# [-19.71688715 -19.70615743]
# k_duffing:
# [0.11285991 0.10124564]
# c_lin:
# [-8.52404941]
# c_optomech:
# [-0.1619822]
# Loss: 105270.5884
# Raw gradient relative difference: 1.1444e-03
# Normalized gradient relative difference: 2.8547e-04
# Score matching gradient norm: 8.4006e+05
# CD1 gradient norm: 8.3913e+05
# ---
# Epoch 1230
# k_lin:
# [-19.71652535 -19.70540811]
# k_duffing:
# [0.11090352 0.09926167]
# c_lin:
# [-8.52061617]
# c_optomech:
# [-0.15876978]
# Loss: 102964.0768
# Raw gradient relative difference: 1.1247e-03
# Normalized gradient relative difference: 2.8863e-04
# Score matching gradient norm: 7.9277e+05
# CD1 gradient norm: 7.9190e+05
# ---
# Epoch 1240
# k_lin:
# [-19.71605082 -19.70454247]
# k_duffing:
# [0.10904794 0.09737976]
# c_lin:
# [-8.51705372]
# c_optomech:
# [-0.15572061]
# Loss: 100894.4793
# Raw gradient relative difference: 1.1069e-03
# Normalized gradient relative difference: 2.9241e-04
# Score matching gradient norm: 7.4794e+05
# CD1 gradient norm: 7.4714e+05
# ---
# Epoch 1250
# k_lin:
# [-19.71546833 -19.70356533]
# k_duffing:
# [0.10728845 0.09559514]
# c_lin:
# [-8.51336687]
# c_optomech:
# [-0.15282713]
# Loss: 99037.6494
# Raw gradient relative difference: 1.0910e-03
# Normalized gradient relative difference: 2.9685e-04
# Score matching gradient norm: 7.0546e+05
# CD1 gradient norm: 7.0472e+05
# ---
# Epoch 1260
# k_lin:
# [-19.71478241 -19.70248128]
# k_duffing:
# [0.10562049 0.09390321]
# c_lin:
# [-8.50956024]
# c_optomech:
# [-0.15008207]
# Loss: 97371.7783
# Raw gradient relative difference: 1.0770e-03
# Normalized gradient relative difference: 3.0195e-04
# Score matching gradient norm: 6.6523e+05
# CD1 gradient norm: 6.6454e+05
# ---
# Epoch 1270
# k_lin:
# [-19.71399744 -19.70129471]
# k_duffing:
# [0.10403968 0.09229959]
# c_lin:
# [-8.50563826]
# c_optomech:
# [-0.14747847]
# Loss: 95877.1809
# Raw gradient relative difference: 1.0649e-03
# Normalized gradient relative difference: 3.0774e-04
# Score matching gradient norm: 6.2714e+05
# CD1 gradient norm: 6.2650e+05
# ---
# Epoch 1280
# k_lin:
# [-19.71311758 -19.70000986]
# k_duffing:
# [0.10254186 0.09078004]
# c_lin:
# [-8.50160516]
# c_optomech:
# [-0.14500962]
# Loss: 94536.1002
# Raw gradient relative difference: 1.0547e-03
# Normalized gradient relative difference: 3.1426e-04
# Score matching gradient norm: 5.9108e+05
# CD1 gradient norm: 5.9048e+05
# ---
# Epoch 1290
# k_lin:
# [-19.71214684 -19.69863076]
# k_duffing:
# [0.101123   0.08934054]
# c_lin:
# [-8.49746499]
# c_optomech:
# [-0.1426691]
# Loss: 93332.5287
# Raw gradient relative difference: 1.0463e-03
# Normalized gradient relative difference: 3.2154e-04
# Score matching gradient norm: 5.5696e+05
# CD1 gradient norm: 5.5640e+05
# ---
# Epoch 1300
# k_lin:
# [-19.71108905 -19.69716129]
# k_duffing:
# [0.09977928 0.0879772 ]
# c_lin:
# [-8.49322165]
# c_optomech:
# [-0.14045075]
# Loss: 92252.0451
# Raw gradient relative difference: 1.0398e-03
# Normalized gradient relative difference: 3.2961e-04
# Score matching gradient norm: 5.2468e+05
# CD1 gradient norm: 5.2416e+05
# ---
# Epoch 1310
# k_lin:
# [-19.70994788 -19.69560515]
# k_duffing:
# [0.09850702 0.08668633]
# c_lin:
# [-8.48887884]
# c_optomech:
# [-0.13834866]
# Loss: 91281.6659
# Raw gradient relative difference: 1.0351e-03
# Normalized gradient relative difference: 3.3850e-04
# Score matching gradient norm: 4.9415e+05
# CD1 gradient norm: 4.9367e+05
# ---
# Epoch 1320
# k_lin:
# [-19.70872683 -19.69396589]
# k_duffing:
# [0.0973027  0.08546436]
# c_lin:
# [-8.4844401]
# c_optomech:
# [-0.13635717]
# Loss: 90409.7090
# Raw gradient relative difference: 1.0323e-03
# Normalized gradient relative difference: 3.4827e-04
# Score matching gradient norm: 4.6530e+05
# CD1 gradient norm: 4.6485e+05
# ---
# Epoch 1330
# k_lin:
# [-19.70742925 -19.69224689]
# k_duffing:
# [0.09616295 0.0843079 ]
# c_lin:
# [-8.47990885]
# c_optomech:
# [-0.13447086]
# Loss: 89625.6705
# Raw gradient relative difference: 1.0313e-03
# Normalized gradient relative difference: 3.5895e-04
# Score matching gradient norm: 4.3803e+05
# CD1 gradient norm: 4.3760e+05
# ---
# Epoch 1340
# k_lin:
# [-19.70605835 -19.69045141]
# k_duffing:
# [0.09508455 0.0832137 ]
# c_lin:
# [-8.4752883]
# c_optomech:
# [-0.13268453]
# Loss: 88920.1120
# Raw gradient relative difference: 1.0323e-03
# Normalized gradient relative difference: 3.7060e-04
# Score matching gradient norm: 4.1227e+05
# CD1 gradient norm: 4.1187e+05
# ---
# Epoch 1350
# k_lin:
# [-19.7046172  -19.68858253]
# k_duffing:
# [0.09406442 0.08217865]
# c_lin:
# [-8.47058157]
# c_optomech:
# [-0.1309932]
# Loss: 88284.5580
# Raw gradient relative difference: 1.0352e-03
# Normalized gradient relative difference: 3.8326e-04
# Score matching gradient norm: 3.8794e+05
# CD1 gradient norm: 3.8756e+05
# ---
# Epoch 1360
# k_lin:
# [-19.70310872 -19.68664321]
# k_duffing:
# [0.09309962 0.08119978]
# c_lin:
# [-8.46579161]
# c_optomech:
# [-0.12939213]
# Loss: 87711.4028
# Raw gradient relative difference: 1.0401e-03
# Normalized gradient relative difference: 3.9700e-04
# Score matching gradient norm: 3.6497e+05
# CD1 gradient norm: 3.6461e+05
# ---
# Epoch 1370
# k_lin:
# [-19.70153569 -19.68463629]
# k_duffing:
# [0.09218734 0.08027424]
# c_lin:
# [-8.46092123]
# c_optomech:
# [-0.12787674]
# Loss: 87193.8255
# Raw gradient relative difference: 1.0469e-03
# Normalized gradient relative difference: 4.1187e-04
# Score matching gradient norm: 3.4329e+05
# CD1 gradient norm: 3.4296e+05
# ---
# Epoch 1380
# k_lin:
# [-19.6999008  -19.68256445]
# k_duffing:
# [0.09132488 0.07939932]
# c_lin:
# [-8.45597313]
# c_optomech:
# [-0.12644271]
# Loss: 86725.7135
# Raw gradient relative difference: 1.0558e-03
# Normalized gradient relative difference: 4.2794e-04
# Score matching gradient norm: 3.2284e+05
# CD1 gradient norm: 3.2252e+05
# ---
# Epoch 1390
# k_lin:
# [-19.69820658 -19.68043028]
# k_duffing:
# [0.09050969 0.07857242]
# c_lin:
# [-8.45094987]
# c_optomech:
# [-0.12508586]
# Loss: 86301.5925
# Raw gradient relative difference: 1.0669e-03
# Normalized gradient relative difference: 4.4528e-04
# Score matching gradient norm: 3.0355e+05
# CD1 gradient norm: 3.0325e+05
# ---
# Epoch 1400
# k_lin:
# [-19.69645546 -19.67823623]
# k_duffing:
# [0.0897393  0.07779107]
# c_lin:
# [-8.4458539]
# c_optomech:
# [-0.12380221]
# Loss: 85916.5628
# Raw gradient relative difference: 1.0800e-03
# Normalized gradient relative difference: 4.6397e-04
# Score matching gradient norm: 2.8536e+05
# CD1 gradient norm: 2.8508e+05
# ---
# Epoch 1410
# k_lin:
# [-19.69464974 -19.67598463]
# k_duffing:
# [0.0890114 0.0770529]
# c_lin:
# [-8.44068754]
# c_optomech:
# [-0.12258799]
# Loss: 85566.2427
# Raw gradient relative difference: 1.0954e-03
# Normalized gradient relative difference: 4.8409e-04
# Score matching gradient norm: 2.6823e+05
# CD1 gradient norm: 2.6796e+05
# ---
# Epoch 1420
# k_lin:
# [-19.69279165 -19.67367772]
# k_duffing:
# [0.08832373 0.07635566]
# c_lin:
# [-8.435453]
# c_optomech:
# [-0.12143956]
# Loss: 85246.7156
# Raw gradient relative difference: 1.1132e-03
# Normalized gradient relative difference: 5.0571e-04
# Score matching gradient norm: 2.5208e+05
# CD1 gradient norm: 2.5183e+05
# ---
# Epoch 1430
# k_lin:
# [-19.69088327 -19.67131763]
# k_duffing:
# [0.08767418 0.07569719]
# c_lin:
# [-8.43015241]
# c_optomech:
# [-0.12035346]
# Loss: 84954.4836
# Raw gradient relative difference: 1.1333e-03
# Normalized gradient relative difference: 5.2894e-04
# Score matching gradient norm: 2.3687e+05
# CD1 gradient norm: 2.3664e+05
# ---
# Epoch 1440
# k_lin:
# [-19.6889266  -19.66890638]
# k_duffing:
# [0.08706073 0.07507545]
# c_lin:
# [-8.42478775]
# c_optomech:
# [-0.1193264]
# Loss: 84686.4248
# Raw gradient relative difference: 1.1558e-03
# Normalized gradient relative difference: 5.5387e-04
# Score matching gradient norm: 2.2256e+05
# CD1 gradient norm: 2.2233e+05
# ---
# Epoch 1450
# k_lin:
# [-19.68692354 -19.66644589]
# k_duffing:
# [0.08648143 0.07448847]
# c_lin:
# [-8.41936095]
# c_optomech:
# [-0.11835522]
# Loss: 84439.7545
# Raw gradient relative difference: 1.1810e-03
# Normalized gradient relative difference: 5.8061e-04
# Score matching gradient norm: 2.0909e+05
# CD1 gradient norm: 2.0888e+05
# ---
# Epoch 1460
# k_lin:
# [-19.68487591 -19.663938  ]
# k_duffing:
# [0.08593444 0.0739344 ]
# c_lin:
# [-8.41387381]
# c_optomech:
# [-0.11743695]
# Loss: 84211.9910
# Raw gradient relative difference: 1.2088e-03
# Normalized gradient relative difference: 6.0926e-04
# Score matching gradient norm: 1.9642e+05
# CD1 gradient norm: 1.9621e+05
# ---
# Epoch 1470
# k_lin:
# [-19.68278543 -19.66138444]
# k_duffing:
# [0.08541802 0.07341145]
# c_lin:
# [-8.40832805]
# c_optomech:
# [-0.1165687]
# Loss: 84000.9236
# Raw gradient relative difference: 1.2393e-03
# Normalized gradient relative difference: 6.3995e-04
# Score matching gradient norm: 1.8450e+05
# CD1 gradient norm: 1.8431e+05
# ---
# Epoch 1480
# k_lin:
# [-19.68065373 -19.65878688]
# k_duffing:
# [0.0849305  0.07291794]
# c_lin:
# [-8.4027253]
# c_optomech:
# [-0.11574778]
# Loss: 83804.5851
# Raw gradient relative difference: 1.2728e-03
# Normalized gradient relative difference: 6.7278e-04
# Score matching gradient norm: 1.7330e+05
# CD1 gradient norm: 1.7311e+05
# ---
# Epoch 1490
# k_lin:
# [-19.67848237 -19.65614689]
# k_duffing:
# [0.08447028 0.07245225]
# c_lin:
# [-8.39706712]
# c_optomech:
# [-0.11497158]
# Loss: 83621.2256
# Raw gradient relative difference: 1.3092e-03
# Normalized gradient relative difference: 7.0790e-04
# Score matching gradient norm: 1.6278e+05
# CD1 gradient norm: 1.6260e+05
# ---
# Epoch 1500
# k_lin:
# [-19.67627281 -19.65346596]
# k_duffing:
# [0.08403586 0.07201287]
# c_lin:
# [-8.39135498]
# c_optomech:
# [-0.11423764]
# Loss: 83449.2899
# Raw gradient relative difference: 1.3488e-03
# Normalized gradient relative difference: 7.4543e-04
# Score matching gradient norm: 1.5289e+05
# ...
# k_lin:
# [0.01103799 0.01059647]
# k_duffing:
# [1.06191744e-05 1.03598096e-04]
# c_lin:
# [-0.00013248]
# c_optomech:
# [7.21181836e-05]
# Loss: 0.2417
# Raw gradient relative difference: 1.5170e-01
# Normalized gradient relative difference: 1.4688e-01
# Score matching gradient norm: 2.8530e+03
# CD1 gradient norm: 2.9348e+03
# ---
# Epoch 19510
# k_lin:
# [0.0108563  0.01066841]
# k_duffing:
# [-0.00019002  0.00018346]
# c_lin:
# [-0.00019321]
# c_optomech:
# [5.84764159e-05]
# Loss: 0.4524
# Raw gradient relative difference: 1.0705e-01
# Normalized gradient relative difference: 1.0577e-01
# Score matching gradient norm: 4.0429e+03
# CD1 gradient norm: 3.9498e+03
# ---
# Epoch 19520
# k_lin:
# [0.01114555 0.01063071]
# k_duffing:
# [0.00012922 0.00014136]
# c_lin:
# [-5.28017266e-05]
# c_optomech:
# [0.00015005]
# Loss: 0.3609
# Raw gradient relative difference: 1.2213e-01
# Normalized gradient relative difference: 8.2848e-03
# Score matching gradient norm: 3.5438e+03
# CD1 gradient norm: 3.1119e+03
# ---
# Epoch 19530
# k_lin:
# [0.01101716 0.01070962]
# k_duffing:
# [-1.25744940e-05  2.28790708e-04]
# c_lin:
# [-7.95821534e-05]
# c_optomech:
# [0.00016808]
# Loss: 0.4507
# Raw gradient relative difference: 1.0410e-01
# Normalized gradient relative difference: 8.7858e-02
# Score matching gradient norm: 4.1574e+03
# CD1 gradient norm: 3.9087e+03
# ---
# Epoch 19540
# k_lin:
# [0.01106324 0.01096707]
# k_duffing:
# [3.78141089e-05 5.12926160e-04]
# c_lin:
# [9.38945051e-05]
# c_optomech:
# [0.00043005]
# Loss: 2.2146
# Raw gradient relative difference: 4.7302e-02
# Normalized gradient relative difference: 3.0782e-02
# Score matching gradient norm: 9.1491e+03
# CD1 gradient norm: 8.8162e+03
# ---
# Epoch 19550
# k_lin:
# [0.01109617 0.01072584]
# k_duffing:
# [7.45505539e-05 2.45417497e-04]
# c_lin:
# [-2.47173852e-05]
# c_optomech:
# [0.00021808]
# Loss: 1.1231
# Raw gradient relative difference: 6.6472e-02
# Normalized gradient relative difference: 3.9584e-02
# Score matching gradient norm: 6.5109e+03
# CD1 gradient norm: 6.1581e+03
# ---
# Epoch 19560
# k_lin:
# [0.01095718 0.01025924]
# k_duffing:
# [-7.79362542e-05 -2.68348731e-04]
# c_lin:
# [-0.00037135]
# c_optomech:
# [-0.00028041]
# Loss: 0.7248
# Raw gradient relative difference: 8.2576e-02
# Normalized gradient relative difference: 4.3017e-02
# Score matching gradient norm: 5.2412e+03
# CD1 gradient norm: 5.6058e+03
# ---
# Epoch 19570
# k_lin:
# [0.01102128 0.01053713]
# k_duffing:
# [-7.72885999e-06  3.75657378e-05]
# c_lin:
# [-0.00017518]
# c_optomech:
# [8.71493942e-06]
# Loss: -0.0048
# Raw gradient relative difference: 1.0793e+00
# Normalized gradient relative difference: 7.0347e-01
# Score matching gradient norm: 4.0103e+02
# CD1 gradient norm: 6.4471e+02
# ---
# Epoch 19580
# k_lin:
# [0.01108409 0.01061404]
# k_duffing:
# [6.14119695e-05 1.22152694e-04]
# c_lin:
# [-9.59198765e-05]
# c_optomech:
# [0.00010708]
# Loss: 0.1754
# Raw gradient relative difference: 1.6692e-01
# Normalized gradient relative difference: 7.2613e-02
# Score matching gradient norm: 2.5929e+03
# CD1 gradient norm: 2.1963e+03
# ---
# Epoch 19590
# k_lin:
# [0.01104784 0.01057619]
# k_duffing:
# [2.14994493e-05 8.05143894e-05]
# c_lin:
# [-0.00013787]
# c_optomech:
# [5.64772148e-05]
# Loss: 0.0649
# Raw gradient relative difference: 2.5982e-01
# Normalized gradient relative difference: 1.6707e-01
# Score matching gradient norm: 1.6658e+03
# CD1 gradient norm: 1.3103e+03
# ---
# Epoch 19600
# k_lin:
# [0.01105413 0.01058675]
# k_duffing:
# [2.84121815e-05 9.21289569e-05]
# c_lin:
# [-0.00012827]
# c_optomech:
# [6.90107022e-05]
# Loss: 0.0700
# Raw gradient relative difference: 2.5132e-01
# Normalized gradient relative difference: 1.5962e-01
# Score matching gradient norm: 1.7222e+03
# CD1 gradient norm: 1.3652e+03
# ---
# Epoch 19610
# k_lin:
# [0.01113133 0.01075297]
# k_duffing:
# [0.00011327 0.00027486]
# c_lin:
# [1.06776339e-05]
# c_optomech:
# [0.00025725]
# Loss: 0.6275
# Raw gradient relative difference: 8.9429e-02
# Normalized gradient relative difference: 4.2484e-02
# Score matching gradient norm: 4.8397e+03
# CD1 gradient norm: 4.4544e+03
# ---
# Epoch 19620
# k_lin:
# [0.01152454 0.01126212]
# k_duffing:
# [0.00054538 0.0008311 ]
# c_lin:
# [0.00052249]
# c_optomech:
# [0.00088147]
# Loss: 7.9152
# Raw gradient relative difference: 2.5622e-02
# Normalized gradient relative difference: 8.5548e-03
# Score matching gradient norm: 1.6887e+04
# CD1 gradient norm: 1.6478e+04
# ---
# Epoch 19630
# k_lin:
# [0.01118614 0.01019782]
# k_duffing:
# [ 0.00017354 -0.00033345]
# c_lin:
# [-0.00028069]
# c_optomech:
# [-0.0002377]
# Loss: 1.6806
# Raw gradient relative difference: 5.8197e-02
# Normalized gradient relative difference: 5.8219e-02
# Score matching gradient norm: 7.4366e+03
# CD1 gradient norm: 7.4201e+03
# ---
# Epoch 19640
# k_lin:
# [0.01097353 0.01063302]
# k_duffing:
# [-6.00939312e-05  1.41934946e-04]
# c_lin:
# [-0.00014618]
# c_optomech:
# [7.58024767e-05]
# Loss: 0.4137
# Raw gradient relative difference: 1.1796e-01
# Normalized gradient relative difference: 1.1237e-01
# Score matching gradient norm: 3.6691e+03
# CD1 gradient norm: 3.7796e+03
# ---
# Epoch 19650
# k_lin:
# [0.01100398 0.01047591]
# k_duffing:
# [-2.64822690e-05 -2.95639179e-05]
# c_lin:
# [-0.00022007]
# c_optomech:
# [-5.47736939e-05]
# Loss: 0.0270
# Raw gradient relative difference: 4.1263e-01
# Normalized gradient relative difference: 4.0417e-01
# Score matching gradient norm: 1.0489e+03
# CD1 gradient norm: 8.4100e+02
# ---
# Epoch 19660
# k_lin:
# [0.01105119 0.01046149]
# k_duffing:
# [ 2.51471748e-05 -4.53401473e-05]
# c_lin:
# [-0.00020232]
# c_optomech:
# [-4.92117628e-05]
# Loss: 0.0261
# Raw gradient relative difference: 3.7704e-01
# Normalized gradient relative difference: 1.1514e-01
# Score matching gradient norm: 1.1479e+03
# CD1 gradient norm: 1.5526e+03
# ---
# Epoch 19670
# k_lin:
# [0.01102454 0.01056293]
# k_duffing:
# [-4.15495058e-06  6.53728101e-05]
# c_lin:
# [-0.00015859]
# c_optomech:
# [3.19146681e-05]
# Loss: 0.0362
# Raw gradient relative difference: 3.3223e-01
# Normalized gradient relative difference: 2.0953e-01
# Score matching gradient norm: 1.3028e+03
# CD1 gradient norm: 9.3706e+02
# ---
# Epoch 19680
# k_lin:
# [0.01101543 0.01048732]
# k_duffing:
# [-1.39756174e-05 -1.71157363e-05]
# c_lin:
# [-0.00020717]
# c_optomech:
# [-3.99640627e-05]
# Loss: -0.0046
# Raw gradient relative difference: 1.0845e+00
# Normalized gradient relative difference: 2.5337e-01
# Score matching gradient norm: 3.9908e+02
# CD1 gradient norm: 8.0731e+02
# ---
# Epoch 19690
# k_lin:
# [0.01104148 0.01046288]
# k_duffing:
# [ 1.45382549e-05 -4.38118472e-05]
# c_lin:
# [-0.00020687]
# c_optomech:
# [-5.17956575e-05]
# Loss: 0.0121
# Raw gradient relative difference: 4.8376e-01
# Normalized gradient relative difference: 3.5190e-01
# Score matching gradient norm: 8.9469e+02
# CD1 gradient norm: 1.1414e+03
# ---
# Epoch 19700
# k_lin:
# [0.0109954  0.01046654]
# k_duffing:
# [-3.58361383e-05 -3.97701458e-05]
# c_lin:
# [-0.00023021]
# c_optomech:
# [-6.66024931e-05]
# Loss: 0.0107
# Raw gradient relative difference: 5.1199e-01
# Normalized gradient relative difference: 5.6626e-02
# Score matching gradient norm: 8.4537e+02
# CD1 gradient norm: 1.2742e+03
# ---
# Epoch 19710
# k_lin:
# [0.01098751 0.01040059]
# k_duffing:
# [-4.43338637e-05 -1.11707437e-04]
# c_lin:
# [-0.00027255]
# c_optomech:
# [-0.00012927]
# Loss: 0.0918
# Raw gradient relative difference: 2.2401e-01
# Normalized gradient relative difference: 8.0573e-02
# Score matching gradient norm: 1.9322e+03
# CD1 gradient norm: 2.3298e+03
# ---
# Epoch 19720
# k_lin:
# [0.0108859  0.01004091]
# k_duffing:
# [-0.00015473 -0.00050359]
# c_lin:
# [-0.00053627]
# c_optomech:
# [-0.00049384]
# Loss: 1.8960
# Raw gradient relative difference: 5.1413e-02
# Normalized gradient relative difference: 2.5088e-02
# Score matching gradient norm: 8.4177e+03
# CD1 gradient norm: 8.7928e+03
# ---
# Epoch 19730
# k_lin:
# [0.0103384  0.01004176]
# k_duffing:
# [-0.00075137 -0.0004988 ]
# c_lin:
# [-0.00083361]
# c_optomech:
# [-0.0006815]
# Loss: 8.1400
# Raw gradient relative difference: 2.5875e-02
# Normalized gradient relative difference: 2.8244e-03
# Score matching gradient norm: 1.6721e+04
# CD1 gradient norm: 1.7151e+04
# ---
# Epoch 19740
# k_lin:
# [0.01136594 0.01060785]
# k_duffing:
# [0.0003667  0.00011306]
# c_lin:
# [5.53347734e-05]
# c_optomech:
# [0.00019885]
# Loss: 0.9125
# Raw gradient relative difference: 7.6614e-02
# Normalized gradient relative difference: 1.2297e-02
# Score matching gradient norm: 5.6491e+03
# CD1 gradient norm: 5.2215e+03
# ---
# Epoch 19750
# k_lin:
# [0.0107515  0.01052992]
# k_duffing:
# [-3.00337340e-04  2.93496674e-05]
# c_lin:
# [-0.00032822]
# c_optomech:
# [-0.0001017]
# Loss: 0.3492
# Raw gradient relative difference: 1.3175e-01
# Normalized gradient relative difference: 6.8007e-02
# Score matching gradient norm: 3.2852e+03
# CD1 gradient norm: 3.6483e+03
# ---
# Epoch 19760
# k_lin:
# [0.01122845 0.0104593 ]
# k_duffing:
# [ 2.17168983e-04 -4.74839472e-05]
# c_lin:
# [-0.00010564]
# c_optomech:
# [1.67206199e-05]
# Loss: 0.2508
# Raw gradient relative difference: 1.5482e-01
# Normalized gradient relative difference: 1.3728e-01
# Score matching gradient norm: 2.7956e+03
# CD1 gradient norm: 2.5674e+03
# ---
# Epoch 19770
# k_lin:
# [0.01089547 0.01053043]
# k_duffing:
# [-1.44019215e-04  2.97561762e-05]
# c_lin:
# [-0.00024868]
# c_optomech:
# [-4.71983397e-05]
# Loss: 0.1124
# Raw gradient relative difference: 2.2539e-01
# Normalized gradient relative difference: 1.7103e-01
# Score matching gradient norm: 1.9203e+03
# CD1 gradient norm: 2.1755e+03
# ---
# Epoch 19780
# k_lin:
# [0.01109965 0.01048259]
# k_duffing:
# [ 7.74327751e-05 -2.21725616e-05]
# c_lin:
# [-0.00016334]
# c_optomech:
# [-1.16353365e-05]
# Loss: 0.0249
# Raw gradient relative difference: 4.2048e-01
# Normalized gradient relative difference: 4.3054e-01
# Score matching gradient norm: 1.0294e+03
# CD1 gradient norm: 9.2883e+02
# ---
# Epoch 19790
# k_lin:
# [0.01100383 0.01051607]
# k_duffing:
# [-2.65125112e-05  1.41190392e-05]
# c_lin:
# [-0.00019699]
# c_optomech:
# [-1.8424065e-05]
# Loss: -0.0074
# Raw gradient relative difference: 1.4974e+00
# Normalized gradient relative difference: 1.0445e+00
# Score matching gradient norm: 2.8905e+02
# CD1 gradient norm: 4.7929e+02
# ---
# Epoch 19800
# k_lin:
# [0.01101012 0.01050024]
# k_duffing:
# [-1.96646396e-05 -3.00402929e-06]
# c_lin:
# [-0.00020272]
# c_optomech:
# [-3.02367674e-05]
# Loss: -0.0052
# Raw gradient relative difference: 1.1647e+00
# Normalized gradient relative difference: 4.8149e-01
# Score matching gradient norm: 3.7160e+02
# CD1 gradient norm: 7.2498e+02
# ---
# Epoch 19810
# k_lin:
# [0.01104473 0.01048527]
# k_duffing:
# [ 1.78877058e-05 -1.92229600e-05]
# c_lin:
# [-0.00019223]
# c_optomech:
# [-3.03608909e-05]
# Loss: -0.0039
# Raw gradient relative difference: 9.6658e-01
# Normalized gradient relative difference: 7.1170e-01
# Score matching gradient norm: 4.4778e+02
# CD1 gradient norm: 6.4844e+02
# ---
# Epoch 19820
# k_lin:
# [0.01103094 0.0104876 ]
# k_duffing:
# [ 2.93360340e-06 -1.66886497e-05]
# c_lin:
# [-0.00019852]
# c_optomech:
# [-3.35801797e-05]
# Loss: -0.0073
# Raw gradient relative difference: 1.4206e+00
# Normalized gradient relative difference: 6.5191e-01
# Score matching gradient norm: 3.0467e+02
# CD1 gradient norm: 6.2990e+02
# ---
# Epoch 19830
# k_lin:
# [0.0110098  0.01046705]
# k_duffing:
# [-1.99472922e-05 -3.88933309e-05]
# c_lin:
# [-0.00022221]
# c_optomech:
# [-6.02061255e-05]
# Loss: 0.0019
# Raw gradient relative difference: 6.5928e-01
# Normalized gradient relative difference: 1.6821e-01
# Score matching gradient norm: 6.5650e+02
# CD1 gradient norm: 1.0658e+03
# ---
# Epoch 19840
# k_lin:
# [0.01091324 0.01029991]
# k_duffing:
# [-0.00012432 -0.0002195 ]
# c_lin:
# [-0.00037303]
# c_optomech:
# [-0.00024759]
# Loss: 0.3757
# Raw gradient relative difference: 1.1596e-01
# Normalized gradient relative difference: 3.6089e-02
# Score matching gradient norm: 3.7324e+03
# CD1 gradient norm: 4.1413e+03
# ---
# Epoch 19850
# k_lin:
# [0.01016162 0.00939116]
# k_duffing:
# [-0.00093528 -0.00119518]
# c_lin:
# [-0.00131415]
# c_optomech:
# [-0.00132032]
# Loss: 16.6063
# Raw gradient relative difference: 1.7817e-02
# Normalized gradient relative difference: 4.4886e-03
# Score matching gradient norm: 2.4273e+04
# CD1 gradient norm: 2.4691e+04
# ---
# Epoch 19860
# k_lin:
# [0.01173066 0.01106605]
# k_duffing:
# [0.00075318 0.00060184]
# c_lin:
# [0.00051781]
# c_optomech:
# [0.00071252]
# Loss: 6.7467
# Raw gradient relative difference: 2.8105e-02
# Normalized gradient relative difference: 6.0017e-03
# Score matching gradient norm: 1.5395e+04
# CD1 gradient norm: 1.4972e+04
# ---
# Epoch 19870
# k_lin:
# [0.0107758  0.01052332]
# k_duffing:
# [-2.70456805e-04  2.19176081e-05]
# c_lin:
# [-0.00031802]
# c_optomech:
# [-9.97577499e-05]
# Loss: 1.8665
# Raw gradient relative difference: 5.7164e-02
# Normalized gradient relative difference: 2.4029e-02
# Score matching gradient norm: 7.5710e+03
# CD1 gradient norm: 7.9615e+03
# ---
# Epoch 19880
# k_lin:
# [0.0107412  0.01032769]
# k_duffing:
# [-0.00030701 -0.00018718]
# c_lin:
# [-0.0004493]
# c_optomech:
# [-0.0002726]
# Loss: 0.5999
# Raw gradient relative difference: 9.6888e-02
# Normalized gradient relative difference: 8.0409e-03
# Score matching gradient norm: 4.4671e+03
# CD1 gradient norm: 4.8983e+03
# ---
# Epoch 19890
# k_lin:
# [0.01107525 0.01058792]
# k_duffing:
# [5.01112921e-05 9.06715714e-05]
# c_lin:
# [-0.00011662]
# c_optomech:
# [6.81991246e-05]
# Loss: 0.2801
# Raw gradient relative difference: 1.3843e-01
# Normalized gradient relative difference: 6.0814e-03
# Score matching gradient norm: 3.1266e+03
# CD1 gradient norm: 2.6941e+03
# ---
# Epoch 19900
# k_lin:
# [0.01112209 0.01050606]
# k_duffing:
# [1.00370192e-04 3.12927133e-06]
# c_lin:
# [-0.00013771]
# c_optomech:
# [1.54325663e-05]
# Loss: 0.0491
# Raw gradient relative difference: 3.2036e-01
# Normalized gradient relative difference: 3.2464e-01
# Score matching gradient norm: 1.3510e+03
# CD1 gradient norm: 1.2744e+03
# ---
# Epoch 19910
# k_lin:
# [0.01100173 0.01046135]
# k_duffing:
# [-2.83472156e-05 -4.45362242e-05]
# c_lin:
# [-0.0002295]
# c_optomech:
# [-6.53037146e-05]
# Loss: 0.0144
# Raw gradient relative difference: 4.9175e-01
# Normalized gradient relative difference: 6.9282e-02
# Score matching gradient norm: 8.8017e+02
# CD1 gradient norm: 1.3066e+03
# ---
# Epoch 19920
# k_lin:
# [0.01100627 0.01053821]
# k_duffing:
# [-2.36171821e-05  3.76056227e-05]
# c_lin:
# [-0.000183]
# c_optomech:
# [7.22923157e-07]
# Loss: 0.0031
# Raw gradient relative difference: 6.2316e-01
# Normalized gradient relative difference: 6.5519e-01
# Score matching gradient norm: 6.9456e+02
# CD1 gradient norm: 5.9519e+02
# ---
# Epoch 19930
# k_lin:
# [0.01104104 0.01047876]
# k_duffing:
# [ 1.36827270e-05 -2.59689266e-05]
# c_lin:
# [-0.00019792]
# c_optomech:
# [-3.67040905e-05]
# Loss: -0.0012
# Raw gradient relative difference: 7.7809e-01
# Normalized gradient relative difference: 5.3901e-01
# Score matching gradient norm: 5.5626e+02
# CD1 gradient norm: 7.9789e+02
# ---
# Epoch 19940
# k_lin:
# [0.01102353 0.01051494]
# k_duffing:
# [-5.10781227e-06  1.27108294e-05]
# c_lin:
# [-0.00018683]
# c_optomech:
# [-1.25499881e-05]
# Loss: -0.0073
# Raw gradient relative difference: 1.4162e+00
# Normalized gradient relative difference: 1.1786e+00
# Score matching gradient norm: 3.0562e+02
# CD1 gradient norm: 4.1373e+02
# ---
# Epoch 19950
# k_lin:
# [0.01102471 0.01049485]
# k_duffing:
# [-3.80818061e-06 -8.75464775e-06]
# c_lin:
# [-0.00019768]
# c_optomech:
# [-2.89785773e-05]
# Loss: -0.0094
# Raw gradient relative difference: 3.2095e+00
# Normalized gradient relative difference: 7.0029e-01
# Score matching gradient norm: 1.3485e+02
# CD1 gradient norm: 5.2547e+02
# ---
# Epoch 19960
# k_lin:
# [0.0110276  0.01050278]
# k_duffing:
# [-7.34807895e-07 -2.85439800e-07]
# c_lin:
# [-0.00019156]
# c_optomech:
# [-2.13295575e-05]
# Loss: -0.0099
# Raw gradient relative difference: 4.0184e+01
# Normalized gradient relative difference: 1.3033e+00
# Score matching gradient norm: 1.0771e+01
# CD1 gradient norm: 4.3431e+02
# ---
# Epoch 19970
# k_lin:
# [0.01102682 0.01050479]
# k_duffing:
# [-1.57354821e-06  1.86115606e-06]
# c_lin:
# [-0.00019084]
# c_optomech:
# [-1.99125142e-05]
# Loss: -0.0097
# Raw gradient relative difference: 6.2264e+00
# Normalized gradient relative difference: 1.9335e+00
# Score matching gradient norm: 6.9513e+01
# CD1 gradient norm: 3.7103e+02
# ---
# Epoch 19980
# k_lin:
# [0.01102558 0.01050148]
# k_duffing:
# [-2.89703486e-06 -1.67460383e-06]
# c_lin:
# [-0.00019341]
# c_optomech:
# [-2.31291823e-05]
# Loss: -0.0098
# Raw gradient relative difference: 2.2511e+01
# Normalized gradient relative difference: 8.3043e-01
# Score matching gradient norm: 1.9227e+01
# CD1 gradient norm: 4.4517e+02
# ---
# Epoch 19990
# k_lin:
# [0.01102708 0.01049957]
# k_duffing:
# [-1.28655448e-06 -3.71866074e-06]
# c_lin:
# [-0.00019368]
# c_optomech:
# [-2.419146e-05]
# Loss: -0.0098
# Raw gradient relative difference: 9.9853e+00
# Normalized gradient relative difference: 9.6105e-01
# Score matching gradient norm: 4.3346e+01
# CD1 gradient norm: 4.5460e+02
# ---

# %%
# Convert histories to arrays for plotting
slicing = 1
params_history = jnp.array(params_history[::slicing])
k_lin_history = jnp.zeros((len(params_history), N_osc))
k_duff_history = jnp.zeros((len(params_history), N_osc))
c_lin_history = jnp.zeros((len(params_history), 1))
c_optomech_history = jnp.zeros((len(params_history), 1))

for i in range(len(params_history)):
    k_lin, k_duff, c_lin, c_optomech = unflatten(params_history[i])
    k_lin_history = k_lin_history.at[i].set(k_lin)
    k_duff_history = k_duff_history.at[i].set(k_duff)
    c_lin_history = c_lin_history.at[i].set(c_lin)
    c_optomech_history = c_optomech_history.at[i].set(c_optomech)

loss_history = jnp.array(loss_history[::slicing])
gradient_diff_history = jnp.array(gradient_diff_history[::slicing])
gradient_diff_norm_history = jnp.array(gradient_diff_norm_history[::slicing])
sm_grad_norm_history = jnp.array(sm_grad_norm_history[::slicing])
cd1_grad_norm_history = jnp.array(cd1_grad_norm_history[::slicing])

# Create figure with 4 rows and 2 columns
fig, axes = plt.subplots(4, 2, figsize=(20, 32))

# Plot k_lin evolution
for i in range(N_osc):
    axes[0, 0].plot(k_lin_history[:, i], label=f'k_lin[{i}]')
axes[0, 0].set_title(f'Evolution of k_lin\nFinal values:\n' + 
                     '\n'.join([f'k_lin[{i}] = {k_lin_history[-1,i]:.3f}' 
                               for i in range(N_osc)]))
axes[0, 0].set_xlabel('Epoch')
axes[0, 0].set_ylabel('Linear Strength')
axes[0, 0].legend()
axes[0, 0].grid(True)

# Plot k_duff evolution
for i in range(N_osc):
    axes[0, 1].plot(k_duff_history[:, i], label=f'k_duff[{i}]')
axes[0, 1].set_title(f'Evolution of k_duff\nFinal values:\n' + 
                     '\n'.join([f'k_duff[{i}] = {k_duff_history[-1,i]:.3f}' 
                               for i in range(N_osc)]))
axes[0, 1].set_xlabel('Epoch')
axes[0, 1].set_ylabel('Duffing Strength')
axes[0, 1].legend()
axes[0, 1].grid(True)

# Plot c_lin and c_optomech evolution
axes[1, 0].plot(c_lin_history, label='c_lin')
axes[1, 0].plot(c_optomech_history, label='c_optomech')
axes[1, 0].set_title(f'Evolution of Coupling Parameters\nFinal values:\n' +
                     f'c_lin = {c_lin_history[-1,0]:.3f}\n' +
                     f'c_optomech = {c_optomech_history[-1,0]:.3f}')
axes[1, 0].set_xlabel('Epoch')
axes[1, 0].set_ylabel('Coupling Strength')
axes[1, 0].legend()
axes[1, 0].grid(True)

# Plot loss evolution
axes[1, 1].semilogy(loss_history, label='Loss')
axes[1, 1].set_title(f'Evolution of Loss\nFinal value: {loss_history[-1]:.3e}')
axes[1, 1].set_xlabel('Epoch')
axes[1, 1].set_ylabel('Loss')
axes[1, 1].legend()
axes[1, 1].grid(True)

# Plot raw gradient difference evolution
axes[2, 0].semilogy(gradient_diff_history, label='Raw Gradient Difference')
axes[2, 0].set_title('Evolution of Raw Gradient Difference\n' +
                     f'Final value: {gradient_diff_history[-1]:.2e}')
axes[2, 0].set_xlabel('Epoch')
axes[2, 0].set_ylabel('Relative Difference')
axes[2, 0].legend()
axes[2, 0].grid(True)

# Plot normalized gradient difference evolution
axes[2, 1].semilogy(gradient_diff_norm_history, label='Normalized Gradient Difference')
axes[2, 1].set_title('Evolution of Normalized Gradient Difference\n' +
                     f'Final value: {gradient_diff_norm_history[-1]:.2e}')
axes[2, 1].set_xlabel('Epoch')
axes[2, 1].set_ylabel('Relative Difference')
axes[2, 1].legend()
axes[2, 1].grid(True)

# Plot gradient norms evolution
axes[3, 0].semilogy(sm_grad_norm_history, label='Score Matching Gradient Norm')
axes[3, 0].semilogy(cd1_grad_norm_history, label='CD1 Gradient Norm')
axes[3, 0].set_title('Evolution of Gradient Norms\n' +
                     f'Final SM value: {sm_grad_norm_history[-1]:.2e}\n' +
                     f'Final CD1 value: {cd1_grad_norm_history[-1]:.2e}')
axes[3, 0].set_xlabel('Epoch')
axes[3, 0].set_ylabel('Gradient Norm')
axes[3, 0].legend()
axes[3, 0].grid(True)

# Hide the empty subplot
axes[3, 1].set_visible(False)

plt.tight_layout()
plt.show()

# %%
# Create figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# Plot initial energy landscape
energy_initial = jnp.zeros((n_points, n_points))
energy_final = jnp.zeros((n_points, n_points))
for i in range(n_points):
    for j in range(n_points):
        x = jnp.array([X1[i,j], X2[i,j]])
        energy_initial = energy_initial.at[i,j].set(energy_fn(x, flattened_args_initial))
        energy_final = energy_final.at[i,j].set(energy_fn(x, params))

contour1 = ax1.contourf(X1, X2, energy_initial, levels=20, cmap='viridis', alpha=0.7)
plt.colorbar(contour1, ax=ax1, label='Energy')
ax1.scatter(samples[:, 0], samples[:, 1], c='black', s=1, alpha=0.9, label='Training Samples')
ax1.set_xlabel('x₁')
ax1.set_ylabel('x₂')
ax1.set_title('Initial Energy Landscape')
ax1.legend()


contour2 = ax2.contourf(X1, X2, energy_final, levels=20, cmap='viridis', alpha=0.7)
plt.colorbar(contour2, ax=ax2, label='Energy')
ax2.scatter(samples[:, 0], samples[:, 1], c='black', s=1, alpha=0.9, label='Training Samples')
ax2.set_xlabel('x₁')
ax2.set_ylabel('x₂')
ax2.set_title('Final Energy Landscape')
ax2.legend()

plt.tight_layout()
plt.show()

# %%
# Get final values from histories
k_lin_final = k_lin_history[-1]
k_duff_final = k_duff_history[-1]
c_lin_final = c_lin_history[-1]
c_optomech_final = c_optomech_history[-1]

# Create tuple of final args in same structure as initial args
args_final = (k_lin_final, k_duff_final, c_lin_final, c_optomech_final)

# Flatten using the same unflatten function from earlier
flattened_args_final, _ = flatten_util.ravel_pytree(args_final)

# %%
# Compare gradient differences with score_matching_loss for different dt values
dt_values = jnp.logspace(-18, 1, 30)  # logarithmically spaced dt values
key = jr.PRNGKey(1)

# Get score matching gradient results (only need to compute once)
score_matching_loss = setup_score_matching_loss(energy_fn, samples)
score_matching_grad = grad_loss(score_matching_loss, flattened_args_final)

# Initialize arrays to store results
n_params = len(flattened_args_final)
relative_differences = jnp.zeros((len(dt_values), n_params))
total_relative_differences = jnp.zeros(len(dt_values))  # New array for total differences

# Loop over dt values
for i, dt in enumerate(dt_values):
    key, subkey = jr.split(key)
    
    # Get CD1 gradient for this dt
    cd1_grad = -CD1_gradient(energy_fn, samples, flattened_args_final, 
                            dt=dt, D=1, key=subkey, num_noise_samples=0)
    
    # Calculate relative difference for each parameter
    rel_diff = jnp.abs(cd1_grad - score_matching_grad) / jnp.abs(score_matching_grad)
    relative_differences = relative_differences.at[i].set(rel_diff)
    
    # Calculate total relative difference using L2 norm
    total_rel_diff = jnp.linalg.norm(cd1_grad - score_matching_grad) / jnp.linalg.norm(score_matching_grad)
    total_relative_differences = total_relative_differences.at[i].set(total_rel_diff)

# Create figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 6))

# First subplot: Individual parameter differences
param_names = ['k_lin_1', 'k_lin_2', 'k_duff_1', 'k_duff_2', 'c_lin', 'c_optomech']
for param_idx in range(n_params):
    ax1.loglog(dt_values, relative_differences[:, param_idx], 'o-', 
               label=param_names[param_idx])

ax1.set_xlabel('dt')
ax1.set_ylabel('Relative Difference')
ax1.set_title('Individual Parameter Relative Differences')
ax1.grid(True)
ax1.legend()

# Second subplot: Total gradient difference
ax2.loglog(dt_values, total_relative_differences, 'o-', color='black', label='Total gradient')
ax2.set_xlabel('dt')
ax2.set_ylabel('Total Relative Difference')
ax2.set_title('Total Gradient Relative Difference (L2 norm)')
ax2.grid(True)
ax2.legend()

plt.tight_layout()
plt.show()

# Print the minimum relative differences
print("\nIndividual parameter minimum differences:")
for param_idx in range(n_params):
    min_idx = jnp.argmin(relative_differences[:, param_idx])
    print(f"\n{param_names[param_idx]}:")
    print(f"Minimum relative difference: {relative_differences[min_idx, param_idx]:.2e}")
    print(f"Optimal dt: {dt_values[min_idx]:.2e}")

print("\nTotal gradient minimum difference:")
min_total_idx = jnp.argmin(total_relative_differences)
print(f"Minimum total relative difference: {total_relative_differences[min_total_idx]:.2e}")
print(f"Optimal dt: {dt_values[min_total_idx]:.2e}")
# Out:
# Individual parameter minimum differences:
#
# k_lin_1:
# Minimum relative difference: 1.00e+00
# Optimal dt: 1.00e-18
#
# k_lin_2:
# Minimum relative difference: 1.00e+00
# Optimal dt: 1.00e-18
#
# k_duff_1:
# Minimum relative difference: 1.00e+00
# Optimal dt: 1.00e-18
#
# k_duff_2:
# Minimum relative difference: 1.00e+00
# Optimal dt: 1.00e-18
#
# c_lin:
# Minimum relative difference: 1.00e+00
# Optimal dt: 1.00e-18
#
# c_optomech:
# Minimum relative difference: 1.00e+00
# Optimal dt: 1.00e-18
#
# Total gradient minimum difference:
# Minimum total relative difference: 1.00e+00
# Optimal dt: 1.00e-18

# %%
# def drift_x_fn(t, state, args):
#     """
#     Drift function for the XY model with effective temperature
#     Args:
#         t: time
#         state: array of phases (shape: N_osc)
#         args: tuple containing (W, h)
#     Returns:
#         Array of phase velocities
#     """
#     W, h = args
#     # Compute force from energy gradient
#     dE_dtheta = jax.grad(XY_energy, argnums=0)(state, W, h)
    
#     # Damping term
#     gamma = 1.0  # Damping coefficient, adjust as needed
    
#     dtheta_dt = -gamma * dE_dtheta
    
#     return dtheta_dt

# def diffusion_x_fn(t, state, args):
#     """
#     Diffusion function for the XY model with effective temperature
#     Args:
#         t: time
#         state: array of phases (shape: N_osc)
#         args: additional arguments
#     Returns:
#         Noise matrix (shape: N_osc x 1)
#     """
#     T_eff = 1.0  # Effective temperature, adjust as needed
#     gamma = 1.0  # Same damping coefficient as in drift
    
#     noise_strength = jnp.sqrt(2 * gamma * T_eff)
#     noise_matrix = jnp.eye(N_osc)
#     return noise_strength * noise_matrix

# %%
# # Calculate characteristic time scales
# gamma = 1.0
# T_eff = 1.0
# J = jnp.max(jnp.abs(W))  # Coupling strength

# tau_relax = 1/gamma
# tau_diffusion = gamma/(2*T_eff)

# print(f"Relaxation time scale: {tau_relax:.2f}")
# print(f"Diffusion time scale: {tau_diffusion:.2f}")

# # Set simulation time accordingly
# t0 = 0.0
# t1 = 100 * max(tau_relax, tau_diffusion)  # Simulate for 10x the longest time scale
# dt0 = min(tau_relax, tau_diffusion) / 10  # Initial time step should be smaller than fastest time scale

# print(f"\nSuggested simulation parameters:")
# print(f"Total time: {t1:.2f}")
# print(f"Initial dt: {dt0:.2f}")

# ts = jnp.linspace(t0, t1, 10000)
# dt = ts[1] - ts[0]

# y0_x = jnp.array([jnp.pi,jnp.pi])

# %%
# # Update shape to match number of oscillators
# w_shape = (N_osc,)  # state is just phases for each oscillator
# brownian_motion = diffrax.VirtualBrownianTree(
#     t0, t1, 1.e-11, w_shape, jr.PRNGKey(0), diffrax.SpaceTimeLevyArea
# )
# terms_x = MultiTerm(ODETerm(drift_x_fn), ControlTerm(diffusion_x_fn, brownian_motion))
# saveat = diffrax.SaveAt(ts=ts)


# # sample 1000 points
# solution_x = diffrax.diffeqsolve(
#     terms_x,
#     solver=diffrax.SRA1(),
#     t0=t0,
#     t1=t1,
#     dt0=dt0,
#     y0=y0_x,
#     args=(),
#     saveat=saveat,
#     progress_meter=diffrax.TqdmProgressMeter(),
#     max_steps=1000000000,
#     stepsize_controller=diffrax.PIDController(rtol=1e-3, atol=1e-6),  # Enable adaptive stepping
# )
# sde_samples_x = solution_x.ys

# %%
# # Calculate number of timesteps corresponding to one relaxation time
# relax_steps = int(1/(gamma * dt))

# # Thin the samples by taking every relax_steps point
# sde_samples_x = solution_x.ys[::relax_steps]
# ts = ts[::relax_steps]

# %%
# # Create figure with a grid of subplots
# fig = plt.figure(figsize=(16, 12))
# gs = plt.GridSpec(2, 2, height_ratios=[2, 1])

# # Top left: Phase trajectories
# ax1 = fig.add_subplot(gs[0, 0])
# # Mod 2π for time trajectories
# ax1.plot(ts, jnp.mod(sde_samples_x[:, 0], 2*jnp.pi), label='θ₁(t)')
# ax1.plot(ts, jnp.mod(sde_samples_x[:, 1], 2*jnp.pi), label='θ₂(t)')
# ax1.set_xlabel('Time')
# ax1.set_ylabel('Phase (rad)')
# ax1.set_title('SDE Simulation: Phase vs Time')
# ax1.grid(True)
# ax1.legend()

# # Top right: Phase space with Energy contour
# ax2 = fig.add_subplot(gs[0, 1])
# contour = ax2.contourf(X1, X2, energy, levels=20, cmap='RdYlBu')
# plt.colorbar(contour, ax=ax2, label='Energy')

# # Mod 2π for phase space trajectory
# wrapped_x = jnp.mod(sde_samples_x, 2*jnp.pi)
# ax2.scatter(wrapped_x[:, 0], wrapped_x[:, 1], c='g', s=1, alpha=0.9999, label='Trajectory')
# ax2.plot(wrapped_x[0, 0], wrapped_x[0, 1], 'go', label='Start', markersize=10)


# ax2.set_xlabel('θ₁')
# ax2.set_ylabel('θ₂')
# ax2.set_title('Phase Space (Torus)')
# ax2.legend()

# # Bottom left: θ₁ histogram (mod 2π)
# ax3 = fig.add_subplot(gs[1, 0])
# ax3.hist(wrapped_x[:, 0], bins=50, density=True, alpha=0.7, label='θ₁ distribution')
# ax3.set_xlabel('θ₁')
# ax3.set_ylabel('Probability Density')
# ax3.grid(True)
# ax3.legend()

# # Bottom right: θ₂ histogram (mod 2π)
# ax4 = fig.add_subplot(gs[1, 1])
# ax4.hist(wrapped_x[:, 1], bins=50, density=True, alpha=0.7, label='θ₂ distribution')
# ax4.set_xlabel('θ₂')
# ax4.set_ylabel('Probability Density')
# ax4.grid(True)
# ax4.legend()

# plt.tight_layout()
# # Add title with parameters
# title = f'T_eff={T_eff}, γ={gamma}'
# plt.suptitle(title, y=1.02)

# plt.show()
