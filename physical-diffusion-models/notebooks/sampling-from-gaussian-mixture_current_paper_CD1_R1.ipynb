# %%
import sys
sys.path.append("..")

from datetime import datetime


import jax
from jax import flatten_util, vmap 
import jax.numpy as jnp
import jax.random as jr
import os
import matplotlib.pyplot as plt
from physical_diffusion_fns.helper_fns import sample_gaussian_mixture,sample_forward_process, smooth_parameters, interpolate_parameters
# NOTE: the score-matching loss factory was renamed to `setup_score_matching_LOSS_per_batch`
# (capital LOSS) in the library refactor. Alias it back to the name used below (cell "Learning").
from physical_diffusion_fns.learning_fns import CD1_gradient, run_optimization, setup_score_matching_LOSS_per_batch as setup_score_matching_loss_per_batch
from physical_diffusion_fns.plotting_fns import plot_energy_and_distributions, plot_parameter_evolution, plot_forward_marginals, visualize_connectivity, plot_parameter_as_fn_of_time, plot_sampels_energy_marginals_for_SGM_vs_ES
from physical_diffusion_fns.network_fns import setup_energy_fn, setup_overdamped_SDE, solve_SDE, setup_duffing_network_analytical_derivatives

jax.config.update("jax_enable_x64", True)

# %% [markdown]
# # Random keys

# %%
master_key  = jax.random.PRNGKey(0)          # single seed
sample_target_key, optimization_key, reverse_sde_key = jr.split(master_key, 3)

# %% [markdown]
# # Generate samples from a Gaussian mixture - the target distribution

# %%
# Parameters
N = 2  # number of dimensions
N_mixgauss = 3  # number of mixture components
n_samples = 10000

# Define mixture weights (must sum to 1)
weights = jnp.array([.6, .4])

# Define means
means = jnp.array([
    [1., 0.5],   # mean of first Gaussian
    [-1., -0.5],  # mean of second Gaussian
])

# Define covariance matrices
covs = jnp.array([
    [[0.001, 0.0],    # covariance of first Gaussian
        [0.0, 0.001]],
    [[0.001, 0.0],   # covariance of second Gaussian
        [0.0, 0.001]],
])
# Generate samples
samples_target = sample_gaussian_mixture(sample_target_key, n_samples, weights, means, covs)

# %% [markdown]
# ### Plot samples and marginal of target distributions

# %%
# Plot samples and marginal distributions
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
fig.suptitle('Target distribution, p_0(x)', fontsize=14)

# First subplot: Scatter plot of samples
ax1.scatter(samples_target[:, 0], samples_target[:, 1], alpha=0.5)
ax1.set_title('Samples')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')

# Second subplot: Combined marginal distributions
ax2.hist(samples_target[:, 0], bins=50, density=True, alpha=0.7, label='X distribution')
ax2.hist(samples_target[:, 1], bins=50, density=True, alpha=0.7, label='Y distribution')

# Add exact marginal Gaussians
x = jnp.linspace(-1.5, 1.5, 1000)
for dim in range(2):
    marginal = jnp.zeros_like(x)
    for w, m, c in zip(weights, means, covs):
        mean = m[dim]
        std = jnp.sqrt(c[dim, dim])
        marginal += w * jnp.exp(-0.5 * ((x - mean) / std) ** 2) / (std * jnp.sqrt(2 * jnp.pi))
    ax2.plot(x, marginal, '--', linewidth=2, label=f'Exact marginal {["X", "Y"][dim]}')

ax2.set_title('Marginal Distributions')
ax2.set_xlabel('Value')
ax2.set_ylabel('Density')
ax2.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Physical system

# %% [markdown]
# ## Network size and topology and temperature

# %%
Temp = .01
N_osc = 2
connectivity = jnp.array([[0, 1]])
num_connections = connectivity.shape[0]
visualize_connectivity(connectivity,grid_size_x=2,grid_size_y=1)

# %% [markdown]
# ## Energy

# %%
k_lin_0 = -1.*jnp.ones(N_osc)
k_duff_0 = jnp.ones(N_osc)
k_6_0 = jnp.ones(N_osc)
c_lin_0 = jnp.zeros(num_connections)
c_optomech_0 = jnp.zeros(num_connections)
c_duff_0 = jnp.zeros(num_connections)
biases_0 = jnp.zeros(N_osc)
params_initial = (k_lin_0, k_duff_0, k_6_0, c_lin_0, c_optomech_0, c_duff_0, biases_0)
params_names = ['k_lin', 'k_duff', 'k_6', 'c_lin', 'c_optomech', 'c_duff', 'biases']
params_flattened_initial, unflatten = flatten_util.ravel_pytree(params_initial)
constraint_indices_k6_self = jnp.arange(2*N_osc,3*N_osc)
constraint_indices = constraint_indices_k6_self

# Set up energy fn
energy_fn = setup_energy_fn(connectivity, unflatten)
# Set up analytical derivatives
gradient_fn, trace_hessian_fn, gradient_wrt_params_fn, trace_hessian_wrt_params_fn = setup_duffing_network_analytical_derivatives(connectivity, unflatten)

# %% [markdown]
# ### Plot initial energy landscape

# %%
# Example usage:
param_list = [params_flattened_initial]
titles = ["Initial Parameters"]

plot_energy_and_distributions(
    energy_fn=energy_fn,
    param_list=param_list,
    samples=samples_target,
    x1_range=(-1, 1),   
    x2_range=(-1, 1),   
    n_points=30,       
    titles=titles,      
    figsize=(16, 8),   
    fontsize=16,        
    sample_stride=1,
    suptitle="Plot initial energy landscape" 
)
# Out:
# Initial Parameters probability distribution total (should be ≈ 1): 1.000000

# %% [markdown]
# # Learning

# %%
# Choose training method
training_method = "CD1"  # Options: "SM" (Score Matching), "CD1" (Contrastive Divergence), "MLE" (Maximum Likelihood)

CD1_dt = 0.0001
CD1_num_noise_samples = 3000
loss_fn_per_batch = setup_score_matching_loss_per_batch(energy_fn)
gradient_fn_per_batch = lambda flattened_args, batch, key_CD1: -CD1_gradient(energy_fn, batch, flattened_args, dt=CD1_dt, D=Temp, key=key_CD1, num_noise_samples=CD1_num_noise_samples)
learning_rate = 0.01*Temp
maximize = False

# %% [markdown]
# #### Optimization parameters and filenames

# %%
# Forward process parameters
n_time_steps = 10
t_forward = 5.
sigma_forward = 1.
exponential_time_pts = False
if exponential_time_pts:
    forward_time_pts = jnp.exp(jnp.linspace(jnp.log(1e-7), jnp.log(t_forward), n_time_steps))
    forward_time_pts = forward_time_pts.at[0].set(0.)
else:
    forward_time_pts = jnp.linspace(0., t_forward, n_time_steps)
# print('forward_time_pts', forward_time_pts)

# Optimization parameters
learning_rate = 0.01
n_epochs = 100000
batch_size = 16*128
window_size=100
tolerance=1e-3
patience=20

# %%
problem_type_folder = f"mixture_of_2_gaussians_in_2d"
physics_folder = f"Network_with_6th_order_local_and_duffing_coupling_energy_trained_w_CD1"
optimization_folder = (
    f"CD1_dt_{CD1_dt}_CD1_num_noise_samples_{CD1_num_noise_samples}_"
    + f"temp_{Temp}_"
    + f"exp_time_pts_{exponential_time_pts}_"
    + f"t_forward_{t_forward}_"
    + f"n_timesteps_{n_time_steps}_"
        f"sigma_forward_{sigma_forward}_"
        f"lr_{learning_rate}_"
        f"epochs_{n_epochs}_"
        f"batch_{batch_size}_"
        f"window_{window_size}_"
        f"tol_{tolerance}_"
        f"patience_{patience}")

# Setup output directories
# here = os.path.dirname(os.path.abspath(__file__))
current_date = datetime.now().strftime("%Y_%m_%d")

base_dir = "../out/"
output_dir = os.path.join(base_dir, current_date, problem_type_folder,physics_folder, optimization_folder)
plot_folder = os.path.join(output_dir, 'aaa_final_plots')

# Create directories if they don't exist
os.makedirs(output_dir, exist_ok=True)
os.makedirs(plot_folder, exist_ok=True)
print(f"Output directory: {output_dir}")
print(f"Plot directory: {plot_folder}")

save_fig = False
# Out:
# Output directory: ../out/2026_07_06/mixture_of_2_gaussians_in_2d/Network_with_6th_order_local_and_duffing_coupling_energy_trained_w_CD1/CD1_dt_0.0001_CD1_num_noise_samples_3000_temp_0.01_exp_time_pts_False_t_forward_5.0_n_timesteps_10_sigma_forward_1.0_lr_0.01_epochs_100000_batch_2048_window_100_tol_0.001_patience_20
# Plot directory: ../out/2026_07_06/mixture_of_2_gaussians_in_2d/Network_with_6th_order_local_and_duffing_coupling_energy_trained_w_CD1/CD1_dt_0.0001_CD1_num_noise_samples_3000_temp_0.01_exp_time_pts_False_t_forward_5.0_n_timesteps_10_sigma_forward_1.0_lr_0.01_epochs_100000_batch_2048_window_100_tol_0.001_patience_20/aaa_final_plots

# %%
params_history_path = f"{output_dir}/params_history.npy"
# if os.path.exists(params_history_path):
#     # Load existing parameters
#     print('Loading existing parameters from', params_history_path)
#     params_history_all_t = jnp.load(params_history_path)
# else:
    # print('No existing parameters found, running optimization')    

# Setup optimization parameters
mask = jnp.ones(params_flattened_initial.shape[0])

# Plotting parameters
plot_steps = True  # Flag to control whether to plot during optimization
plot_slice = 1     # Plot every nth step

params_history_all_t = []
current_params = params_flattened_initial

# Loop over time points
for t_idx, t_curr in enumerate(forward_time_pts):
    print(f"t_idx: {t_idx}, t_curr: {t_curr}")
    optimization_key, optimization_subkey = jr.split(optimization_key)
    
    if t_idx == 0:
        samples_0 = sample_forward_process(t_forward, n_samples, D=1, sigma_final=sigma_forward, samples0=samples_target, key=optimization_key)
        plot_forward_marginals(samples_0, t_forward, sigma_forward, beta=1.0, path=output_dir, save_fig=save_fig, fontsize=16, plot_show=True)
    
    sampler = lambda key: sample_forward_process(
            t_curr, n_samples = batch_size, D=Temp, sigma_final=sigma_forward, samples0=samples_target, key=key, beta= 1
        )
    
    # Perform optimization starting from previous best parameters
    params_history, loss_history, current_params, best_loss, best_epoch = run_optimization(
        loss_fn_per_batch=loss_fn_per_batch,
        params_initial=current_params,
        sampler=sampler,
        mask=mask,
        gradient_fn_per_batch=gradient_fn_per_batch,
        key=optimization_subkey,
        learning_rate=learning_rate,
        n_epochs=n_epochs,
        maximize=maximize,
        window_size=window_size,
        tolerance=tolerance,
        patience=patience,
        constraint_indices=constraint_indices
    )
    
    params_history_all_t.append(current_params)
    
    if plot_steps:
        if t_idx % plot_slice == 0:
            # Plot optimization progress
            plot_parameter_evolution(
                params_history=params_history,
                loss_history=loss_history,
                best_params=current_params,
                best_loss=best_loss,
                best_idx=best_epoch,
                time = t_curr,
                time_index = t_idx,
                unflatten=unflatten,
                N_osc=N_osc,
                # slicing=10,
                title=f"{training_method} (t = {t_curr:.3f})",
                maximize=maximize,
                labels_on=True,
                save_fig=save_fig,
                path=output_dir,
                param_names=params_names,
                plot_show=True
            )
        
# Convert params_history_all_t to array for easier analysis
params_history_all_t = jnp.array(params_history_all_t)
jnp.save(f"{output_dir}/params_history.npy", params_history_all_t)

print('Optimization complete; saved parameters to', output_dir)
# Out:
# t_idx: 0, t_curr: 0.0
# Epoch 0 - Loss: -6.5017 - Best Loss: -6.5017 (Epoch 0)
# Epoch 100 - Loss: -4.5906 - Best Loss: -6.5017 (Epoch 0)
# Epoch 200 - Loss: -5.5583 - Best Loss: -6.5017 (Epoch 0)
# Epoch 300 - Loss: -6.5694 - Best Loss: -6.5744 (Epoch 299)
# Epoch 400 - Loss: -7.5401 - Best Loss: -7.5711 (Epoch 399)
# Epoch 500 - Loss: -8.4459 - Best Loss: -8.4814 (Epoch 498)
# Epoch 600 - Loss: -9.2870 - Best Loss: -9.2901 (Epoch 598)
# Epoch 700 - Loss: -10.0269 - Best Loss: -10.0382 (Epoch 694)
# Epoch 800 - Loss: -10.6547 - Best Loss: -10.6547 (Epoch 800)
# Epoch 900 - Loss: -11.2426 - Best Loss: -11.2434 (Epoch 896)
# Epoch 1000 - Loss: -11.6678 - Best Loss: -11.7175 (Epoch 988)
# Epoch 1100 - Loss: -12.1517 - Best Loss: -12.1583 (Epoch 1096)
# Epoch 1200 - Loss: -12.5650 - Best Loss: -12.5650 (Epoch 1200)
# Epoch 1300 - Loss: -12.9099 - Best Loss: -12.9273 (Epoch 1298)
# Epoch 1400 - Loss: -13.2070 - Best Loss: -13.2539 (Epoch 1397)
# Epoch 1500 - Loss: -13.4725 - Best Loss: -13.5305 (Epoch 1497)
# Epoch 1600 - Loss: -13.7056 - Best Loss: -13.7458 (Epoch 1573)
# Epoch 1700 - Loss: -13.9816 - Best Loss: -13.9816 (Epoch 1700)
# Epoch 1800 - Loss: -14.1863 - Best Loss: -14.1922 (Epoch 1797)
# Epoch 1900 - Loss: -14.3593 - Best Loss: -14.3593 (Epoch 1900)
# Epoch 2000 - Loss: -14.4672 - Best Loss: -14.5148 (Epoch 1998)
# Convergence reached at epoch 2000. Stopping optimization.
# Best loss: -1.4515e+01
# Found at epoch: 1998
# t_idx: 1, t_curr: 0.5555555555555556
# Epoch 0 - Loss: -2.0832 - Best Loss: -2.0832 (Epoch 0)
# Epoch 100 - Loss: -5.4985 - Best Loss: -5.5653 (Epoch 92)
# Epoch 200 - Loss: -4.8308 - Best Loss: -5.6145 (Epoch 113)
# Epoch 300 - Loss: -4.1072 - Best Loss: -5.6145 (Epoch 113)
# Epoch 400 - Loss: -3.6254 - Best Loss: -5.6145 (Epoch 113)
# Epoch 500 - Loss: -3.3213 - Best Loss: -5.6145 (Epoch 113)
# Epoch 600 - Loss: -3.1119 - Best Loss: -5.6145 (Epoch 113)
# Epoch 700 - Loss: -3.0056 - Best Loss: -5.6145 (Epoch 113)
# Epoch 800 - Loss: -2.9147 - Best Loss: -5.6145 (Epoch 113)
# Epoch 900 - Loss: -2.8656 - Best Loss: -5.6145 (Epoch 113)
# Epoch 1000 - Loss: -2.7961 - Best Loss: -5.6145 (Epoch 113)
# Epoch 1100 - Loss: -2.7940 - Best Loss: -5.6145 (Epoch 113)
# Epoch 1200 - Loss: -2.7627 - Best Loss: -5.6145 (Epoch 113)
# Epoch 1300 - Loss: -2.7146 - Best Loss: -5.6145 (Epoch 113)
# Epoch 1400 - Loss: -2.6826 - Best Loss: -5.6145 (Epoch 113)
# Epoch 1500 - Loss: -2.6626 - Best Loss: -5.6145 (Epoch 113)
# Epoch 1600 - Loss: -2.6677 - Best Loss: -5.6145 (Epoch 113)
# Epoch 1700 - Loss: -2.6278 - Best Loss: -5.6145 (Epoch 113)
# Epoch 1800 - Loss: -2.6442 - Best Loss: -5.6145 (Epoch 113)
# Epoch 1900 - Loss: -2.6027 - Best Loss: -5.6145 (Epoch 113)
# Epoch 2000 - Loss: -2.6038 - Best Loss: -5.6145 (Epoch 113)
# Convergence reached at epoch 2000. Stopping optimization.
# Best loss: -5.6145e+00
# Found at epoch: 113
# t_idx: 2, t_curr: 1.1111111111111112
# Epoch 0 - Loss: -2.2187 - Best Loss: -2.2187 (Epoch 0)
# Epoch 100 - Loss: -2.0683 - Best Loss: -2.6324 (Epoch 11)
# Epoch 200 - Loss: -1.7973 - Best Loss: -2.6324 (Epoch 11)
# Epoch 300 - Loss: -1.7135 - Best Loss: -2.6324 (Epoch 11)
# Epoch 400 - Loss: -1.7312 - Best Loss: -2.6324 (Epoch 11)
# Epoch 500 - Loss: -1.6819 - Best Loss: -2.6324 (Epoch 11)
# Epoch 600 - Loss: -1.6950 - Best Loss: -2.6324 (Epoch 11)
# Epoch 700 - Loss: -1.6593 - Best Loss: -2.6324 (Epoch 11)
# Epoch 800 - Loss: -1.6969 - Best Loss: -2.6324 (Epoch 11)
# Epoch 900 - Loss: -1.6242 - Best Loss: -2.6324 (Epoch 11)
# Epoch 1000 - Loss: -1.7178 - Best Loss: -2.6324 (Epoch 11)
# Epoch 1100 - Loss: -1.6683 - Best Loss: -2.6324 (Epoch 11)
# Epoch 1200 - Loss: -1.6763 - Best Loss: -2.6324 (Epoch 11)
# Epoch 1300 - Loss: -1.6633 - Best Loss: -2.6324 (Epoch 11)
# Epoch 1400 - Loss: -1.6704 - Best Loss: -2.6324 (Epoch 11)
# Epoch 1500 - Loss: -1.6734 - Best Loss: -2.6324 (Epoch 11)
# Epoch 1600 - Loss: -1.6581 - Best Loss: -2.6324 (Epoch 11)
# Epoch 1700 - Loss: -1.7001 - Best Loss: -2.6324 (Epoch 11)
# Epoch 1800 - Loss: -1.6521 - Best Loss: -2.6324 (Epoch 11)
# Epoch 1900 - Loss: -1.6507 - Best Loss: -2.6324 (Epoch 11)
# Epoch 2000 - Loss: -1.6607 - Best Loss: -2.6324 (Epoch 11)
# Convergence reached at epoch 2000. Stopping optimization.
# Best loss: -2.6324e+00
# Found at epoch: 11
# t_idx: 3, t_curr: 1.6666666666666667
# Epoch 0 - Loss: -1.7473 - Best Loss: -1.7473 (Epoch 0)
# Epoch 100 - Loss: -1.3241 - Best Loss: -1.7473 (Epoch 0)
# Epoch 200 - Loss: -1.4319 - Best Loss: -1.7473 (Epoch 0)
# Epoch 300 - Loss: -1.3858 - Best Loss: -1.7473 (Epoch 0)
# Epoch 400 - Loss: -1.3864 - Best Loss: -1.7473 (Epoch 0)
# Epoch 500 - Loss: -1.4235 - Best Loss: -1.7473 (Epoch 0)
# Epoch 600 - Loss: -1.3866 - Best Loss: -1.7473 (Epoch 0)
# Epoch 700 - Loss: -1.3954 - Best Loss: -1.7473 (Epoch 0)
# Epoch 800 - Loss: -1.4527 - Best Loss: -1.7473 (Epoch 0)
# Epoch 900 - Loss: -1.3473 - Best Loss: -1.7473 (Epoch 0)
# Epoch 1000 - Loss: -1.4354 - Best Loss: -1.7473 (Epoch 0)
# Epoch 1100 - Loss: -1.3820 - Best Loss: -1.7473 (Epoch 0)
# Epoch 1200 - Loss: -1.4168 - Best Loss: -1.7473 (Epoch 0)
# Epoch 1300 - Loss: -1.3929 - Best Loss: -1.7473 (Epoch 0)
# Epoch 1400 - Loss: -1.4457 - Best Loss: -1.7473 (Epoch 0)
# Epoch 1500 - Loss: -1.4039 - Best Loss: -1.7473 (Epoch 0)
# Epoch 1600 - Loss: -1.4086 - Best Loss: -1.7473 (Epoch 0)
# Epoch 1700 - Loss: -1.3926 - Best Loss: -1.7473 (Epoch 0)
# Epoch 1800 - Loss: -1.4259 - Best Loss: -1.7473 (Epoch 0)
# Epoch 1900 - Loss: -1.3956 - Best Loss: -1.7473 (Epoch 0)
# Epoch 2000 - Loss: -1.3816 - Best Loss: -1.7473 (Epoch 0)
# Convergence reached at epoch 2000. Stopping optimization.
# Best loss: -1.7473e+00
# Found at epoch: 0
# t_idx: 4, t_curr: 2.2222222222222223
# Epoch 0 - Loss: -1.4478 - Best Loss: -1.4478 (Epoch 0)
# Epoch 100 - Loss: -1.1932 - Best Loss: -1.4478 (Epoch 0)
# Epoch 200 - Loss: -1.3270 - Best Loss: -1.4478 (Epoch 0)
# Epoch 300 - Loss: -1.4291 - Best Loss: -1.4686 (Epoch 234)
# Epoch 400 - Loss: -1.4331 - Best Loss: -1.5018 (Epoch 359)
# Epoch 500 - Loss: -1.4009 - Best Loss: -1.5040 (Epoch 454)
# Epoch 600 - Loss: -1.4730 - Best Loss: -1.5254 (Epoch 567)
# Epoch 700 - Loss: -1.4688 - Best Loss: -1.5254 (Epoch 567)
# Epoch 800 - Loss: -1.4463 - Best Loss: -1.5254 (Epoch 567)
# Epoch 900 - Loss: -1.4853 - Best Loss: -1.5254 (Epoch 567)
# Epoch 1000 - Loss: -1.4829 - Best Loss: -1.5254 (Epoch 567)
# Epoch 1100 - Loss: -1.4528 - Best Loss: -1.5254 (Epoch 567)
# Epoch 1200 - Loss: -1.4782 - Best Loss: -1.5269 (Epoch 1185)
# Epoch 1300 - Loss: -1.4944 - Best Loss: -1.5269 (Epoch 1185)
# Epoch 1400 - Loss: -1.4832 - Best Loss: -1.5269 (Epoch 1185)
# Epoch 1500 - Loss: -1.4942 - Best Loss: -1.5269 (Epoch 1185)
# Epoch 1600 - Loss: -1.4713 - Best Loss: -1.5269 (Epoch 1185)
# Epoch 1700 - Loss: -1.4608 - Best Loss: -1.5269 (Epoch 1185)
# Epoch 1800 - Loss: -1.4729 - Best Loss: -1.5269 (Epoch 1185)
# Epoch 1900 - Loss: -1.4743 - Best Loss: -1.5269 (Epoch 1185)
# Epoch 2000 - Loss: -1.4766 - Best Loss: -1.5269 (Epoch 1185)
# Convergence reached at epoch 2000. Stopping optimization.
# Best loss: -1.5269e+00
# Found at epoch: 1185
# t_idx: 5, t_curr: 2.7777777777777777
# Epoch 0 - Loss: -1.4390 - Best Loss: -1.4390 (Epoch 0)
# Epoch 100 - Loss: -1.6468 - Best Loss: -1.7729 (Epoch 60)
# Epoch 200 - Loss: -1.6990 - Best Loss: -1.7996 (Epoch 166)
# Epoch 300 - Loss: -1.6579 - Best Loss: -1.7996 (Epoch 166)
# Epoch 400 - Loss: -1.7040 - Best Loss: -1.7996 (Epoch 166)
# Epoch 500 - Loss: -1.7130 - Best Loss: -1.7996 (Epoch 166)
# Epoch 600 - Loss: -1.7493 - Best Loss: -1.7996 (Epoch 166)
# Epoch 700 - Loss: -1.6553 - Best Loss: -1.7996 (Epoch 166)
# Epoch 800 - Loss: -1.6635 - Best Loss: -1.7996 (Epoch 166)
# Epoch 900 - Loss: -1.6622 - Best Loss: -1.7996 (Epoch 166)
# Epoch 1000 - Loss: -1.6666 - Best Loss: -1.7996 (Epoch 166)
# Epoch 1100 - Loss: -1.6823 - Best Loss: -1.7996 (Epoch 166)
# Epoch 1200 - Loss: -1.7370 - Best Loss: -1.7996 (Epoch 166)
# Epoch 1300 - Loss: -1.7044 - Best Loss: -1.7996 (Epoch 166)
# Epoch 1400 - Loss: -1.7014 - Best Loss: -1.7996 (Epoch 166)
# Epoch 1500 - Loss: -1.6885 - Best Loss: -1.7996 (Epoch 166)
# Epoch 1600 - Loss: -1.7424 - Best Loss: -1.7996 (Epoch 166)
# Epoch 1700 - Loss: -1.7259 - Best Loss: -1.7996 (Epoch 166)
# Epoch 1800 - Loss: -1.6982 - Best Loss: -1.7996 (Epoch 166)
# Epoch 1900 - Loss: -1.6818 - Best Loss: -1.7996 (Epoch 166)
# Epoch 2000 - Loss: -1.6762 - Best Loss: -1.7996 (Epoch 166)
# Convergence reached at epoch 2000. Stopping optimization.
# Best loss: -1.7996e+00
# Found at epoch: 166
# t_idx: 6, t_curr: 3.3333333333333335
# Epoch 0 - Loss: -1.7654 - Best Loss: -1.7654 (Epoch 0)
# Epoch 100 - Loss: -1.8831 - Best Loss: -1.9680 (Epoch 47)
# Epoch 200 - Loss: -1.8638 - Best Loss: -1.9680 (Epoch 47)
# Epoch 300 - Loss: -1.9006 - Best Loss: -1.9680 (Epoch 47)
# Epoch 400 - Loss: -1.9757 - Best Loss: -1.9918 (Epoch 398)
# Epoch 500 - Loss: -1.8770 - Best Loss: -1.9918 (Epoch 398)
# Epoch 600 - Loss: -1.9038 - Best Loss: -1.9918 (Epoch 398)
# Epoch 700 - Loss: -1.8688 - Best Loss: -1.9918 (Epoch 398)
# Epoch 800 - Loss: -1.8846 - Best Loss: -1.9918 (Epoch 398)
# Epoch 900 - Loss: -1.8818 - Best Loss: -1.9918 (Epoch 398)
# Epoch 1000 - Loss: -1.8766 - Best Loss: -1.9918 (Epoch 398)
# Epoch 1100 - Loss: -1.8472 - Best Loss: -1.9918 (Epoch 398)
# Epoch 1200 - Loss: -1.9311 - Best Loss: -1.9918 (Epoch 398)
# Epoch 1300 - Loss: -1.8415 - Best Loss: -1.9918 (Epoch 398)
# Epoch 1400 - Loss: -1.8492 - Best Loss: -1.9918 (Epoch 398)
# Epoch 1500 - Loss: -1.8686 - Best Loss: -1.9918 (Epoch 398)
# Epoch 1600 - Loss: -1.8554 - Best Loss: -1.9918 (Epoch 398)
# Epoch 1700 - Loss: -1.8916 - Best Loss: -1.9918 (Epoch 398)
# Epoch 1800 - Loss: -1.8675 - Best Loss: -1.9918 (Epoch 398)
# Epoch 1900 - Loss: -1.8446 - Best Loss: -1.9918 (Epoch 398)
# Epoch 2000 - Loss: -1.8748 - Best Loss: -1.9918 (Epoch 398)
# Convergence reached at epoch 2000. Stopping optimization.
# Best loss: -1.9918e+00
# Found at epoch: 398
# t_idx: 7, t_curr: 3.8888888888888893
# Epoch 0 - Loss: -1.9806 - Best Loss: -1.9806 (Epoch 0)
# Epoch 100 - Loss: -1.9625 - Best Loss: -2.0099 (Epoch 86)
# Epoch 200 - Loss: -1.9362 - Best Loss: -2.0099 (Epoch 86)
# Epoch 300 - Loss: -1.9651 - Best Loss: -2.0594 (Epoch 239)
# Epoch 400 - Loss: -1.9752 - Best Loss: -2.0594 (Epoch 239)
# Epoch 500 - Loss: -1.8820 - Best Loss: -2.0594 (Epoch 239)
# Epoch 600 - Loss: -1.9641 - Best Loss: -2.0594 (Epoch 239)
# Epoch 700 - Loss: -1.9577 - Best Loss: -2.0594 (Epoch 239)
# Epoch 800 - Loss: -1.9517 - Best Loss: -2.0594 (Epoch 239)
# Epoch 900 - Loss: -1.9344 - Best Loss: -2.0594 (Epoch 239)
# Epoch 1000 - Loss: -1.9627 - Best Loss: -2.0594 (Epoch 239)
# Epoch 1100 - Loss: -1.9381 - Best Loss: -2.0594 (Epoch 239)
# Epoch 1200 - Loss: -1.9232 - Best Loss: -2.0594 (Epoch 239)
# Epoch 1300 - Loss: -1.9256 - Best Loss: -2.0594 (Epoch 239)
# Epoch 1400 - Loss: -1.8945 - Best Loss: -2.0594 (Epoch 239)
# Epoch 1500 - Loss: -1.9309 - Best Loss: -2.0594 (Epoch 239)
# Epoch 1600 - Loss: -1.9393 - Best Loss: -2.0594 (Epoch 239)
# Epoch 1700 - Loss: -1.9488 - Best Loss: -2.0594 (Epoch 239)
# Epoch 1800 - Loss: -1.9073 - Best Loss: -2.0594 (Epoch 239)
# Epoch 1900 - Loss: -1.9560 - Best Loss: -2.0594 (Epoch 239)
# Epoch 2000 - Loss: -1.9417 - Best Loss: -2.0594 (Epoch 239)
# Convergence reached at epoch 2000. Stopping optimization.
# Best loss: -2.0594e+00
# Found at epoch: 239
# t_idx: 8, t_curr: 4.444444444444445
# Epoch 0 - Loss: -2.0542 - Best Loss: -2.0542 (Epoch 0)
# Epoch 100 - Loss: -1.9746 - Best Loss: -2.0924 (Epoch 5)
# Epoch 200 - Loss: -2.0131 - Best Loss: -2.0924 (Epoch 5)
# Epoch 300 - Loss: -1.9750 - Best Loss: -2.0924 (Epoch 5)
# Epoch 400 - Loss: -1.9637 - Best Loss: -2.0924 (Epoch 5)
# Epoch 500 - Loss: -1.9434 - Best Loss: -2.0924 (Epoch 5)
# Epoch 600 - Loss: -1.9624 - Best Loss: -2.0924 (Epoch 5)
# Epoch 700 - Loss: -2.0170 - Best Loss: -2.0924 (Epoch 5)
# Epoch 800 - Loss: -1.9205 - Best Loss: -2.0924 (Epoch 5)
# Epoch 900 - Loss: -1.9570 - Best Loss: -2.0924 (Epoch 5)
# Epoch 1000 - Loss: -1.9481 - Best Loss: -2.0924 (Epoch 5)
# Epoch 1100 - Loss: -2.0176 - Best Loss: -2.0924 (Epoch 5)
# Epoch 1200 - Loss: -1.9069 - Best Loss: -2.0924 (Epoch 5)
# Epoch 1300 - Loss: -1.9193 - Best Loss: -2.0924 (Epoch 5)
# Epoch 1400 - Loss: -1.9533 - Best Loss: -2.0924 (Epoch 5)
# Epoch 1500 - Loss: -1.9586 - Best Loss: -2.0924 (Epoch 5)
# Epoch 1600 - Loss: -1.9777 - Best Loss: -2.0924 (Epoch 5)
# Epoch 1700 - Loss: -1.9808 - Best Loss: -2.0924 (Epoch 5)
# Epoch 1800 - Loss: -1.9770 - Best Loss: -2.0924 (Epoch 5)
# Epoch 1900 - Loss: -1.9416 - Best Loss: -2.0924 (Epoch 5)
# Epoch 2000 - Loss: -1.9676 - Best Loss: -2.0924 (Epoch 5)
# Convergence reached at epoch 2000. Stopping optimization.
# Best loss: -2.0924e+00
# Found at epoch: 5
# t_idx: 9, t_curr: 5.0
# Epoch 0 - Loss: -2.0864 - Best Loss: -2.0864 (Epoch 0)
# Epoch 100 - Loss: -2.0322 - Best Loss: -2.1107 (Epoch 21)
# Epoch 200 - Loss: -2.0178 - Best Loss: -2.1107 (Epoch 21)
# Epoch 300 - Loss: -1.9729 - Best Loss: -2.1107 (Epoch 21)
# Epoch 400 - Loss: -1.9476 - Best Loss: -2.1107 (Epoch 21)
# Epoch 500 - Loss: -1.9693 - Best Loss: -2.1107 (Epoch 21)
# Epoch 600 - Loss: -2.0014 - Best Loss: -2.1107 (Epoch 21)
# Epoch 700 - Loss: -1.9987 - Best Loss: -2.1107 (Epoch 21)
# Epoch 800 - Loss: -1.9868 - Best Loss: -2.1107 (Epoch 21)
# Epoch 900 - Loss: -1.9884 - Best Loss: -2.1107 (Epoch 21)
# Epoch 1000 - Loss: -1.9297 - Best Loss: -2.1107 (Epoch 21)
# Epoch 1100 - Loss: -2.0010 - Best Loss: -2.1107 (Epoch 21)
# Epoch 1200 - Loss: -2.0018 - Best Loss: -2.1107 (Epoch 21)
# Epoch 1300 - Loss: -2.0289 - Best Loss: -2.1107 (Epoch 21)
# Epoch 1400 - Loss: -1.9960 - Best Loss: -2.1107 (Epoch 21)
# Epoch 1500 - Loss: -1.9191 - Best Loss: -2.1107 (Epoch 21)
# Epoch 1600 - Loss: -1.9707 - Best Loss: -2.1107 (Epoch 21)
# Epoch 1700 - Loss: -2.0187 - Best Loss: -2.1107 (Epoch 21)
# Epoch 1800 - Loss: -1.9987 - Best Loss: -2.1107 (Epoch 21)
# Epoch 1900 - Loss: -2.0052 - Best Loss: -2.1107 (Epoch 21)
# Epoch 2000 - Loss: -1.9908 - Best Loss: -2.1107 (Epoch 21)
# Convergence reached at epoch 2000. Stopping optimization.
# Best loss: -2.1107e+00
# Found at epoch: 21
# Optimization complete; saved parameters to ../out/2026_07_06/mixture_of_2_gaussians_in_2d/Network_with_6th_order_local_and_duffing_coupling_energy_trained_w_CD1/CD1_dt_0.0001_CD1_num_noise_samples_3000_temp_0.01_exp_time_pts_False_t_forward_5.0_n_timesteps_10_sigma_forward_1.0_lr_0.01_epochs_100000_batch_2048_window_100_tol_0.001_patience_20

# %% [markdown]
# ### Smoothen and interpolate parameter evolution

# %%
use_smoothed_params = False
smoothed_params = smooth_parameters(params_history_all_t, window_lengths=[10] * params_history_all_t.shape[1], poly_orders=[3] * params_history_all_t.shape[1])

# Get interpolator functions
params_interpolator_smoothed = interpolate_parameters(smoothed_params, forward_time_pts)
params_interpolator_non_smoothed = interpolate_parameters(params_history_all_t, forward_time_pts)

# Then interpolate the smoothed parameters
time_eval = jnp.linspace(forward_time_pts[0], forward_time_pts[-1], 200)
interpolated_params_smoothed = params_interpolator_smoothed(time_eval)
interpolated_params_non_smoothed = params_interpolator_non_smoothed(time_eval)

plot_parameter_as_fn_of_time(params_names, forward_time_pts, forward_time_pts, params_history_all_t, params_interpolator_smoothed, unflatten, N_osc, save_fig=True, path=plot_folder, log_scale=False,plot_show=True)

if use_smoothed_params:
    params_interpolator = params_interpolator_smoothed
else:
    params_interpolator = params_interpolator_non_smoothed

# %% [markdown]
# ### Run reverse SDE:

# %%
forward_params = jnp.zeros_like(params_flattened_initial)
forward_params = forward_params.at[0:N_osc].set(1.)
if Temp == 0.0:
    params_interpolator_reverse_plus_linear = lambda t: params_interpolator(t_forward - t) - 1 / sigma_forward**2 * forward_params
elif training_method == "CD1" or training_method == "SM_local":
    params_interpolator_reverse_plus_linear = lambda t: 2*params_interpolator(t_forward - t) - 1 / sigma_forward**2 * forward_params
else: 
    params_interpolator_reverse_plus_linear = lambda t: 2*Temp*params_interpolator(t_forward - t) - 1 / sigma_forward**2 * forward_params


# Setup SDE functions
drift_fn, diffusion_fn = setup_overdamped_SDE(energy_fn, params_interpolator_reverse_plus_linear, N_osc, time_dependent_parms=True, Temp=Temp)

t0 = 0.0
t1 = t_forward
ts = jnp.linspace(t0, t1, 100)
dt0 = 0.00000001
atol = 1e-2
rtol = 1e-3

n_trajectories = 2000

# Generate multiple initial states
reverse_sde_key, subkey_initial = jr.split(reverse_sde_key)
initial_states = sample_forward_process(t_forward, n_trajectories, sigma_final=sigma_forward, D=Temp, samples0=samples_target, key=subkey_initial)

# Generate a key for each initial condition
keys_brownian = jr.split(reverse_sde_key, n_trajectories)

# Vectorize solve_SDE across both initial states and keys
vectorized_solve_SDE = vmap(
    lambda init_state, key_b: solve_SDE(
        drift_fn,
        diffusion_fn,
        init_state,
        key_b,
        t0,
        t1,
        ts.shape[0],
        dt0,
        rtol=rtol,
        atol=atol
    ),
    in_axes=(0, 0)
)

# Run SDE for all initial states at once
solutions = vectorized_solve_SDE(initial_states, keys_brownian)
all_trajectories = solutions.ys
final_states = all_trajectories[:, -1, :]
# Out:
# /usr/local/lib/python3.10/dist-packages/jax/_src/core.py:701: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/jax/_src/core.py:701: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/jax/_src/core.py:701: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/jax/_src/core.py:701: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# 100.00%|##########| [00:00<00:00, 268.90%/s]

# %% [markdown]
# ### Run equillibirum SDE

# %%
t1 = 0.1*n_trajectories*t_forward
sde_samples_direct_path = f"{output_dir}/sde_samples_direct_simT_{t1}.npy"
if os.path.exists(sde_samples_direct_path):
    # Load existing parameters
    print('Loading existing equilibrium trajectory', sde_samples_direct_path)
    sde_samples_direct = jnp.load(sde_samples_direct_path)
else:
    print('No existing equilibrium trajectory found, running optimization')   
    drift_fn, diffusion_fn = setup_overdamped_SDE(energy_fn, params_interpolator(0), N_osc, Temp=Temp, time_dependent_parms=False)
    t0 = 0.0
    ts = jnp.linspace(t0, t1, n_trajectories)
    dt0 = ts[1] - ts[0]
    initial_state = jnp.array([-.0,0.])

    reverse_sde_key, subkey_direct = jr.split(reverse_sde_key)
    solution_direct = solve_SDE(drift_fn, diffusion_fn, initial_state,subkey_direct, t0, t1, ts.shape[0], dt0,atol=atol,rtol=rtol)
    sde_samples_direct = solution_direct.ys
    jnp.save(f"{output_dir}/sde_samples_direct.npy", sde_samples_direct)
# Out:
# No existing equilibrium trajectory found, running optimization
# /usr/local/lib/python3.10/dist-packages/jax/_src/core.py:701: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/jax/_src/core.py:701: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/jax/_src/core.py:701: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/jax/_src/core.py:701: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
#
# 0.00%|          | [00:00<?, ?%/s]
# 0.00%|          | [00:00<?, ?%/s]
# 0.15%|          | [00:00<00:48,  2.07%/s]
# 0.23%|          | [00:00<01:01,  1.63%/s]
# 0.23%|          | [00:00<01:01,  1.63%/s]
# 0.33%|          | [00:00<01:01,  1.63%/s]
# 0.41%|          | [00:00<01:08,  1.46%/s]
# 0.41%|          | [00:00<01:08,  1.46%/s]
# 0.50%|          | [00:00<01:08,  1.46%/s]
# 0.58%|          | [00:00<01:11,  1.39%/s]
# 0.58%|          | [00:00<01:11,  1.39%/s]
# 0.65%|          | [00:00<01:11,  1.39%/s]
# 0.73%|          | [00:00<01:16,  1.30%/s]
# 0.73%|          | [00:00<01:16,  1.30%/s]
# 0.80%|          | [00:00<01:16,  1.30%/s]
# 0.88%|          | [00:00<01:19,  1.25%/s]
# 0.88%|          | [00:00<01:19,  1.25%/s]
# 0.95%|          | [00:00<01:19,  1.25%/s]
# 1.03%|1         | [00:00<01:21,  1.21%/s]
# 1.03%|1         | [00:00<01:21,  1.21%/s]
# 1.12%|1         | [00:00<01:21,  1.21%/s]
# 1.18%|1         | [00:00<01:22,  1.19%/s]
# 1.18%|1         | [00:00<01:22,  1.19%/s]
# 1.23%|1         | [00:00<01:22,  1.19%/s]
# 1.31%|1         | [00:01<01:27,  1.13%/s]
# 1.31%|1         | [00:01<01:27,  1.13%/s]
# 1.37%|1         | [00:01<01:27,  1.13%/s]
# 1.45%|1         | [00:01<01:28,  1.11%/s]
# 1.45%|1         | [00:01<01:28,  1.11%/s]
# 1.52%|1         | [00:01<01:28,  1.11%/s]
# 1.63%|1         | [00:01<01:22,  1.19%/s]
# 1.63%|1         | [00:01<01:22,  1.19%/s]
# 1.69%|1         | [00:01<01:22,  1.19%/s]
# 1.77%|1         | [00:01<01:25,  1.15%/s]
# 1.77%|1         | [00:01<01:25,  1.15%/s]
# 1.86%|1         | [00:01<01:25,  1.15%/s]
# 1.92%|1         | [00:01<01:25,  1.15%/s]
# 1.92%|1         | [00:01<01:25,  1.15%/s]
# 1.98%|1         | [00:01<01:25,  1.15%/s]
# 2.06%|2         | [00:01<01:26,  1.13%/s]
# 2.06%|2         | [00:01<01:26,  1.13%/s]
# 2.13%|2         | [00:01<01:26,  1.13%/s]
# 2.19%|2         | [00:01<01:30,  1.09%/s]
# 2.19%|2         | [00:01<01:30,  1.09%/s]
# 2.27%|2         | [00:01<01:30,  1.09%/s]
# 2.34%|2         | [00:01<01:28,  1.10%/s]
# 2.34%|2         | [00:01<01:28,  1.10%/s]
# 2.41%|2         | [00:02<01:28,  1.10%/s]
# 2.47%|2         | [00:02<01:31,  1.07%/s]
# 2.47%|2         | [00:02<01:31,  1.07%/s]
# 2.56%|2         | [00:02<01:30,  1.07%/s]
# 2.61%|2         | [00:02<01:30,  1.07%/s]
# 2.61%|2         | [00:02<01:30,  1.07%/s]
# 2.68%|2         | [00:02<01:30,  1.07%/s]
# 2.78%|2         | [00:02<01:25,  1.14%/s]
# 2.78%|2         | [00:02<01:25,  1.14%/s]
# 2.85%|2         | [00:02<01:24,  1.14%/s]
# 2.92%|2         | [00:02<01:26,  1.12%/s]
# 2.92%|2         | [00:02<01:26,  1.12%/s]
# 2.97%|2         | [00:02<01:26,  1.12%/s]
# 3.06%|3         | [00:02<01:27,  1.10%/s]
# 3.06%|3         | [00:02<01:27,  1.10%/s]
# 3.12%|3         | [00:02<01:27,  1.10%/s]
# 3.19%|3         | [00:02<01:30,  1.07%/s]
# 3.19%|3         | [00:02<01:30,  1.07%/s]
# 3.27%|3         | [00:02<01:30,  1.07%/s]
# 3.36%|3         | [00:02<01:24,  1.14%/s]
# 3.36%|3         | [00:02<01:24,  1.14%/s]
# 3.44%|3         | [00:02<01:24,  1.14%/s]
# 3.52%|3         | [00:03<01:22,  1.17%/s]
# 3.52%|3         | [00:03<01:22,  1.17%/s]
# 3.59%|3         | [00:03<01:22,  1.17%/s]
# 3.68%|3         | [00:03<01:21,  1.19%/s]
# 3.68%|3         | [00:03<01:21,  1.19%/s]
# 3.77%|3         | [00:03<01:21,  1.19%/s]
# 3.82%|3         | [00:03<01:23,  1.15%/s]
# 3.82%|3         | [00:03<01:23,  1.15%/s]
# 3.92%|3         | [00:03<01:23,  1.15%/s]
# 4.00%|4         | [00:03<01:18,  1.22%/s]
# 4.00%|4         | [00:03<01:18,  1.22%/s]
# 4.08%|4         | [00:03<01:18,  1.22%/s]
# 4.17%|4         | [00:03<01:17,  1.24%/s]
# 4.17%|4         | [00:03<01:17,  1.24%/s]
# 4.24%|4         | [00:03<01:17,  1.24%/s]
# 4.33%|4         | [00:03<01:17,  1.24%/s]
# 4.33%|4         | [00:03<01:17,  1.24%/s]
# 4.39%|4         | [00:03<01:17,  1.24%/s]
# 4.49%|4         | [00:03<01:17,  1.23%/s]
# 4.49%|4         | [00:03<01:17,  1.23%/s]
# 4.57%|4         | [00:03<01:17,  1.23%/s]
# 4.65%|4         | [00:03<01:17,  1.23%/s]
# 4.65%|4         | [00:03<01:17,  1.23%/s]
# 4.73%|4         | [00:03<01:17,  1.23%/s]
# 4.79%|4         | [00:04<01:20,  1.18%/s]
# 4.79%|4         | [00:04<01:20,  1.18%/s]
# 4.87%|4         | [00:04<01:20,  1.18%/s]
# 4.95%|4         | [00:04<01:19,  1.19%/s]
# 4.95%|4         | [00:04<01:19,  1.19%/s]
# 5.05%|5         | [00:04<01:19,  1.19%/s]
# 5.14%|5         | [00:04<01:14,  1.27%/s]
# 5.14%|5         | [00:04<01:14,  1.27%/s]
# 5.21%|5         | [00:04<01:14,  1.27%/s]
# 5.27%|5         | [00:04<01:20,  1.18%/s]
# 5.27%|5         | [00:04<01:20,  1.18%/s]
# 5.38%|5         | [00:04<01:19,  1.18%/s]
# 5.45%|5         | [00:04<01:16,  1.24%/s]
# 5.45%|5         | [00:04<01:16,  1.24%/s]
# 5.55%|5         | [00:04<01:16,  1.24%/s]
# 5.61%|5         | [00:04<01:16,  1.23%/s]
# 5.61%|5         | [00:04<01:16,  1.23%/s]
# 5.70%|5         | [00:04<01:16,  1.23%/s]
# 5.78%|5         | [00:04<01:15,  1.25%/s]
# 5.78%|5         | [00:04<01:15,  1.25%/s]
# 5.84%|5         | [00:04<01:15,  1.25%/s]
# 5.93%|5         | [00:04<01:16,  1.22%/s]
# 5.93%|5         | [00:04<01:16,  1.22%/s]
# 6.01%|6         | [00:05<01:16,  1.22%/s]
# 6.07%|6         | [00:05<01:19,  1.18%/s]
# 6.07%|6         | [00:05<01:19,  1.18%/s]
# 6.15%|6         | [00:05<01:19,  1.18%/s]
# 6.22%|6         | [00:05<01:20,  1.17%/s]
# 6.22%|6         | [00:05<01:20,  1.17%/s]
# 6.29%|6         | [00:05<01:20,  1.17%/s]
# 6.36%|6         | [00:05<01:22,  1.14%/s]
# 6.36%|6         | [00:05<01:22,  1.14%/s]
# 6.42%|6         | [00:05<01:22,  1.14%/s]
# 6.49%|6         | [00:05<01:25,  1.10%/s]
# 6.49%|6         | [00:05<01:25,  1.10%/s]
# 6.57%|6         | [00:05<01:25,  1.10%/s]
# 6.65%|6         | [00:05<01:22,  1.13%/s]
# 6.65%|6         | [00:05<01:22,  1.13%/s]
# 6.73%|6         | [00:05<01:22,  1.13%/s]
# 6.80%|6         | [00:05<01:22,  1.14%/s]
# 6.80%|6         | [00:05<01:22,  1.14%/s]
# 6.88%|6         | [00:05<01:21,  1.14%/s]
# 6.96%|6         | [00:05<01:19,  1.16%/s]
# 6.96%|6         | [00:05<01:19,  1.16%/s]
# 7.04%|7         | [00:05<01:19,  1.16%/s]
# 7.11%|7         | [00:06<01:20,  1.16%/s]
# 7.11%|7         | [00:06<01:20,  1.16%/s]
# 7.17%|7         | [00:06<01:20,  1.16%/s]
# 7.25%|7         | [00:06<01:21,  1.13%/s]
# 7.25%|7         | [00:06<01:21,  1.13%/s]
# 7.35%|7         | [00:06<01:21,  1.13%/s]
# 7.44%|7         | [00:06<01:15,  1.23%/s]
# 7.44%|7         | [00:06<01:15,  1.23%/s]
# 7.52%|7         | [00:06<01:15,  1.23%/s]
# 7.60%|7         | [00:06<01:15,  1.23%/s]
# 7.60%|7         | [00:06<01:15,  1.23%/s]
# 7.67%|7         | [00:06<01:15,  1.23%/s]
# 7.74%|7         | [00:06<01:18,  1.18%/s]
# 7.74%|7         | [00:06<01:18,  1.18%/s]
# 7.82%|7         | [00:06<01:18,  1.18%/s]
# 7.89%|7         | [00:06<01:18,  1.17%/s]
# 7.89%|7         | [00:06<01:18,  1.17%/s]
# 7.98%|7         | [00:06<01:18,  1.17%/s]
# 8.05%|8         | [00:06<01:17,  1.19%/s]
# 8.05%|8         | [00:06<01:17,  1.19%/s]
# 8.11%|8         | [00:06<01:17,  1.19%/s]
# 8.18%|8         | [00:06<01:21,  1.13%/s]
# 8.18%|8         | [00:06<01:21,  1.13%/s]
# 8.26%|8         | [00:07<01:21,  1.13%/s]
# 8.34%|8         | [00:07<01:19,  1.16%/s]
# 8.34%|8         | [00:07<01:19,  1.16%/s]
# 8.42%|8         | [00:07<01:19,  1.16%/s]
# 8.48%|8         | [00:07<01:20,  1.13%/s]
# 8.48%|8         | [00:07<01:20,  1.13%/s]
# 8.57%|8         | [00:07<01:20,  1.13%/s]
# 8.66%|8         | [00:07<01:15,  1.20%/s]
# 8.66%|8         | [00:07<01:15,  1.20%/s]
# 8.74%|8         | [00:07<01:15,  1.20%/s]
# 8.82%|8         | [00:07<01:15,  1.21%/s]
# 8.82%|8         | [00:07<01:15,  1.21%/s]
# 8.89%|8         | [00:07<01:15,  1.21%/s]
# 8.98%|8         | [00:07<01:14,  1.21%/s]
# 8.98%|8         | [00:07<01:14,  1.21%/s]
# 9.05%|9         | [00:07<01:14,  1.21%/s]
# 9.12%|9         | [00:07<01:17,  1.17%/s]
# 9.12%|9         | [00:07<01:17,  1.17%/s]
# 9.21%|9         | [00:07<01:17,  1.17%/s]
# 9.29%|9         | [00:07<01:14,  1.21%/s]
# 9.29%|9         | [00:07<01:14,  1.21%/s]
# 9.38%|9         | [00:07<01:14,  1.21%/s]
# 9.44%|9         | [00:07<01:15,  1.19%/s]
# 9.44%|9         | [00:07<01:15,  1.19%/s]
# 9.54%|9         | [00:08<01:15,  1.19%/s]
# 9.60%|9         | [00:08<01:15,  1.20%/s]
# 9.60%|9         | [00:08<01:15,  1.20%/s]
# 9.67%|9         | [00:08<01:15,  1.20%/s]
# 9.76%|9         | [00:08<01:14,  1.21%/s]
# 9.76%|9         | [00:08<01:14,  1.21%/s]
# 9.83%|9         | [00:08<01:14,  1.21%/s]
# 9.90%|9         | [00:08<01:17,  1.16%/s]
# 9.90%|9         | [00:08<01:17,  1.16%/s]
# 9.99%|9         | [00:08<01:17,  1.16%/s]
# 10.08%|#         | [00:08<01:12,  1.24%/s]
# 10.08%|#         | [00:08<01:12,  1.24%/s]
# 10.17%|#         | [00:08<01:12,  1.24%/s]
# 10.24%|#         | [00:08<01:12,  1.24%/s]
# 10.24%|#         | [00:08<01:12,  1.24%/s]
# 10.34%|#         | [00:08<01:12,  1.24%/s]
# 10.44%|#         | [00:08<01:07,  1.33%/s]
# 10.44%|#         | [00:08<01:07,  1.33%/s]
# 10.51%|#         | [00:08<01:07,  1.33%/s]
# 10.59%|#         | [00:08<01:10,  1.27%/s]
# 10.59%|#         | [00:08<01:10,  1.27%/s]
# 10.69%|#         | [00:08<01:10,  1.27%/s]
# 10.79%|#         | [00:09<01:06,  1.34%/s]
# 10.79%|#         | [00:09<01:06,  1.34%/s]
# 10.85%|#         | [00:09<01:06,  1.34%/s]
# 10.93%|#         | [00:09<01:10,  1.26%/s]
# 10.93%|#         | [00:09<01:10,  1.26%/s]
# 11.03%|#1        | [00:09<01:10,  1.26%/s]
# 11.08%|#1        | [00:09<01:12,  1.23%/s]
# 11.08%|#1        | [00:09<01:12,  1.23%/s]
# 11.16%|#1        | [00:09<01:12,  1.23%/s]
# 11.24%|#1        | [00:09<01:12,  1.23%/s]
# 11.24%|#1        | [00:09<01:12,  1.23%/s]
# 11.31%|#1        | [00:09<01:12,  1.23%/s]
# 11.41%|#1        | [00:09<01:11,  1.25%/s]
# 11.41%|#1        | [00:09<01:11,  1.25%/s]
# 11.48%|#1        | [00:09<01:11,  1.25%/s]
# 11.57%|#1        | [00:09<01:11,  1.24%/s]
# 11.57%|#1        | [00:09<01:11,  1.24%/s]
# 11.65%|#1        | [00:09<01:11,  1.24%/s]
# 11.73%|#1        | [00:09<01:11,  1.23%/s]
# 11.73%|#1        | [00:09<01:11,  1.23%/s]
# 11.82%|#1        | [00:09<01:11,  1.23%/s]
# 11.89%|#1        | [00:09<01:11,  1.23%/s]
# 11.89%|#1        | [00:09<01:11,  1.23%/s]
# 11.96%|#1        | [00:10<01:11,  1.23%/s]
# 12.02%|#2        | [00:10<01:16,  1.16%/s]
# 12.02%|#2        | [00:10<01:16,  1.16%/s]
# 12.08%|#2        | [00:10<01:16,  1.16%/s]
# 12.14%|#2        | [00:10<01:21,  1.08%/s]
# 12.14%|#2        | [00:10<01:21,  1.08%/s]
# 12.22%|#2        | [00:10<01:21,  1.08%/s]
# 12.29%|#2        | [00:10<01:19,  1.10%/s]
# 12.29%|#2        | [00:10<01:19,  1.10%/s]
# 12.36%|#2        | [00:10<01:19,  1.10%/s]
# 12.46%|#2        | [00:10<01:15,  1.16%/s]
# 12.46%|#2        | [00:10<01:15,  1.16%/s]
# 12.52%|#2        | [00:10<01:15,  1.16%/s]
# 12.63%|#2        | [00:10<01:12,  1.20%/s]
# 12.63%|#2        | [00:10<01:12,  1.20%/s]
# 12.69%|#2        | [00:10<01:12,  1.20%/s]
# 12.77%|#2        | [00:10<01:15,  1.16%/s]
# 12.77%|#2        | [00:10<01:15,  1.16%/s]
# 12.82%|#2        | [00:10<01:15,  1.16%/s]
# 12.91%|#2        | [00:10<01:17,  1.13%/s]
# 12.91%|#2        | [00:10<01:17,  1.13%/s]
# 12.98%|#2        | [00:10<01:17,  1.13%/s]
# 13.05%|#3        | [00:11<01:18,  1.11%/s]
# 13.05%|#3        | [00:11<01:18,  1.11%/s]
# 13.13%|#3        | [00:11<01:18,  1.11%/s]
# 13.19%|#3        | [00:11<01:19,  1.10%/s]
# 13.19%|#3        | [00:11<01:19,  1.10%/s]
# 13.27%|#3        | [00:11<01:19,  1.10%/s]
# 13.34%|#3        | [00:11<01:18,  1.11%/s]
# 13.34%|#3        | [00:11<01:18,  1.11%/s]
# 13.41%|#3        | [00:11<01:18,  1.11%/s]
# 13.49%|#3        | [00:11<01:17,  1.12%/s]
# 13.49%|#3        | [00:11<01:17,  1.12%/s]
# 13.57%|#3        | [00:11<01:17,  1.12%/s]
# 13.65%|#3        | [00:11<01:15,  1.15%/s]
# 13.65%|#3        | [00:11<01:15,  1.15%/s]
# 13.70%|#3        | [00:11<01:15,  1.15%/s]
# 13.77%|#3        | [00:11<01:20,  1.07%/s]
# 13.77%|#3        | [00:11<01:20,  1.07%/s]
# 13.83%|#3        | [00:11<01:20,  1.07%/s]
# 13.90%|#3        | [00:11<01:22,  1.05%/s]
# 13.90%|#3        | [00:11<01:22,  1.05%/s]
# 14.00%|#4        | [00:11<01:22,  1.05%/s]
# 14.07%|#4        | [00:11<01:16,  1.12%/s]
# 14.07%|#4        | [00:11<01:16,  1.12%/s]
# 14.13%|#4        | [00:11<01:16,  1.12%/s]
# 14.20%|#4        | [00:12<01:19,  1.08%/s]
# 14.20%|#4        | [00:12<01:19,  1.08%/s]
# 14.28%|#4        | [00:12<01:19,  1.08%/s]
# 14.36%|#4        | [00:12<01:16,  1.12%/s]
# 14.36%|#4        | [00:12<01:16,  1.12%/s]
# 14.43%|#4        | [00:12<01:16,  1.12%/s]
# 14.51%|#4        | [00:12<01:15,  1.13%/s]
# 14.51%|#4        | [00:12<01:15,  1.13%/s]
# 14.60%|#4        | [00:12<01:15,  1.13%/s]
# 14.69%|#4        | [00:12<01:10,  1.20%/s]
# 14.69%|#4        | [00:12<01:10,  1.20%/s]
# 14.74%|#4        | [00:12<01:10,  1.20%/s]
# 14.83%|#4        | [00:12<01:13,  1.16%/s]
# 14.83%|#4        | [00:12<01:13,  1.16%/s]
# 14.88%|#4        | [00:12<01:13,  1.16%/s]
# 14.96%|#4        | [00:12<01:16,  1.11%/s]
# 14.96%|#4        | [00:12<01:16,  1.11%/s]
# 15.05%|#5        | [00:12<01:16,  1.11%/s]
# 15.13%|#5        | [00:12<01:12,  1.17%/s]
# 15.13%|#5        | [00:12<01:12,  1.17%/s]
# 15.19%|#5        | [00:12<01:12,  1.17%/s]
# 15.28%|#5        | [00:12<01:13,  1.16%/s]
# 15.28%|#5        | [00:12<01:13,  1.16%/s]
# 15.35%|#5        | [00:13<01:13,  1.16%/s]
# 15.42%|#5        | [00:13<01:14,  1.13%/s]
# 15.42%|#5        | [00:13<01:14,  1.13%/s]
# 15.51%|#5        | [00:13<01:14,  1.13%/s]
# 15.58%|#5        | [00:13<01:12,  1.16%/s]
# 15.58%|#5        | [00:13<01:12,  1.16%/s]
# 15.66%|#5        | [00:13<01:12,  1.16%/s]
# 15.73%|#5        | [00:13<01:12,  1.16%/s]
# 15.73%|#5        | [00:13<01:12,  1.16%/s]
# 15.82%|#5        | [00:13<01:12,  1.16%/s]
# 15.91%|#5        | [00:13<01:08,  1.22%/s]
# 15.91%|#5        | [00:13<01:08,  1.22%/s]
# 15.97%|#5        | [00:13<01:08,  1.22%/s]
# 16.04%|#6        | [00:13<01:13,  1.15%/s]
# 16.04%|#6        | [00:13<01:13,  1.15%/s]
# 16.11%|#6        | [00:13<01:13,  1.15%/s]
# 16.17%|#6        | [00:13<01:16,  1.10%/s]
# 16.17%|#6        | [00:13<01:16,  1.10%/s]
# 16.23%|#6        | [00:13<01:16,  1.10%/s]
# 16.31%|#6        | [00:13<01:16,  1.09%/s]
# 16.31%|#6        | [00:13<01:16,  1.09%/s]
# 16.40%|#6        | [00:13<01:16,  1.09%/s]
# 16.48%|#6        | [00:14<01:12,  1.15%/s]
# 16.48%|#6        | [00:14<01:12,  1.15%/s]
# 16.59%|#6        | [00:14<01:12,  1.15%/s]
# 16.67%|#6        | [00:14<01:07,  1.24%/s]
# 16.67%|#6        | [00:14<01:07,  1.24%/s]
# 16.74%|#6        | [00:14<01:07,  1.24%/s]
# 16.81%|#6        | [00:14<01:10,  1.18%/s]
# 16.81%|#6        | [00:14<01:10,  1.18%/s]
# 16.88%|#6        | [00:14<01:10,  1.18%/s]
# 16.97%|#6        | [00:14<01:09,  1.19%/s]
# 16.97%|#6        | [00:14<01:09,  1.19%/s]
# 17.05%|#7        | [00:14<01:09,  1.19%/s]
# 17.12%|#7        | [00:14<01:10,  1.18%/s]
# 17.12%|#7        | [00:14<01:10,  1.18%/s]
# 17.21%|#7        | [00:14<01:10,  1.18%/s]
# 17.29%|#7        | [00:14<01:08,  1.21%/s]
# 17.29%|#7        | [00:14<01:08,  1.21%/s]
# 17.38%|#7        | [00:14<01:08,  1.21%/s]
# 17.46%|#7        | [00:14<01:06,  1.24%/s]
# 17.46%|#7        | [00:14<01:06,  1.24%/s]
# 17.52%|#7        | [00:14<01:06,  1.24%/s]
# 17.60%|#7        | [00:14<01:09,  1.19%/s]
# 17.60%|#7        | [00:14<01:09,  1.19%/s]
# 17.67%|#7        | [00:15<01:09,  1.19%/s]
# 17.76%|#7        | [00:15<01:08,  1.20%/s]
# 17.76%|#7        | [00:15<01:08,  1.20%/s]
# 17.84%|#7        | [00:15<01:08,  1.20%/s]
# 17.92%|#7        | [00:15<01:08,  1.20%/s]
# 17.92%|#7        | [00:15<01:08,  1.20%/s]
# 17.97%|#7        | [00:15<01:08,  1.20%/s]
# 18.05%|#8        | [00:15<01:11,  1.14%/s]
# 18.05%|#8        | [00:15<01:11,  1.14%/s]
# 18.13%|#8        | [00:15<01:11,  1.14%/s]
# 18.22%|#8        | [00:15<01:08,  1.19%/s]
# 18.22%|#8        | [00:15<01:08,  1.19%/s]
# 18.30%|#8        | [00:15<01:08,  1.19%/s]
# 18.38%|#8        | [00:15<01:08,  1.19%/s]
# 18.38%|#8        | [00:15<01:08,  1.19%/s]
# 18.47%|#8        | [00:15<01:08,  1.19%/s]
# 18.54%|#8        | [00:15<01:07,  1.20%/s]
# 18.54%|#8        | [00:15<01:07,  1.20%/s]
# 18.61%|#8        | [00:15<01:07,  1.20%/s]
# 18.71%|#8        | [00:15<01:06,  1.23%/s]
# 18.71%|#8        | [00:15<01:06,  1.23%/s]
# 18.79%|#8        | [00:15<01:06,  1.23%/s]
# 18.86%|#8        | [00:16<01:07,  1.20%/s]
# 18.86%|#8        | [00:16<01:07,  1.20%/s]
# 18.96%|#8        | [00:16<01:07,  1.20%/s]
# 19.04%|#9        | [00:16<01:04,  1.25%/s]
# 19.04%|#9        | [00:16<01:04,  1.25%/s]
# 19.11%|#9        | [00:16<01:04,  1.25%/s]
# 19.18%|#9        | [00:16<01:07,  1.20%/s]
# 19.18%|#9        | [00:16<01:07,  1.20%/s]
# 19.25%|#9        | [00:16<01:07,  1.20%/s]
# 19.33%|#9        | [00:16<01:08,  1.18%/s]
# 19.33%|#9        | [00:16<01:08,  1.18%/s]
# 19.41%|#9        | [00:16<01:08,  1.18%/s]
# 19.50%|#9        | [00:16<01:06,  1.21%/s]
# 19.50%|#9        | [00:16<01:06,  1.21%/s]
# 19.58%|#9        | [00:16<01:06,  1.21%/s]
# 19.64%|#9        | [00:16<01:08,  1.17%/s]
# 19.64%|#9        | [00:16<01:08,  1.17%/s]
# 19.74%|#9        | [00:16<01:08,  1.17%/s]
# 19.81%|#9        | [00:16<01:06,  1.20%/s]
# 19.81%|#9        | [00:16<01:06,  1.20%/s]
# 19.88%|#9        | [00:16<01:06,  1.20%/s]
# 19.97%|#9        | [00:16<01:06,  1.21%/s]
# 19.97%|#9        | [00:16<01:06,  1.21%/s]
# 20.03%|##        | [00:16<01:06,  1.21%/s]
# 20.11%|##        | [00:17<01:08,  1.17%/s]
# 20.11%|##        | [00:17<01:08,  1.17%/s]
# 20.17%|##        | [00:17<01:08,  1.17%/s]
# 20.24%|##        | [00:17<01:11,  1.11%/s]
# 20.24%|##        | [00:17<01:11,  1.11%/s]
# 20.32%|##        | [00:17<01:11,  1.11%/s]
# 20.40%|##        | [00:17<01:09,  1.14%/s]
# 20.40%|##        | [00:17<01:09,  1.14%/s]
# 20.48%|##        | [00:17<01:09,  1.14%/s]
# 20.56%|##        | [00:17<01:08,  1.17%/s]
# 20.56%|##        | [00:17<01:08,  1.17%/s]
# 20.63%|##        | [00:17<01:08,  1.17%/s]
# 20.72%|##        | [00:17<01:07,  1.18%/s]
# 20.72%|##        | [00:17<01:07,  1.18%/s]
# 20.80%|##        | [00:17<01:07,  1.18%/s]
# 20.89%|##        | [00:17<01:05,  1.21%/s]
# 20.89%|##        | [00:17<01:05,  1.21%/s]
# 20.95%|##        | [00:17<01:05,  1.21%/s]
# 21.03%|##1       | [00:17<01:07,  1.17%/s]
# 21.03%|##1       | [00:17<01:07,  1.17%/s]
# 21.11%|##1       | [00:17<01:07,  1.17%/s]
# 21.18%|##1       | [00:17<01:08,  1.16%/s]
# 21.18%|##1       | [00:17<01:08,  1.16%/s]
# 21.26%|##1       | [00:18<01:07,  1.16%/s]
# 21.34%|##1       | [00:18<01:06,  1.18%/s]
# 21.34%|##1       | [00:18<01:06,  1.18%/s]
# 21.43%|##1       | [00:18<01:06,  1.18%/s]
# 21.50%|##1       | [00:18<01:06,  1.19%/s]
# 21.50%|##1       | [00:18<01:06,  1.19%/s]
# 21.58%|##1       | [00:18<01:05,  1.19%/s]
# 21.66%|##1       | [00:18<01:05,  1.20%/s]
# 21.66%|##1       | [00:18<01:05,  1.20%/s]
# 21.74%|##1       | [00:18<01:05,  1.20%/s]
# 21.82%|##1       | [00:18<01:05,  1.20%/s]
# 21.82%|##1       | [00:18<01:05,  1.20%/s]
# 21.88%|##1       | [00:18<01:05,  1.20%/s]
# 21.96%|##1       | [00:18<01:07,  1.16%/s]
# 21.96%|##1       | [00:18<01:07,  1.16%/s]
# 22.03%|##2       | [00:18<01:07,  1.16%/s]
# 22.08%|##2       | [00:18<01:11,  1.09%/s]
# 22.08%|##2       | [00:18<01:11,  1.09%/s]
# 22.18%|##2       | [00:18<01:11,  1.09%/s]
# 22.27%|##2       | [00:18<01:04,  1.20%/s]
# 22.27%|##2       | [00:18<01:04,  1.20%/s]
# 22.35%|##2       | [00:18<01:04,  1.20%/s]
# 22.42%|##2       | [00:19<01:05,  1.18%/s]
# 22.42%|##2       | [00:19<01:05,  1.18%/s]
# 22.50%|##2       | [00:19<01:05,  1.18%/s]
# 22.57%|##2       | [00:19<01:06,  1.17%/s]
# 22.57%|##2       | [00:19<01:06,  1.17%/s]
# 22.64%|##2       | [00:19<01:06,  1.17%/s]
# 22.71%|##2       | [00:19<01:07,  1.14%/s]
# 22.71%|##2       | [00:19<01:07,  1.14%/s]
# 22.78%|##2       | [00:19<01:07,  1.14%/s]
# 22.87%|##2       | [00:19<01:06,  1.16%/s]
# 22.87%|##2       | [00:19<01:06,  1.16%/s]
# 22.94%|##2       | [00:19<01:06,  1.16%/s]
# 23.02%|##3       | [00:19<01:06,  1.16%/s]
# 23.02%|##3       | [00:19<01:06,  1.16%/s]
# 23.07%|##3       | [00:19<01:06,  1.16%/s]
# 23.13%|##3       | [00:19<01:06,  1.16%/s]
# 23.19%|##3       | [00:19<01:13,  1.04%/s]
# 23.19%|##3       | [00:19<01:13,  1.04%/s]
# 23.24%|##3       | [00:19<01:13,  1.04%/s]
# 23.32%|##3       | [00:19<01:14,  1.03%/s]
# 23.32%|##3       | [00:19<01:14,  1.03%/s]
# 23.40%|##3       | [00:19<01:14,  1.03%/s]
# 23.48%|##3       | [00:20<01:10,  1.08%/s]
# 23.48%|##3       | [00:20<01:10,  1.08%/s]
# 23.58%|##3       | [00:20<01:10,  1.08%/s]
# 23.63%|##3       | [00:20<01:09,  1.10%/s]
# 23.63%|##3       | [00:20<01:09,  1.10%/s]
# 23.72%|##3       | [00:20<01:09,  1.10%/s]
# 23.79%|##3       | [00:20<01:07,  1.14%/s]
# 23.79%|##3       | [00:20<01:07,  1.14%/s]
# 23.86%|##3       | [00:20<01:06,  1.14%/s]
# 23.95%|##3       | [00:20<01:05,  1.16%/s]
# 23.95%|##3       | [00:20<01:05,  1.16%/s]
# 24.03%|##4       | [00:20<01:05,  1.16%/s]
# 24.11%|##4       | [00:20<01:04,  1.18%/s]
# 24.11%|##4       | [00:20<01:04,  1.18%/s]
# 24.17%|##4       | [00:20<01:04,  1.18%/s]
# 24.25%|##4       | [00:20<01:06,  1.15%/s]
# 24.25%|##4       | [00:20<01:06,  1.15%/s]
# 24.32%|##4       | [00:20<01:06,  1.15%/s]
# 24.40%|##4       | [00:20<01:06,  1.14%/s]
# 24.40%|##4       | [00:20<01:06,  1.14%/s]
# 24.47%|##4       | [00:20<01:05,  1.14%/s]
# 24.56%|##4       | [00:20<01:04,  1.17%/s]
# 24.56%|##4       | [00:20<01:04,  1.17%/s]
# 24.63%|##4       | [00:20<01:04,  1.17%/s]
# 24.71%|##4       | [00:21<01:04,  1.16%/s]
# 24.71%|##4       | [00:21<01:04,  1.16%/s]
# 24.79%|##4       | [00:21<01:04,  1.16%/s]
# 24.86%|##4       | [00:21<01:05,  1.15%/s]
# 24.86%|##4       | [00:21<01:05,  1.15%/s]
# 24.94%|##4       | [00:21<01:05,  1.15%/s]
# 24.99%|##4       | [00:21<01:07,  1.11%/s]
# 24.99%|##4       | [00:21<01:07,  1.11%/s]
# 25.07%|##5       | [00:21<01:07,  1.11%/s]
# 25.14%|##5       | [00:21<01:07,  1.11%/s]
# 25.14%|##5       | [00:21<01:07,  1.11%/s]
# 25.24%|##5       | [00:21<01:07,  1.11%/s]
# 25.30%|##5       | [00:21<01:05,  1.15%/s]
# 25.30%|##5       | [00:21<01:05,  1.15%/s]
# 25.37%|##5       | [00:21<01:05,  1.15%/s]
# 25.43%|##5       | [00:21<01:07,  1.10%/s]
# 25.43%|##5       | [00:21<01:07,  1.10%/s]
# 25.52%|##5       | [00:21<01:07,  1.10%/s]
# 25.61%|##5       | [00:21<01:02,  1.18%/s]
# 25.61%|##5       | [00:21<01:02,  1.18%/s]
# 25.68%|##5       | [00:21<01:02,  1.18%/s]
# 25.76%|##5       | [00:21<01:03,  1.17%/s]
# 25.76%|##5       | [00:21<01:03,  1.17%/s]
# 25.84%|##5       | [00:22<01:03,  1.17%/s]
# 25.91%|##5       | [00:22<01:03,  1.16%/s]
# 25.91%|##5       | [00:22<01:03,  1.16%/s]
# 25.99%|##5       | [00:22<01:03,  1.16%/s]
# 26.07%|##6       | [00:22<01:02,  1.18%/s]
# 26.07%|##6       | [00:22<01:02,  1.18%/s]
# 26.14%|##6       | [00:22<01:02,  1.18%/s]
# 26.20%|##6       | [00:22<01:05,  1.12%/s]
# 26.20%|##6       | [00:22<01:05,  1.12%/s]
# 26.28%|##6       | [00:22<01:05,  1.12%/s]
# 26.38%|##6       | [00:22<01:01,  1.20%/s]
# 26.38%|##6       | [00:22<01:01,  1.20%/s]
# 26.43%|##6       | [00:22<01:01,  1.20%/s]
# 26.51%|##6       | [00:22<01:04,  1.14%/s]
# 26.51%|##6       | [00:22<01:04,  1.14%/s]
# 26.59%|##6       | [00:22<01:04,  1.14%/s]
# 26.67%|##6       | [00:22<01:02,  1.16%/s]
# 26.67%|##6       | [00:22<01:02,  1.16%/s]
# 26.74%|##6       | [00:22<01:02,  1.16%/s]
# 26.81%|##6       | [00:22<01:04,  1.14%/s]
# 26.81%|##6       | [00:22<01:04,  1.14%/s]
# 26.91%|##6       | [00:22<01:04,  1.14%/s]
# 26.97%|##6       | [00:23<01:02,  1.16%/s]
# 26.97%|##6       | [00:23<01:02,  1.16%/s]
# 27.03%|##7       | [00:23<01:02,  1.16%/s]
# 27.10%|##7       | [00:23<01:05,  1.11%/s]
# 27.10%|##7       | [00:23<01:05,  1.11%/s]
# 27.19%|##7       | [00:23<01:05,  1.11%/s]
# 27.27%|##7       | [00:23<01:02,  1.17%/s]
# 27.27%|##7       | [00:23<01:02,  1.17%/s]
# 27.36%|##7       | [00:23<01:01,  1.17%/s]
# 27.44%|##7       | [00:23<00:59,  1.21%/s]
# 27.44%|##7       | [00:23<00:59,  1.21%/s]
# 27.53%|##7       | [00:23<00:59,  1.21%/s]
# 27.60%|##7       | [00:23<00:59,  1.22%/s]
# 27.60%|##7       | [00:23<00:59,  1.22%/s]
# 27.68%|##7       | [00:23<00:59,  1.22%/s]
# 27.75%|##7       | [00:23<01:00,  1.19%/s]
# 27.75%|##7       | [00:23<01:00,  1.19%/s]
# 27.83%|##7       | [00:23<01:00,  1.19%/s]
# 27.92%|##7       | [00:23<00:58,  1.23%/s]
# 27.92%|##7       | [00:23<00:58,  1.23%/s]
# 28.00%|##8       | [00:23<00:58,  1.23%/s]
# 28.09%|##8       | [00:23<00:57,  1.25%/s]
# 28.09%|##8       | [00:23<00:57,  1.25%/s]
# 28.15%|##8       | [00:24<00:57,  1.25%/s]
# 28.21%|##8       | [00:24<00:57,  1.25%/s]
# 28.28%|##8       | [00:24<01:02,  1.14%/s]
# 28.28%|##8       | [00:24<01:02,  1.14%/s]
# 28.35%|##8       | [00:24<01:02,  1.14%/s]
# 28.43%|##8       | [00:24<01:02,  1.14%/s]
# 28.43%|##8       | [00:24<01:02,  1.14%/s]
# 28.49%|##8       | [00:24<01:02,  1.14%/s]
# 28.56%|##8       | [00:24<01:04,  1.11%/s]
# 28.56%|##8       | [00:24<01:04,  1.11%/s]
# 28.62%|##8       | [00:24<01:04,  1.11%/s]
# 28.67%|##8       | [00:24<01:04,  1.11%/s]
# 28.75%|##8       | [00:24<01:07,  1.05%/s]
# 28.75%|##8       | [00:24<01:07,  1.05%/s]
# 28.83%|##8       | [00:24<01:07,  1.05%/s]
# 28.89%|##8       | [00:24<01:07,  1.06%/s]
# 28.89%|##8       | [00:24<01:07,  1.06%/s]
# 28.99%|##8       | [00:24<01:07,  1.06%/s]
# 29.08%|##9       | [00:24<01:00,  1.17%/s]
# 29.08%|##9       | [00:24<01:00,  1.17%/s]
# 29.18%|##9       | [00:24<01:00,  1.17%/s]
# 29.25%|##9       | [00:24<00:58,  1.20%/s]
# 29.25%|##9       | [00:24<00:58,  1.20%/s]
# 29.33%|##9       | [00:25<00:58,  1.20%/s]
# 29.43%|##9       | [00:25<00:56,  1.25%/s]
# 29.43%|##9       | [00:25<00:56,  1.25%/s]
# 29.50%|##9       | [00:25<00:56,  1.25%/s]
# 29.57%|##9       | [00:25<00:58,  1.20%/s]
# 29.57%|##9       | [00:25<00:58,  1.20%/s]
# 29.65%|##9       | [00:25<00:58,  1.20%/s]
# 29.74%|##9       | [00:25<00:57,  1.23%/s]
# 29.74%|##9       | [00:25<00:57,  1.23%/s]
# 29.79%|##9       | [00:25<00:57,  1.23%/s]
# 29.85%|##9       | [00:25<00:57,  1.23%/s]
# 29.94%|##9       | [00:25<01:01,  1.15%/s]
# 29.94%|##9       | [00:25<01:01,  1.15%/s]
# 30.01%|###       | [00:25<01:00,  1.15%/s]
# 30.09%|###       | [00:25<01:00,  1.15%/s]
# 30.09%|###       | [00:25<01:00,  1.15%/s]
# 30.16%|###       | [00:25<01:00,  1.15%/s]
# 30.23%|###       | [00:25<01:01,  1.13%/s]
# 30.23%|###       | [00:25<01:01,  1.13%/s]
# 30.33%|###       | [00:25<01:01,  1.13%/s]
# 30.40%|###       | [00:25<00:59,  1.18%/s]
# 30.40%|###       | [00:25<00:59,  1.18%/s]
# 30.47%|###       | [00:26<00:59,  1.18%/s]
# 30.54%|###       | [00:26<01:00,  1.15%/s]
# 30.54%|###       | [00:26<01:00,  1.15%/s]
# 30.61%|###       | [00:26<01:00,  1.15%/s]
# 30.69%|###       | [00:26<01:00,  1.15%/s]
# 30.69%|###       | [00:26<01:00,  1.15%/s]
# 30.76%|###       | [00:26<01:00,  1.15%/s]
# 30.83%|###       | [00:26<01:01,  1.13%/s]
# 30.83%|###       | [00:26<01:01,  1.13%/s]
# 30.91%|###       | [00:26<01:01,  1.13%/s]
# 31.00%|###1      | [00:26<00:58,  1.18%/s]
# 31.00%|###1      | [00:26<00:58,  1.18%/s]
# 31.07%|###1      | [00:26<00:58,  1.18%/s]
# 31.13%|###1      | [00:26<01:01,  1.12%/s]
# 31.13%|###1      | [00:26<01:01,  1.12%/s]
# 31.19%|###1      | [00:26<01:01,  1.12%/s]
# 31.27%|###1      | [00:26<01:02,  1.11%/s]
# 31.27%|###1      | [00:26<01:02,  1.11%/s]
# 31.36%|###1      | [00:26<01:02,  1.11%/s]
# 31.43%|###1      | [00:26<01:00,  1.14%/s]
# 31.43%|###1      | [00:26<01:00,  1.14%/s]
# 31.52%|###1      | [00:26<01:00,  1.14%/s]
# 31.59%|###1      | [00:27<00:58,  1.16%/s]
# 31.59%|###1      | [00:27<00:58,  1.16%/s]
# 31.68%|###1      | [00:27<00:58,  1.16%/s]
# 31.74%|###1      | [00:27<00:58,  1.16%/s]
# 31.74%|###1      | [00:27<00:58,  1.16%/s]
# 31.84%|###1      | [00:27<00:58,  1.16%/s]
# 31.91%|###1      | [00:27<00:56,  1.20%/s]
# 31.91%|###1      | [00:27<00:56,  1.20%/s]
# 31.98%|###1      | [00:27<00:56,  1.20%/s]
# 32.07%|###2      | [00:27<00:56,  1.20%/s]
# 32.07%|###2      | [00:27<00:56,  1.20%/s]
# 32.14%|###2      | [00:27<00:56,  1.20%/s]
# 32.20%|###2      | [00:27<00:59,  1.14%/s]
# 32.20%|###2      | [00:27<00:59,  1.14%/s]
# 32.27%|###2      | [00:27<00:59,  1.14%/s]
# 32.35%|###2      | [00:27<00:59,  1.14%/s]
# 32.35%|###2      | [00:27<00:59,  1.14%/s]
# 32.41%|###2      | [00:27<00:59,  1.14%/s]
# 32.50%|###2      | [00:27<00:59,  1.14%/s]
# 32.50%|###2      | [00:27<00:59,  1.14%/s]
# 32.58%|###2      | [00:27<00:59,  1.14%/s]
# 32.66%|###2      | [00:27<00:57,  1.16%/s]
# 32.66%|###2      | [00:27<00:57,  1.16%/s]
# 32.74%|###2      | [00:27<00:57,  1.16%/s]
# 32.82%|###2      | [00:28<00:57,  1.18%/s]
# 32.82%|###2      | [00:28<00:57,  1.18%/s]
# 32.88%|###2      | [00:28<00:57,  1.18%/s]
# 32.95%|###2      | [00:28<00:59,  1.12%/s]
# 32.95%|###2      | [00:28<00:59,  1.12%/s]
# 33.04%|###3      | [00:28<00:59,  1.12%/s]
# 33.11%|###3      | [00:28<00:58,  1.15%/s]
# 33.11%|###3      | [00:28<00:58,  1.15%/s]
# 33.17%|###3      | [00:28<00:58,  1.15%/s]
# 33.24%|###3      | [00:28<01:00,  1.10%/s]
# 33.24%|###3      | [00:28<01:00,  1.10%/s]
# 33.32%|###3      | [00:28<01:00,  1.10%/s]
# 33.40%|###3      | [00:28<00:58,  1.13%/s]
# 33.40%|###3      | [00:28<00:58,  1.13%/s]
# 33.48%|###3      | [00:28<00:58,  1.13%/s]
# 33.55%|###3      | [00:28<00:58,  1.13%/s]
# 33.55%|###3      | [00:28<00:58,  1.13%/s]
# 33.62%|###3      | [00:28<00:58,  1.13%/s]
# 33.70%|###3      | [00:28<00:58,  1.14%/s]
# 33.70%|###3      | [00:28<00:58,  1.14%/s]
# 33.78%|###3      | [00:28<00:58,  1.14%/s]
# 33.88%|###3      | [00:28<00:54,  1.20%/s]
# 33.88%|###3      | [00:28<00:54,  1.20%/s]
# 33.95%|###3      | [00:29<00:54,  1.20%/s]
# 34.02%|###4      | [00:29<00:56,  1.16%/s]
# 34.02%|###4      | [00:29<00:56,  1.16%/s]
# 34.10%|###4      | [00:29<00:56,  1.16%/s]
# 34.18%|###4      | [00:29<00:56,  1.17%/s]
# 34.18%|###4      | [00:29<00:56,  1.17%/s]
# 34.25%|###4      | [00:29<00:55,  1.17%/s]
# 34.30%|###4      | [00:29<00:59,  1.10%/s]
# 34.30%|###4      | [00:29<00:59,  1.10%/s]
# 34.37%|###4      | [00:29<00:59,  1.10%/s]
# 34.44%|###4      | [00:29<01:00,  1.09%/s]
# 34.44%|###4      | [00:29<01:00,  1.09%/s]
# 34.54%|###4      | [00:29<01:00,  1.09%/s]
# 34.61%|###4      | [00:29<00:56,  1.15%/s]
# 34.61%|###4      | [00:29<00:56,  1.15%/s]
# 34.67%|###4      | [00:29<00:56,  1.15%/s]
# 34.75%|###4      | [00:29<00:58,  1.12%/s]
# 34.75%|###4      | [00:29<00:58,  1.12%/s]
# 34.83%|###4      | [00:29<00:58,  1.12%/s]
# 34.90%|###4      | [00:29<00:57,  1.13%/s]
# 34.90%|###4      | [00:29<00:57,  1.13%/s]
# 34.97%|###4      | [00:29<00:57,  1.13%/s]
# 35.05%|###5      | [00:30<00:56,  1.14%/s]
# 35.05%|###5      | [00:30<00:56,  1.14%/s]
# 35.14%|###5      | [00:30<00:56,  1.14%/s]
# 35.20%|###5      | [00:30<00:56,  1.15%/s]
# 35.20%|###5      | [00:30<00:56,  1.15%/s]
# 35.26%|###5      | [00:30<00:56,  1.15%/s]
# 35.33%|###5      | [00:30<00:58,  1.11%/s]
# 35.33%|###5      | [00:30<00:58,  1.11%/s]
# 35.40%|###5      | [00:30<00:58,  1.11%/s]
# 35.47%|###5      | [00:30<00:58,  1.11%/s]
# 35.47%|###5      | [00:30<00:58,  1.11%/s]
# 35.56%|###5      | [00:30<00:58,  1.11%/s]
# 35.65%|###5      | [00:30<00:53,  1.20%/s]
# 35.65%|###5      | [00:30<00:53,  1.20%/s]
# 35.73%|###5      | [00:30<00:53,  1.20%/s]
# 35.82%|###5      | [00:30<00:52,  1.23%/s]
# 35.82%|###5      | [00:30<00:52,  1.23%/s]
# 35.90%|###5      | [00:30<00:52,  1.23%/s]
# 35.96%|###5      | [00:30<00:54,  1.18%/s]
# 35.96%|###5      | [00:30<00:54,  1.18%/s]
# 36.03%|###6      | [00:30<00:54,  1.18%/s]
# 36.13%|###6      | [00:30<00:52,  1.21%/s]
# 36.13%|###6      | [00:30<00:52,  1.21%/s]
# 36.21%|###6      | [00:31<00:52,  1.21%/s]
# 36.28%|###6      | [00:31<00:53,  1.19%/s]
# 36.28%|###6      | [00:31<00:53,  1.19%/s]
# 36.37%|###6      | [00:31<00:53,  1.19%/s]
# 36.44%|###6      | [00:31<00:52,  1.20%/s]
# 36.44%|###6      | [00:31<00:52,  1.20%/s]
# 36.51%|###6      | [00:31<00:52,  1.20%/s]
# 36.59%|###6      | [00:31<00:53,  1.18%/s]
# 36.59%|###6      | [00:31<00:53,  1.18%/s]
# 36.67%|###6      | [00:31<00:53,  1.18%/s]
# 36.78%|###6      | [00:31<00:50,  1.26%/s]
# 36.78%|###6      | [00:31<00:50,  1.26%/s]
# 36.86%|###6      | [00:31<00:50,  1.26%/s]
# 36.92%|###6      | [00:31<00:52,  1.20%/s]
# 36.92%|###6      | [00:31<00:52,  1.20%/s]
# 37.00%|###7      | [00:31<00:52,  1.20%/s]
# 37.08%|###7      | [00:31<00:52,  1.21%/s]
# 37.08%|###7      | [00:31<00:52,  1.21%/s]
# 37.16%|###7      | [00:31<00:52,  1.21%/s]
# 37.22%|###7      | [00:31<00:53,  1.16%/s]
# 37.22%|###7      | [00:31<00:53,  1.16%/s]
# 37.30%|###7      | [00:31<00:53,  1.16%/s]
# 37.37%|###7      | [00:31<00:54,  1.15%/s]
# 37.37%|###7      | [00:31<00:54,  1.15%/s]
# 37.46%|###7      | [00:32<00:54,  1.15%/s]
# 37.53%|###7      | [00:32<00:53,  1.17%/s]
# 37.53%|###7      | [00:32<00:53,  1.17%/s]
# 37.61%|###7      | [00:32<00:53,  1.17%/s]
# 37.67%|###7      | [00:32<00:54,  1.14%/s]
# 37.67%|###7      | [00:32<00:54,  1.14%/s]
# 37.75%|###7      | [00:32<00:54,  1.14%/s]
# 37.83%|###7      | [00:32<00:53,  1.17%/s]
# 37.83%|###7      | [00:32<00:53,  1.17%/s]
# 37.91%|###7      | [00:32<00:53,  1.17%/s]
# 37.98%|###7      | [00:32<00:53,  1.16%/s]
# 37.98%|###7      | [00:32<00:53,  1.16%/s]
# 38.05%|###8      | [00:32<00:53,  1.16%/s]
# 38.12%|###8      | [00:32<00:54,  1.13%/s]
# 38.12%|###8      | [00:32<00:54,  1.13%/s]
# 38.23%|###8      | [00:32<00:54,  1.13%/s]
# 38.31%|###8      | [00:32<00:50,  1.23%/s]
# 38.31%|###8      | [00:32<00:50,  1.23%/s]
# 38.38%|###8      | [00:32<00:50,  1.23%/s]
# 38.46%|###8      | [00:32<00:51,  1.20%/s]
# 38.46%|###8      | [00:32<00:51,  1.20%/s]
# 38.55%|###8      | [00:32<00:51,  1.20%/s]
# 38.63%|###8      | [00:33<00:49,  1.23%/s]
# 38.63%|###8      | [00:33<00:49,  1.23%/s]
# 38.73%|###8      | [00:33<00:49,  1.23%/s]
# 38.80%|###8      | [00:33<00:48,  1.25%/s]
# 38.80%|###8      | [00:33<00:48,  1.25%/s]
# 38.87%|###8      | [00:33<00:48,  1.25%/s]
# 38.93%|###8      | [00:33<00:52,  1.17%/s]
# 38.93%|###8      | [00:33<00:52,  1.17%/s]
# 39.02%|###9      | [00:33<00:51,  1.17%/s]
# 39.09%|###9      | [00:33<00:51,  1.19%/s]
# 39.09%|###9      | [00:33<00:51,  1.19%/s]
# 39.17%|###9      | [00:33<00:51,  1.19%/s]
# 39.24%|###9      | [00:33<00:51,  1.17%/s]
# 39.24%|###9      | [00:33<00:51,  1.17%/s]
# 39.31%|###9      | [00:33<00:51,  1.17%/s]
# 39.41%|###9      | [00:33<00:50,  1.21%/s]
# 39.41%|###9      | [00:33<00:50,  1.21%/s]
# 39.49%|###9      | [00:33<00:49,  1.21%/s]
# 39.56%|###9      | [00:33<00:50,  1.19%/s]
# 39.56%|###9      | [00:33<00:50,  1.19%/s]
# 39.63%|###9      | [00:33<00:50,  1.19%/s]
# 39.70%|###9      | [00:33<00:52,  1.15%/s]
# 39.70%|###9      | [00:33<00:52,  1.15%/s]
# 39.77%|###9      | [00:34<00:52,  1.15%/s]
# 39.84%|###9      | [00:34<00:53,  1.13%/s]
# 39.84%|###9      | [00:34<00:53,  1.13%/s]
# 39.90%|###9      | [00:34<00:53,  1.13%/s]
# 39.96%|###9      | [00:34<00:56,  1.07%/s]
# 39.96%|###9      | [00:34<00:56,  1.07%/s]
# 40.06%|####      | [00:34<00:56,  1.07%/s]
# 40.14%|####      | [00:34<00:51,  1.16%/s]
# 40.14%|####      | [00:34<00:51,  1.16%/s]
# 40.22%|####      | [00:34<00:51,  1.16%/s]
# 40.30%|####      | [00:34<00:50,  1.18%/s]
# 40.30%|####      | [00:34<00:50,  1.18%/s]
# 40.38%|####      | [00:34<00:50,  1.18%/s]
# 40.48%|####      | [00:34<00:48,  1.23%/s]
# 40.48%|####      | [00:34<00:48,  1.23%/s]
# 40.56%|####      | [00:34<00:48,  1.23%/s]
# 40.63%|####      | [00:34<00:49,  1.21%/s]
# 40.63%|####      | [00:34<00:49,  1.21%/s]
# 40.71%|####      | [00:34<00:49,  1.21%/s]
# 40.77%|####      | [00:34<00:50,  1.17%/s]
# 40.77%|####      | [00:34<00:50,  1.17%/s]
# 40.84%|####      | [00:34<00:50,  1.17%/s]
# 40.91%|####      | [00:35<00:51,  1.14%/s]
# 40.91%|####      | [00:35<00:51,  1.14%/s]
# 40.98%|####      | [00:35<00:51,  1.14%/s]
# 41.05%|####1     | [00:35<00:52,  1.13%/s]
# 41.05%|####1     | [00:35<00:52,  1.13%/s]
# 41.12%|####1     | [00:35<00:51,  1.13%/s]
# 41.22%|####1     | [00:35<00:48,  1.20%/s]
# 41.22%|####1     | [00:35<00:48,  1.20%/s]
# 41.29%|####1     | [00:35<00:48,  1.20%/s]
# 41.36%|####1     | [00:35<00:50,  1.16%/s]
# 41.36%|####1     | [00:35<00:50,  1.16%/s]
# 41.43%|####1     | [00:35<00:50,  1.16%/s]
# 41.51%|####1     | [00:35<00:50,  1.16%/s]
# 41.51%|####1     | [00:35<00:50,  1.16%/s]
# 41.57%|####1     | [00:35<00:50,  1.16%/s]
# 41.64%|####1     | [00:35<00:52,  1.11%/s]
# 41.64%|####1     | [00:35<00:52,  1.11%/s]
# 41.72%|####1     | [00:35<00:52,  1.11%/s]
# 41.80%|####1     | [00:35<00:50,  1.14%/s]
# 41.80%|####1     | [00:35<00:50,  1.14%/s]
# 41.89%|####1     | [00:35<00:50,  1.14%/s]
# 41.97%|####1     | [00:35<00:48,  1.19%/s]
# 41.97%|####1     | [00:35<00:48,  1.19%/s]
# 42.02%|####2     | [00:35<00:48,  1.19%/s]
# 42.09%|####2     | [00:36<00:52,  1.11%/s]
# 42.09%|####2     | [00:36<00:52,  1.11%/s]
# 42.15%|####2     | [00:36<00:52,  1.11%/s]
# 42.24%|####2     | [00:36<00:51,  1.12%/s]
# 42.24%|####2     | [00:36<00:51,  1.12%/s]
# 42.32%|####2     | [00:36<00:51,  1.12%/s]
# 42.42%|####2     | [00:36<00:48,  1.20%/s]
# 42.42%|####2     | [00:36<00:48,  1.20%/s]
# 42.47%|####2     | [00:36<00:48,  1.20%/s]
# 42.56%|####2     | [00:36<00:49,  1.16%/s]
# 42.56%|####2     | [00:36<00:49,  1.16%/s]
# 42.64%|####2     | [00:36<00:49,  1.16%/s]
# 42.72%|####2     | [00:36<00:48,  1.18%/s]
# 42.72%|####2     | [00:36<00:48,  1.18%/s]
# 42.78%|####2     | [00:36<00:48,  1.18%/s]
# 42.85%|####2     | [00:36<00:50,  1.12%/s]
# 42.85%|####2     | [00:36<00:50,  1.12%/s]
# 42.92%|####2     | [00:36<00:50,  1.12%/s]
# 43.00%|####3     | [00:36<00:50,  1.13%/s]
# 43.00%|####3     | [00:36<00:50,  1.13%/s]
# 43.08%|####3     | [00:36<00:50,  1.13%/s]
# 43.15%|####3     | [00:36<00:50,  1.13%/s]
# 43.15%|####3     | [00:36<00:50,  1.13%/s]
# 43.23%|####3     | [00:37<00:50,  1.13%/s]
# 43.31%|####3     | [00:37<00:48,  1.16%/s]
# 43.31%|####3     | [00:37<00:48,  1.16%/s]
# 43.38%|####3     | [00:37<00:48,  1.16%/s]
# 43.45%|####3     | [00:37<00:50,  1.13%/s]
# 43.45%|####3     | [00:37<00:50,  1.13%/s]
# 43.53%|####3     | [00:37<00:50,  1.13%/s]
# 43.61%|####3     | [00:37<00:48,  1.16%/s]
# 43.61%|####3     | [00:37<00:48,  1.16%/s]
# 43.69%|####3     | [00:37<00:48,  1.16%/s]
# 43.76%|####3     | [00:37<00:48,  1.15%/s]
# 43.76%|####3     | [00:37<00:48,  1.15%/s]
# 43.84%|####3     | [00:37<00:48,  1.15%/s]
# 43.91%|####3     | [00:37<00:48,  1.15%/s]
# 43.91%|####3     | [00:37<00:48,  1.15%/s]
# 43.99%|####3     | [00:37<00:48,  1.15%/s]
# 44.06%|####4     | [00:37<00:48,  1.15%/s]
# 44.06%|####4     | [00:37<00:48,  1.15%/s]
# 44.13%|####4     | [00:37<00:48,  1.15%/s]
# 44.20%|####4     | [00:37<00:49,  1.12%/s]
# 44.20%|####4     | [00:37<00:49,  1.12%/s]
# 44.27%|####4     | [00:37<00:49,  1.12%/s]
# 44.34%|####4     | [00:38<00:50,  1.11%/s]
# 44.34%|####4     | [00:38<00:50,  1.11%/s]
# 44.41%|####4     | [00:38<00:50,  1.11%/s]
# 44.52%|####4     | [00:38<00:46,  1.19%/s]
# 44.52%|####4     | [00:38<00:46,  1.19%/s]
# 44.59%|####4     | [00:38<00:46,  1.19%/s]
# 44.66%|####4     | [00:38<00:48,  1.15%/s]
# 44.66%|####4     | [00:38<00:48,  1.15%/s]
# 44.73%|####4     | [00:38<00:48,  1.15%/s]
# 44.81%|####4     | [00:38<00:48,  1.15%/s]
# 44.81%|####4     | [00:38<00:48,  1.15%/s]
# 44.90%|####4     | [00:38<00:47,  1.15%/s]
# 44.97%|####4     | [00:38<00:47,  1.17%/s]
# 44.97%|####4     | [00:38<00:47,  1.17%/s]
# 45.05%|####5     | [00:38<00:47,  1.17%/s]
# 45.12%|####5     | [00:38<00:47,  1.16%/s]
# 45.12%|####5     | [00:38<00:47,  1.16%/s]
# 45.19%|####5     | [00:38<00:47,  1.16%/s]
# 45.26%|####5     | [00:38<00:48,  1.13%/s]
# 45.26%|####5     | [00:38<00:48,  1.13%/s]
# 45.32%|####5     | [00:38<00:48,  1.13%/s]
# 45.40%|####5     | [00:38<00:48,  1.12%/s]
# 45.40%|####5     | [00:38<00:48,  1.12%/s]
# 45.47%|####5     | [00:38<00:48,  1.12%/s]
# 45.55%|####5     | [00:39<00:48,  1.12%/s]
# 45.55%|####5     | [00:39<00:48,  1.12%/s]
# 45.61%|####5     | [00:39<00:48,  1.12%/s]
# 45.68%|####5     | [00:39<00:50,  1.09%/s]
# 45.68%|####5     | [00:39<00:50,  1.09%/s]
# 45.75%|####5     | [00:39<00:49,  1.09%/s]
# 45.82%|####5     | [00:39<00:50,  1.08%/s]
# 45.82%|####5     | [00:39<00:50,  1.08%/s]
# 45.90%|####5     | [00:39<00:49,  1.08%/s]
# 45.98%|####5     | [00:39<00:47,  1.13%/s]
# 45.98%|####5     | [00:39<00:47,  1.13%/s]
# 46.05%|####6     | [00:39<00:47,  1.13%/s]
# 46.11%|####6     | [00:39<00:49,  1.09%/s]
# 46.11%|####6     | [00:39<00:49,  1.09%/s]
# 46.20%|####6     | [00:39<00:49,  1.09%/s]
# 46.29%|####6     | [00:39<00:45,  1.17%/s]
# 46.29%|####6     | [00:39<00:45,  1.17%/s]
# 46.37%|####6     | [00:39<00:45,  1.17%/s]
# 46.45%|####6     | [00:39<00:45,  1.19%/s]
# 46.45%|####6     | [00:39<00:45,  1.19%/s]
# 46.51%|####6     | [00:39<00:45,  1.19%/s]
# 46.59%|####6     | [00:39<00:46,  1.15%/s]
# 46.59%|####6     | [00:39<00:46,  1.15%/s]
# 46.67%|####6     | [00:40<00:46,  1.15%/s]
# 46.77%|####6     | [00:40<00:43,  1.22%/s]
# 46.77%|####6     | [00:40<00:43,  1.22%/s]
# 46.85%|####6     | [00:40<00:43,  1.22%/s]
# 46.90%|####6     | [00:40<00:46,  1.15%/s]
# 46.90%|####6     | [00:40<00:46,  1.15%/s]
# 46.97%|####6     | [00:40<00:46,  1.15%/s]
# 47.07%|####7     | [00:40<00:44,  1.20%/s]
# 47.07%|####7     | [00:40<00:44,  1.20%/s]
# 47.13%|####7     | [00:40<00:44,  1.20%/s]
# 47.21%|####7     | [00:40<00:45,  1.16%/s]
# 47.21%|####7     | [00:40<00:45,  1.16%/s]
# 47.30%|####7     | [00:40<00:45,  1.16%/s]
# 47.34%|####7     | [00:40<00:47,  1.11%/s]
# 47.34%|####7     | [00:40<00:47,  1.11%/s]
# 47.42%|####7     | [00:40<00:47,  1.11%/s]
# 47.49%|####7     | [00:40<00:46,  1.12%/s]
# 47.49%|####7     | [00:40<00:46,  1.12%/s]
# 47.56%|####7     | [00:40<00:46,  1.12%/s]
# 47.62%|####7     | [00:40<00:48,  1.08%/s]
# 47.62%|####7     | [00:40<00:48,  1.08%/s]
# 47.69%|####7     | [00:40<00:48,  1.08%/s]
# 47.78%|####7     | [00:41<00:46,  1.13%/s]
# 47.78%|####7     | [00:41<00:46,  1.13%/s]
# 47.84%|####7     | [00:41<00:46,  1.13%/s]
# 47.92%|####7     | [00:41<00:46,  1.11%/s]
# 47.92%|####7     | [00:41<00:46,  1.11%/s]
# 48.00%|####8     | [00:41<00:46,  1.11%/s]
# 48.08%|####8     | [00:41<00:45,  1.14%/s]
# 48.08%|####8     | [00:41<00:45,  1.14%/s]
# 48.15%|####8     | [00:41<00:45,  1.14%/s]
# 48.23%|####8     | [00:41<00:45,  1.15%/s]
# 48.23%|####8     | [00:41<00:45,  1.15%/s]
# 48.31%|####8     | [00:41<00:45,  1.15%/s]
# 48.37%|####8     | [00:41<00:45,  1.13%/s]
# 48.37%|####8     | [00:41<00:45,  1.13%/s]
# 48.44%|####8     | [00:41<00:45,  1.13%/s]
# 48.52%|####8     | [00:41<00:45,  1.13%/s]
# 48.52%|####8     | [00:41<00:45,  1.13%/s]
# 48.61%|####8     | [00:41<00:45,  1.13%/s]
# 48.67%|####8     | [00:41<00:45,  1.14%/s]
# 48.67%|####8     | [00:41<00:45,  1.14%/s]
# 48.76%|####8     | [00:41<00:45,  1.14%/s]
# 48.84%|####8     | [00:41<00:43,  1.19%/s]
# 48.84%|####8     | [00:41<00:43,  1.19%/s]
# 48.94%|####8     | [00:41<00:43,  1.19%/s]
# 49.01%|####9     | [00:42<00:41,  1.22%/s]
# 49.01%|####9     | [00:42<00:41,  1.22%/s]
# 49.09%|####9     | [00:42<00:41,  1.22%/s]
# 49.18%|####9     | [00:42<00:40,  1.24%/s]
# 49.18%|####9     | [00:42<00:40,  1.24%/s]
# 49.25%|####9     | [00:42<00:40,  1.24%/s]
# 49.32%|####9     | [00:42<00:42,  1.19%/s]
# 49.32%|####9     | [00:42<00:42,  1.19%/s]
# 49.38%|####9     | [00:42<00:42,  1.19%/s]
# 49.46%|####9     | [00:42<00:43,  1.16%/s]
# 49.46%|####9     | [00:42<00:43,  1.16%/s]
# 49.53%|####9     | [00:42<00:43,  1.16%/s]
# 49.61%|####9     | [00:42<00:43,  1.16%/s]
# 49.61%|####9     | [00:42<00:43,  1.16%/s]
# 49.67%|####9     | [00:42<00:43,  1.16%/s]
# 49.73%|####9     | [00:42<00:46,  1.08%/s]
# 49.73%|####9     | [00:42<00:46,  1.08%/s]
# 49.80%|####9     | [00:42<00:46,  1.08%/s]
# 49.87%|####9     | [00:42<00:46,  1.08%/s]
# 49.87%|####9     | [00:42<00:46,  1.08%/s]
# 49.96%|####9     | [00:42<00:46,  1.08%/s]
# 50.04%|#####     | [00:42<00:43,  1.14%/s]
# 50.04%|#####     | [00:42<00:43,  1.14%/s]
# 50.10%|#####     | [00:43<00:43,  1.14%/s]
# 50.17%|#####     | [00:43<00:45,  1.10%/s]
# 50.17%|#####     | [00:43<00:45,  1.10%/s]
# 50.25%|#####     | [00:43<00:45,  1.10%/s]
# 50.32%|#####     | [00:43<00:44,  1.12%/s]
# 50.32%|#####     | [00:43<00:44,  1.12%/s]
# 50.40%|#####     | [00:43<00:44,  1.12%/s]
# 50.48%|#####     | [00:43<00:43,  1.15%/s]
# 50.48%|#####     | [00:43<00:43,  1.15%/s]
# 50.56%|#####     | [00:43<00:42,  1.15%/s]
# 50.62%|#####     | [00:43<00:43,  1.13%/s]
# 50.62%|#####     | [00:43<00:43,  1.13%/s]
# 50.68%|#####     | [00:43<00:43,  1.13%/s]
# 50.79%|#####     | [00:43<00:41,  1.18%/s]
# 50.79%|#####     | [00:43<00:41,  1.18%/s]
# 50.86%|#####     | [00:43<00:41,  1.18%/s]
# 50.94%|#####     | [00:43<00:41,  1.17%/s]
# 50.94%|#####     | [00:43<00:41,  1.17%/s]
# 51.02%|#####1    | [00:43<00:41,  1.17%/s]
# 51.11%|#####1    | [00:43<00:40,  1.21%/s]
# 51.11%|#####1    | [00:43<00:40,  1.21%/s]
# 51.19%|#####1    | [00:43<00:40,  1.21%/s]
# 51.29%|#####1    | [00:44<00:38,  1.26%/s]
# 51.29%|#####1    | [00:44<00:38,  1.26%/s]
# 51.37%|#####1    | [00:44<00:38,  1.26%/s]
# 51.47%|#####1    | [00:44<00:37,  1.30%/s]
# 51.47%|#####1    | [00:44<00:37,  1.30%/s]
# 51.52%|#####1    | [00:44<00:37,  1.30%/s]
# 51.61%|#####1    | [00:44<00:39,  1.23%/s]
# 51.61%|#####1    | [00:44<00:39,  1.23%/s]
# 51.67%|#####1    | [00:44<00:39,  1.23%/s]
# 51.75%|#####1    | [00:44<00:40,  1.19%/s]
# 51.75%|#####1    | [00:44<00:40,  1.19%/s]
# 51.83%|#####1    | [00:44<00:40,  1.19%/s]
# 51.90%|#####1    | [00:44<00:40,  1.18%/s]
# 51.90%|#####1    | [00:44<00:40,  1.18%/s]
# 51.98%|#####1    | [00:44<00:40,  1.18%/s]
# 52.04%|#####2    | [00:44<00:41,  1.15%/s]
# 52.04%|#####2    | [00:44<00:41,  1.15%/s]
# 52.13%|#####2    | [00:44<00:41,  1.15%/s]
# 52.20%|#####2    | [00:44<00:40,  1.17%/s]
# 52.20%|#####2    | [00:44<00:40,  1.17%/s]
# 52.26%|#####2    | [00:44<00:40,  1.17%/s]
# 52.34%|#####2    | [00:44<00:41,  1.14%/s]
# 52.34%|#####2    | [00:44<00:41,  1.14%/s]
# 52.40%|#####2    | [00:44<00:41,  1.14%/s]
# 52.50%|#####2    | [00:45<00:40,  1.16%/s]
# 52.50%|#####2    | [00:45<00:40,  1.16%/s]
# 52.58%|#####2    | [00:45<00:40,  1.16%/s]
# 52.67%|#####2    | [00:45<00:39,  1.20%/s]
# 52.67%|#####2    | [00:45<00:39,  1.20%/s]
# 52.73%|#####2    | [00:45<00:39,  1.20%/s]
# 52.81%|#####2    | [00:45<00:40,  1.16%/s]
# 52.81%|#####2    | [00:45<00:40,  1.16%/s]
# 52.90%|#####2    | [00:45<00:40,  1.16%/s]
# 52.98%|#####2    | [00:45<00:38,  1.21%/s]
# 52.98%|#####2    | [00:45<00:38,  1.21%/s]
# 53.05%|#####3    | [00:45<00:38,  1.21%/s]
# 53.12%|#####3    | [00:45<00:40,  1.17%/s]
# 53.12%|#####3    | [00:45<00:40,  1.17%/s]
# 53.19%|#####3    | [00:45<00:40,  1.17%/s]
# 53.26%|#####3    | [00:45<00:40,  1.15%/s]
# 53.26%|#####3    | [00:45<00:40,  1.15%/s]
# 53.34%|#####3    | [00:45<00:40,  1.15%/s]
# 53.41%|#####3    | [00:45<00:39,  1.17%/s]
# 53.41%|#####3    | [00:45<00:39,  1.17%/s]
# 53.50%|#####3    | [00:45<00:39,  1.17%/s]
# 53.58%|#####3    | [00:45<00:38,  1.21%/s]
# 53.58%|#####3    | [00:45<00:38,  1.21%/s]
# 53.63%|#####3    | [00:46<00:38,  1.21%/s]
# 53.71%|#####3    | [00:46<00:40,  1.15%/s]
# 53.71%|#####3    | [00:46<00:40,  1.15%/s]
# 53.78%|#####3    | [00:46<00:40,  1.15%/s]
# 53.85%|#####3    | [00:46<00:41,  1.12%/s]
# 53.85%|#####3    | [00:46<00:41,  1.12%/s]
# 53.93%|#####3    | [00:46<00:40,  1.12%/s]
# 54.01%|#####4    | [00:46<00:39,  1.16%/s]
# 54.01%|#####4    | [00:46<00:39,  1.16%/s]
# 54.10%|#####4    | [00:46<00:39,  1.16%/s]
# 54.16%|#####4    | [00:46<00:39,  1.17%/s]
# 54.16%|#####4    | [00:46<00:39,  1.17%/s]
# 54.22%|#####4    | [00:46<00:39,  1.17%/s]
# 54.28%|#####4    | [00:46<00:41,  1.09%/s]
# 54.28%|#####4    | [00:46<00:41,  1.09%/s]
# 54.37%|#####4    | [00:46<00:41,  1.09%/s]
# 54.46%|#####4    | [00:46<00:38,  1.18%/s]
# 54.46%|#####4    | [00:46<00:38,  1.18%/s]
# 54.53%|#####4    | [00:46<00:38,  1.18%/s]
# 54.62%|#####4    | [00:46<00:38,  1.19%/s]
# 54.62%|#####4    | [00:46<00:38,  1.19%/s]
# 54.70%|#####4    | [00:46<00:38,  1.19%/s]
# 54.78%|#####4    | [00:47<00:37,  1.20%/s]
# 54.78%|#####4    | [00:47<00:37,  1.20%/s]
# 54.85%|#####4    | [00:47<00:37,  1.20%/s]
# 54.94%|#####4    | [00:47<00:37,  1.21%/s]
# 54.94%|#####4    | [00:47<00:37,  1.21%/s]
# 55.00%|#####5    | [00:47<00:37,  1.21%/s]
# 55.09%|#####5    | [00:47<00:37,  1.19%/s]
# 55.09%|#####5    | [00:47<00:37,  1.19%/s]
# 55.18%|#####5    | [00:47<00:37,  1.19%/s]
# 55.27%|#####5    | [00:47<00:35,  1.24%/s]
# 55.27%|#####5    | [00:47<00:35,  1.24%/s]
# 55.33%|#####5    | [00:47<00:35,  1.24%/s]
# 55.42%|#####5    | [00:47<00:36,  1.22%/s]
# 55.42%|#####5    | [00:47<00:36,  1.22%/s]
# 55.50%|#####5    | [00:47<00:36,  1.22%/s]
# 55.58%|#####5    | [00:47<00:36,  1.22%/s]
# 55.58%|#####5    | [00:47<00:36,  1.22%/s]
# 55.64%|#####5    | [00:47<00:36,  1.22%/s]
# 55.71%|#####5    | [00:47<00:38,  1.15%/s]
# 55.71%|#####5    | [00:47<00:38,  1.15%/s]
# 55.78%|#####5    | [00:47<00:38,  1.15%/s]
# ...
# 81.30%|########1 | [01:09<00:16,  1.14%/s]
# 81.30%|########1 | [01:09<00:16,  1.14%/s]
# 81.37%|########1 | [01:09<00:16,  1.14%/s]
# 81.46%|########1 | [01:09<00:15,  1.17%/s]
# 81.46%|########1 | [01:09<00:15,  1.17%/s]
# 81.55%|########1 | [01:10<00:15,  1.17%/s]
# 81.62%|########1 | [01:10<00:15,  1.18%/s]
# 81.62%|########1 | [01:10<00:15,  1.18%/s]
# 81.70%|########1 | [01:10<00:15,  1.18%/s]
# 81.77%|########1 | [01:10<00:15,  1.17%/s]
# 81.77%|########1 | [01:10<00:15,  1.17%/s]
# 81.83%|########1 | [01:10<00:15,  1.17%/s]
# 81.91%|########1 | [01:10<00:15,  1.14%/s]
# 81.91%|########1 | [01:10<00:15,  1.14%/s]
# 81.97%|########1 | [01:10<00:15,  1.14%/s]
# 82.03%|########2 | [01:10<00:16,  1.07%/s]
# 82.03%|########2 | [01:10<00:16,  1.07%/s]
# 82.09%|########2 | [01:10<00:16,  1.07%/s]
# 82.18%|########2 | [01:10<00:16,  1.09%/s]
# 82.18%|########2 | [01:10<00:16,  1.09%/s]
# 82.23%|########2 | [01:10<00:16,  1.09%/s]
# 82.31%|########2 | [01:10<00:16,  1.06%/s]
# 82.31%|########2 | [01:10<00:16,  1.06%/s]
# 82.37%|########2 | [01:10<00:16,  1.06%/s]
# 82.42%|########2 | [01:10<00:17,  1.00s/%]
# 82.42%|########2 | [01:10<00:17,  1.00s/%]
# 82.48%|########2 | [01:10<00:17,  1.00s/%]
# 82.54%|########2 | [01:11<00:17,  1.03s/%]
# 82.54%|########2 | [01:11<00:17,  1.03s/%]
# 82.61%|########2 | [01:11<00:17,  1.03s/%]
# 82.70%|########2 | [01:11<00:16,  1.05%/s]
# 82.70%|########2 | [01:11<00:16,  1.05%/s]
# 82.78%|########2 | [01:11<00:16,  1.05%/s]
# 82.86%|########2 | [01:11<00:15,  1.10%/s]
# 82.86%|########2 | [01:11<00:15,  1.10%/s]
# 82.92%|########2 | [01:11<00:15,  1.10%/s]
# 83.00%|########2 | [01:11<00:15,  1.09%/s]
# 83.00%|########2 | [01:11<00:15,  1.09%/s]
# 83.09%|########3 | [01:11<00:15,  1.09%/s]
# 83.18%|########3 | [01:11<00:14,  1.17%/s]
# 83.18%|########3 | [01:11<00:14,  1.17%/s]
# 83.25%|########3 | [01:11<00:14,  1.17%/s]
# 83.30%|########3 | [01:11<00:15,  1.09%/s]
# 83.30%|########3 | [01:11<00:15,  1.09%/s]
# 83.36%|########3 | [01:11<00:15,  1.09%/s]
# 83.46%|########3 | [01:11<00:14,  1.13%/s]
# 83.46%|########3 | [01:11<00:14,  1.13%/s]
# 83.52%|########3 | [01:11<00:14,  1.13%/s]
# 83.58%|########3 | [01:11<00:15,  1.07%/s]
# 83.58%|########3 | [01:11<00:15,  1.07%/s]
# 83.66%|########3 | [01:12<00:15,  1.07%/s]
# 83.76%|########3 | [01:12<00:14,  1.16%/s]
# 83.76%|########3 | [01:12<00:14,  1.16%/s]
# 83.83%|########3 | [01:12<00:13,  1.16%/s]
# 83.91%|########3 | [01:12<00:13,  1.15%/s]
# 83.91%|########3 | [01:12<00:13,  1.15%/s]
# 83.98%|########3 | [01:12<00:13,  1.15%/s]
# 84.05%|########4 | [01:12<00:14,  1.13%/s]
# 84.05%|########4 | [01:12<00:14,  1.13%/s]
# 84.15%|########4 | [01:12<00:14,  1.13%/s]
# 84.21%|########4 | [01:12<00:13,  1.16%/s]
# 84.21%|########4 | [01:12<00:13,  1.16%/s]
# 84.28%|########4 | [01:12<00:13,  1.16%/s]
# 84.34%|########4 | [01:12<00:14,  1.11%/s]
# 84.34%|########4 | [01:12<00:14,  1.11%/s]
# 84.41%|########4 | [01:12<00:14,  1.11%/s]
# 84.49%|########4 | [01:12<00:13,  1.12%/s]
# 84.49%|########4 | [01:12<00:13,  1.12%/s]
# 84.57%|########4 | [01:12<00:13,  1.12%/s]
# 84.64%|########4 | [01:12<00:13,  1.13%/s]
# 84.64%|########4 | [01:12<00:13,  1.13%/s]
# 84.73%|########4 | [01:12<00:13,  1.13%/s]
# 84.82%|########4 | [01:13<00:12,  1.20%/s]
# 84.82%|########4 | [01:13<00:12,  1.20%/s]
# 84.91%|########4 | [01:13<00:12,  1.20%/s]
# 85.00%|########5 | [01:13<00:11,  1.25%/s]
# 85.00%|########5 | [01:13<00:11,  1.25%/s]
# 85.07%|########5 | [01:13<00:11,  1.25%/s]
# 85.15%|########5 | [01:13<00:12,  1.22%/s]
# 85.15%|########5 | [01:13<00:12,  1.22%/s]
# 85.24%|########5 | [01:13<00:12,  1.22%/s]
# 85.31%|########5 | [01:13<00:12,  1.22%/s]
# 85.31%|########5 | [01:13<00:12,  1.22%/s]
# 85.38%|########5 | [01:13<00:11,  1.22%/s]
# 85.48%|########5 | [01:13<00:11,  1.25%/s]
# 85.48%|########5 | [01:13<00:11,  1.25%/s]
# 85.54%|########5 | [01:13<00:11,  1.25%/s]
# 85.59%|########5 | [01:13<00:11,  1.25%/s]
# 85.66%|########5 | [01:13<00:12,  1.12%/s]
# 85.66%|########5 | [01:13<00:12,  1.12%/s]
# 85.74%|########5 | [01:13<00:12,  1.12%/s]
# 85.83%|########5 | [01:13<00:12,  1.17%/s]
# 85.83%|########5 | [01:13<00:12,  1.17%/s]
# 85.90%|########5 | [01:13<00:12,  1.17%/s]
# 85.97%|########5 | [01:13<00:12,  1.14%/s]
# 85.97%|########5 | [01:13<00:12,  1.14%/s]
# 86.04%|########6 | [01:14<00:12,  1.14%/s]
# 86.13%|########6 | [01:14<00:11,  1.16%/s]
# 86.13%|########6 | [01:14<00:11,  1.16%/s]
# 86.20%|########6 | [01:14<00:11,  1.16%/s]
# 86.26%|########6 | [01:14<00:12,  1.11%/s]
# 86.26%|########6 | [01:14<00:12,  1.11%/s]
# 86.32%|########6 | [01:14<00:12,  1.11%/s]
# 86.39%|########6 | [01:14<00:12,  1.08%/s]
# 86.39%|########6 | [01:14<00:12,  1.08%/s]
# 86.45%|########6 | [01:14<00:12,  1.08%/s]
# 86.54%|########6 | [01:14<00:12,  1.10%/s]
# 86.54%|########6 | [01:14<00:12,  1.10%/s]
# 86.63%|########6 | [01:14<00:12,  1.10%/s]
# 86.71%|########6 | [01:14<00:11,  1.16%/s]
# 86.71%|########6 | [01:14<00:11,  1.16%/s]
# 86.78%|########6 | [01:14<00:11,  1.16%/s]
# 86.86%|########6 | [01:14<00:11,  1.16%/s]
# 86.86%|########6 | [01:14<00:11,  1.16%/s]
# 86.93%|########6 | [01:14<00:11,  1.16%/s]
# 87.01%|########7 | [01:14<00:11,  1.15%/s]
# 87.01%|########7 | [01:14<00:11,  1.15%/s]
# 87.09%|########7 | [01:14<00:11,  1.15%/s]
# 87.17%|########7 | [01:15<00:10,  1.18%/s]
# 87.17%|########7 | [01:15<00:10,  1.18%/s]
# 87.25%|########7 | [01:15<00:10,  1.18%/s]
# 87.34%|########7 | [01:15<00:10,  1.21%/s]
# 87.34%|########7 | [01:15<00:10,  1.21%/s]
# 87.40%|########7 | [01:15<00:10,  1.21%/s]
# 87.47%|########7 | [01:15<00:10,  1.14%/s]
# 87.47%|########7 | [01:15<00:10,  1.14%/s]
# 87.56%|########7 | [01:15<00:10,  1.14%/s]
# 87.64%|########7 | [01:15<00:10,  1.19%/s]
# 87.64%|########7 | [01:15<00:10,  1.19%/s]
# 87.74%|########7 | [01:15<00:10,  1.19%/s]
# 87.83%|########7 | [01:15<00:09,  1.27%/s]
# 87.83%|########7 | [01:15<00:09,  1.27%/s]
# 87.89%|########7 | [01:15<00:09,  1.27%/s]
# 87.96%|########7 | [01:15<00:10,  1.18%/s]
# 87.96%|########7 | [01:15<00:10,  1.18%/s]
# 88.03%|########8 | [01:15<00:10,  1.18%/s]
# 88.11%|########8 | [01:15<00:10,  1.17%/s]
# 88.11%|########8 | [01:15<00:10,  1.17%/s]
# 88.21%|########8 | [01:15<00:10,  1.17%/s]
# 88.29%|########8 | [01:15<00:09,  1.23%/s]
# 88.29%|########8 | [01:15<00:09,  1.23%/s]
# 88.37%|########8 | [01:16<00:09,  1.23%/s]
# 88.45%|########8 | [01:16<00:09,  1.23%/s]
# 88.45%|########8 | [01:16<00:09,  1.23%/s]
# 88.52%|########8 | [01:16<00:09,  1.23%/s]
# 88.60%|########8 | [01:16<00:09,  1.20%/s]
# 88.60%|########8 | [01:16<00:09,  1.20%/s]
# 88.67%|########8 | [01:16<00:09,  1.20%/s]
# 88.74%|########8 | [01:16<00:09,  1.16%/s]
# 88.74%|########8 | [01:16<00:09,  1.16%/s]
# 88.81%|########8 | [01:16<00:09,  1.16%/s]
# 88.90%|########8 | [01:16<00:09,  1.18%/s]
# 88.90%|########8 | [01:16<00:09,  1.18%/s]
# 88.99%|########8 | [01:16<00:09,  1.18%/s]
# 89.06%|########9 | [01:16<00:09,  1.19%/s]
# 89.06%|########9 | [01:16<00:09,  1.19%/s]
# 89.13%|########9 | [01:16<00:09,  1.19%/s]
# 89.20%|########9 | [01:16<00:09,  1.16%/s]
# 89.20%|########9 | [01:16<00:09,  1.16%/s]
# 89.29%|########9 | [01:16<00:09,  1.16%/s]
# 89.36%|########9 | [01:16<00:09,  1.18%/s]
# 89.36%|########9 | [01:16<00:09,  1.18%/s]
# 89.43%|########9 | [01:16<00:08,  1.18%/s]
# 89.51%|########9 | [01:16<00:08,  1.17%/s]
# 89.51%|########9 | [01:16<00:08,  1.17%/s]
# 89.60%|########9 | [01:17<00:08,  1.17%/s]
# 89.69%|########9 | [01:17<00:08,  1.23%/s]
# 89.69%|########9 | [01:17<00:08,  1.23%/s]
# 89.77%|########9 | [01:17<00:08,  1.23%/s]
# 89.85%|########9 | [01:17<00:08,  1.23%/s]
# 89.85%|########9 | [01:17<00:08,  1.23%/s]
# 89.94%|########9 | [01:17<00:08,  1.23%/s]
# 90.02%|######### | [01:17<00:07,  1.26%/s]
# 90.02%|######### | [01:17<00:07,  1.26%/s]
# 90.12%|######### | [01:17<00:07,  1.26%/s]
# 90.21%|######### | [01:17<00:07,  1.32%/s]
# 90.21%|######### | [01:17<00:07,  1.32%/s]
# 90.27%|######### | [01:17<00:07,  1.32%/s]
# 90.35%|######### | [01:17<00:07,  1.25%/s]
# 90.35%|######### | [01:17<00:07,  1.25%/s]
# 90.41%|######### | [01:17<00:07,  1.25%/s]
# 90.49%|######### | [01:17<00:07,  1.19%/s]
# 90.49%|######### | [01:17<00:07,  1.19%/s]
# 90.57%|######### | [01:17<00:07,  1.19%/s]
# 90.63%|######### | [01:17<00:08,  1.16%/s]
# 90.63%|######### | [01:17<00:08,  1.16%/s]
# 90.72%|######### | [01:17<00:08,  1.16%/s]
# 90.79%|######### | [01:18<00:07,  1.18%/s]
# 90.79%|######### | [01:18<00:07,  1.18%/s]
# 90.86%|######### | [01:18<00:07,  1.18%/s]
# 90.93%|######### | [01:18<00:07,  1.14%/s]
# 90.93%|######### | [01:18<00:07,  1.14%/s]
# 91.01%|#########1| [01:18<00:07,  1.14%/s]
# 91.08%|#########1| [01:18<00:07,  1.15%/s]
# 91.08%|#########1| [01:18<00:07,  1.15%/s]
# 91.15%|#########1| [01:18<00:07,  1.15%/s]
# 91.22%|#########1| [01:18<00:07,  1.12%/s]
# 91.22%|#########1| [01:18<00:07,  1.12%/s]
# 91.33%|#########1| [01:18<00:07,  1.12%/s]
# 91.41%|#########1| [01:18<00:07,  1.22%/s]
# 91.41%|#########1| [01:18<00:07,  1.22%/s]
# 91.48%|#########1| [01:18<00:06,  1.22%/s]
# 91.54%|#########1| [01:18<00:07,  1.15%/s]
# 91.54%|#########1| [01:18<00:07,  1.15%/s]
# 91.61%|#########1| [01:18<00:07,  1.15%/s]
# 91.69%|#########1| [01:18<00:07,  1.15%/s]
# 91.69%|#########1| [01:18<00:07,  1.15%/s]
# 91.75%|#########1| [01:18<00:07,  1.15%/s]
# 91.82%|#########1| [01:18<00:07,  1.11%/s]
# 91.82%|#########1| [01:18<00:07,  1.11%/s]
# 91.89%|#########1| [01:19<00:07,  1.11%/s]
# 91.95%|#########1| [01:19<00:07,  1.07%/s]
# 91.95%|#########1| [01:19<00:07,  1.07%/s]
# 92.03%|#########2| [01:19<00:07,  1.07%/s]
# 92.10%|#########2| [01:19<00:07,  1.09%/s]
# 92.10%|#########2| [01:19<00:07,  1.09%/s]
# 92.16%|#########2| [01:19<00:07,  1.09%/s]
# 92.25%|#########2| [01:19<00:06,  1.11%/s]
# 92.25%|#########2| [01:19<00:06,  1.11%/s]
# 92.32%|#########2| [01:19<00:06,  1.11%/s]
# 92.43%|#########2| [01:19<00:06,  1.19%/s]
# 92.43%|#########2| [01:19<00:06,  1.19%/s]
# 92.49%|#########2| [01:19<00:06,  1.19%/s]
# 92.56%|#########2| [01:19<00:06,  1.13%/s]
# 92.56%|#########2| [01:19<00:06,  1.13%/s]
# 92.65%|#########2| [01:19<00:06,  1.13%/s]
# 92.73%|#########2| [01:19<00:06,  1.18%/s]
# 92.73%|#########2| [01:19<00:06,  1.18%/s]
# 92.78%|#########2| [01:19<00:06,  1.18%/s]
# 92.85%|#########2| [01:19<00:06,  1.10%/s]
# 92.85%|#########2| [01:19<00:06,  1.10%/s]
# 92.92%|#########2| [01:19<00:06,  1.10%/s]
# 92.99%|#########2| [01:20<00:06,  1.09%/s]
# 92.99%|#########2| [01:20<00:06,  1.09%/s]
# 93.05%|#########3| [01:20<00:06,  1.09%/s]
# 93.15%|#########3| [01:20<00:06,  1.13%/s]
# 93.15%|#########3| [01:20<00:06,  1.13%/s]
# 93.21%|#########3| [01:20<00:06,  1.13%/s]
# 93.28%|#########3| [01:20<00:06,  1.09%/s]
# 93.28%|#########3| [01:20<00:06,  1.09%/s]
# 93.37%|#########3| [01:20<00:06,  1.09%/s]
# 93.44%|#########3| [01:20<00:05,  1.13%/s]
# 93.44%|#########3| [01:20<00:05,  1.13%/s]
# 93.53%|#########3| [01:20<00:05,  1.13%/s]
# 93.60%|#########3| [01:20<00:05,  1.16%/s]
# 93.60%|#########3| [01:20<00:05,  1.16%/s]
# 93.66%|#########3| [01:20<00:05,  1.16%/s]
# 93.72%|#########3| [01:20<00:05,  1.09%/s]
# 93.72%|#########3| [01:20<00:05,  1.09%/s]
# 93.80%|#########3| [01:20<00:05,  1.09%/s]
# 93.86%|#########3| [01:20<00:05,  1.08%/s]
# 93.86%|#########3| [01:20<00:05,  1.08%/s]
# 93.93%|#########3| [01:20<00:05,  1.08%/s]
# 94.01%|#########4| [01:20<00:05,  1.10%/s]
# 94.01%|#########4| [01:20<00:05,  1.10%/s]
# 94.07%|#########4| [01:20<00:05,  1.10%/s]
# 94.14%|#########4| [01:21<00:05,  1.07%/s]
# 94.14%|#########4| [01:21<00:05,  1.07%/s]
# 94.21%|#########4| [01:21<00:05,  1.07%/s]
# 94.28%|#########4| [01:21<00:05,  1.07%/s]
# 94.28%|#########4| [01:21<00:05,  1.07%/s]
# 94.38%|#########4| [01:21<00:05,  1.07%/s]
# 94.45%|#########4| [01:21<00:04,  1.14%/s]
# 94.45%|#########4| [01:21<00:04,  1.14%/s]
# 94.52%|#########4| [01:21<00:04,  1.14%/s]
# 94.61%|#########4| [01:21<00:04,  1.16%/s]
# 94.61%|#########4| [01:21<00:04,  1.16%/s]
# 94.69%|#########4| [01:21<00:04,  1.16%/s]
# 94.77%|#########4| [01:21<00:04,  1.18%/s]
# 94.77%|#########4| [01:21<00:04,  1.18%/s]
# 94.85%|#########4| [01:21<00:04,  1.18%/s]
# 94.95%|#########4| [01:21<00:04,  1.24%/s]
# 94.95%|#########4| [01:21<00:04,  1.24%/s]
# 95.04%|#########5| [01:21<00:04,  1.24%/s]
# 95.12%|#########5| [01:21<00:03,  1.26%/s]
# 95.12%|#########5| [01:21<00:03,  1.26%/s]
# 95.19%|#########5| [01:21<00:03,  1.26%/s]
# 95.26%|#########5| [01:21<00:03,  1.20%/s]
# 95.26%|#########5| [01:21<00:03,  1.20%/s]
# 95.35%|#########5| [01:22<00:03,  1.20%/s]
# 95.42%|#########5| [01:22<00:03,  1.21%/s]
# 95.42%|#########5| [01:22<00:03,  1.21%/s]
# 95.50%|#########5| [01:22<00:03,  1.21%/s]
# 95.57%|#########5| [01:22<00:03,  1.19%/s]
# 95.57%|#########5| [01:22<00:03,  1.19%/s]
# 95.65%|#########5| [01:22<00:03,  1.19%/s]
# 95.74%|#########5| [01:22<00:03,  1.22%/s]
# 95.74%|#########5| [01:22<00:03,  1.22%/s]
# 95.85%|#########5| [01:22<00:03,  1.22%/s]
# 95.94%|#########5| [01:22<00:03,  1.31%/s]
# 95.94%|#########5| [01:22<00:03,  1.31%/s]
# 96.02%|#########6| [01:22<00:03,  1.31%/s]
# 96.09%|#########6| [01:22<00:03,  1.27%/s]
# 96.09%|#########6| [01:22<00:03,  1.27%/s]
# 96.15%|#########6| [01:22<00:03,  1.27%/s]
# 96.23%|#########6| [01:22<00:03,  1.21%/s]
# 96.23%|#########6| [01:22<00:03,  1.21%/s]
# 96.29%|#########6| [01:22<00:03,  1.21%/s]
# 96.38%|#########6| [01:22<00:03,  1.19%/s]
# 96.38%|#########6| [01:22<00:03,  1.19%/s]
# 96.46%|#########6| [01:22<00:02,  1.19%/s]
# 96.55%|#########6| [01:23<00:02,  1.22%/s]
# 96.55%|#########6| [01:23<00:02,  1.22%/s]
# 96.59%|#########6| [01:23<00:02,  1.22%/s]
# 96.65%|#########6| [01:23<00:02,  1.22%/s]
# 96.72%|#########6| [01:23<00:03,  1.08%/s]
# 96.72%|#########6| [01:23<00:03,  1.08%/s]
# 96.81%|#########6| [01:23<00:02,  1.08%/s]
# 96.90%|#########6| [01:23<00:02,  1.17%/s]
# 96.90%|#########6| [01:23<00:02,  1.17%/s]
# 96.97%|#########6| [01:23<00:02,  1.17%/s]
# 97.05%|#########7| [01:23<00:02,  1.16%/s]
# 97.05%|#########7| [01:23<00:02,  1.16%/s]
# 97.13%|#########7| [01:23<00:02,  1.16%/s]
# 97.20%|#########7| [01:23<00:02,  1.16%/s]
# 97.20%|#########7| [01:23<00:02,  1.16%/s]
# 97.28%|#########7| [01:23<00:02,  1.16%/s]
# 97.37%|#########7| [01:23<00:02,  1.20%/s]
# 97.37%|#########7| [01:23<00:02,  1.20%/s]
# 97.43%|#########7| [01:23<00:02,  1.20%/s]
# 97.51%|#########7| [01:23<00:02,  1.16%/s]
# 97.51%|#########7| [01:23<00:02,  1.16%/s]
# 97.58%|#########7| [01:23<00:02,  1.16%/s]
# 97.65%|#########7| [01:23<00:02,  1.13%/s]
# 97.65%|#########7| [01:23<00:02,  1.13%/s]
# 97.73%|#########7| [01:24<00:02,  1.13%/s]
# 97.81%|#########7| [01:24<00:01,  1.16%/s]
# 97.81%|#########7| [01:24<00:01,  1.16%/s]
# 97.87%|#########7| [01:24<00:01,  1.16%/s]
# 97.94%|#########7| [01:24<00:01,  1.11%/s]
# 97.94%|#########7| [01:24<00:01,  1.11%/s]
# 98.01%|#########8| [01:24<00:01,  1.11%/s]
# 98.10%|#########8| [01:24<00:01,  1.15%/s]
# 98.10%|#########8| [01:24<00:01,  1.15%/s]
# 98.16%|#########8| [01:24<00:01,  1.15%/s]
# 98.24%|#########8| [01:24<00:01,  1.12%/s]
# 98.24%|#########8| [01:24<00:01,  1.12%/s]
# 98.32%|#########8| [01:24<00:01,  1.12%/s]
# 98.38%|#########8| [01:24<00:01,  1.11%/s]
# 98.38%|#########8| [01:24<00:01,  1.11%/s]
# 98.47%|#########8| [01:24<00:01,  1.11%/s]
# 98.55%|#########8| [01:24<00:01,  1.17%/s]
# 98.55%|#########8| [01:24<00:01,  1.17%/s]
# 98.61%|#########8| [01:24<00:01,  1.17%/s]
# 98.68%|#########8| [01:24<00:01,  1.12%/s]
# 98.68%|#########8| [01:24<00:01,  1.12%/s]
# 98.75%|#########8| [01:24<00:01,  1.12%/s]
# 98.84%|#########8| [01:25<00:01,  1.15%/s]
# 98.84%|#########8| [01:25<00:01,  1.15%/s]
# 98.92%|#########8| [01:25<00:00,  1.15%/s]
# 99.00%|#########9| [01:25<00:00,  1.17%/s]
# 99.00%|#########9| [01:25<00:00,  1.17%/s]
# 99.06%|#########9| [01:25<00:00,  1.17%/s]
# 99.11%|#########9| [01:25<00:00,  1.17%/s]
# 99.18%|#########9| [01:25<00:00,  1.07%/s]
# 99.18%|#########9| [01:25<00:00,  1.07%/s]
# 99.26%|#########9| [01:25<00:00,  1.07%/s]
# 99.34%|#########9| [01:25<00:00,  1.11%/s]
# 99.34%|#########9| [01:25<00:00,  1.11%/s]
# 99.43%|#########9| [01:25<00:00,  1.11%/s]
# 99.50%|#########9| [01:25<00:00,  1.14%/s]
# 99.50%|#########9| [01:25<00:00,  1.14%/s]
# 99.57%|#########9| [01:25<00:00,  1.14%/s]
# 99.64%|#########9| [01:25<00:00,  1.12%/s]
# 99.64%|#########9| [01:25<00:00,  1.12%/s]
# 99.70%|#########9| [01:25<00:00,  1.12%/s]
# 99.76%|#########9| [01:25<00:00,  1.06%/s]
# 99.76%|#########9| [01:25<00:00,  1.06%/s]
# 99.85%|#########9| [01:25<00:00,  1.06%/s]
# 99.92%|#########9| [01:26<00:00,  1.11%/s]
# 99.92%|#########9| [01:26<00:00,  1.11%/s]
# 100.00%|##########| [01:26<00:00,  1.16%/s]

# %% [markdown]
# ## Plot samples

# %%
plot_sampels_energy_marginals_for_SGM_vs_ES(
    energy_fn,
    params_interpolator(0)/Temp,
    params_interpolator(0)/Temp,
    final_states,
    sde_samples_direct,
    weights, means, covs,
    n_points=50,
    num_bins=75,
    sample_stride=5,
    x1_range=(-1.5,1.5),
    x2_range=(-1.5,1.5),
    figsize=(20,10),
    fontsize=16,
    label_fontsize=16,
    iso_levels=7,
    colormap='bwr',
    contour_linewidth=2.5,
    scatter_size=4,
    scatter_alpha=0.9,
    plot_folder=plot_folder,
    n_trajectories=n_trajectories,
    atol=atol,
    rtol=rtol,
    Temp=Temp
)
# Out:
#     Reverse Trajectory total prob ≈ 1.000000
#   Equilibrium Sampling total prob ≈ 1.000000
